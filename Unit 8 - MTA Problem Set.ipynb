# %% [markdown]
# 1.Save the Saturday, June 17th, 2017 data to a csv file. You can find it here: http://web.mta.info/developers/turnstile.html and read it in using read_csv. View the head of the dataframe.

# %%
import pandas as pd
MTA = pd.read_csv('MTA_Data.csv')  
print(MTA.columns)
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %% [markdown]
# 2.View the dataframe columns. Is there extra whitespace at the end of any of the column names? Strip all of the whitespace.

# %%
MTA.columns = MTA.columns.str.strip()
print(MTA.columns)
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %% [markdown]
# 3.In one line, determine how many rows are in your dataframe and if there are are any null entries.

# %%
MTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197209 entries, 0 to 197208
# Data columns (total 11 columns):
# C/A         197209 non-null object
# UNIT        197209 non-null object
# SCP         197209 non-null object
# STATION     197209 non-null object
# LINENAME    197209 non-null object
# DIVISION    197209 non-null object
# DATE        197209 non-null object
# TIME        197209 non-null object
# DESC        197209 non-null object
# ENTRIES     197209 non-null int64
# EXITS       197209 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# 4.In one line, print out the unique STATION names. How many are there? (Hint: use set).

# %%
set(MTA.STATION)
print(len(set(MTA.STATION)))
# Out:
# 376

# %% [markdown]
# 5.Okay, so we understand what station represents. But what the heck are C/A, UNIT, and SCP? Keep in mind that in the larger stations, you might have multiple areas within one station that look like this:
#
# <img src="image.jpg" style="width: 300px;"/>
#
# Further complicating things, there are a few station names like 14TH ST that refer to more than one station location along that street.
#
# This data set is not very well documented. Welcome to the joys of real world data science!!!
#
# Read the following two links carefully to see other people's confusion and what information they have been able to gather:
#
# https://groups.google.com/forum/#!topic/mtadeveloperresources/AMVx2WUY9iI
#
# https://groups.google.com/forum/#!searchin/mtadeveloperresources/%22remote$20unit%22%7Csort:relevance/mtadeveloperresources/z8l3ZU9cY6Y/OFlHGkFAimQJ
#
# What did Patrick O'Hara and Katie Toth have to say?

# %% [markdown]
# Patrick says there are mutliple names for one station which is very confusing
# Katie says everytime someone walks in through a turnstile, it says regular. Sometimes it has error and says log-on or door close, ignore those.

# %% [markdown]
# 6.To simplify our calculations right now, let's only look at ridership on Monday, June 12th, 2017. In one line, create a dataset called monday that just includes the dates listed as 06/12/2017.
#
# Then, use the command "monday = monday.reset_index(drop=True)" to reset the index.

# %%
monday = MTA[MTA.DATE == '06/12/2017']
monday = monday.reset_index(drop=True)
monday
# Out:
#          C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 1       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 2       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 3       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 4       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 5       A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 6       A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 7       A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 8       A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 9       A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 10      A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 11      A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 12      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 13      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 14      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 15      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 16      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 17      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 18      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 19      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 20      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 21      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 22      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 23      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 24      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 25      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 26      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 27      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 28      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 29      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# ...      ...   ...       ...            ...      ...      ...         ...
# 28364  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28365  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28366  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28367  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28368  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28369  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28370  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28371  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28372  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28373  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28374  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28375  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28376  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28377  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28378  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28379  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28380  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28381  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28382  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28383  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28384  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28385  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28386  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28387  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28388  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28389  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28390  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28391  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28392  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 28393  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
#
#            TIME     DESC  ENTRIES    EXITS
# 0      00:00:00  REGULAR  6217322  2104727
# 1      04:00:00  REGULAR  6217332  2104729
# 2      08:00:00  REGULAR  6217372  2104813
# 3      12:00:00  REGULAR  6217540  2105024
# 4      16:00:00  REGULAR  6217825  2105081
# 5      20:00:00  REGULAR  6218576  2105134
# 6      00:00:00  REGULAR  5615700  1247458
# 7      04:00:00  REGULAR  5615704  1247462
# 8      08:00:00  REGULAR  5615730  1247491
# 9      12:00:00  REGULAR  5615864  1247619
# 10     16:00:00  REGULAR  5616095  1247669
# 11     20:00:00  REGULAR  5616672  1247719
# 12     00:00:00  REGULAR   926860  3436699
# 13     04:00:00  REGULAR   926865  3436710
# 14     08:00:00  REGULAR   926883  3436892
# 15     12:00:00  REGULAR   926944  3437546
# 16     16:00:00  REGULAR   927047  3437864
# 17     20:00:00  REGULAR   927333  3438394
# 18     00:00:00  REGULAR   318404   512214
# 19     04:00:00  REGULAR   318416   512231
# 20     08:00:00  REGULAR   318457   512463
# 21     12:00:00  REGULAR   318606   513093
# 22     16:00:00  REGULAR   318878   513383
# 23     20:00:00  REGULAR   319437   513848
# 24     00:00:00  REGULAR  5400290  7438496
# 25     04:00:00  REGULAR  5400303  7438506
# 26     08:00:00  REGULAR  5400363  7438717
# 27     12:00:00  REGULAR  5400553  7439250
# 28     16:00:00  REGULAR  5400853  7439439
# 29     20:00:00  REGULAR  5401471  7439725
# ...         ...      ...      ...      ...
# 28364  01:00:00  REGULAR  2239308    24013
# 28365  05:00:00  REGULAR  2239314    24014
# 28366  09:00:00  REGULAR  2239859    24018
# 28367  13:00:00  REGULAR  2240343    24021
# 28368  17:00:00  REGULAR  2240600    24022
# 28369  21:00:00  REGULAR  2240828    24027
# 28370  01:00:00  REGULAR   416942    16785
# 28371  05:00:00  REGULAR   416942    16788
# 28372  09:00:00  REGULAR   416965    16789
# 28373  13:00:00  REGULAR   416992    16789
# 28374  17:00:00  REGULAR   417074    16790
# 28375  21:00:00  REGULAR   417146    16794
# 28376  01:00:00  REGULAR  2753286   382211
# 28377  05:00:00  REGULAR  2753286   382211
# 28378  09:00:00  REGULAR  2753314   382211
# 28379  13:00:00  REGULAR  2753373   382212
# 28380  17:00:00  REGULAR  2753480   382214
# 28381  21:00:00  REGULAR  2753554   382226
# 28382  01:00:00  REGULAR     2660       62
# 28383  05:00:00  REGULAR     2660       62
# 28384  09:00:00  REGULAR     2660       62
# 28385  13:00:00  REGULAR     2660       62
# 28386  17:00:00  REGULAR     2661       62
# 28387  21:00:00  REGULAR     2661       62
# 28388  01:00:00  REGULAR     5554      299
# 28389  05:00:00  REGULAR     5554      299
# 28390  09:00:00  REGULAR     5554      299
# 28391  13:00:00  REGULAR     5554      299
# 28392  17:00:00  REGULAR     5554      299
# 28393  21:00:00  REGULAR     5554      299
#
# [28394 rows x 11 columns]

# %% [markdown]
# 7.Create a dictionary called monday_dict mapping the tuple (C/A, UNIT,SCP, STATION) to a list of tuples containing (TIME,EXITS).
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') in your dictionary should give the value:
#
# [('00:00:00', 2104727),
#  ('04:00:00', 2104729),
#  ('08:00:00', 2104813),
#  ('12:00:00', 2105024),
#  ('16:00:00', 2105081),
#  ('20:00:00', 2105134)]

# %%
monday_dict = {}
for i in range(len(monday.index)):
    mytuple = (monday["C/A"][i],monday.UNIT[i],monday.SCP[i],monday.STATION[i])
    if mytuple not in monday_dict.keys():
        monday_dict[mytuple] = [(monday.TIME[i],monday.EXITS[i])]
    else:
        monday_dict[mytuple].append((monday.TIME[i],monday.EXITS[i]))


print(monday_dict[('A002', 'R051', '02-00-00','59 ST')])
# Out:
# [('00:00:00', 2104727), ('04:00:00', 2104729), ('08:00:00', 2104813), ('12:00:00', 2105024), ('16:00:00', 2105081), ('20:00:00', 2105134)]

# %% [markdown]
# 8.Note: as you get more comfortable with pandas, you will rely more on built-in pandas capabilities and less on creating dictionaries from scratch. For example, run the following lines of code to verify that this dataframe gives you the same info that you got in Exercise 7.

# %%
x=monday.groupby(['C/A', 'UNIT', 'SCP', 'STATION']).groups #the keys are the station pairs and the values are the row indices
flds = ['TIME','EXITS'] #we want to make values out of the remaining columns
monday_exits = {key: monday.loc[val,flds] for key, val in x.items()}
monday_exits[('A002', 'R051', '02-00-00','59 ST')]
# Out:
#        TIME    EXITS
# 0  00:00:00  2104727
# 1  04:00:00  2104729
# 2  08:00:00  2104813
# 3  12:00:00  2105024
# 4  16:00:00  2105081
# 5  20:00:00  2105134

# %% [markdown]
# 9.What the heck do these exit numbers represent? We can assume that they represent some sort of counter on the turnstile. We can subtract the exits at t=20 minus t=0 to figure out how many riders exited this turnstile between midnight and 8 pm.
#
# Can we calculate 20 - 0 for all of the stations? No! Unfortunately, the time increments aren't standardized. Many of the times are listed in 4 hour intervals of midnight, 4 am, 8 am, etc but not all. Make a frequency chart of the times for the monday dataframe from Exercise 6.

# %%
monday.TIME.value_counts()
# Out:
# 00:00:00    2409
# 12:00:00    2408
# 20:00:00    2408
# 08:00:00    2407
# 16:00:00    2405
# 04:00:00    2405
# 17:00:00    1741
# 05:00:00    1740
# 13:00:00    1740
# 01:00:00    1740
# 09:00:00    1739
# 21:00:00    1738
# 18:00:00     110
# 14:00:00     110
# 02:00:00     110
# 06:00:00     110
# 22:00:00     110
# 10:00:00     110
# 11:00:00      39
# 23:00:00      39
# 15:00:00      39
# 19:00:00      39
# 07:00:00      39
# 03:00:00      39
# 08:22:00      37
# 12:22:00      37
# 16:22:00      37
# 20:22:00      37
# 04:22:00      37
# 00:22:00      37
#             ...
# 10:32:39       1
# 23:06:28       1
# 09:26:03       1
# 10:57:57       1
# 15:44:32       1
# 02:52:11       1
# 04:18:49       1
# 12:13:18       1
# 06:04:20       1
# 03:21:29       1
# 08:48:12       1
# 03:14:15       1
# 00:39:49       1
# 09:15:59       1
# 02:08:39       1
# 17:03:27       1
# 21:24:56       1
# 07:56:12       1
# 01:01:09       1
# 08:53:48       1
# 15:53:47       1
# 04:05:43       1
# 22:19:05       1
# 16:52:44       1
# 11:28:09       1
# 19:26:40       1
# 05:23:19       1
# 09:49:35       1
# 20:42:42       1
# 22:04:46       1
# Name: TIME, Length: 1887, dtype: int64

# %% [markdown]
# 10.Use your monday_dict from Exercise 7 to create a dictionary called monday_dict_diff that maps (C/A, UNIT, SCP, STATION) to the differences in exits between two consective times in order to see how many people exited through a turnstile within a given time interval.
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') should map to:
#
# [('04:00:00', 2),
#  ('08:00:00', 84),
#  ('12:00:00', 211),
#  ('16:00:00', 57),
#  ('20:00:00', 53)]

# %%
monday_dict_diff = {}

for key,value in monday_dict.items():
    for i in range(1,len(value)):
        if key not in monday_dict_diff:
            monday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            monday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

print(monday_dict_diff[('A002', 'R051', '02-00-00','59 ST')])
# Out:
# [('04:00:00', 2), ('08:00:00', 84), ('12:00:00', 211), ('16:00:00', 57), ('20:00:00', 53)]

# %% [markdown]
# 11.Once again, note that pandas can do the above calculation for you. If you used the monday_exits dataframe from Exercise 8, run the following code to verify that you obtain what you just got in Exercise 10. It may take a bit longer to run.

# %%
monday_diff = {}

for turnstile, slice_df in monday_exits.items():
    diff = slice_df['EXITS'].diff().values #calculates the exit difference between each entry
    monday_diff[turnstile] = pd.Series(diff, index=slice_df['TIME'].values) #maps turnstile to (time, exit difference) pairs
    for i,(key, val) in enumerate(monday_diff[turnstile].items()):
        try: #need a try because you'll get an error for NAN difference values since there is one less difference than the number of times
            monday_exits[turnstile].at[i,'EXITS'] = val
        except:
            continue
    monday_exits[turnstile] = monday_exits[turnstile].drop(0)    #drop the first time because you only calculate differences after the second time.                   
    
monday_exits[('A002', 'R051', '02-00-00', '59 ST')]

# %% [markdown]
# 12.Find how many people in total passed through a given turnstile between the hours given for 06/12/2017. For example, if a turnstile is on increments of 0,4,8,...,20, then you want to find out how many total people passed through between midnight and 8 pm. Create a dictionary called total_turnstile that maps (C/A,UNIT,SCP,STATION) to total Monday ridership. Use your dictionary from Exercise 10.
#
# Hint: the key ('A002', 'R051', '02-00-00', '59 ST') should map to 407 total riders.

# %%
total_turnstile = {}
for key,value in monday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]
        
print(total_turnstile[('A002', 'R051', '02-00-00', '59 ST')])
# Out:
# 407

# %% [markdown]
# 13.Use your work in Exercise 12 to create a dictionary called total_riders that maps the (C/A, UNIT, STATION) location to all riders that passed through ALL of the turnstiles in that area on Monday.
#
# Hint 1: use the get command
#
# Hint 2: ('A002', 'R051', '59 ST') should have 6704 total riders.

# %%
total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value
    
print(total_riders[('A002', 'R051', '59 ST')])
# Out:
# 6704

# %% [markdown]
# 14.Create a list of tuples called tuple_list using your total_riders dictionary so that you can sort the list in decending order to see busiest stations. Hint: the busiest area should be the PATH World Trade Center station.

# %%
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)
print(tuple_list)
# Out:
# [(56297, 'PATH NEW WTC'), (50291, 'GRD CNTRL-42 ST'), (39654, 'GRD CNTRL-42 ST'), (31126, '86 ST'), (27180, '47-50 STS ROCK'), (26181, '34 ST-PENN STA'), (25527, '34 ST-HERALD SQ'), (24776, 'FLUSHING-MAIN'), (24129, '14 ST-UNION SQ'), (24085, '34 ST-HERALD SQ'), (24053, '34 ST-HERALD SQ'), (24049, '59 ST COLUMBUS'), (23536, 'BEDFORD AV'), (23504, '14 ST-UNION SQ'), (23196, 'LEXINGTON AV/53'), (23123, 'W 4 ST-WASH SQ'), (22670, 'JKSN HT-ROOSVLT'), (22189, '42 ST-PORT AUTH'), (22075, '47-50 STS ROCK'), (21168, '125 ST'), (20911, '96 ST'), (20589, '14 ST-UNION SQ'), (20076, 'TIMES SQ-42 ST'), (19889, 'PAVONIA/NEWPORT'), (19870, 'THIRTY THIRD ST'), (19814, 'GRD CNTRL-42 ST'), (19367, 'TIMES SQ-42 ST'), (19271, 'NEWARK HM HE'), (19260, 'JAMAICA CENTER'), (19161, 'GROVE STREET'), (19090, '42 ST-BRYANT PK'), (18894, '77 ST'), (18671, '34 ST-PENN STA'), (18496, 'CHAMBERS ST'), (18491, '59 ST COLUMBUS'), (18132, 'ATL AV-BARCLAY'), (17924, '34 ST-HERALD SQ'), (17543, 'FULTON ST'), (17058, '34 ST-PENN STA'), (16808, 'SUTPHIN-ARCHER'), (16332, 'EXCHANGE PLACE'), (16073, 'CANAL ST'), (16069, 'SOUTH FERRY'), (15975, '68ST-HUNTER CO'), (15842, '61 ST WOODSIDE'), (15761, '72 ST'), (15604, '82 ST-JACKSON H'), (15369, 'CITY / BUS'), (15354, '5 AV/53 ST'), (15312, 'TIMES SQ-42 ST'), (15311, '125 ST'), (15209, 'PARKCHESTER'), (15189, 'KEW GARDENS'), (14887, "B'WAY-LAFAYETTE"), (14793, 'JUNCTION BLVD'), (14219, '72 ST-2 AVE'), (14214, 'TIMES SQ-42 ST'), (13967, 'CANAL ST'), (13952, 'BOWLING GREEN'), (13934, 'GRAND ST'), (13920, '34 ST-PENN STA'), (13916, '42 ST-BRYANT PK'), (13586, 'CROWN HTS-UTICA'), (13442, 'LEXINGTON AV/53'), (13093, '5 AV/53 ST'), (13014, '42 ST-PORT AUTH'), (12945, '168 ST'), (12901, '145 ST'), (12688, '23 ST'), (12645, '59 ST'), (12450, '50 ST'), (12232, '1 AV'), (12130, '8 AV'), (11951, 'THIRTY ST'), (11948, 'FULTON ST'), (11948, '51 ST'), (11942, 'FLUSHING-MAIN'), (11883, '57 ST'), (11850, '8 AV'), (11811, 'TWENTY THIRD ST'), (11630, 'LACKAWANNA'), (11580, 'ASTORIA DITMARS'), (11362, 'ASTOR PL'), (11311, '103 ST-CORONA'), (11258, "B'WAY-LAFAYETTE"), (11207, '47-50 STS ROCK'), (11200, 'WOODHAVEN BLVD'), (11144, '5 AVE'), (11136, '96 ST'), (11064, 'KEW GARDENS'), (10999, '59 ST'), (10997, 'BROOKLYN BRIDGE'), (10820, '42 ST-PORT AUTH'), (10769, 'ATL AV-BARCLAY'), (10766, '103 ST'), (10704, 'CHURCH AV'), (10670, '14 ST'), (10639, 'W 4 ST-WASH SQ'), (10558, '72 ST'), (10528, '86 ST'), (10393, 'WHITEHALL S-FRY'), (10380, '34 ST-HUDSON YD'), (10367, '34 ST-HERALD SQ'), (10328, '50 ST'), (10297, '7 AV'), (10265, 'CORTLANDT ST'), (10222, '23 ST'), (10197, 'FULTON ST'), (10137, '14 ST-UNION SQ'), (10005, '66 ST-LINCOLN'), (9861, '181 ST'), (9839, 'CHAMBERS ST'), (9718, 'JAY ST-METROTEC'), (9686, '59 ST COLUMBUS'), (9481, '72 ST-2 AVE'), (9429, 'SHEEPSHEAD BAY'), (9397, 'WALL ST'), (9365, 'JAY ST-METROTEC'), (9362, 'CANAL ST'), (9337, 'WORLD TRADE CTR'), (9325, 'WALL ST'), (9281, 'METS-WILLETS PT'), (9268, '23 ST'), (9080, 'BOROUGH HALL'), (9080, '28 ST'), (9073, 'LEXINGTON AV/63'), (9019, '34 ST-PENN STA'), (9007, '34 ST-PENN STA'), (8926, 'JAMAICA CENTER'), (8863, '30 AV'), (8836, 'CONEY IS-STILLW'), (8802, '59 ST'), (8799, 'NEWKIRK PLAZA'), (8779, '86 ST-2 AVE'), (8730, 'LEXINGTON AV/53'), (8714, 'SPRING ST'), (8697, '42 ST-PORT AUTH'), (8673, 'BOROUGH HALL'), (8652, '7 AV'), (8561, 'FULTON ST'), (8486, 'BOWLING GREEN'), (8485, 'NEWARK HW BMEBE'), (8347, '81 ST-MUSEUM'), (8346, '7 AV'), (8345, 'HARRISON'), (8317, '28 ST'), (8159, '2 AV'), (8135, '33 ST'), (8080, 'PRINCE ST'), (8050, 'LEXINGTON AV/63'), (7927, 'JKSN HT-ROOSVLT'), (7908, 'HOYT-SCHER'), (7901, 'GRAND-NEWTOWN'), (7882, 'GRD CNTRL-42 ST'), (7826, 'CHAMBERS ST'), (7811, '167 ST'), (7742, 'PATH WTC 2'), (7678, '40 ST LOWERY ST'), (7649, 'JFK JAMAICA CT1'), (7647, '191 ST'), (7607, 'HUNTS POINT AV'), (7574, '23 ST'), (7559, 'BROADWAY'), (7495, 'TIMES SQ-42 ST'), (7443, '137 ST CITY COL'), (7437, '33 ST-RAWSON ST'), (7433, 'DEKALB AV'), (7422, 'GUN HILL RD'), (7412, 'VERNO ...

# %% [markdown]
# 15.Look at the three smallest riderships in your above tuple list. Do they make sense? What about your data caused negative numbers? Welcome to the world of buggy real world data! Remove these three items from your tuple list.

# %%
print(tuple_list[-1])
print(tuple_list[-2])
print(tuple_list[-3])
print(tuple_list[-4])
#negative numbers because data is flawed, glitched
del tuple_list[-1]
del tuple_list[-1]
del tuple_list[-1]
print(tuple_list[-1])
print(tuple_list[-2])
print(tuple_list[-3])
print(tuple_list[-4])
len(tuple_list)
# Out:
# (-45421, 'JOURNAL SQUARE')
# (-2060, 'GRD CNTRL-42 ST')
# (-333, '116 ST')
# (0, '161/YANKEE STAD')
# (0, '161/YANKEE STAD')
# (0, '161/YANKEE STAD')
# (0, '18 AV')
# (0, 'AVENUE N')
# 727

# %% [markdown]
# 16.Create a barchart for the number of riders. You don't need to keep track of the names of each station, as that would get really messy to plot. Instead, you can just use a list comprehension to save the rider numbers to the y-values and give the stations the numbers 0,1,2,3,... for the x-values. You can use the following piece of code. Remember to add in axis labels and a title.
#
# x = range(len(tuple_list))
#
# y = [tuple_list[i][0] for i in range(len(tuple_list))]
#
# plt.bar(x,y)

# %%
import matplotlib.pyplot as plt
% matplotlib inline

x = range(len(tuple_list))
y = [tuple_list[i][0] for i in range(len(tuple_list))]
plt.bar(x,y)

plt.xlabel('Station number')
plt.ylabel('Number of riders')
plt.title('Ridership by Station');

# %% [markdown]
# 17.Perhaps we don't care about total ridership in a 24 period. Perhaps we only care about the morning commute. Let's assume that the majority of people arrive at their work location subway exit between 8 and 9 am.
#
# Go back up to your frequency chart in Exercise 9. Note that the most common morning commutes would be gained from subtracting 9 am - 5 am and 10 am - 6 am and 11 am - 7 am and 12pm - 8am, for the stations that are broken down by those specific four hour intervals.
#
# As a dirty way to consider only the stations that are on these time intervals, save just the rows in your original monday dataframe that contain the TIME strings '05:00:00', '06:00:00',..., '12:00:00'. Remember you can do this by using OR statements using the "|" symbol and remembering parenthesis. Call this new dataframe "morning". Be sure to reset its index.

# %%
morning = monday[(monday.TIME=='05:00:00')|(monday.TIME=='06:00:00')|(monday.TIME=='07:00:00')|(monday.TIME=='08:00:00')|(monday.TIME=='09:00:00')|(monday.TIME=='10:00:00')|(monday.TIME=='11:00:00')|(monday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
morning
# Out:
#         C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0      A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 1      A002  R051  02-00-00          59 ST  NQR456W      BMT  06/12/2017
# 2      A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 3      A002  R051  02-00-01          59 ST  NQR456W      BMT  06/12/2017
# 4      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 5      A002  R051  02-03-00          59 ST  NQR456W      BMT  06/12/2017
# 6      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 7      A002  R051  02-03-01          59 ST  NQR456W      BMT  06/12/2017
# 8      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 9      A002  R051  02-03-02          59 ST  NQR456W      BMT  06/12/2017
# 10     A002  R051  02-03-03          59 ST  NQR456W      BMT  06/12/2017
# 11     A002  R051  02-03-03          59 ST  NQR456W      BMT  06/12/2017
# 12     A002  R051  02-03-04          59 ST  NQR456W      BMT  06/12/2017
# 13     A002  R051  02-03-04          59 ST  NQR456W      BMT  06/12/2017
# 14     A002  R051  02-03-05          59 ST  NQR456W      BMT  06/12/2017
# 15     A002  R051  02-03-05          59 ST  NQR456W      BMT  06/12/2017
# 16     A002  R051  02-03-06          59 ST  NQR456W      BMT  06/12/2017
# 17     A002  R051  02-03-06          59 ST  NQR456W      BMT  06/12/2017
# 18     A002  R051  02-05-00          59 ST  NQR456W      BMT  06/12/2017
# 19     A002  R051  02-05-00          59 ST  NQR456W      BMT  06/12/2017
# 20     A002  R051  02-05-01          59 ST  NQR456W      BMT  06/12/2017
# 21     A002  R051  02-05-01          59 ST  NQR456W      BMT  06/12/2017
# 22     A002  R051  02-06-00          59 ST  NQR456W      BMT  06/12/2017
# 23     A002  R051  02-06-00          59 ST  NQR456W      BMT  06/12/2017
# 24     A006  R079  00-00-00     5 AV/59 ST     NQRW      BMT  06/12/2017
# 25     A006  R079  00-00-00     5 AV/59 ST     NQRW      BMT  06/12/2017
# 26     A006  R079  00-00-01     5 AV/59 ST     NQRW      BMT  06/12/2017
# 27     A006  R079  00-00-01     5 AV/59 ST     NQRW      BMT  06/12/2017
# 28     A006  R079  00-00-02     5 AV/59 ST     NQRW      BMT  06/12/2017
# 29     A006  R079  00-00-02     5 AV/59 ST     NQRW      BMT  06/12/2017
# ...     ...   ...       ...            ...      ...      ...         ...
# 8562   S102  R165  00-03-00  TOMPKINSVILLE        1      SRT  06/12/2017
# 8563   S102  R165  00-03-00  TOMPKINSVILLE        1      SRT  06/12/2017
# 8564   S102  R165  00-03-01  TOMPKINSVILLE        1      SRT  06/12/2017
# 8565   S102  R165  00-03-01  TOMPKINSVILLE        1      SRT  06/12/2017
# 8566   S102  R165  00-03-02  TOMPKINSVILLE        1      SRT  06/12/2017
# 8567   S102  R165  00-03-02  TOMPKINSVILLE        1      SRT  06/12/2017
# 8568   S102  R165  00-05-00  TOMPKINSVILLE        1      SRT  06/12/2017
# 8569   S102  R165  00-05-00  TOMPKINSVILLE        1      SRT  06/12/2017
# 8570   S102  R165  00-05-01  TOMPKINSVILLE        1      SRT  06/12/2017
# 8571   S102  R165  00-05-01  TOMPKINSVILLE        1      SRT  06/12/2017
# 8572  TRAM1  R468  00-00-00  RIT-MANHATTAN        R      RIT  06/12/2017
# 8573  TRAM1  R468  00-00-00  RIT-MANHATTAN        R      RIT  06/12/2017
# 8574  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  06/12/2017
# 8575  TRAM1  R468  00-00-01  RIT-MANHATTAN        R      RIT  06/12/2017
# 8576  TRAM1  R468  00-00-02  RIT-MANHATTAN        R      RIT  06/12/2017
# 8577  TRAM1  R468  00-00-02  RIT-MANHATTAN        R      RIT  06/12/2017
# 8578  TRAM1  R468  00-05-00  RIT-MANHATTAN        R      RIT  06/12/2017
# 8579  TRAM1  R468  00-05-00  RIT-MANHATTAN        R      RIT  06/12/2017
# 8580  TRAM2  R469  00-00-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8581  TRAM2  R469  00-00-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8582  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8583  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8584  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8585  TRAM2  R469  00-03-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8586  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8587  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8588  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8589  TRAM2  R469  00-05-00  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8590  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
# 8591  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/12/2017
#
#           TIME     DESC   ENTRIES    EXITS
# 0     08:00:00  REGULAR   6217372  2104813
# 1     12:00:00  REGULAR   6217540  2105024
# 2     08:00:00  REGULAR   5615730  1247491
# 3     12:00:00  REGULAR   5615864  1247619
# 4     08:00:00  REGULAR    926883  3436892
# 5     12:00:00  REGULAR    926944  3437546
# 6     08:00:00  REGULAR    318457   512463
# 7     12:00:00  REGULAR    318606   513093
# 8     08:00:00  REGULAR   5400363  7438717
# 9     12:00:00  REGULAR   5400553  7439250
# 10    08:00:00  REGULAR   5033045  5951883
# 11    12:00:00  REGULAR   5033227  5952284
# 12    08:00:00  REGULAR   6327512  3378334
# 13    12:00:00  REGULAR   6327747  3378520
# 14    08:00:00  REGULAR  10201416  1316123
# 15    12:00:00  REGULAR  10201794  1316172
# 16    08:00:00  REGULAR   8030072   482988
# 17    12:00:00  REGULAR   8030401   482996
# 18    08:00:00  REGULAR      1401        0
# 19    12:00:00  REGULAR      1401        0
# 20    08:00:00  REGULAR         0      738
# 21    12:00:00  REGULAR         0      738
# 22    08:00:00  REGULAR   7079950   151005
# 23    12:00:00  REGULAR   7080265   151009
# 24    06:00:00  REGULAR   2875674  4909941
# 25    10:00:00  REGULAR   2875736  4910982
# 26    06:00:00  REGULAR   4097127  2578652
# 27    10:00:00  REGULAR   4097180  2578979
# 28    06:00:00  REGULAR   7800085  3430553
# 29    10:00:00  REGULAR   7800135  3430764
# ...        ...      ...       ...      ...
# 8562  06:00:00  REGULAR    465160       12
# 8563  10:00:00  REGULAR    465193       12
# 8564  06:00:00  REGULAR   7390271  2410682
# 8565  10:00:00  REGULAR   7390293  2410682
# 8566  06:00:00  REGULAR    205557        3
# 8567  10:00:00  REGULAR    205579        3
# 8568  06:00:00  REGULAR    262239    65536
# 8569  10:00:00  REGULAR    262239    65536
# 8570  06:00:00  REGULAR        54        0
# 8571  10:00:00  REGULAR        54        0
# 8572  05:00:00  REGULAR    631355    12099
# 8573  09:00:00  REGULAR    631394    12102
# 8574  05:00:00  REGULAR   2231888    22309
# 8575  09:00:00  REGULAR   2231972    22310
# 8576  05:00:00  REGULAR   1510434    19654
# 8577  09:00:00  REGULAR   1510454    19654
# 8578  05:00:00  REGULAR      1940        0
# 8579  09:00:00  REGULAR      1940        0
# 8580  05:00:00  REGULAR   3718545    52578
# 8581  09:00:00  REGULAR   3718889    52581
# 8582  05:00:00  REGULAR   2239314    24014
# 8583  09:00:00  REGULAR   2239859    24018
# 8584  05:00:00  REGULAR    416942    16788
# 8585  09:00:00  REGULAR    416965    16789
# 8586  05:00:00  REGULAR   2753286   382211
# 8587  09:00:00  REGULAR   2753314   382211
# 8588  05:00:00  REGULAR      2660       62
# 8589  09:00:00  REGULAR      2660       62
# 8590  05:00:00  REGULAR      5554      299
# 8591  09:00:00  REGULAR      5554      299
#
# [8592 rows x 11 columns]

# %% [markdown]
# 18.Now create a morning_dict by repeating your work in Exercise 7 on this morning dataframe. The dictionary should map the tuple (C/A, UNIT, SCP,STATION) to an inner dictionary containing {TIME: EXITS} for all Monday rides.
#
# Hint: ('A002', 'R051', '02-00-00','59 ST') should map to {'08:00:00': 2104813, '12:00:00': 2105024}.

# %%
#number of people who exited given station at given time that morning
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

morning_dict[('A002', 'R051', '02-00-00','59 ST')]
# Out:
# {'08:00:00': 2104813, '12:00:00': 2105024}

# %% [markdown]
# 19.We're almost ready to subtract the two consecutive times for each station to get the morning commutes. That is, if there are exactly two times for each station. Find which stations keys in your dictionary above do not contain exactly two times and delete them from the morning dictionary.
#
# How many keys are left in your morning_dict? There should be 4293.

# %%
bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

print(len(morning_dict))
# Out:
# 4293

# %% [markdown]
# 20.Create a dictionary called morning_differences where (C/A, UNIT, STATION) maps to an inner dictionary containing {SCP: Morning Exit Differences}.
#
# For example, ('A002', 'R051', '59 ST') should map to:
#
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %%
morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

morning_differences[ ('A002', 'R051', '59 ST')]
# Out:
# {'02-00-00': 211,
#  '02-00-01': [128],
#  '02-03-00': [654],
#  '02-03-01': [630],
#  '02-03-02': [533],
#  '02-03-03': [401],
#  '02-03-04': [186],
#  '02-03-05': [49],
#  '02-03-06': [8],
#  '02-05-00': [0],
#  '02-05-01': [0],
#  '02-06-00': [4]}

# %% [markdown]
# 21.Create a dictionary called total_morning_diff that maps each (C/A, Unit, Station) location to the total morning riders passing through ALL of the turnstiles in that area.
#
# Hint 1: see your work in Exercise 13.
#
# Hint 2: ('A002', 'R051','59 ST') should have 2804 morning commuter exits.

# %%
total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val
     
print(total_morning_diff[('A002', 'R051', '59 ST')])
# Out:
# [2804]

# %% [markdown]
# 22.Create a list of sorted tuples to see the most popular morning exits.
#
# Hint:  ('R238', 'R046', 'GRD CNTRL-42 ST') should be the highest with 17,300 morning exits.

# %%
tuples = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    tuples.append(mytuple)
tuples.sort(reverse=True)
for key,value in tuples:
    print(key,value)
# Out:
# [17300] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [16250] ('N500', 'R020', '47-50 STS ROCK')
# [13194] ('N501', 'R020', '47-50 STS ROCK')
# [12576] ('N306', 'R017', 'LEXINGTON AV/53')
# [12545] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [10593] ('N504', 'R021', '42 ST-BRYANT PK')
# [10213] ('A025', 'R023', '34 ST-HERALD SQ')
# [9605] ('N304', 'R015', '5 AV/53 ST')
# [9393] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9234] ('N505', 'R022', '34 ST-HERALD SQ')
# [8903] ('R249', 'R179', '86 ST')
# [8893] ('N051', 'R084', '59 ST COLUMBUS')
# [8049] ('R116', 'R030', 'CHAMBERS ST')
# [7708] ('N049', 'R084', '59 ST COLUMBUS')
# [7641] ('N303', 'R015', '5 AV/53 ST')
# [7423] ('N305', 'R017', 'LEXINGTON AV/53')
# [7155] ('N507', 'R023', '34 ST-HERALD SQ')
# [6820] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6776] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6531] ('N506', 'R022', '34 ST-HERALD SQ')
# [6373] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6360] ('N098', 'R028', 'FULTON ST')
# [6251] ('N503', 'R021', '42 ST-BRYANT PK')
# [6194] ('N501A', 'R020', '47-50 STS ROCK')
# [6187] ('R155', 'R116', '50 ST')
# [5974] ('R243', 'R049', '51 ST')
# [5929] ('N520', 'R240', 'GRAND ST')
# [5856] ('R245A', 'R051', '59 ST')
# [5727] ('R206', 'R014', 'FULTON ST')
# [5708] ('R202', 'R042', 'BOWLING GREEN')
# [5696] ('R258', 'R132', '125 ST')
# [5512] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [5392] ('R182', 'R035', '168 ST')
# [5309] ('R246', 'R177', '68ST-HUNTER CO')
# [5046] ('A033', 'R170', '14 ST-UNION SQ')
# [5020] ('N509', 'R203', '23 ST')
# [5009] ('R111', 'R027', 'WALL ST')
# [4932] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4864] ('R533', 'R055', 'FLUSHING-MAIN')
# [4847] ('N092', 'R029', 'CHAMBERS ST')
# [4754] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4751] ('N508', 'R453', '23 ST')
# [4658] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4650] ('R201', 'R041', 'BOWLING GREEN')
# [4635] ('R204', 'R043', 'WALL ST')
# [4617] ('R154', 'R116', '50 ST')
# [4571] ('R113', 'R028', 'FULTON ST')
# [4544] ('A022', 'R022', '34 ST-HERALD SQ')
# [4440] ('R244', 'R050', '59 ST')
# [4376] ('N102', 'R127', 'JAY ST-METROTEC')
# [4346] ('R221', 'R170', '14 ST-UNION SQ')
# [4336] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [4324] ('R247', 'R178', '77 ST')
# [4312] ('H009', 'R235', 'BEDFORD AV')
# [4305] ('R550', 'R072', '34 ST-HUDSON YD')
# [4305] ('N089', 'R139', 'CANAL ST')
# [4266] ('A034', 'R170', '14 ST-UNION SQ')
# [4171] ('N601', 'R319', 'LEXINGTON AV/63')
# [4108] ('R244A', 'R050', '59 ST')
# [4094] ('N600', 'R302', '57 ST')
# [3965] ('N606', 'R025', 'JAMAICA CENTER')
# [3875] ('N067', 'R012', '34 ST-PENN STA')
# [3862] ('N301', 'R113', '7 AV')
# [3853] ('R110', 'R027', 'WALL ST')
# [3841] ('N103', 'R127', 'JAY ST-METROTEC')
# [3775] ('R501', 'R054', '5 AVE')
# [3765] ('R601A', 'R108', 'BOROUGH HALL')
# [3747] ('R142', 'R293', '34 ST-PENN STA')
# [3721] ('N091', 'R029', 'CHAMBERS ST')
# [3628] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3611] ('N094', 'R029', 'WORLD TRADE CTR')
# [3580] ('N502', 'R021', '42 ST-BRYANT PK')
# [3575] ('N700A', 'R570', '72 ST-2 AVE')
# [3555] ('N026', 'R102', '125 ST')
# [3499] ('R158', 'R084', '59 ST COLUMBUS')
# [3495] ('N095A', 'R014', 'FULTON ST')
# [3481] ('N060', 'R010', '42 ST-PORT AUTH')
# [3446] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3410] ('R169', 'R168', '96 ST')
# [3382] ('R516', 'R291', '33 ST-RAWSON ST')
# [3378] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3347] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3343] ('R112', 'R027', 'WALL ST')
# [3340] ('R200A', 'R041', 'BOWLING GREEN')
# [3315] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3307] ('A006', 'R079', '5 AV/59 ST')
# [3302] ('R242', 'R049', '51 ST')
# [3285] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3270] ('N400A', 'R359', 'COURT SQ')
# [3210] ('N700', 'R570', '72 ST-2 AVE')
# [3204] ('R526', 'R096', '82 ST-JACKSON H')
# [3158] ('H008', 'R248', '1 AV')
# [3143] ('R228', 'R143', '28 ST')
# [3075] ('A042', 'R086', 'PRINCE ST')
# [3066] ('A029', 'R082', '28 ST')
# [3040] ('A031', 'R083', '23 ST')
# [3026] ('N090', 'R139', 'CANAL ST')
# [3024] ('N601A', 'R319', 'LEXINGTON AV/63')
# [3012] ('R161B', 'R452', '72 ST')
# [2957] ('A015', 'R081', '49 ST')
# [2956] ('R216', 'R322', 'SPRING ST')
# [2912] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [2896] ('R602', 'R108', 'BOROUGH HALL')
# [2867] ('N078', 'R175', '14 ST')
# [2866] ('A035', 'R170', '14 ST-UNION SQ')
# [2864] ('R112A', 'R027', 'WALL ST')
# [2841] ('A046', 'R463', 'CANAL ST')
# [2828] ('A030', 'R083', '23 ST')
# [2810] ('A043', 'R462', 'CANAL ST')
# [2804] ('A002', 'R051', '59 ST')
# [2803] ('N071', 'R013', '34 ST-PENN STA')
# [2778] ('A010', 'R080', '57 ST-7 AV')
# [2745] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2728] ('A049', 'R088', 'CORTLANDT ST')
# [2721] ('R101', 'R001', 'SOUTH FERRY')
# [2692] ('R226', 'R131', '23 ST')
# [2690] ('N108', 'R217', 'HOYT-SCHER')
# [2689] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2641] ('N095', 'R014', 'FULTON ST')
# [2639] ('A013', 'R081', '49 ST')
# [2629] ('R138', 'R293', '34 ST-PENN STA')
# [2572] ('N020', 'R101', '145 ST')
# [2552] ('R159', 'R164', '66 ST-LINCOLN')
# [2549] ('N300', 'R113', '7 AV')
# [2538] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2497] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2490] ('R248', 'R178', '77 ST')
# [2487] ('A081', 'R028', 'FULTON ST')
# [2411] ('R141', 'R031', '34 ST-PENN STA')
# [2380] ('N070', 'R012', '34 ST-PENN STA')
# [2373] ('R232', 'R176', '33 ST')
# [2370] ('N076', 'R111', '23 ST')
# [2321] ('R114', 'R028', 'FULTON ST')
# [2317] ('H001', 'R175', '8 AV')
# [2310] ('C008', 'R099', 'DEKALB AV')
# [2302] ('N068', 'R012', '34 ST-PENN STA')
# [2262] ('N512', 'R163', '14 ST')
# [2255] ('A039', 'R085', '8 ST-NYU')
# [2238] ('N056', 'R188', '50 ST')
# [2235] ('R203', 'R043', 'WALL ST')
# [2218] ('A060', 'R001', 'WHITEHALL S-FRY')
# [2213] ('R252', 'R180', '103 ST')
# [2195] ('N309A', 'R140', 'QUEENS PLAZA')
# [2187] ('N046', 'R281', '72 ST')
# [2175] ('R168A', 'R168', '96 ST')
# [2162] ('H007', 'R248', '1 AV')
# [2155] ('R242A', 'R049', '51 ST')
# [2147] ('R507', 'R134', 'HUNTERS PT AV')
# [2134] ('R534', 'R055', 'FLUSHING-MAIN')
# [2115] ('N073', 'R013', '34 ST-PENN STA')
# [2066] ('R183', 'R260', '181 ST')
# [2059] ('A027', 'R082', '28 ST')
# [2053] ('N069', 'R013', '34 ST-PENN STA')
# [2052] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2009] ('N510', 'R163', '14 ST')
# [2004] ('R102', 'R304', 'RECTOR ST')
# [1993] ('R137', 'R031', '34 ST-PENN STA')
# [1944] ('R229', 'R143', '28 ST')
# [1900] ('A058', 'R001', 'WHITEHALL S-FRY')
# [1878] ('N077', 'R111', '23 ST')
# [1863] ('R132', 'R190', '23 ST')
# [1853] ('R127', 'R105', '14 ST')
# [1830] ('R523', 'R147', '61 ST WOODSIDE')
# [1817] ('R208', 'R014', 'FULTON ST')
# [1810] ('A011', 'R080', '57 ST-7 AV')
# [1793] ('N523', 'R300', '2 AV')
# [1770] ('R508', 'R346', 'COURT SQ')
# [1768] ('A069', 'R044', 'CHAMBERS ST')
# [1766] ('R173', 'R159', '116 ST-COLUMBIA')
# [1745] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1719] ('R165', 'R167', '86 ST')
# [1717] ('A047', 'R087', 'CITY HALL')
# [1711] ('N072', 'R012', '34 ST-PENN STA')
# [1703] ('R124', 'R290', 'HOUSTON ST')
# [1682] ('R528', 'R097', 'JUNCTION BLVD')
# [1679] ('R261', 'R205', '149/GRAND CONC')
# [1661] ('R605', 'R456', 'HOYT ST')
# [1633] ('R220', 'R160', 'ASTOR PL')
# [1630] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1613] ('B016', 'R098', 'CHURCH AV')
# [1612] ('N063', 'R011', '42 ST-PORT AUTH')
# [1607] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1587] ('A037', 'R170', '14 ST-UNION SQ')
# [1578] ('R217A', 'R194', 'BLEECKER ST')
# [1571] ('R115', 'R029', 'PARK PLACE')
# [1561] ('A014', 'R081', '49 ST')
# [1552] ('R161A', 'R452', '72 ST')
# [1532] ('D002', 'R390', '8 AV')
# [1525] ('R412', 'R146', 'HUNTS POINT AV')
# [1522] ('N044', 'R187', '81 ST-MUSEUM')
# [1513] ('N511', 'R163', '14 ST')
# [1507] ('R529', 'R208', '103 ST-CORONA')
# [1503] ('R301', 'R323', 'CENTRAL PK N110')
# [1502] ('R135', 'R031', '34 ST-PENN STA')
# [1488] ('N607', 'R025', 'JAMAICA CENTER')
# [1446] ('R174', 'R034', '125 ST')
# [1444] ('N536', 'R270', 'SMITH-9 ST')
# [1436] ('H005', 'R330', '3 AV')
# [1434] ('R609', 'R056', 'NEVINS ST')
# [1430] ('N101', 'R252', 'HIGH ST')
# [1420] ('R420', 'R107', 'WESTCHESTER SQ')
# [1412] ('R283', 'R221', '167 ST')
# [1399] ('R331', 'R364', 'GUN HILL RD')
# [1393] ('R518', 'R261', '40 ST LOWERY ST')
# [1390] ('R204A', 'R043', 'WALL ST')
# [1390] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1390] ('C012', 'R258', '4AV-9 ST')
# [1387] ('N062', 'R011', '42 ST-PORT AUTH')
# [1374] ('R185', 'R274', '191 ST')
# [1367] ('A041', 'R086', 'PRINCE ST')
# [1365] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1344] ('R130', 'R321', '18 ST')
# [1341] ('N405', 'R239', 'GREENPOINT AV')
# [1335] ('R250', 'R179', '86 ST')
# [1331] ('C018', 'R197', '36 ST')
# [1331] ('B031', 'R172', 'BRIGHTON BEACH')
# [1325] ('A016', 'R081', '49 ST')
# [1323] ('N539A', 'R288', '7 AV')
# [1313] ('R126', 'R189', 'CHRISTOPHER ST')
# [1312] ('R134', 'R272', '28 ST')
# [1295] ('R251', 'R144', '96 ST')
# [1286] ('N057', 'R188', '50 ST')
# [1276] ('R205A', 'R014', 'FULTON ST')
# [1269] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1269] ('N043', 'R186', '86 ST')
# [1255] ('R164', 'R167', '86 ST')
# [1252] ('R256', 'R182', '116 ST')
# [1250] ('R160A', 'R164', '66 ST-LINCOLN')
# [1245] ('N521', 'R300', '2 AV')
# [1241] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1234] ('R160', 'R164', '66 ST-LINCOLN')
# [1226] ('R503', 'R276', 'VERNON-JACKSON')
# [1223] ('N513', 'R163', '14 ST')
# [1221] ('N701A', 'R571', '86 ST-2 AVE')
# [1210] ('R311', 'R053', '3 AV-149 ST')
# [1191] ('N124', 'R103', 'BROADWAY JCT')
# [1190] ('R417', 'R222', 'PARKCHESTER')
# [1184] ('B024', 'R211', 'KINGS HWY')
# [1180] ('A083', 'R125', 'BROAD ST')
# [1172] ('R231A', 'R176', '33 ST')
# [1171] ('J001', 'R460', 'MARCY AV')
# [1166] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1162] ('R231', 'R176', '33 ST')
# [1149] ('R513', 'R093', '30 AV')
# [1134] ('R608', 'R056', 'NEVINS ST')
# [1122] ('R527', 'R122', '90 ST-ELMHURST')
# [1116] ('R512', 'R092', 'BROADWAY')
# [1115] ('N040', 'R251', '96 ST')
# [1113] ('N315', 'R238', 'STEINWAY ST')
# [1108] ('R284', 'R243', '170 ST')
# [1091] ('N327', 'R254', 'GRAND-NEWTOWN')
# [1074] ('A050', 'R088', 'CORTLANDT ST')
# [1072] ('R245', 'R051', '59 ST')
# [1060] ('R515', 'R095', 'ASTORIA DITMARS')
# [1058] ('J002', 'R460', 'MARCY AV')
# [1058] ('A007', 'R079', '5 AV/59 ST')
# [1051] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [1050] ('R519', 'R223', '46 ST BLISS ST')
# [1050] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1049] ('H016', 'R250', 'GRAND ST')
# [1026] ('N339A', 'R114', 'PARSONS BLVD')
# [1025] ('R120', 'R320', 'CANAL ST')
# [1024] ('N702', 'R572', '96 ST-2 AVE')
# [1007] ('R511', 'R091', '36 AV')
# [999] ('N422', 'R318', 'FULTON ST')
# [964] ('R604', 'R108', 'BOROUGH HALL')
# [954] ('B024A', 'R211', 'KINGS HWY')
# [952] ('C003', 'R089', 'JAY ST-METROTEC')
# [946] ('N702A', 'R572', '96 ST-2 AVE')
# [944] ('N329', 'R201', 'WOODHAVEN BLVD')
# [938] ('R253', 'R181', '110 ST')
# [932] ('R128', 'R105', '14 ST')
# [930] ('N330', 'R202', '63 DR-REGO PARK')
# [924] ('R232A', 'R176', '33 ST')
# [918] ('A064', 'R311', 'BOWERY')
# [912] ('C025', 'R215', '86 ST')
# [907] ('N116', 'R198', 'NOSTRAND AV')
# [902] ('B004', 'R171', '7 AV')
# [898] ('N117', 'R198', 'NOSTRAND AV')
# [885] ('N528', 'R257', 'EAST BROADWAY')
# [882] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [882] ('N217', 'R112', 'FORDHAM RD')
# [879] ('A077', 'R028', 'FULTON ST')
# [875] ('N310', 'R140', 'QUEENS PLAZA')
# [869] ('N526', 'R142', 'DELANCEY/ESSEX')
# [866] ('R304', 'R206', '125 ST')
# [866] ('N535', 'R220', 'CARROLL ST')
# [864] ('B029', 'R172', 'BRIGHTON BEACH')
# [861] ('N537', 'R258', '4 AV-9 ST')
# [859] ('H014', 'R249', 'GRAHAM AV')
# [859] ('B022', 'R229', 'AVENUE M')
# [850] ('N604', 'R342', 'JAMAICA VAN WK')
# [848] ('R423', 'R429', 'PELHAM BAY PARK')
# [843] ('R230', 'R143', '28 ST')
# [836] ('R530', 'R310', '111 ST')
# [835] ('H003', 'R163', '6 AV')
# [834] ('E004', 'R234', '50 ST')
# [833] ('N120', 'R153', 'UTICA AV')
# [833] ('N013', 'R035', '168 ST')
# [828] ('R629', 'R065', 'ROCKAWAY AV')
# [824] ('G009', 'R151', 'CONEY IS-STILLW')
# [819] ('N307', 'R359', 'COURT SQ-23 ST')
# [814] ('R517', 'R291', '33 ST-RAWSON ST')
# [809] ('R418', 'R106', 'CASTLE HILL AV')
# [803] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [802] ('R401', 'R445', '3 AV 138 ST')
# [797] ('R103', 'R304', 'RECTOR ST')
# [797] ('N602', 'R259', 'ROOSEVELT ISLND')
# [796] ('R175', 'R169', '137 ST CITY COL')
# [794] ('R171', 'R192', 'CATHEDRAL PKWY')
# [794] ('N025', 'R102', '125 ST')
# [792] ('R287', 'R244', 'BURNSIDE AV')
# [790] ('N546', 'R204', 'CHURCH AV')
# [788] ('R291', 'R183', 'BEDFORD PK BLVD')
# [786] ('R622', 'R123', 'FRANKLIN AV')
# [780] ('R336', 'R145', 'WAKEFIELD/241')
# [779] ('A054', 'R227', 'RECTOR ST')
# [766] ('R634', 'R069', 'NEW LOTS AV')
# [766] ('N549', 'R242', '18 AV')
# [766] ('N196', 'R285', 'FAR ROCKAWAY')
# [760] ('N213', 'R154', 'TREMONT AV')
# [753] ('N312', 'R339', '36 ST')
# [749] ('R290', 'R161', 'KINGSBRIDGE RD')
# [741] ('C019', 'R232', '45 ST')
# [739] ('N316A', 'R267', '46 ST')
# [736] ('R635', 'R277', 'PRESIDENT ST')
# [736] ('N530', 'R301', 'YORK ST')
# [733] ('R310', 'R053', '3 AV-149 ST')
# [728] ('J007', 'R377', 'FLUSHING AV')
# [726] ('H019', 'R294', 'MORGAN AV')
# [725] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [724] ('R177', 'R273', '145 ST')
# [721] ('N701', 'R571', '86 ST-2 AVE')
# [721] ('N086', 'R282', 'SPRING ST')
# [715] ('N333B', 'R141', 'FOREST HILLS 71')
# [714] ('N100', 'R252', 'HIGH ST')
# [709] ('N419', 'R287', 'CLASSON AV')
# [707] ('R285', 'R308', 'MT EDEN AV')
# [707] ('R254', 'R181', '110 ST')
# [699] ('R514', 'R094', 'ASTORIA BLVD')
# [697] ('H006', 'R330', '3 AV')
# [696] ('D005', 'R398', 'NEW UTRECHT AV')
# [694] ('R131', 'R190', '23 ST')
# [690] ('N401', 'R360', '21 ST')
# [689] ('R227A', 'R131', '23 ST')
# [689] ('B019', 'R149', 'NEWKIRK PLAZA')
# [688] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [687] ('R133', 'R272', '28 ST')
# [682] ('R525', 'R018', '74 ST-BROADWAY')
# [677] ('R219', 'R160', 'ASTOR PL')
# [676] ('N010', 'R126', '175 ST')
# [674] ('R624', 'R124', 'KINGSTON AV')
# [673] ('R628', 'R064', 'SARATOGA AV')
# [673] ('R170', 'R191', '103 ST')
# [671] ('R162', 'R166', '79 ST')
# [668] ('J020', 'R433', 'ALABAMA AV')
# [666] ('R510', 'R090', '39 AV')
# [657] ('R600', 'R224', 'CLARK ST')
# [654] ('N408A', 'R256', 'NASSAU AV')
# [654] ('H039', 'R375', 'NEW LOTS')
# [652] ('N409', 'R268', 'METROPOLITAN AV')
# [652] ('N039', 'R251', '96 ST')
# [652] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [649] ('A038', 'R085', '8 ST-NYU')
# [647] ('N529', 'R257', 'EAST BROADWAY')
# [646] ('N019', 'R101', '145 ST')
# [645] ('N141', 'R356', 'OZONE PK LEFFRT')
# [643] ('R504', 'R276', 'VERNON-JACKSON')
# [641] ('R323', 'R387', 'WEST FARMS SQ')
# [637] ('R215', 'R322', 'SPRING ST')
# [634] ('R606', 'R225', 'HOYT ST')
# [634] ('B012', 'R196', 'PROSPECT PARK')
# [629] ('A066', 'R118', 'CANAL ST')
# [628] ('R118', 'R343', 'FRANKLIN ST')
# [621] ('H040', 'R376', 'EAST 105 ST')
# [619] ('R623', 'R061', 'NOSTRAND AV')
# [618] ('N531', 'R129', 'BERGEN ST')
# [618] ('N343', 'R019', 'JAMAICA 179 ST')
# [615] ('R625', 'R062', 'CROWN HTS-UTICA')
# [612] ('B021', 'R228', 'AVENUE J')
# [609] ('H017', 'R265', 'MONTROSE AV')
# [598] ('R415', 'R120', 'MORISN AV/SNDVW')
# [591] ('R129', 'R321', '18 ST')
# [589] ('R403', 'R446', 'BROOK AV')
# [588] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [587] ('J009', 'R378', 'MYRTLE AV')
# [585] ('R286', 'R309', '176 ST')
# [584] ('R414', 'R162', 'ELDER AV')
# [583] ('R163', 'R166', '79 ST')
# [577] ('R524', 'R347', '69 ST')
# [574] ('R325', 'R388', 'E 180 ST')
# [571] ('H015', 'R250', 'GRAND ST')
# [568] ('G001', 'R151', 'CONEY IS-STILLW')
# [567] ('R139', 'R031', '34 ST-PENN STA')
# [557] ('N128', 'R200', 'EUCLID AV')
# [555] ('N024', 'R332', '135 ST')
# [551] ('R259', 'R307', '138/GRAND CONC')
# [537] ('R186', 'R036', 'DYCKMAN ST')
# [535] ('N111', 'R284', 'CLINTON-WASH AV')
# [532] ('R532', 'R328', 'METS-WILLETS PT')
# [531] ('N340', 'R115', '169 ST')
# [531] ('C021', 'R212', '59 ST')
# [524] ('R309', 'R345', 'HARLEM 148 ST')
# [522] ('R293', 'R133', 'MOSHOLU PKWY')
# [518] ('R123', 'R290', 'HOUSTON ST')
# [513] ('N207', 'R104', '167 ST')
# [512] ('C017', 'R455', '25 ST')
# [511] ('E001', 'R368', '9 AV')
# [510] ('R203A', 'R043', 'WALL ST')
# [510] ('B013', 'R196', 'PROSPECT PARK')
# [505] ('R316', 'R407', 'INTERVALE AV')
# [504] ('H023', 'R236', 'DEKALB AV')
# [502] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [494] ('R321', 'R386', '174 ST')
# [493] ('N118', 'R199', 'KINGSTON-THROOP')
# [490] ('N412', 'R299', 'BROADWAY')
# [489] ('R188', 'R037', '207 ST')
# [488] ('C011', 'R231', 'UNION ST')
# [487] ('R176', 'R169', '137 ST CITY COL')
# [485] ('R521', 'R327', '52 ST')
# [482] ('N114', 'R297', 'FRANKLIN AV')
# [478] ('R411', 'R450', 'LONGWOOD AV')
# [478] ('R197', 'R117', 'V.CORTLANDT PK')
# [477] ('N314', 'R238', 'STEINWAY ST')
# [470] ('N331', 'R219', '67 AV')
# [469] ('D010', 'R394', 'BAY PKWY')
# [467] ('N340A', 'R115', '169 ST')
# [467] ('E014', 'R374', 'BAY PKWY')
# [465] ('B010', 'R412', 'BOTANIC GARDEN')
# [458] ('R257', 'R182', '116 ST')
# [455] ('N129', 'R382', 'GRANT AV')
# [444] ('B023', 'R211', 'KINGS HWY')
# [442] ('R288', 'R275', '183 ST')
# [441] ('R226A', 'R131', '23 ST')
# [441] ('N222', 'R156', 'BEDFORD PK BLVD')
# [436] ('N030', 'R333', '116 ST')
# [430] ('R319', 'R409', 'FREEMAN ST')
# [430] ('N120A', 'R153', 'UTICA AV')
# [427] ('R125', 'R189', 'CHRISTOPHER ST')
# [420] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [420] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [420] ('B015', 'R098', 'CHURCH AV')
# [419] ('R409', 'R449', 'E 149 ST')
# [417] ('R305', 'R206', '125 ST')
# [416] ('E003', 'R369', 'FT HAMILTON PKY')
# [415] ('R172', 'R192', 'CATHEDRAL PKWY')
# [415] ('C001', 'R108', 'BOROUGH HALL')
# [412] ('N414', 'R316', 'FLUSHING AV')
# [410] ('R416', 'R245', 'ST LAWRENCE AV')
# [408] ('R405', 'R447', 'CYPRESS AV')
# [407] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [405] ('N319', 'R298', 'NORTHERN BLVD')
# [403] ('B020', 'R263', 'AVENUE H')
# [402] ('R419', 'R326', 'ZEREGA AV')
# [399] ('N333A', 'R141', 'FOREST HILLS 71')
# [393] ('J024', 'R437', 'CRESCENT ST')
# [387] ('N342', 'R019', 'JAMAICA 179 ST')
# [386] ('R178', 'R273', '145 ST')
# [385] ('N318', 'R298', 'NORTHERN BLVD')
# [385] ('N035', 'R334', 'CATHEDRAL PKWY')
# [384] ('N122', 'R439', 'ROCKAWAY AV')
# [379] ('R632', 'R067', 'PENNSYLVANIA AV')
# [377] ('N532', 'R129', 'BERGEN ST')
# [377] ('N023', 'R332', '135 ST')
# [376] ('R289', 'R119', 'FORDHAM RD')
# [372] ('N075', 'R111', '23 ST')
# [367] ('N045', 'R187', '81 ST-MUSEUM')
# [366] ('R166', 'R167', '86 ST')
# [365] ('H032', 'R295', 'WILSON AV')
# [364] ('R408', 'R449', 'E 149 ST')
# [361] ('R303', 'R324', '116 ST')
# [360] ('A071', 'R044', 'CHAMBERS ST')
# [359] ('J028', 'R004', '75 ST-ELDERTS')
# [358] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [357] ('N037', 'R314', '103 ST')
# [357] ('B014', 'R148', 'PARKSIDE AV')
# [356] ('R636', 'R209', 'STERLING ST')
# [356] ('E011', 'R371', '79 ST')
# [354] ('N224', 'R157', 'NORWOOD 205 ST')
# [348] ('N112A', 'R284', 'CLINTON-WASH AV')
# [346] ('R644', 'R135', 'NEWKIRK AV')
# [345] ('R179', 'R193', '157 ST')
# [345] ('C024', 'R214', '77 ST')
# [342] ('N087', 'R282', 'SPRING ST')
# [342] ('N009', 'R174', '181 ST')
# [341] ('N191', 'R335', 'BEACH 67 ST')
# [339] ('R302', 'R324', '116 ST')
# [339] ('N557', 'R130', 'KINGS HWY')
# [339] ('K026', 'R100', 'METROPOLITAN AV')
# [338] ('N220', 'R155', 'KINGSBRIDGE RD')
# [336] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [334] ('E005', 'R247', '55 ST')
# [328] ('N034', 'R334', 'CATHEDRAL PKWY')
# [325] ('R727', 'R430', 'PELHAM PKWY')
# [323] ('R633', 'R068', 'VAN SICLEN AV')
# [322] ('B009', 'R411', 'PARK PLACE')
# [320] ('R328', 'R361', 'PELHAM PKWY')
# [320] ('K025', 'R404', 'FRESH POND RD')
# [317] ('R119', 'R320', 'CANAL ST')
# [316] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [316] ('D003', 'R391', 'FT HAMILTON PKY')
# [315] ('R306', 'R207', '135 ST')
# [314] ('H038', 'R350', 'LIVONIA AV')
# [312] ('R227', 'R131', '23 ST')
# [312] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [308] ('N556', 'R424', 'AVENUE P')
# [307] ('B032', 'R264', 'OCEAN PKWY')
# [305] ('N551', 'R421', 'AVENUE I')
# [305] ('N414A', 'R316', 'FLUSHING AV')
# [299] ('N006A', 'R280', '190 ST')
# [299] ('K019', 'R413', 'KNICKERBOCKER')
# [298] ('J035', 'R008', '111 ST')
# [295] ('N555', 'R423', 'AVENUE N')
# [295] ('K017', 'R401', 'CENTRAL AV')
# [294] ('R637', 'R451', 'WINTHROP ST')
# [294] ('N221', 'R155', 'KINGSBRIDGE RD')
# [294] ('N121B', 'R438', 'RALPH AV')
# [294] ('H022', 'R279', 'JEFFERSON ST')
# [293] ('J031', 'R006', 'WOODHAVEN BLVD')
# [291] ('C010', 'R231', 'UNION ST')
# [289] ('H037', 'R349', 'SUTTER AV')
# [288] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [288] ('N113', 'R297', 'FRANKLIN AV')
# [288] ('J005', 'R353', 'LORIMER ST')
# [288] ('B018', 'R184', 'CORTELYOU RD')
# [287] ('R404', 'R447', 'CYPRESS AV')
# [286] ('N561', 'R271', 'AVENUE X')
# [285] ('N209', 'R443', '170 ST')
# [285] ('J023', 'R436', 'NORWOOD AV')
# [284] ('R402', 'R446', 'BROOK AV')
# [284] ('N338B', 'R128', 'SUTPHIN BLVD')
# [284] ('N119', 'R199', 'KINGSTON-THROOP')
# [283] ('N325A', 'R218', 'ELMHURST AV')
# [281] ('R180', 'R193', '157 ST')
# [279] ('R618', 'R058', 'BERGEN ST')
# [277] ('R413', 'R325', 'WHITLOCK AV')
# [272] ('R307', 'R207', '135 ST')
# [272] ('C016', 'R278', '25 ST')
# [270] ('D012', 'R395', 'KINGS HWY')
# [270] ('B025', 'R150', 'AVENUE U')
# [266] ('R421', 'R427', 'MIDDLETOWN RD')
# [266] ('N125', 'R440', 'LIBERTY AV')
# [265] ('R407', 'R448', "E 143/ST MARY'S")
# [264] ('E016', 'R400', 'BAY 50 ST')
# [263] ('N007A', 'R174', '181 ST')
# [258] ('N195', 'R358', 'BEACH 25 ST')
# [257] ('N559', 'R425', 'AVENUE U')
# [257] ('N110', 'R283', 'LAFAYETTE AV')
# [257] ('H030', 'R266', 'HALSEY ST')
# [256] ('N311', 'R339', '36 ST')
# [255] ('J013', 'R380', 'GATES AV')
# [253] ('J022', 'R435', 'CLEVELAND ST')
# [250] ('B017', 'R262', 'BEVERLEY ROAD')
# [249] ('R639', 'R109', 'CHURCH AV')
# [247] ('J012', 'R379', 'KOSCIUSZKO ST')
# [246] ('N333', 'R141', 'FOREST HILLS 71')
# [245] ('N126', 'R441', 'VAN SICLEN AVE')
# [245] ('J021', 'R434', 'VAN SICLEN AV')
# [243] ('R294', 'R052', 'WOODLAWN')
# [239] ('N337', 'R255', 'BRIARWOOD')
# [238] ('N202', 'R315', '155 ST')
# [234] ('N215', 'R237', '182-183 STS')
# [233] ('J016', 'R381', 'HALSEY ST')
# [225] ('R410', 'R450', 'LONGWOOD AV')
# [220] ('A055', 'R227', 'RECTOR ST')
# [218] ('E012', 'R372', '18 AV')
# [216] ('R329', 'R362', 'ALLERTON AV')
# [216] ('R117', 'R343', 'FRANKLIN ST')
# [212] ('R617', 'R058', 'BERGEN ST')
# [212] ('R327', 'R361', 'PELHAM PKWY')
# [212] ('R326', 'R389', 'BRONX PARK EAST')
# [212] ('N316', 'R267', '46 ST')
# [208] ('N192', 'R336', 'BEACH 60 ST')
# [207] ('N548', 'R420', 'DITMAS AV')
# [203] ('N534', 'R220', 'CARROLL ST')
# [202] ('R422', 'R428', 'BUHRE AV')
# [200] ('R728', 'R226', 'GUN HILL RD')
# [200] ('N225', 'R157', 'NORWOOD 205 ST')
# [199] ('H013', 'R249', 'GRAHAM AV')
# [196] ('N212', 'R253', '174-175 STS')
# [194] ('N001', 'R173', 'INWOOD-207 ST')
# [193] ('R333', 'R366', '225 ST')
# [193] ('R121', 'R290', 'HOUSTON ST')
# [192] ('N134', 'R385', 'ROCKAWAY BLVD')
# [192] ('D015', 'R396', 'AVENUE U')
# [189] ('N017', 'R331', '155 ST')
# [188] ('E009', 'R370', '71 ST')
# [186] ('R260', 'R205', '149/GRAND CONC')
# [186] ('R122', 'R290', 'HOUSTON ST')
# [185] ('H035', 'R348', 'ATLANTIC AV')
# [182] ('N322', 'R340', '65 ST')
# [182] ('N012', 'R035', '168 ST')
# [181] ('R194', 'R040', '231 ST')
# [180] ('R312', 'R405', 'JACKSON AV')
# [180] ('N553', 'R422', 'BAY PKWY')
# [179] ('N127', 'R442', 'SHEPHERD AV')
# [177] ('N206', 'R104', '167 ST')
# [176] ('N002A', 'R173', 'INWOOD-207 ST')
# [175] ('H028', 'R266', 'HALSEY ST')
# [174] ('R190', 'R038', '215 ST')
# [174] ('N011', 'R126', '175 ST')
# [172] ('R315', 'R406', 'PROSPECT AV')
# [169] ('J030', 'R005', '85 ST-FOREST PK')
# [168] ('E013', 'R373', '20 AV')
# [167] ('N332', 'R219', '67 AV')
# [166] ('R192', 'R039', 'MARBLE HILL-225')
# [164] ('R334', 'R367', '233 ST')
# [156] ('J003', 'R352', 'HEWES ST')
# [155] ('K024', 'R403', 'FOREST AVE')
# [152] ('R335', 'R444', 'NEREID AV')
# [152] ('N210', 'R253', '174-175 STS')
# [152] ('C022', 'R212', '59 ST')
# [150] ('N208', 'R443', '170 ST')
# [148] ('N562', 'R426', 'NEPTUNE AV')
# [143] ('A082', 'R028', 'FULTON ST')
# [142] ('R726', 'R329', 'MORRIS PARK')
# [142] ('C004', 'R089', 'JAY ST-METROTEC')
# [139] ('N194', 'R338', 'BEACH 36 ST')
# [139] ('N187', 'R419', 'ROCKAWAY PARK B')
# [138] ('H012', 'R268', 'LORIMER ST')
# [136] ('J017', 'R432', 'CHAUNCEY ST')
# [135] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [127] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [124] ('N543', 'R289', 'FT HAMILTON PKY')
# [123] ('N185', 'R417', 'BEACH 98 ST')
# [122] ('R314', 'R406', 'PROSPECT AV')
# [118] ('H033', 'R313', 'BUSHWICK AV')
# [117] ('K022', 'R402', 'SENECA AVE')
# [115] ('R406', 'R448', "E 143/ST MARY'S")
# [114] ('R318', 'R408', 'SIMPSON ST')
# [112] ('R332', 'R365', '219 ST')
# [112] ('R317', 'R408', 'SIMPSON ST')
# [109] ('J025', 'R003', 'CYPRESS HILLS')
# [109] ('D016', 'R397', '86 ST')
# [106] ('R330', 'R363', 'BURKE AV')
# [106] ('N317', 'R267', '46 ST')
# [104] ('B026', 'R230', 'NECK RD')
# [103] ('N330C', 'R202', '63 DR-REGO PARK')
# [102] ('B034', 'R264', 'OCEAN PKWY')
# [97] ('N545', 'R204', 'CHURCH AV')
# [96] ('R641', 'R210', 'BEVERLY RD')
# [96] ('R520', 'R223', '46 ST BLISS ST')
# [96] ('N016A', 'R296', '163 ST-AMSTERDM')
# [95] ('N533', 'R129', 'BERGEN ST')
# [91] ('N193', 'R337', 'BEACH 44 ST')
# [89] ('N181', 'R357', 'AQUEDUCT N.COND')
# [89] ('N135', 'R385', 'ROCKAWAY BLVD')
# [87] ('E015', 'R399', '25 AV')
# [84] ('R322', 'R386', '174 ST')
# [73] ('N334B', 'R341', '75 AV')
# [71] ('R320', 'R409', 'FREEMAN ST')
# [68] ('N137', 'R354', '104 ST')
# [65] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [65] ('N131', 'R383', '80 ST')
# [64] ('R729', 'R292', 'BAYCHESTER AV')
# [62] ('N420B', 'R317', 'CLINTON-WASH AV')
# [62] ('N218', 'R112', 'FORDHAM RD')
# [52] ('C026', 'R215', '86 ST')
# [50] ('N558', 'R130', 'KINGS HWY')
# [50] ('N182', 'R414', 'HOWARD BCH JFK')
# [49] ('N184', 'R416', 'BEACH 90 ST')
# [48] ('N133', 'R384', '88 ST')
# [45] ('R308', 'R344', '145 ST')
# [45] ('J032', 'R006', 'WOODHAVEN BLVD')
# [44] ('R643', 'R135', 'NEWKIRK AV')
# [42] ('N339', 'R114', 'PARSONS BLVD')
# [40] ('N186', 'R418', 'BEACH 105 ST')
# [38] ('N547', 'R420', 'DITMAS AV')
# [38] ('N544', 'R289', 'FT HAMILTON PKY')
# [37] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [36] ('J037', 'R009', '121 ST')
# [36] ('D009', 'R393', '20 AV')
# [34] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [34] ('D008', 'R392', '18 AV')
# [32] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [28] ('N338', 'R128', 'SUTPHIN BLVD')
# [28] ('N130', 'R383', '80 ST')
# [27] ('N139', 'R355', '111 ST')
# [23] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [23] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [22] ('N003', 'R185', 'DYCKMAN ST')
# [21] ('R506', 'R276', 'VERNON-JACKSON')
# [16] ('N183', 'R415', 'BROAD CHANNEL')
# [15] ('J034', 'R007', '104 ST')
# [12] ('N022', 'R332', '135 ST')
# [10] ('R196', 'R306', '238 ST')
# [8] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [7] ('N123B', 'R439', 'ROCKAWAY AV')
# [6] ('R532H', 'R328', 'METS-WILLETS PT')
# [5] ('N223', 'R156', 'BEDFORD PK BLVD')
# [5] ('A084', 'R125', 'BROAD ST')
# [4] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [2] ('N138', 'R355', '111 ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# 0 ('A085', 'R125', 'BROAD ST')
# [-18] ('N029', 'R333', '116 ST')
# [-1189] ('R241A', 'R048', 'GRD CNTRL-42 ST')

# %% [markdown]
# 23.We notice that the ('R204', 'R043', 'WALL ST') stop is pretty high on the Monday morning list. How can we tell if this exit is more of a commuter or tourist exit? Maybe we'll see if the total number of people is higher on a weekday than a weekend. Go back to the original df dataframe. Save only the items that contain ('R204', 'R043', 'WALL ST') to a dataframe called wallstreet and create a list of tuples where the first entry is the date and the second entry is the total ridership.
#
# Hint: there should be 9936 riders on 06/15/2017.

# %%
wallstreet = MTA[(MTA["C/A"]=="R204")&(MTA.UNIT == "R043")&(MTA.STATION=="WALL ST")]
wallstreet = wallstreet.reset_index(drop=True)
wall_dict = {}
for i in range(len(wallstreet)):
    mytuple = wallstreet.DATE[i]
    if mytuple not in wall_dict:
        wall_dict[mytuple]={wallstreet.SCP[i]:{wallstreet.TIME[i]:wallstreet.EXITS[i]}}
    if wallstreet.SCP[i] not in wall_dict[mytuple]:
        wall_dict[mytuple][wallstreet.SCP[i]]={wallstreet.TIME[i]:wallstreet.EXITS[i]}
    else:
        wall_dict[mytuple][wallstreet.SCP[i]][wallstreet.TIME[i]]= wallstreet.EXITS[i]
print(wall_dict['06/12/2017'])

wall_exits = {}
for date,turnstiles in wall_dict.items():
    for turnstile,time in turnstiles.items():
        for i,exit in enumerate(time.values()):
            if i == 0:
                begin = exit
            if i==len(time.values())-1:
                end = exit
        if date not in wall_exits:
            wall_exits[date]={turnstile:(end-begin)}
        else: 
            wall_exits[date][turnstile]=end-begin
print(wall_dict['06/12/2017'])

tuple_list = []
for date, turnstiles in wall_exits.items():
    count=0
    for exits in turnstiles.values():
        count+=exits
    tuple_list.append((date,count))
tuple_list.sort()
tuple_list
# Out:
# {'02-00-00': {'02:00:00': 4077482, '06:00:00': 4077513, '10:00:00': 4078185, '14:00:00': 4078445, '18:00:00': 4078695, '22:00:00': 4078870}, '02-00-01': {'02:00:00': 3793526, '06:00:00': 3793561, '10:00:00': 3794179, '14:00:00': 3794350, '18:00:00': 3794538, '22:00:00': 3794706}, '02-03-00': {'02:00:00': 3128134, '06:00:00': 3128148, '10:00:00': 3129230, '14:00:00': 3129631, '18:00:00': 3129962, '22:00:00': 3130137}, '02-03-01': {'02:00:00': 817631, '06:00:00': 817635, '10:00:00': 818066, '14:00:00': 818204, '18:00:00': 818305, '22:00:00': 818358}, '02-03-02': {'02:00:00': 439118, '06:00:00': 439120, '10:00:00': 439474, '14:00:00': 439570, '18:00:00': 439641, '22:00:00': 439685}, '02-03-03': {'02:00:00': 877221, '06:00:00': 877225, '10:00:00': 877650, '14:00:00': 877819, '18:00:00': 877932, '22:00:00': 878003}, '02-05-00': {'02:00:00': 751942, '06:00:00': 751954, '10:00:00': 752377, '14:00:00': 752605, '18:00:00': 752819, '22:00:00': 752985}, '02-05-01': {'02:00:00': 235226335, '06:00:00': 235226344, '10:00:00': 235226521, '14:00:00': 235226601, '18:00:00': 235226662, '22:00:00': 235226707}, '02-06-00': {'02:00:00': 17929050, '06:00:00': 17929067, '10:00:00': 17929453, '14:00:00': 17929734, '18:00:00': 17930015, '22:00:00': 17930185}, '02-06-01': {'02:00:00': 252878, '06:00:00': 252881, '10:00:00': 252948, '14:00:00': 252977, '18:00:00': 253046, '22:00:00': 253078}}
# {'02-00-00': {'02:00:00': 4077482, '06:00:00': 4077513, '10:00:00': 4078185, '14:00:00': 4078445, '18:00:00': 4078695, '22:00:00': 4078870}, '02-00-01': {'02:00:00': 3793526, '06:00:00': 3793561, '10:00:00': 3794179, '14:00:00': 3794350, '18:00:00': 3794538, '22:00:00': 3794706}, '02-03-00': {'02:00:00': 3128134, '06:00:00': 3128148, '10:00:00': 3129230, '14:00:00': 3129631, '18:00:00': 3129962, '22:00:00': 3130137}, '02-03-01': {'02:00:00': 817631, '06:00:00': 817635, '10:00:00': 818066, '14:00:00': 818204, '18:00:00': 818305, '22:00:00': 818358}, '02-03-02': {'02:00:00': 439118, '06:00:00': 439120, '10:00:00': 439474, '14:00:00': 439570, '18:00:00': 439641, '22:00:00': 439685}, '02-03-03': {'02:00:00': 877221, '06:00:00': 877225, '10:00:00': 877650, '14:00:00': 877819, '18:00:00': 877932, '22:00:00': 878003}, '02-05-00': {'02:00:00': 751942, '06:00:00': 751954, '10:00:00': 752377, '14:00:00': 752605, '18:00:00': 752819, '22:00:00': 752985}, '02-05-01': {'02:00:00': 235226335, '06:00:00': 235226344, '10:00:00': 235226521, '14:00:00': 235226601, '18:00:00': 235226662, '22:00:00': 235226707}, '02-06-00': {'02:00:00': 17929050, '06:00:00': 17929067, '10:00:00': 17929453, '14:00:00': 17929734, '18:00:00': 17930015, '22:00:00': 17930185}, '02-06-01': {'02:00:00': 252878, '06:00:00': 252881, '10:00:00': 252948, '14:00:00': 252977, '18:00:00': 253046, '22:00:00': 253078}}
# [('06/10/2017', 11),
#  ('06/11/2017', 1745),
#  ('06/12/2017', 9397),
#  ('06/13/2017', 9730),
#  ('06/14/2017', 9501),
#  ('06/15/2017', 9936),
#  ('06/16/2017', 8778)]

# %% [markdown]
# 24.Plot the list of tuples you made where date is the x-axis and ridership is the y-axis for this wall street station.
#
# Hint: you'll first need to use datetime to convert the dates to datetime format.

# %%
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

realdatelist = []
ridershiplist = []

for date,ridership in tuple_list:
    realdate = datetime.strptime(date,"%m/%d/%Y")
    realdatelist.append(realdate)
    ridershiplist.append(ridership)

x = [realdatelist[i] for i in range(len(realdatelist))]
y=[ridershiplist[i] for i in range(len(ridershiplist))]
plt.bar(x,y)
plt.xlabel('Date')
plt.ylabel('Riders');

# %% [markdown]
# 25.Now use datetime to convert the dates to "Mon", "Tues", etc and print the days of the week with corresponding ridership. Is this a commuter stop or a tourist stop?

# %%
for date,riders in tuple_list:
    date1 = datetime.strptime(date,"%m/%d/%Y")
    print(date1.strftime("%a"),riders)
#commuter since number of riders is higher on weekdays than weekends
# Out:
# Sat 11
# Sun 1745
# Mon 9397
# Tue 9730
# Wed 9501
# Thu 9936
# Fri 8778

# %%
monday_morning = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    tuples.append(mytuple)
tuples.sort(reverse=True)
for key,value in tuples:
    print(key,value)
# Out:
# [17300] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [17300] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [16250] ('N500', 'R020', '47-50 STS ROCK')
# [16250] ('N500', 'R020', '47-50 STS ROCK')
# [13194] ('N501', 'R020', '47-50 STS ROCK')
# [13194] ('N501', 'R020', '47-50 STS ROCK')
# [12576] ('N306', 'R017', 'LEXINGTON AV/53')
# [12576] ('N306', 'R017', 'LEXINGTON AV/53')
# [12545] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [12545] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [10593] ('N504', 'R021', '42 ST-BRYANT PK')
# [10593] ('N504', 'R021', '42 ST-BRYANT PK')
# [10213] ('A025', 'R023', '34 ST-HERALD SQ')
# [10213] ('A025', 'R023', '34 ST-HERALD SQ')
# [9605] ('N304', 'R015', '5 AV/53 ST')
# [9605] ('N304', 'R015', '5 AV/53 ST')
# [9393] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9393] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9234] ('N505', 'R022', '34 ST-HERALD SQ')
# [9234] ('N505', 'R022', '34 ST-HERALD SQ')
# [8903] ('R249', 'R179', '86 ST')
# [8903] ('R249', 'R179', '86 ST')
# [8893] ('N051', 'R084', '59 ST COLUMBUS')
# [8893] ('N051', 'R084', '59 ST COLUMBUS')
# [8049] ('R116', 'R030', 'CHAMBERS ST')
# [8049] ('R116', 'R030', 'CHAMBERS ST')
# [7708] ('N049', 'R084', '59 ST COLUMBUS')
# [7708] ('N049', 'R084', '59 ST COLUMBUS')
# [7641] ('N303', 'R015', '5 AV/53 ST')
# [7641] ('N303', 'R015', '5 AV/53 ST')
# [7423] ('N305', 'R017', 'LEXINGTON AV/53')
# [7423] ('N305', 'R017', 'LEXINGTON AV/53')
# [7155] ('N507', 'R023', '34 ST-HERALD SQ')
# [7155] ('N507', 'R023', '34 ST-HERALD SQ')
# [6820] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6820] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6776] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6776] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6531] ('N506', 'R022', '34 ST-HERALD SQ')
# [6531] ('N506', 'R022', '34 ST-HERALD SQ')
# [6373] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6373] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6360] ('N098', 'R028', 'FULTON ST')
# [6360] ('N098', 'R028', 'FULTON ST')
# [6251] ('N503', 'R021', '42 ST-BRYANT PK')
# [6251] ('N503', 'R021', '42 ST-BRYANT PK')
# [6194] ('N501A', 'R020', '47-50 STS ROCK')
# [6194] ('N501A', 'R020', '47-50 STS ROCK')
# [6187] ('R155', 'R116', '50 ST')
# [6187] ('R155', 'R116', '50 ST')
# [5974] ('R243', 'R049', '51 ST')
# [5974] ('R243', 'R049', '51 ST')
# [5929] ('N520', 'R240', 'GRAND ST')
# [5929] ('N520', 'R240', 'GRAND ST')
# [5856] ('R245A', 'R051', '59 ST')
# [5856] ('R245A', 'R051', '59 ST')
# [5727] ('R206', 'R014', 'FULTON ST')
# [5727] ('R206', 'R014', 'FULTON ST')
# [5708] ('R202', 'R042', 'BOWLING GREEN')
# [5708] ('R202', 'R042', 'BOWLING GREEN')
# [5696] ('R258', 'R132', '125 ST')
# [5696] ('R258', 'R132', '125 ST')
# [5512] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [5512] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [5392] ('R182', 'R035', '168 ST')
# [5392] ('R182', 'R035', '168 ST')
# [5309] ('R246', 'R177', '68ST-HUNTER CO')
# [5309] ('R246', 'R177', '68ST-HUNTER CO')
# [5046] ('A033', 'R170', '14 ST-UNION SQ')
# [5046] ('A033', 'R170', '14 ST-UNION SQ')
# [5020] ('N509', 'R203', '23 ST')
# [5020] ('N509', 'R203', '23 ST')
# [5009] ('R111', 'R027', 'WALL ST')
# [5009] ('R111', 'R027', 'WALL ST')
# [4932] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4932] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4864] ('R533', 'R055', 'FLUSHING-MAIN')
# [4864] ('R533', 'R055', 'FLUSHING-MAIN')
# [4847] ('N092', 'R029', 'CHAMBERS ST')
# [4847] ('N092', 'R029', 'CHAMBERS ST')
# [4754] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4754] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4751] ('N508', 'R453', '23 ST')
# [4751] ('N508', 'R453', '23 ST')
# [4658] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4658] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4650] ('R201', 'R041', 'BOWLING GREEN')
# [4650] ('R201', 'R041', 'BOWLING GREEN')
# [4635] ('R204', 'R043', 'WALL ST')
# [4635] ('R204', 'R043', 'WALL ST')
# [4617] ('R154', 'R116', '50 ST')
# [4617] ('R154', 'R116', '50 ST')
# [4571] ('R113', 'R028', 'FULTON ST')
# [4571] ('R113', 'R028', 'FULTON ST')
# [4544] ('A022', 'R022', '34 ST-HERALD SQ')
# [4544] ('A022', 'R022', '34 ST-HERALD SQ')
# [4440] ('R244', 'R050', '59 ST')
# [4440] ('R244', 'R050', '59 ST')
# [4376] ('N102', 'R127', 'JAY ST-METROTEC')
# [4376] ('N102', 'R127', 'JAY ST-METROTEC')
# [4346] ('R221', 'R170', '14 ST-UNION SQ')
# [4346] ('R221', 'R170', '14 ST-UNION SQ')
# [4336] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [4336] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [4324] ('R247', 'R178', '77 ST')
# [4324] ('R247', 'R178', '77 ST')
# [4312] ('H009', 'R235', 'BEDFORD AV')
# [4312] ('H009', 'R235', 'BEDFORD AV')
# [4305] ('R550', 'R072', '34 ST-HUDSON YD')
# [4305] ('R550', 'R072', '34 ST-HUDSON YD')
# [4305] ('N089', 'R139', 'CANAL ST')
# [4305] ('N089', 'R139', 'CANAL ST')
# [4266] ('A034', 'R170', '14 ST-UNION SQ')
# [4266] ('A034', 'R170', '14 ST-UNION SQ')
# [4171] ('N601', 'R319', 'LEXINGTON AV/63')
# [4171] ('N601', 'R319', 'LEXINGTON AV/63')
# [4108] ('R244A', 'R050', '59 ST')
# [4108] ('R244A', 'R050', '59 ST')
# [4094] ('N600', 'R302', '57 ST')
# [4094] ('N600', 'R302', '57 ST')
# [3965] ('N606', 'R025', 'JAMAICA CENTER')
# [3965] ('N606', 'R025', 'JAMAICA CENTER')
# [3875] ('N067', 'R012', '34 ST-PENN STA')
# [3875] ('N067', 'R012', '34 ST-PENN STA')
# [3862] ('N301', 'R113', '7 AV')
# [3862] ('N301', 'R113', '7 AV')
# [3853] ('R110', 'R027', 'WALL ST')
# [3853] ('R110', 'R027', 'WALL ST')
# [3841] ('N103', 'R127', 'JAY ST-METROTEC')
# [3841] ('N103', 'R127', 'JAY ST-METROTEC')
# [3775] ('R501', 'R054', '5 AVE')
# [3775] ('R501', 'R054', '5 AVE')
# [3765] ('R601A', 'R108', 'BOROUGH HALL')
# [3765] ('R601A', 'R108', 'BOROUGH HALL')
# [3747] ('R142', 'R293', '34 ST-PENN STA')
# [3747] ('R142', 'R293', '34 ST-PENN STA')
# [3721] ('N091', 'R029', 'CHAMBERS ST')
# [3721] ('N091', 'R029', 'CHAMBERS ST')
# [3628] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3628] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3611] ('N094', 'R029', 'WORLD TRADE CTR')
# [3611] ('N094', 'R029', 'WORLD TRADE CTR')
# [3580] ('N502', 'R021', '42 ST-BRYANT PK')
# [3580] ('N502', 'R021', '42 ST-BRYANT PK')
# [3575] ('N700A', 'R570', '72 ST-2 AVE')
# [3575] ('N700A', 'R570', '72 ST-2 AVE')
# [3555] ('N026', 'R102', '125 ST')
# [3555] ('N026', 'R102', '125 ST')
# [3499] ('R158', 'R084', '59 ST COLUMBUS')
# [3499] ('R158', 'R084', '59 ST COLUMBUS')
# [3495] ('N095A', 'R014', 'FULTON ST')
# [3495] ('N095A', 'R014', 'FULTON ST')
# [3481] ('N060', 'R010', '42 ST-PORT AUTH')
# [3481] ('N060', 'R010', '42 ST-PORT AUTH')
# [3446] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3446] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3410] ('R169', 'R168', '96 ST')
# [3410] ('R169', 'R168', '96 ST')
# [3382] ('R516', 'R291', '33 ST-RAWSON ST')
# [3382] ('R516', 'R291', '33 ST-RAWSON ST')
# [3378] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3378] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3347] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3347] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3343] ('R112', 'R027', 'WALL ST')
# [3343] ('R112', 'R027', 'WALL ST')
# [3340] ('R200A', 'R041', 'BOWLING GREEN')
# [3340] ('R200A', 'R041', 'BOWLING GREEN')
# [3315] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3315] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3307] ('A006', 'R079', '5 AV/59 ST')
# [3307] ('A006', 'R079', '5 AV/59 ST')
# [3302] ('R242', 'R049', '51 ST')
# [3302] ('R242', 'R049', '51 ST')
# [3285] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3285] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3270] ('N400A', 'R359', 'COURT SQ')
# [3270] ('N400A', 'R359', 'COURT SQ')
# [3210] ('N700', 'R570', '72 ST-2 AVE')
# [3210] ('N700', 'R570', '72 ST-2 AVE')
# [3204] ('R526', 'R096', '82 ST-JACKSON H')
# [3204] ('R526', 'R096', '82 ST-JACKSON H')
# [3158] ('H008', 'R248', '1 AV')
# [3158] ('H008', 'R248', '1 AV')
# [3143] ('R228', 'R143', '28 ST')
# [3143] ('R228', 'R143', '28 ST')
# [3075] ('A042', 'R086', 'PRINCE ST')
# [3075] ('A042', 'R086', 'PRINCE ST')
# [3066] ('A029', 'R082', '28 ST')
# [3066] ('A029', 'R082', '28 ST')
# [3040] ('A031', 'R083', '23 ST')
# [3040] ('A031', 'R083', '23 ST')
# [3026] ('N090', 'R139', 'CANAL ST')
# [3026] ('N090', 'R139', 'CANAL ST')
# [3024] ('N601A', 'R319', 'LEXINGTON AV/63')
# [3024] ('N601A', 'R319', 'LEXINGTON AV/63')
# [3012] ('R161B', 'R452', '72 ST')
# [3012] ('R161B', 'R452', '72 ST')
# [2957] ('A015', 'R081', '49 ST')
# [2957] ('A015', 'R081', '49 ST')
# [2956] ('R216', 'R322', 'SPRING ST')
# [2956] ('R216', 'R322', 'SPRING ST')
# [2912] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [2912] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [2896] ('R602', 'R108', 'BOROUGH HALL')
# [2896] ('R602', 'R108', 'BOROUGH HALL')
# [2867] ('N078', 'R175', '14 ST')
# [2867] ('N078', 'R175', '14 ST')
# [2866] ('A035', 'R170', '14 ST-UNION SQ')
# [2866] ('A035', 'R170', '14 ST-UNION SQ')
# [2864] ('R112A', 'R027', 'WALL ST')
# [2864] ('R112A', 'R027', 'WALL ST')
# [2841] ('A046', 'R463', 'CANAL ST')
# [2841] ('A046', 'R463', 'CANAL ST')
# [2828] ('A030', 'R083', '23 ST')
# [2828] ('A030', 'R083', '23 ST')
# [2810] ('A043', 'R462', 'CANAL ST')
# [2810] ('A043', 'R462', 'CANAL ST')
# [2804] ('A002', 'R051', '59 ST')
# [2804] ('A002', 'R051', '59 ST')
# [2803] ('N071', 'R013', '34 ST-PENN STA')
# [2803] ('N071', 'R013', '34 ST-PENN STA')
# [2778] ('A010', 'R080', '57 ST-7 AV')
# [2778] ('A010', 'R080', '57 ST-7 AV')
# [2745] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2745] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2728] ('A049', 'R088', 'CORTLANDT ST')
# [2728] ('A049', 'R088', 'CORTLANDT ST')
# [2721] ('R101', 'R001', 'SOUTH FERRY')
# [2721] ('R101', 'R001', 'SOUTH FERRY')
# [2692] ('R226', 'R131', '23 ST')
# [2692] ('R226', 'R131', '23 ST')
# [2690] ('N108', 'R217', 'HOYT-SCHER')
# [2690] ('N108', 'R217', 'HOYT-SCHER')
# [2689] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2689] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2641] ('N095', 'R014', 'FULTON ST')
# [2641] ('N095', 'R014', 'FULTON ST')
# [2639] ('A013', 'R081', '49 ST')
# [2639] ('A013', 'R081', '49 ST')
# [2629] ('R138', 'R293', '34 ST-PENN STA')
# [2629] ('R138', 'R293', '34 ST-PENN STA')
# [2572] ('N020', 'R101', '145 ST')
# [2572] ('N020', 'R101', '145 ST')
# [2552] ('R159', 'R164', '66 ST-LINCOLN')
# [2552] ('R159', 'R164', '66 ST-LINCOLN')
# [2549] ('N300', 'R113', '7 AV')
# [2549] ('N300', 'R113', '7 AV')
# [2538] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2538] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2497] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2497] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2490] ('R248', 'R178', '77 ST')
# [2490] ('R248', 'R178', '77 ST')
# [2487] ('A081', 'R028', 'FULTON ST')
# [2487] ('A081', 'R028', 'FULTON ST')
# [2411] ('R141', 'R031', '34 ST-PENN STA')
# [2411] ('R141', 'R031', '34 ST-PENN STA')
# [2380] ('N070', 'R012', '34 ST-PENN STA')
# [2380] ('N070', 'R012', '34 ST-PENN STA')
# [2373] ('R232', 'R176', '33 ST')
# [2373] ('R232', 'R176', '33 ST')
# [2370] ('N076', 'R111', '23 ST')
# [2370] ('N076', 'R111', '23 ST')
# [2321] ('R114', 'R028', 'FULTON ST')
# [2321] ('R114', 'R028', 'FULTON ST')
# [2317] ('H001', 'R175', '8 AV')
# [2317] ('H001', 'R175', '8 AV')
# [2310] ('C008', 'R099', 'DEKALB AV')
# [2310] ('C008', 'R099', 'DEKALB AV')
# [2302] ('N068', 'R012', '34 ST-PENN STA')
# [2302] ('N068', 'R012', '34 ST-PENN STA')
# [2262] ('N512', 'R163', '14 ST')
# [2262] ('N512', 'R163', '14 ST')
# [2255] ('A039', 'R085', '8 ST-NYU')
# [2255] ('A039', 'R085', '8 ST-NYU')
# [2238] ('N056', 'R188', '50 ST')
# [2238] ('N056', 'R188', '50 ST')
# [2235] ('R203', 'R043', 'WALL ST')
# [2235] ('R203', 'R043', 'WALL ST')
# [2218] ('A060', 'R001', 'WHITEHALL S-FRY')
# [2218] ('A060', 'R001', 'WHITEHALL S-FRY')
# [2213] ('R252', 'R180', '103 ST')
# [2213] ('R252', 'R180', '103 ST')
# [2195] ('N309A', 'R140', 'QUEENS PLAZA')
# [2195] ('N309A', 'R140', 'QUEENS PLAZA')
# [2187] ('N046', 'R281', '72 ST')
# [2187] ('N046', 'R281', '72 ST')
# [2175] ('R168A', 'R168', '96 ST')
# [2175] ('R168A', 'R168', '96 ST')
# [2162] ('H007', 'R248', '1 AV')
# [2162] ('H007', 'R248', '1 AV')
# [2155] ('R242A', 'R049', '51 ST')
# [2155] ('R242A', 'R049', '51 ST')
# [2147] ('R507', 'R134', 'HUNTERS PT AV')
# [2147] ('R507', 'R134', 'HUNTERS PT AV')
# [2134] ('R534', 'R055', 'FLUSHING-MAIN')
# [2134] ('R534', 'R055', 'FLUSHING-MAIN')
# [2115] ('N073', 'R013', '34 ST-PENN STA')
# [2115] ('N073', 'R013', '34 ST-PENN STA')
# [2066] ('R183', 'R260', '181 ST')
# [2066] ('R183', 'R260', '181 ST')
# [2059] ('A027', 'R082', '28 ST')
# [2059] ('A027', 'R082', '28 ST')
# [2053] ('N069', 'R013', '34 ST-PENN STA')
# [2053] ('N069', 'R013', '34 ST-PENN STA')
# [2052] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2052] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2009] ('N510', 'R163', '14 ST')
# [2009] ('N510', 'R163', '14 ST')
# [2004] ('R102', 'R304', 'RECTOR ST')
# [2004] ('R102', 'R304', 'RECTOR ST')
# [1993] ('R137', 'R031', '34 ST-PENN STA')
# [1993] ('R137', 'R031', '34 ST-PENN STA')
# [1944] ('R229', 'R143', '28 ST')
# [1944] ('R229', 'R143', '28 ST')
# [1900] ('A058', 'R001', 'WHITEHALL S-FRY')
# [1900] ('A058', 'R001', 'WHITEHALL S-FRY')
# [1878] ('N077', 'R111', '23 ST')
# [1878] ('N077', 'R111', '23 ST')
# [1863] ('R132', 'R190', '23 ST')
# [1863] ('R132', 'R190', '23 ST')
# [1853] ('R127', 'R105', '14 ST')
# [1853] ('R127', 'R105', '14 ST')
# [1830] ('R523', 'R147', '61 ST WOODSIDE')
# [1830] ('R523', 'R147', '61 ST WOODSIDE')
# [1817] ('R208', 'R014', 'FULTON ST')
# [1817] ('R208', 'R014', 'FULTON ST')
# [1810] ('A011', 'R080', '57 ST-7 AV')
# [1810] ('A011', 'R080', '57 ST-7 AV')
# [1793] ('N523', 'R300', '2 AV')
# [1793] ('N523', 'R300', '2 AV')
# [1770] ('R508', 'R346', 'COURT SQ')
# [1770] ('R508', 'R346', 'COURT SQ')
# [1768] ('A069', 'R044', 'CHAMBERS ST')
# [1768] ('A069', 'R044', 'CHAMBERS ST')
# [1766] ('R173', 'R159', '116 ST-COLUMBIA')
# [1766] ('R173', 'R159', '116 ST-COLUMBIA')
# [1745] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1745] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1719] ('R165', 'R167', '86 ST')
# [1719] ('R165', 'R167', '86 ST')
# [1717] ('A047', 'R087', 'CITY HALL')
# [1717] ('A047', 'R087', 'CITY HALL')
# [1711] ('N072', 'R012', '34 ST-PENN STA')
# [1711] ('N072', 'R012', '34 ST-PENN STA')
# [1703] ('R124', 'R290', 'HOUSTON ST')
# [1703] ('R124', 'R290', 'HOUSTON ST')
# [1682] ('R528', 'R097', 'JUNCTION BLVD')
# [1682] ('R528', 'R097', 'JUNCTION BLVD')
# [1679] ('R261', 'R205', '149/GRAND CONC')
# [1679] ('R261', 'R205', '149/GRAND CONC')
# [1661] ('R605', 'R456', 'HOYT ST')
# [1661] ('R605', 'R456', 'HOYT ST')
# [1633] ('R220', 'R160', 'ASTOR PL')
# [1633] ('R220', 'R160', 'ASTOR PL')
# [1630] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1630] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1613] ('B016', 'R098', 'CHURCH AV')
# [1613] ('B016', 'R098', 'CHURCH AV')
# [1612] ('N063', 'R011', '42 ST-PORT AUTH')
# [1612] ('N063', 'R011', '42 ST-PORT AUTH')
# [1607] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1607] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1587] ('A037', 'R170', '14 ST-UNION SQ')
# [1587] ('A037', 'R170', '14 ST-UNION SQ')
# [1578] ('R217A', 'R194', 'BLEECKER ST')
# [1578] ('R217A', 'R194', 'BLEECKER ST')
# [1571] ('R115', 'R029', 'PARK PLACE')
# [1571] ('R115', 'R029', 'PARK PLACE')
# [1561] ('A014', 'R081', '49 ST')
# [1561] ('A014', 'R081', '49 ST')
# [1552] ('R161A', 'R452', '72 ST')
# [1552] ('R161A', 'R452', '72 ST')
# [1532] ('D002', 'R390', '8 AV')
# [1532] ('D002', 'R390', '8 AV')
# [1525] ('R412', 'R146', 'HUNTS POINT AV')
# [1525] ('R412', 'R146', 'HUNTS POINT AV')
# [1522] ('N044', 'R187', '81 ST-MUSEUM')
# [1522] ('N044', 'R187', '81 ST-MUSEUM')
# [1513] ('N511', 'R163', '14 ST')
# [1513] ('N511', 'R163', '14 ST')
# [1507] ('R529', 'R208', '103 ST-CORONA')
# [1507] ('R529', 'R208', '103 ST-CORONA')
# [1503] ('R301', 'R323', 'CENTRAL PK N110')
# [1503] ('R301', 'R323', 'CENTRAL PK N110')
# [1502] ('R135', 'R031', '34 ST-PENN STA')
# [1502] ('R135', 'R031', '34 ST-PENN STA')
# [1488] ('N607', 'R025', 'JAMAICA CENTER')
# [1488] ('N607', 'R025', 'JAMAICA CENTER')
# [1446] ('R174', 'R034', '125 ST')
# [1446] ('R174', 'R034', '125 ST')
# [1444] ('N536', 'R270', 'SMITH-9 ST')
# [1444] ('N536', 'R270', 'SMITH-9 ST')
# [1436] ('H005', 'R330', '3 AV')
# [1436] ('H005', 'R330', '3 AV')
# [1434] ('R609', 'R056', 'NEVINS ST')
# [1434] ('R609', 'R056', 'NEVINS ST')
# [1430] ('N101', 'R252', 'HIGH ST')
# [1430] ('N101', 'R252', 'HIGH ST')
# [1420] ('R420', 'R107', 'WESTCHESTER SQ')
# [1420] ('R420', 'R107', 'WESTCHESTER SQ')
# [1412] ('R283', 'R221', '167 ST')
# [1412] ('R283', 'R221', '167 ST')
# [1399] ('R331', 'R364', 'GUN HILL RD')
# [1399] ('R331', 'R364', 'GUN HILL RD')
# [1393] ('R518', 'R261', '40 ST LOWERY ST')
# [1393] ('R518', 'R261', '40 ST LOWERY ST')
# [1390] ('R204A', 'R043', 'WALL ST')
# [1390] ('R204A', 'R043', 'WALL ST')
# [1390] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1390] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1390] ('C012', 'R258', '4AV-9 ST')
# [1390] ('C012', 'R258', '4AV-9 ST')
# [1387] ('N062', 'R011', '42 ST-PORT AUTH')
# [1387] ('N062', 'R011', '42 ST-PORT AUTH')
# [1374] ('R185', 'R274', '191 ST')
# [1374] ('R185', 'R274', '191 ST')
# [1367] ('A041', 'R086', 'PRINCE ST')
# [1367] ('A041', 'R086', 'PRINCE ST')
# [1365] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1365] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1344] ('R130', 'R321', '18 ST')
# [1344] ('R130', 'R321', '18 ST')
# [1341] ('N405', 'R239', 'GREENPOINT AV')
# [1341] ('N405', 'R239', 'GREENPOINT AV')
# [1335] ('R250', 'R179', '86 ST')
# [1335] ('R250', 'R179', '86 ST')
# [1331] ('C018', 'R197', '36 ST')
# [1331] ('C018', 'R197', '36 ST')
# [1331] ('B031', 'R172', 'BRIGHTON BEACH')
# [1331] ('B031', 'R172', 'BRIGHTON BEACH')
# [1325] ('A016', 'R081', '49 ST')
# [1325] ('A016', 'R081', '49 ST')
# [1323] ('N539A', 'R288', '7 AV')
# [1323] ('N539A', 'R288', '7 AV')
# [1313] ('R126', 'R189', 'CHRISTOPHER ST')
# [1313] ('R126', 'R189', 'CHRISTOPHER ST')
# [1312] ('R134', 'R272', '28 ST')
# [1312] ('R134', 'R272', '28 ST')
# [1295] ('R251', 'R144', '96 ST')
# [1295] ('R251', 'R144', '96 ST')
# [1286] ('N057', 'R188', '50 ST')
# [1286] ('N057', 'R188', '50 ST')
# [1276] ('R205A', 'R014', 'FULTON ST')
# [1276] ('R205A', 'R014', 'FULTON ST')
# [1269] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1269] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1269] ('N043', 'R186', '86 ST')
# [1269] ('N043', 'R186', '86 ST')
# [1255] ('R164', 'R167', '86 ST')
# [1255] ('R164', 'R167', '86 ST')
# [1252] ('R256', 'R182', '116 ST')
# [1252] ('R256', 'R182', '116 ST')
# [1250] ('R160A', 'R164', '66 ST-LINCOLN')
# [1250] ('R160A', 'R164', '66 ST-LINCOLN')
# [1245] ('N521', 'R300', '2 AV')
# [1245] ('N521', 'R300', '2 AV')
# [1241] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1241] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1234] ('R160', 'R164', '66 ST-LINCOLN')
# [1234] ('R160', 'R164', '66 ST-LINCOLN')
# [1226] ('R503', 'R276', 'VERNON-JACKSON')
# [1226] ('R503', 'R276', 'VERNON-JACKSON')
# [1223] ('N513', 'R163', '14 ST')
# [1223] ('N513', 'R163', '14 ST')
# [1221] ('N701A', 'R571', '86 ST-2 AVE')
# [1221] ('N701A', 'R571', '86 ST-2 AVE')
# [1210] ('R311', 'R053', '3 AV-149 ST')
# [1210] ('R311', 'R053', '3 AV-149 ST')
# [1191] ('N124', 'R103', 'BROADWAY JCT')
# [1191] ('N124', 'R103', 'BROADWAY JCT')
# [1190] ('R417', 'R222', 'PARKCHESTER')
# [1190] ('R417', 'R222', 'PARKCHESTER')
# [1184] ('B024', 'R211', 'KINGS HWY')
# [1184] ('B024', 'R211', 'KINGS HWY')
# [1180] ('A083', 'R125', 'BROAD ST')
# [1180] ('A083', 'R125', 'BROAD ST')
# [1172] ('R231A', 'R176', '33 ST')
# [1172] ('R231A', 'R176', '33 ST')
# [1171] ('J001', 'R460', 'MARCY AV')
# [1171] ('J001', 'R460', 'MARCY AV')
# [1166] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1166] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1162] ('R231', 'R176', '33 ST')
# [1162] ('R231', 'R176', '33 ST')
# [1149] ('R513', 'R093', '30 AV')
# [1149] ('R513', 'R093', '30 AV')
# [1134] ('R608', 'R056', 'NEVINS ST')
# [1134] ('R608', 'R056', 'NEVINS ST')
# [1122] ('R527', 'R122', '90 ST-ELMHURST')
# [1122] ('R527', 'R122', '90 ST-ELMHURST')
# [1116] ('R512', 'R092', 'BROADWAY')
# [1116] ('R512', 'R092', 'BROADWAY')
# [1115] ('N040', 'R251', '96 ST')
# [1115] ('N040', 'R251', '96 ST')
# [1113] ('N315', 'R238', 'STEINWAY ST')
# [1113] ('N315', 'R238', 'STEINWAY ST')
# [1108] ('R284', 'R243', '170 ST')
# [1108] ('R284', 'R243', '170 ST')
# [1091] ('N327', 'R254', 'GRAND-NEWTOWN')
# [1091] ('N327', 'R254', 'GRAND-NEWTOWN')
# [1074] ('A050', 'R088', 'CORTLANDT ST')
# [1074] ('A050', 'R088', 'CORTLANDT ST')
# [1072] ('R245', 'R051', '59 ST')
# [1072] ('R245', 'R051', '59 ST')
# [1060] ('R515', 'R095', 'ASTORIA DITMARS')
# [1060] ('R515', 'R095', 'ASTORIA DITMARS')
# [1058] ('J002', 'R460', 'MARCY AV')
# [1058] ('J002', 'R460', 'MARCY AV')
# [1058] ('A007', 'R079', '5 AV/59 ST')
# [1058] ('A007', 'R079', '5 AV/59 ST')
# [1051] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [1051] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [1050] ('R519', 'R223', '46 ST BLISS ST')
# [1050] ('R519', 'R223', '46 ST BLISS ST')
# [1050] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1050] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1049] ('H016', 'R250', 'GRAND ST')
# [1049] ('H016', 'R250', 'GRAND ST')
# [1026] ('N339A', 'R114', 'PARSONS BLVD')
# [1026] ('N339A', 'R114', 'PARSONS BLVD')
# [1025] ('R120', 'R320', 'CANAL ST')
# [1025] ('R120', 'R320', 'CANAL ST')
# [1024] ('N702', 'R572', '96 ST-2 AVE')
# [1024] ('N702', 'R572', '96 ST-2 AVE')
# [1007] ('R511', 'R091', '36 AV')
# [1007] ('R511', 'R091', '36 AV')
# [999] ('N422', 'R318', 'FULTON ST')
# [999] ('N422', 'R318', 'FULTON ST')
# [964] ('R604', 'R108', 'BOROUGH HALL')
# [964] ('R604', 'R108', 'BOROUGH HALL')
# [954] ('B024A', 'R211', 'KINGS HWY')
# [954] ('B024A', 'R211', 'KINGS HWY')
# [952] ('C003', 'R089', 'JAY ST-METROTEC')
# [952] ('C003', 'R089', 'JAY ST-METROTEC')
# [946] ('N702A', 'R572', '96 ST-2 AVE')
# [946] ('N702A', 'R572', '96 ST-2 AVE')
# [944] ('N329', 'R201', 'WOODHAVEN BLVD')
# [944] ('N329', 'R201', 'WOODHAVEN BLVD')
# [938] ('R253', 'R181', '110 ST')
# [938] ('R253', 'R181', '110 ST')
# [932] ('R128', 'R105', '14 ST')
# [932] ('R128', 'R105', '14 ST')
# [930] ('N330', 'R202', '63 DR-REGO PARK')
# [930] ('N330', 'R202', '63 DR-REGO PARK')
# [924] ('R232A', 'R176', '33 ST')
# [924] ('R232A', 'R176', '33 ST')
# [918] ('A064', 'R311', 'BOWERY')
# [918] ('A064', 'R311', 'BOWERY')
# [912] ('C025', 'R215', '86 ST')
# [912] ('C025', 'R215', '86 ST')
# [907] ('N116', 'R198', 'NOSTRAND AV')
# [907] ('N116', 'R198', 'NOSTRAND AV')
# [902] ('B004', 'R171', '7 AV')
# [902] ('B004', 'R171', '7 AV')
# [898] ('N117', 'R198', 'NOSTRAND AV')
# [898] ('N117', 'R198', 'NOSTRAND AV')
# [885] ('N528', 'R257', 'EAST BROADWAY')
# [885] ('N528', 'R257', 'EAST BROADWAY')
# [882] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [882] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [882] ('N217', 'R112', 'FORDHAM RD')
# [882] ('N217', 'R112', 'FORDHAM RD')
# [879] ('A077', 'R028', 'FULTON ST')
# [879] ('A077', 'R028', 'FULTON ST')
# [875] ('N310', 'R140', 'QUEENS PLAZA')
# [875] ('N310', 'R140', 'QUEENS PLAZA')
# [869] ('N526', 'R142', 'DELANCEY/ESSEX')
# [869] ('N526', 'R142', 'DELANCEY/ESSEX')
# [866] ('R304', 'R206', '125 ST')
# [866] ('R304', 'R206', '125 ST')
# [866] ('N535', 'R220', 'CARROLL ST')
# [866] ('N535', 'R220', 'CARROLL ST')
# [864] ('B029', 'R172', 'BRIGHTON BEACH')
# [864] ('B029', 'R172', 'BRIGHTON BEACH')
# [861] ('N537', 'R258', '4 AV-9 ST')
# [861] ('N537', 'R258', '4 AV-9 ST')
# [859] ('H014', 'R249', 'GRAHAM AV')
# [859] ('H014', 'R249', 'GRAHAM AV')
# [859] ('B022', 'R229', 'AVENUE M')
# [859] ('B022', 'R229', 'AVENUE M')
# [850] ('N604', 'R342', 'JAMAICA VAN WK')
# [850] ('N604', 'R342', 'JAMAICA VAN WK')
# [848] ('R423', 'R429', 'PELHAM BAY PARK')
# [848] ('R423', 'R429', 'PELHAM BAY PARK')
# [843] ('R230', 'R143', '28 ST')
# [843] ('R230', 'R143', '28 ST')
# [836] ('R530', 'R310', '111 ST')
# [836] ('R530', 'R310', '111 ST')
# [835] ('H003', 'R163', '6 AV')
# [835] ('H003', 'R163', '6 AV')
# [834] ('E004', 'R234', '50 ST')
# [834] ('E004', 'R234', '50 ST')
# [833] ('N120', 'R153', 'UTICA AV')
# [833] ('N120', 'R153', 'UTICA AV')
# [833] ('N013', 'R035', '168 ST')
# [833] ('N013', 'R035', '168 ST')
# [828] ('R629', 'R065', 'ROCKAWAY AV')
# [828] ('R629', 'R065', 'ROCKAWAY AV')
# [824] ('G009', 'R151', 'CONEY IS-STILLW')
# [824] ('G009', 'R151', 'CONEY IS-STILLW')
# [819] ('N307', 'R359', 'COURT SQ-23 ST')
# [819] ('N307', 'R359', 'COURT SQ-23 ST')
# [814] ('R517', 'R291', '33 ST-RAWSON ST')
# [814] ('R517', 'R291', '33 ST-RAWSON ST')
# [809] ('R418', 'R106', 'CASTLE HILL AV')
# [809] ('R418', 'R106', 'CASTLE HILL AV')
# [803] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [803] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [802] ('R401', 'R445', '3 AV 138 ST')
# [802] ('R401', 'R445', '3 AV 138 ST')
# [797] ('R103', 'R304', 'RECTOR ST')
# [797] ('R103', 'R304', 'RECTOR ST')
# [797] ('N602', 'R259', 'ROOSEVELT ISLND')
# [797] ('N602', 'R259', 'ROOSEVELT ISLND')
# [796] ('R175', 'R169', '137 ST CITY COL')
# [796] ('R175', 'R169', '137 ST CITY COL')
# [794] ('R171', 'R192', 'CATHEDRAL PKWY')
# [794] ('R171', 'R192', 'CATHEDRAL PKWY')
# [794] ('N025', 'R102', '125 ST')
# [794] ('N025', 'R102', '125 ST')
# [792] ('R287', 'R244', 'BURNSIDE AV')
# [792] ('R287', 'R244', 'BURNSIDE AV')
# [790] ('N546', 'R204', 'CHURCH AV')
# [790] ('N546', 'R204', 'CHURCH AV')
# [788] ('R291', 'R183', 'BEDFORD PK BLVD')
# [788] ('R291', 'R183', 'BEDFORD PK BLVD')
# [786] ('R622', 'R123', 'FRANKLIN AV')
# [786] ('R622', 'R123', 'FRANKLIN AV')
# [780] ('R336', 'R145', 'WAKEFIELD/241')
# [780] ('R336', 'R145', 'WAKEFIELD/241')
# [779] ('A054', 'R227', 'RECTOR ST')
# [779] ('A054', 'R227', 'RECTOR ST')
# [766] ('R634', 'R069', 'NEW LOTS AV')
# [766] ('R634', 'R069', 'NEW LOTS AV')
# [766] ('N549', 'R242', '18 AV')
# [766] ('N549', 'R242', '18 AV')
# [766] ('N196', 'R285', 'FAR ROCKAWAY')
# [766] ('N196', 'R285', 'FAR ROCKAWAY')
# [760] ('N213', 'R154', 'TREMONT AV')
# [760] ('N213', 'R154', 'TREMONT AV')
# [753] ('N312', 'R339', '36 ST')
# [753] ('N312', 'R339', '36 ST')
# [749] ('R290', 'R161', 'KINGSBRIDGE RD')
# [749] ('R290', 'R161', 'KINGSBRIDGE RD')
# [741] ('C019', 'R232', '45 ST')
# [741] ('C019', 'R232', '45 ST')
# [739] ('N316A', 'R267', '46 ST')
# [739] ('N316A', 'R267', '46 ST')
# [736] ('R635', 'R277', 'PRESIDENT ST')
# [736] ('R635', 'R277', 'PRESIDENT ST')
# [736] ('N530', 'R301', 'YORK ST')
# [736] ('N530', 'R301', 'YORK ST')
# [733] ('R310', 'R053', '3 AV-149 ST')
# [733] ('R310', 'R053', '3 AV-149 ST')
# [728] ('J007', 'R377', 'FLUSHING AV')
# [728] ('J007', 'R377', 'FLUSHING AV')
# [726] ('H019', 'R294', 'MORGAN AV')
# [726] ('H019', 'R294', 'MORGAN AV')
# [725] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [725] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [724] ('R177', 'R273', '145 ST')
# [724] ('R177', 'R273', '145 ST')
# [721] ('N701', 'R571', '86 ST-2 AVE')
# [721] ('N701', 'R571', '86 ST-2 AVE')
# [721] ('N086', 'R282', 'SPRING ST')
# [721] ('N086', 'R282', 'SPRING ST')
# [715] ('N333B', 'R141', 'FOREST HILLS 71')
# [715] ('N333B', 'R141', 'FOREST HILLS 71')
# [714] ('N100', 'R252', 'HIGH ST')
# [714] ('N100', 'R252', 'HIGH ST')
# [709] ('N419', 'R287', 'CLASSON AV')
# [709] ('N419', 'R287', 'CLASSON AV')
# [707] ('R285', 'R308', 'MT EDEN AV')
# [707] ('R285', 'R308', 'MT EDEN AV')
# [707] ('R254', 'R181', '110 ST')
# [707] ('R254', 'R181', '110 ST')
# [699] ('R514', 'R094', 'ASTORIA BLVD')
# [699] ('R514', 'R094', 'ASTORIA BLVD')
# [697] ('H006', 'R330', '3 AV')
# [697] ('H006', 'R330', '3 AV')
# [696] ('D005', 'R398', 'NEW UTRECHT AV')
# [696] ('D005', 'R398', 'NEW UTRECHT AV')
# [694] ('R131', 'R190', '23 ST')
# [694] ('R131', 'R190', '23 ST')
# [690] ('N401', 'R360', '21 ST')
# [690] ('N401', 'R360', '21 ST')
# [689] ('R227A', 'R131', '23 ST')
# [689] ('R227A', 'R131', '23 ST')
# [689] ('B019', 'R149', 'NEWKIRK PLAZA')
# [689] ('B019', 'R149', 'NEWKIRK PLAZA')
# [688] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [688] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [687] ('R133', 'R272', '28 ST')
# [687] ('R133', 'R272', '28 ST')
# [682] ('R525', 'R018', '74 ST-BROADWAY')
# [682] ('R525', 'R018', '74 ST-BROADWAY')
# [677] ('R219', 'R160', 'ASTOR PL')
# [677] ('R219', 'R160', 'ASTOR PL')
# [676] ('N010', 'R126', '175 ST')
# [676] ('N010', 'R126', '175 ST')
# [674] ('R624', 'R124', 'KINGSTON AV')
# [674] ('R624', 'R124', 'KINGSTON AV')
# [673] ('R628', 'R064', 'SARATOGA AV')
# [673] ('R628', 'R064', 'SARATOGA AV')
# [673] ('R170', 'R191', '103 ST')
# [673] ('R170', 'R191', '103 ST')
# [671] ('R162', 'R166', '79 ST')
# [671] ('R162', 'R166', '79 ST')
# [668] ('J020', 'R433', 'ALABAMA AV')
# [668] ('J020', 'R433', 'ALABAMA AV')
# [666] ('R510', 'R090', '39 AV')
# [666] ('R510', 'R090', '39 AV')
# [657] ('R600', 'R224', 'CLARK ST')
# [657] ('R600', 'R224', 'CLARK ST')
# [654] ('N408A', 'R256', 'NASSAU AV')
# [654] ('N408A', 'R256', 'NASSAU AV')
# [654] ('H039', 'R375', 'NEW LOTS')
# [654] ('H039', 'R375', 'NEW LOTS')
# [652] ('N409', 'R268', 'METROPOLITAN AV')
# [652] ('N409', 'R268', 'METROPOLITAN AV')
# [652] ('N039', 'R251', '96 ST')
# [652] ('N039', 'R251', '96 ST')
# [652] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [652] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [649] ('A038', 'R085', '8 ST-NYU')
# [649] ('A038', 'R085', '8 ST-NYU')
# [647] ('N529', 'R257', 'EAST BROADWAY')
# [647] ('N529', 'R257', 'EAST BROADWAY')
# [646] ('N019', 'R101', '145 ST')
# [646] ('N019', 'R101', '145 ST')
# [645] ('N141', 'R356', 'OZONE PK LEFFRT')
# [645] ('N141', 'R356', 'OZONE PK LEFFRT')
# [643] ('R504', 'R276', 'VERNON-JACKSON')
# [643] ('R504', 'R276', 'VERNON-JACKSON')
# [641] ('R323', 'R387', 'WEST FARMS SQ')
# [641] ('R323', 'R387', 'WEST FARMS SQ')
# [637] ('R215', 'R322', 'SPRING ST')
# [637] ('R215', 'R322', 'SPRING ST')
# [634] ('R606', 'R225', 'HOYT ST')
# [634] ('R606', 'R225', 'HOYT ST')
# [634] ('B012', 'R196', 'PROSPECT PARK')
# [634] ('B012', 'R196', 'PROSPECT PARK')
# [629] ('A066', 'R118', 'CANAL ST')
# [629] ('A066', 'R118', 'CANAL ST')
# [628] ('R118', 'R343', 'FRANKLIN ST')
# [628] ('R118', 'R343', 'FRANKLIN ST')
# [621] ('H040', 'R376', 'EAST 105 ST')
# [621] ('H040', 'R376', 'EAST 105 ST')
# [619] ('R623', 'R061', 'NOSTRAND AV')
# [619] ('R623', 'R061', 'NOSTRAND AV')
# [618] ('N531', 'R129', 'BERGEN ST')
# [618] ('N531', 'R129', 'BERGEN ST')
# [618] ('N343', 'R019', 'JAMAICA 179 ST')
# [618] ('N343', 'R019', 'JAMAICA 179 ST')
# [615] ('R625', 'R062', 'CROWN HTS-UTICA')
# [615] ('R625', 'R062', 'CROWN HTS-UTICA')
# [612] ('B021', 'R228', 'AVENUE J')
# [612] ('B021', 'R228', 'AVENUE J')
# [609] ('H017', 'R265', 'MONTROSE AV')
# [609] ('H017', 'R265', 'MONTROSE AV')
# [598] ('R415', 'R120', 'MORISN AV/SNDVW')
# [598] ('R415', 'R120', 'MORISN AV/SNDVW')
# [591] ('R129', 'R321', '18 ST')
# [591] ('R129', 'R321', '18 ST')
# [589] ('R403', 'R446', 'BROOK AV')
# [589] ('R403', 'R446', 'BROOK AV')
# [588] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [588] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [587] ('J009', 'R378', 'MYRTLE AV')
# [587] ('J009', 'R378', 'MYRTLE AV')
# [585] ('R286', 'R309', '176 ST')
# [585] ('R286', 'R309', '176 ST')
# [584] ('R414', 'R162', 'ELDER AV')
# [584] ('R414', 'R162', 'ELDER AV')
# [583] ('R163', 'R166', '79 ST')
# [583] ('R163', 'R166', '79 ST')
# [577] ('R524', 'R347', '69 ST')
# [577] ('R524', 'R347', '69 ST')
# [574] ('R325', 'R388', 'E 180 ST')
# [574] ('R325', 'R388', 'E 180 ST')
# [571] ('H015', 'R250', 'GRAND ST')
# [571] ('H015', 'R250', 'GRAND ST')
# [568] ('G001', 'R151', 'CONEY IS-STILLW')
# [568] ('G001', 'R151', 'CONEY IS-STILLW')
# [567] ('R139', 'R031', '34 ST-PENN STA')
# [567] ('R139', 'R031', '34 ST-PENN STA')
# [557] ('N128', 'R200', 'EUCLID AV')
# [557] ('N128', 'R200', 'EUCLID AV')
# [555] ('N024', 'R332', '135 ST')
# [555] ('N024', 'R332', '135 ST')
# [551] ('R259', 'R307', '138/GRAND CONC')
# [551] ('R259', 'R307', '138/GRAND CONC')
# [537] ('R186', 'R036', 'DYCKMAN ST')
# [537] ('R186', 'R036', 'DYCKMAN ST')
# [535] ('N111', 'R284', 'CLINTON-WASH AV')
# [535] ('N111', 'R284', 'CLINTON-WASH AV')
# [532] ('R532', 'R328', 'METS-WILLETS PT')
# [532] ('R532', 'R328', 'METS-WILLETS PT')
# [531] ('N340', 'R115', '169 ST')
# [531] ('N340', 'R115', '169 ST')
# [531] ('C021', 'R212', '59 ST')
# [531] ('C021', 'R212', '59 ST')
# [524] ('R309', 'R345', 'HARLEM 148 ST')
# [524] ('R309', 'R345', 'HARLEM 148 ST')
# [522] ('R293', 'R133', 'MOSHOLU PKWY')
# [522] ('R293', 'R133', 'MOSHOLU PKWY')
# [518] ('R123', 'R290', 'HOUSTON ST')
# [518] ('R123', 'R290', 'HOUSTON ST')
# [513] ('N207', 'R104', '167 ST')
# [513] ('N207', 'R104', '167 ST')
# [512] ('C017', 'R455', '25 ST')
# [512] ('C017', 'R455', '25 ST')
# [511] ('E001', 'R368', '9 AV')
# [511] ('E001', 'R368', '9 AV')
# [510] ('R203A', 'R043', 'WALL ST')
# [510] ('R203A', 'R043', 'WALL ST')
# [510] ('B013', 'R196', 'PROSPECT PARK')
# [510] ('B013', 'R196', 'PROSPECT PARK')
# [505] ('R316', 'R407', 'INTERVALE AV')
# [505] ('R316', 'R407', 'INTERVALE AV')
# [504] ('H023', 'R236', 'DEKALB AV')
# [504] ('H023', 'R236', 'DEKALB AV')
# [502] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [502] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [494] ('R321', 'R386', '174 ST')
# [494] ('R321', 'R386', '174 ST')
# [493] ('N118', 'R199', 'KINGSTON-THROOP')
# [493] ('N118', 'R199', 'KINGSTON-THROOP')
# [490] ('N412', 'R299', 'BROADWAY')
# [490] ('N412', 'R299', 'BROADWAY')
# [489] ('R188', 'R037', '207 ST')
# [489] ('R188', 'R037', '207 ST')
# [488] ('C011', 'R231', 'UNION ST')
# [488] ('C011', 'R231', 'UNION ST')
# [487] ('R176', 'R169', '137 ST CITY COL')
# [487] ('R176', 'R169', '137 ST CITY COL')
# [485] ('R521', 'R327', '52 ST')
# [485] ('R521', 'R327', '52 ST')
# [482] ('N114', 'R297', 'FRANKLIN AV')
# [482] ('N114', 'R297', 'FRANKLIN AV')
# [478] ('R411', 'R450', 'LONGWOOD AV')
# [478] ('R411', 'R450', 'LONGWOOD AV')
# [478] ('R197', 'R117', 'V.CORTLANDT PK')
# [478] ('R197', 'R117', 'V.CORTLANDT PK')
# [477] ('N314', 'R238', 'STEINWAY ST')
# [477] ('N314', 'R238', 'STEINWAY ST')
# [470] ('N331', 'R219', '67 AV')
# [470] ('N331', 'R219', '67 AV')
# [469] ('D010', 'R394', 'BAY PKWY')
# [469] ('D010', 'R394', 'BAY PKWY')
# [467] ('N340A', 'R115', '169 ST')
# [467] ('N340A', 'R115', '169 ST')
# [467] ('E014', 'R374', 'BAY PKWY')
# [467] ('E014', 'R374', 'BAY PKWY')
# [465] ('B010', 'R412', 'BOTANIC GARDEN')
# [465] ('B010', 'R412', 'BOTANIC GARDEN')
# [458] ('R257', 'R182', '116 ST')
# [458] ('R257', 'R182', '116 ST')
# [455] ('N129', 'R382', 'GRANT AV')
# [455] ('N129', 'R382', 'GRANT AV')
# [444] ('B023', 'R211', 'KINGS HWY')
# [444] ('B023', 'R211', 'KINGS HWY')
# [442] ('R288', 'R275', '183 ST')
# [442] ('R288', 'R275', '183 ST')
# [441] ('R226A', 'R131', '23 ST')
# [441] ('R226A', 'R131', '23 ST')
# [441] ('N222', 'R156', 'BEDFORD PK BLVD')
# [441] ('N222', 'R156', 'BEDFORD PK BLVD')
# [436] ('N030', 'R333', '116 ST')
# [436] ('N030', 'R333', '116 ST')
# [430] ('R319', 'R409', 'FREEMAN ST')
# [430] ('R319', 'R409', 'FREEMAN ST')
# [430] ('N120A', 'R153', 'UTICA AV')
# [430] ('N120A', 'R153', 'UTICA AV')
# [427] ('R125', 'R189', 'CHRISTOPHER ST')
# [427] ('R125', 'R189', 'CHRISTOPHER ST')
# [420] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [420] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [420] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [420] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [420] ('B015', 'R098', 'CHURCH AV')
# [420] ('B015', 'R098', 'CHURCH AV')
# [419] ('R409', 'R449', 'E 149 ST')
# [419] ('R409', 'R449', 'E 149 ST')
# [417] ('R305', 'R206', '125 ST')
# [417] ('R305', 'R206', '125 ST')
# [416] ('E003', 'R369', 'FT HAMILTON PKY')
# [416] ('E003', 'R369', 'FT HAMILTON PKY')
# [415] ('R172', 'R192', 'CATHEDRAL PKWY')
# [415] ('R172', 'R192', 'CATHEDRAL PKWY')
# [415] ('C001', 'R108', 'BOROUGH HALL')
# [415] ('C001', 'R108', 'BOROUGH HALL')
# [412] ('N414', 'R316', 'FLUSHING AV')
# [412] ('N414', 'R316', 'FLUSHING AV')
# [410] ('R416', 'R245', 'ST LAWRENCE AV')
# [410] ('R416', 'R245', 'ST LAWRENCE AV')
# [408] ('R405', 'R447', 'CYPRESS AV')
# [408] ('R405', 'R447', 'CYPRESS AV')
# [407] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [407] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [405] ('N319', 'R298', 'NORTHERN BLVD')
# [405] ('N319', 'R298', 'NORTHERN BLVD')
# [403] ('B020', 'R263', 'AVENUE H')
# [403] ('B020', 'R263', 'AVENUE H')
# [402] ('R419', 'R326', 'ZEREGA AV')
# [402] ('R419', 'R326', 'ZEREGA AV')
# [399] ('N333A', 'R141', 'FOREST HILLS 71')
# [399] ('N333A', 'R141', 'FOREST HILLS 71')
# [393] ('J024', 'R437', 'CRESCENT ST')
# [393] ('J024', 'R437', 'CRESCENT ST')
# [387] ('N342', 'R019', 'JAMAICA 179 ST')
# [387] ('N342', 'R019', 'JAMAICA 179 ST')
# [386] ('R178', 'R273', '145 ST')
# [386] ('R178', 'R273', '145 ST')
# [385] ('N318', 'R298', 'NORTHERN BLVD')
# [385] ('N318', 'R298', 'NORTHERN BLVD')
# [385] ('N035', 'R334', 'CATHEDRAL PKWY')
# [385] ('N035', 'R334', 'CATHEDRAL PKWY')
# [384] ('N122', 'R439', 'ROCKAWAY AV')
# [384] ('N122', 'R439', 'ROCKAWAY AV')
# [379] ('R632', 'R067', 'PENNSYLVANIA AV')
# [379] ('R632', 'R067', 'PENNSYLVANIA AV')
# [377] ('N532', 'R129', 'BERGEN ST')
# [377] ('N532', 'R129', 'BERGEN ST')
# [377] ('N023', 'R332', '135 ST')
# [377] ('N023', 'R332', '135 ST')
# [376] ('R289', 'R119', 'FORDHAM RD')
# [376] ('R289', 'R119', 'FORDHAM RD')
# [372] ('N075', 'R111', '23 ST')
# [372] ('N075', 'R111', '23 ST')
# [367] ('N045', 'R187', '81 ST-MUSEUM')
# [367] ('N045', 'R187', '81 ST-MUSEUM')
# [366] ('R166', 'R167', '86 ST')
# [366] ('R166', 'R167', '86 ST')
# [365] ('H032', 'R295', 'WILSON AV')
# [365] ('H032', 'R295', 'WILSON AV')
# [364] ('R408', 'R449', 'E 149 ST')
# [364] ('R408', 'R449', 'E 149 ST')
# [361] ('R303', 'R324', '116 ST')
# [361] ('R303', 'R324', '116 ST')
# [360] ('A071', 'R044', 'CHAMBERS ST')
# [360] ('A071', 'R044', 'CHAMBERS ST')
# [359] ('J028', 'R004', '75 ST-ELDERTS')
# [359] ('J028', 'R004', '75 ST-ELDERTS')
# [358] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [358] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [357] ('N037', 'R314', '103 ST')
# [357] ('N037', 'R314', '103 ST')
# [357] ('B014', 'R148', 'PARKSIDE AV')
# [357] ('B014', 'R148', 'PARKSIDE AV')
# [356] ('R636', 'R209', 'STERLING ST')
# [356] ('R636', 'R209', 'STERLING ST')
# [356] ('E011', 'R371', '79 ST')
# [356] ('E011', 'R371', '79 ST')
# [354] ('N224', 'R157', 'NORWOOD 205 ST')
# [354] ('N224', 'R157', 'NORWOOD 205 ST')
# [348] ('N112A', 'R284', 'CLINTON-WASH AV')
# [348] ('N112A', 'R284', 'CLINTON-WASH AV')
# [346] ('R644', 'R135', 'NEWKIRK AV')
# [346] ('R644', 'R135', 'NEWKIRK AV')
# [345] ('R179', 'R193', '157 ST')
# [345] ('R179', 'R193', '157 ST')
# [345] ('C024', 'R214', '77 ST')
# [345] ('C024', 'R214', '77 ST')
# [342] ('N087', 'R282', 'SPRING ST')
# [342] ('N087', 'R282', 'SPRING ST')
# [342] ('N009', 'R174', '181 ST')
# [342] ('N009', 'R174', '181 ST')
# [341] ('N191', 'R335', 'BEACH 67 ST')
# [341] ('N191', 'R335', 'BEACH 67 ST')
# [339] ('R302', 'R324', '116 ST')
# [339] ('R302', 'R324', '116 ST')
# [339] ('N557', 'R130', 'KINGS HWY')
# [339] ('N557', 'R130', 'KINGS HWY')
# [339] ('K026', 'R100', 'METROPOLITAN AV')
# [339] ('K026', 'R100', 'METROPOLITAN AV')
# [338] ('N220', 'R155', 'KINGSBRIDGE RD')
# [338] ('N220', 'R155', 'KINGSBRIDGE RD')
# [336] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [336] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [334] ('E005', 'R247', '55 ST')
# [334] ('E005', 'R247', '55 ST')
# [328] ('N034', 'R334', 'CATHEDRAL PKWY')
# [328] ('N034', 'R334', 'CATHEDRAL PKWY')
# [325] ('R727', 'R430', 'PELHAM PKWY')
# [325] ('R727', 'R430', 'PELHAM PKWY')
# [323] ('R633', 'R068', 'VAN SICLEN AV')
# [323] ('R633', 'R068', 'VAN SICLEN AV')
# [322] ('B009', 'R411', 'PARK PLACE')
# [322] ('B009', 'R411', 'PARK PLACE')
# [320] ('R328', 'R361', 'PELHAM PKWY')
# [320] ('R328', 'R361', 'PELHAM PKWY')
# [320] ('K025', 'R404', 'FRESH POND RD')
# [320] ('K025', 'R404', 'FRESH POND RD')
# [317] ('R119', 'R320', 'CANAL ST')
# [317] ('R119', 'R320', 'CANAL ST')
# [316] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [316] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [316] ('D003', 'R391', 'FT HAMILTON PKY')
# [316] ('D003', 'R391', 'FT HAMILTON PKY')
# [315] ('R306', 'R207', '135 ST')
# [315] ('R306', 'R207', '135 ST')
# [314] ('H038', 'R350', 'LIVONIA AV')
# [314] ('H038', 'R350', 'LIVONIA AV')
# [312] ('R227', 'R131', '23 ST')
# [312] ('R227', 'R131', '23 ST')
# [312] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [312] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [308] ('N556', 'R424', 'AVENUE P')
# [308] ('N556', 'R424', 'AVENUE P')
# [307] ('B032', 'R264', 'OCEAN PKWY')
# [307] ('B032', 'R264', 'OCEAN PKWY')
# [305] ('N551', 'R421', 'AVENUE I')
# [305] ('N551', 'R421', 'AVENUE I')
# [305] ('N414A', 'R316', 'FLUSHING AV')
# [305] ('N414A', 'R316', 'FLUSHING AV')
# [299] ('N006A', 'R280', '190 ST')
# [299] ('N006A', 'R280', '190 ST')
# [299] ('K019', 'R413', 'KNICKERBOCKER')
# [299] ('K019', 'R413', 'KNICKERBOCKER')
# [298] ('J035', 'R008', '111 ST')
# [298] ('J035', 'R008', '111 ST')
# [295] ('N555', 'R423', 'AVENUE N')
# [295] ('N555', 'R423', 'AVENUE N')
# [295] ('K017', 'R401', 'CENTRAL AV')
# [295] ('K017', 'R401', 'CENTRAL AV')
# [294] ('R637', 'R451', 'WINTHROP ST')
# [294] ('R637', 'R451', 'WINTHROP ST')
# [294] ('N221', 'R155', 'KINGSBRIDGE RD')
# [294] ('N221', 'R155', 'KINGSBRIDGE RD')
# [294] ('N121B', 'R438', 'RALPH AV')
# [294] ('N121B', 'R438', 'RALPH AV')
# [294] ('H022', 'R279', 'JEFFERSON ST')
# [294] ('H022', 'R279', 'JEFFERSON ST')
# [293] ('J031', 'R006', 'WOODHAVEN BLVD')
# [293] ('J031', 'R006', 'WOODHAVEN BLVD')
# [291] ('C010', 'R231', 'UNION ST')
# [291] ('C010', 'R231', 'UNION ST')
# [289] ('H037', 'R349', 'SUTTER AV')
# [289] ('H037', 'R349', 'SUTTER AV')
# [288] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [288] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [288] ('N113', 'R297', 'FRANKLIN AV')
# [288] ('N113', 'R297', 'FRANKLIN AV')
# [288] ('J005', 'R353', 'LORIMER ST')
# [288] ('J005', 'R353', 'LORIMER ST')
# [288] ('B018', 'R184', 'CORTELYOU RD')
# [288] ('B018', 'R184', 'CORTELYOU RD')
# [287] ('R404', 'R447', 'CYPRESS AV')
# [287] ('R404', 'R447', 'CYPRESS AV')
# [286] ('N561', 'R271', 'AVENUE X')
# [286] ('N561', 'R271', 'AVENUE X')
# [285] ('N209', 'R443', '170 ST')
# [285] ('N209', 'R443', '170 ST')
# [285] ('J023', 'R436', 'NORWOOD AV')
# [285] ('J023', 'R436', 'NORWOOD AV')
# [284] ('R402', 'R446', 'BROOK AV')
# [284] ('R402', 'R446', 'BROOK AV')
# [284] ('N338B', 'R128', 'SUTPHIN BLVD')
# [284] ('N338B', 'R128', 'SUTPHIN BLVD')
# [284] ('N119', 'R199', 'KINGSTON-THROOP')
# [284] ('N119', 'R199', 'KINGSTON-THROOP')
# [283] ('N325A', 'R218', 'ELMHURST AV')
# [283] ('N325A', 'R218', 'ELMHURST AV')
# [281] ('R180', 'R193', '157 ST')
# [281] ('R180', 'R193', '157 ST')
# [279] ('R618', 'R058', 'BERGEN ST')
# [279] ('R618', 'R058', 'BERGEN ST')
# [277] ('R413', 'R325', 'WHITLOCK AV')
# [277] ('R413', 'R325', 'WHITLOCK AV')
# [272] ('R307', 'R207', '135 ST')
# [272] ('R307', 'R207', '135 ST')
# [272] ('C016', 'R278', '25 ST')
# [272] ('C016', 'R278', '25 ST')
# [270] ('D012', 'R395', 'KINGS HWY')
# [270] ('D012', 'R395', 'KINGS HWY')
# [270] ('B025', 'R150', 'AVENUE U')
# [270] ('B025', 'R150', 'AVENUE U')
# [266] ('R421', 'R427', 'MIDDLETOWN RD')
# [266] ('R421', 'R427', 'MIDDLETOWN RD')
# [266] ('N125', 'R440', 'LIBERTY AV')
# [266] ('N125', 'R440', 'LIBERTY AV')
# [265] ('R407', 'R448', "E 143/ST MARY'S")
# [265] ('R407', 'R448', "E 143/ST MARY'S")
# [264] ('E016', 'R400', 'BAY 50 ST')
# [264] ('E016', 'R400', 'BAY 50 ST')
# [263] ('N007A', 'R174', '181 ST')
# [263] ('N007A', 'R174', '181 ST')
# [258] ('N195', 'R358', 'BEACH 25 ST')
# [258] ('N195', 'R358', 'BEACH 25 ST')
# [257] ('N559', 'R425', 'AVENUE U')
# [257] ('N559', 'R425', 'AVENUE U')
# [257] ('N110', 'R283', 'LAFAYETTE AV')
# [257] ('N110', 'R283', 'LAFAYETTE AV')
# [257] ('H030', 'R266', 'HALSEY ST')
# [257] ('H030', 'R266', 'HALSEY ST')
# [256] ('N311', 'R339', '36 ST')
# [256] ('N311', 'R339', '36 ST')
# [255] ('J013', 'R380', 'GATES AV')
# [255] ('J013', 'R380', 'GATES AV')
# [253] ('J022', 'R435', 'CLEVELAND ST')
# [253] ('J022', 'R435', 'CLEVELAND ST')
# [250] ('B017', 'R262', 'BEVERLEY ROAD')
# [250] ('B017', 'R262', 'BEVERLEY ROAD')
# [249] ('R639', 'R109', 'CHURCH AV')
# [249] ('R639', 'R109', 'CHURCH AV')
# [247] ('J012', 'R379', 'KOSCIUSZKO ST')
# [247] ('J012', 'R379', 'KOSCIUSZKO ST')
# [246] ('N333', 'R141', 'FOREST HILLS 71')
# [246] ('N333', 'R141', 'FOREST HILLS 71')
# [245] ('N126', 'R441', 'VAN SICLEN AVE')
# [245] ('N126', 'R441', 'VAN SICLEN AVE')
# [245] ('J021', 'R434', 'VAN SICLEN AV')
# [245] ('J021', 'R434', 'VAN SICLEN AV')
# [243] ('R294', 'R052', 'WOODLAWN')
# [243] ('R294', 'R052', 'WOODLAWN')
# [239] ('N337', 'R255', 'BRIARWOOD')
# [239] ('N337', 'R255', 'BRIARWOOD')
# [238] ('N202', 'R315', '155 ST')
# [238] ('N202', 'R315', '155 ST')
# [234] ('N215', 'R237', '182-183 STS')
# [234] ('N215', 'R237', '182-183 STS')
# [233] ('J016', 'R381', 'HALSEY ST')
# [233] ('J016', 'R381', 'HALSEY ST')
# [225] ('R410', 'R450', 'LONGWOOD AV')
# [225] ('R410', 'R450', 'LONGWOOD AV')
# [220] ('A055', 'R227', 'RECTOR ST')
# [220] ('A055', 'R227', 'RECTOR ST')
# [218] ('E012', 'R372', '18 AV')
# [218] ('E012', 'R372', '18 AV')
# [216] ('R329', 'R362', 'ALLERTON AV')
# [216] ('R329', 'R362', 'ALLERTON AV')
# [216] ('R117', 'R343', 'FRANKLIN ST')
# [216] ('R117', 'R343', 'FRANKLIN ST')
# [212] ('R617', 'R058', 'BERGEN ST')
# [212] ('R617', 'R058', 'BERGEN ST')
# [212] ('R327', 'R361', 'PELHAM PKWY')
# [212] ('R327', 'R361', 'PELHAM PKWY')
# [212] ('R326', 'R389', 'BRONX PARK EAST')
# [212] ('R326', 'R389', 'BRONX PARK EAST')
# [212] ('N316', 'R267', '46 ST')
# [212] ('N316', 'R267', '46 ST')
# [208] ('N192', 'R336', 'BEACH 60 ST')
# [208] ('N192', 'R336', 'BEACH 60 ST')
# [207] ('N548', 'R420', 'DITMAS AV')
# [207] ('N548', 'R420', 'DITMAS AV')
# [203] ('N534', 'R220', 'CARROLL ST')
# [203] ('N534', 'R220', 'CARROLL ST')
# [202] ('R422', 'R428', 'BUHRE AV')
# [202] ('R422', 'R428', 'BUHRE AV')
# [200] ('R728', 'R226', 'GUN HILL RD')
# [200] ('R728', 'R226', 'GUN HILL RD')
# [200] ('N225', 'R157', 'NORWOOD 205 ST')
# [200] ('N225', 'R157', 'NORWOOD 205 ST')
# [199] ('H013', 'R249', 'GRAHAM AV')
# [199] ('H013', 'R249', 'GRAHAM AV')
# [196] ('N212', 'R253', '174-175 STS')
# [196] ('N212', 'R253', '174-175 STS')
# [194] ('N001', 'R173', 'INWOOD-207 ST')
# [194] ('N001', 'R173', 'INWOOD-207 ST')
# [193] ('R333', 'R366', '225 ST')
# [193] ('R333', 'R366', '225 ST')
# [193] ('R121', 'R290', 'HOUSTON ST')
# [193] ('R121', 'R290', 'HOUSTON ST')
# [192] ('N134', 'R385', 'ROCKAWAY BLVD')
# [192] ('N134', 'R385', 'ROCKAWAY BLVD')
# [192] ('D015', 'R396', 'AVENUE U')
# [192] ('D015', 'R396', 'AVENUE U')
# [189] ('N017', 'R331', '155 ST')
# [189] ('N017', 'R331', '155 ST')
# [188] ('E009', 'R370', '71 ST')
# [188] ('E009', 'R370', '71 ST')
# [186] ('R260', 'R205', '149/GRAND CONC')
# [186] ('R260', 'R205', '149/GRAND CONC')
# [186] ('R122', 'R290', 'HOUSTON ST')
# [186] ('R122', 'R290', 'HOUSTON ST')
# [185] ('H035', 'R348', 'ATLANTIC AV')
# [185] ('H035', 'R348', 'ATLANTIC AV')
# [182] ('N322', 'R340', '65 ST')
# [182] ('N322', 'R340', '65 ST')
# [182] ('N012', 'R035', '168 ST')
# [182] ('N012', 'R035', '168 ST')
# [181] ('R194', 'R040', '231 ST')
# [181] ('R194', 'R040', '231 ST')
# [180] ('R312', 'R405', 'JACKSON AV')
# [180] ('R312', 'R405', 'JACKSON AV')
# [180] ('N553', 'R422', 'BAY PKWY')
# [180] ('N553', 'R422', 'BAY PKWY')
# [179] ('N127', 'R442', 'SHEPHERD AV')
# [179] ('N127', 'R442', 'SHEPHERD AV')
# [177] ('N206', 'R104', '167 ST')
# [177] ('N206', 'R104', '167 ST')
# [176] ('N002A', 'R173', 'INWOOD-207 ST')
# [176] ('N002A', 'R173', 'INWOOD-207 ST')
# [175] ('H028', 'R266', 'HALSEY ST')
# [175] ('H028', 'R266', 'HALSEY ST')
# [174] ('R190', 'R038', '215 ST')
# [174] ('R190', 'R038', '215 ST')
# [174] ('N011', 'R126', '175 ST')
# [174] ('N011', 'R126', '175 ST')
# [172] ('R315', 'R406', 'PROSPECT AV')
# [172] ('R315', 'R406', 'PROSPECT AV')
# [169] ('J030', 'R005', '85 ST-FOREST PK')
# [169] ('J030', 'R005', '85 ST-FOREST PK')
# [168] ('E013', 'R373', '20 AV')
# [168] ('E013', 'R373', '20 AV')
# [167] ('N332', 'R219', '67 AV')
# [167] ('N332', 'R219', '67 AV')
# [166] ('R192', 'R039', 'MARBLE HILL-225')
# [166] ('R192', 'R039', 'MARBLE HILL-225')
# [164] ('R334', 'R367', '233 ST')
# [164] ('R334', 'R367', '233 ST')
# [156] ('J003', 'R352', 'HEWES ST')
# [156] ('J003', 'R352', 'HEWES ST')
# [155] ('K024', 'R403', 'FOREST AVE')
# [155] ('K024', 'R403', 'FOREST AVE')
# [152] ('R335', 'R444', 'NEREID AV')
# [152] ('R335', 'R444', 'NEREID AV')
# [152] ('N210', 'R253', '174-175 STS')
# [152] ('N210', 'R253', '174-175 STS')
# [152] ('C022', 'R212', '59 ST')
# [152] ('C022', 'R212', '59 ST')
# [150] ('N208', 'R443', '170 ST')
# [150] ('N208', 'R443', '170 ST')
# [148] ('N562', 'R426', 'NEPTUNE AV')
# [148] ('N562', 'R426', 'NEPTUNE AV')
# [143] ('A082', 'R028', 'FULTON ST')
# [143] ('A082', 'R028', 'FULTON ST')
# [142] ('R726', 'R329', 'MORRIS PARK')
# [142] ('R726', 'R329', 'MORRIS PARK')
# [142] ('C004', 'R089', 'JAY ST-METROTEC')
# [142] ('C004', 'R089', 'JAY ST-METROTEC')
# [139] ('N194', 'R338', 'BEACH 36 ST')
# [139] ('N194', 'R338', 'BEACH 36 ST')
# [139] ('N187', 'R419', 'ROCKAWAY PARK B')
# [139] ('N187', 'R419', 'ROCKAWAY PARK B')
# [138] ('H012', 'R268', 'LORIMER ST')
# [138] ('H012', 'R268', 'LORIMER ST')
# [136] ('J017', 'R432', 'CHAUNCEY ST')
# [136] ('J017', 'R432', 'CHAUNCEY ST')
# [135] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [135] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [127] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [127] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [124] ('N543', 'R289', 'FT HAMILTON PKY')
# [124] ('N543', 'R289', 'FT HAMILTON PKY')
# [123] ('N185', 'R417', 'BEACH 98 ST')
# [123] ('N185', 'R417', 'BEACH 98 ST')
# [122] ('R314', 'R406', 'PROSPECT AV')
# [122] ('R314', 'R406', 'PROSPECT AV')
# [118] ('H033', 'R313', 'BUSHWICK AV')
# [118] ('H033', 'R313', 'BUSHWICK AV')
# [117] ('K022', 'R402', 'SENECA AVE')
# [117] ('K022', 'R402', 'SENECA AVE')
# [115] ('R406', 'R448', "E 143/ST MARY'S")
# [115] ('R406', 'R448', "E 143/ST MARY'S")
# [114] ('R318', 'R408', 'SIMPSON ST')
# [114] ('R318', 'R408', 'SIMPSON ST')
# [112] ('R332', 'R365', '219 ST')
# [112] ('R332', 'R365', '219 ST')
# [112] ('R317', 'R408', 'SIMPSON ST')
# [112] ('R317', 'R408', 'SIMPSON ST')
# [109] ('J025', 'R003', 'CYPRESS HILLS')
# [109] ('J025', 'R003', 'CYPRESS HILLS')
# [109] ('D016', 'R397', '86 ST')
# [109] ('D016', 'R397', '86 ST')
# [106] ('R330', 'R363', 'BURKE AV')
# [106] ('R330', 'R363', 'BURKE AV')
# [106] ('N317', 'R267', '46 ST')
# [106] ('N317', 'R267', '46 ST')
# [104] ('B026', 'R230', 'NECK RD')
# [104] ('B026', 'R230', 'NECK RD')
# [103] ('N330C', 'R202', '63 DR-REGO PARK')
# [103] ('N330C', 'R202', '63 DR-REGO PARK')
# [102] ('B034', 'R264', 'OCEAN PKWY')
# [102] ('B034', 'R264', 'OCEAN PKWY')
# [97] ('N545', 'R204', 'CHURCH AV')
# [97] ('N545', 'R204', 'CHURCH AV')
# [96] ('R641', 'R210', 'BEVERLY RD')
# [96] ('R641', 'R210', 'BEVERLY RD')
# [96] ('R520', 'R223', '46 ST BLISS ST')
# [96] ('R520', 'R223', '46 ST BLISS ST')
# [96] ('N016A', 'R296', '163 ST-AMSTERDM')
# [96] ('N016A', 'R296', '163 ST-AMSTERDM')
# [95] ('N533', 'R129', 'BERGEN ST')
# [95] ('N533', 'R129', 'BERGEN ST')
# [91] ('N193', 'R337', 'BEACH 44 ST')
# [91] ('N193', 'R337', 'BEACH 44 ST')
# [89] ('N181', 'R357', 'AQUEDUCT N.COND')
# [89] ('N181', 'R357', 'AQUEDUCT N.COND')
# [89] ('N135', 'R385', 'ROCKAWAY BLVD')
# [89] ('N135', 'R385', 'ROCKAWAY BLVD')
# [87] ('E015', 'R399', '25 AV')
# [87] ('E015', 'R399', '25 AV')
# [84] ('R322', 'R386', '174 ST')
# [84] ('R322', 'R386', '174 ST')
# [73] ('N334B', 'R341', '75 AV')
# [73] ('N334B', 'R341', '75 AV')
# [71] ('R320', 'R409', 'FREEMAN ST')
# [71] ('R320', 'R409', 'FREEMAN ST')
# [68] ('N137', 'R354', '104 ST')
# [68] ('N137', 'R354', '104 ST')
# [65] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [65] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [65] ('N131', 'R383', '80 ST')
# [65] ('N131', 'R383', '80 ST')
# [64] ('R729', 'R292', 'BAYCHESTER AV')
# [64] ('R729', 'R292', 'BAYCHESTER AV')
# [62] ('N420B', 'R317', 'CLINTON-WASH AV')
# [62] ('N420B', 'R317', 'CLINTON-WASH AV')
# [62] ('N218', 'R112', 'FORDHAM RD')
# [62] ('N218', 'R112', 'FORDHAM RD')
# [52] ('C026', 'R215', '86 ST')
# [52] ('C026', 'R215', '86 ST')
# [50] ('N558', 'R130', 'KINGS HWY')
# [50] ('N558', 'R130', 'KINGS HWY')
# [50] ('N182', 'R414', 'HOWARD BCH JFK')
# [50] ('N182', 'R414', 'HOWARD BCH JFK')
# [49] ('N184', 'R416', 'BEACH 90 ST')
# [49] ('N184', 'R416', 'BEACH 90 ST')
# [48] ('N133', 'R384', '88 ST')
# [48] ('N133', 'R384', '88 ST')
# [45] ('R308', 'R344', '145 ST')
# [45] ('R308', 'R344', '145 ST')
# [45] ('J032', 'R006', 'WOODHAVEN BLVD')
# [45] ('J032', 'R006', 'WOODHAVEN BLVD')
# [44] ('R643', 'R135', 'NEWKIRK AV')
# [44] ('R643', 'R135', 'NEWKIRK AV')
# [42] ('N339', 'R114', 'PARSONS BLVD')
# [42] ('N339', 'R114', 'PARSONS BLVD')
# [40] ('N186', 'R418', 'BEACH 105 ST')
# [40] ('N186', 'R418', 'BEACH 105 ST')
# [38] ('N547', 'R420', 'DITMAS AV')
# [38] ('N547', 'R420', 'DITMAS AV')
# [38] ('N544', 'R289', 'FT HAMILTON PKY')
# [38] ('N544', 'R289', 'FT HAMILTON PKY')
# [37] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [37] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [36] ('J037', 'R009', '121 ST')
# [36] ('J037', 'R009', '121 ST')
# [36] ('D009', 'R393', '20 AV')
# [36] ('D009', 'R393', '20 AV')
# [34] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [34] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [34] ('D008', 'R392', '18 AV')
# [34] ('D008', 'R392', '18 AV')
# [32] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [32] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [28] ('N338', 'R128', 'SUTPHIN BLVD')
# [28] ('N338', 'R128', 'SUTPHIN BLVD')
# [28] ('N130', 'R383', '80 ST')
# [28] ('N130', 'R383', '80 ST')
# [27] ('N139', 'R355', '111 ST')
# [27] ('N139', 'R355', '111 ST')
# [23] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [23] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [23] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [23] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [22] ('N003', 'R185', 'DYCKMAN ST')
# [22] ('N003', 'R185', 'DYCKMAN ST')
# [21] ('R506', 'R276', 'VERNON-JACKSON')
# [21] ('R506', 'R276', 'VERNON-JACKSON')
# [16] ('N183', 'R415', 'BROAD CHANNEL')
# [16] ('N183', 'R415', 'BROAD CHANNEL')
# [15] ('J034', 'R007', '104 ST')
# [15] ('J034', 'R007', '104 ST')
# [12] ('N022', 'R332', '135 ST')
# [12] ('N022', 'R332', '135 ST')
# [10] ('R196', 'R306', '238 ST')
# [10] ('R196', 'R306', '238 ST')
# [8] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [8] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [7] ('N123B', 'R439', 'ROCKAWAY AV')
# [7] ('N123B', 'R439', 'ROCKAWAY AV')
# [6] ('R532H', 'R328', 'METS-WILLETS PT')
# [6] ('R532H', 'R328', 'METS-WILLETS PT')
# [5] ('N223', 'R156', 'BEDFORD PK BLVD')
# [5] ('N223', 'R156', 'BEDFORD PK BLVD')
# [5] ('A084', 'R125', 'BROAD ST')
# [5] ('A084', 'R125', 'BROAD ST')
# [4] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [4] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [2] ('N138', 'R355', '111 ST')
# [2] ('N138', 'R355', '111 ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# [0] ('N550', 'R242', '18 AV')
# 0 ('A085', 'R125', 'BROAD ST')
# 0 ('A085', 'R125', 'BROAD ST')
# [-18] ('N029', 'R333', '116 ST')
# [-18] ('N029', 'R333', '116 ST')
# [-1189] ('R241A', 'R048', 'GRD CNTRL-42 ST')
# [-1189] ('R241A', 'R048', 'GRD CNTRL-42 ST')

# %%
tuesday = MTA[MTA.DATE == '06/13/2017']
tuesday = tuesday.reset_index(drop=True)

tuesday_dict = {}
for i in range(len(tuesday.index)):
    mytuple = (tuesday["C/A"][i],tuesday.UNIT[i],tuesday.SCP[i],tuesday.STATION[i])
    if mytuple not in tuesday_dict.keys():
        tuesday_dict[mytuple] = [(tuesday.TIME[i],tuesday.EXITS[i])]
    else:
        tuesday_dict[mytuple].append((tuesday.TIME[i],tuesday.EXITS[i]))

tuesday_dict_diff = {}
for key,value in tuesday_dict.items():
    for i in range(1,len(value)):
        if key not in tuesday_dict_diff:
            tuesday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            tuesday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in tuesday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value
#2055 riders at 6 AV
        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = tuesday[(tuesday.TIME=='05:00:00')|(tuesday.TIME=='06:00:00')|(tuesday.TIME=='07:00:00')|(tuesday.TIME=='08:00:00')|(tuesday.TIME=='09:00:00')|(tuesday.TIME=='10:00:00')|(tuesday.TIME=='11:00:00')|(tuesday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

tuesday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    tuesday_morning_passengers.append(mytuple)
tuesday_morning_passengers.sort(reverse=True)
for key,value in tuesday_morning_passengers:
    print(key,value)
# Out:
# [18018] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [17101] ('N500', 'R020', '47-50 STS ROCK')
# [13909] ('N501', 'R020', '47-50 STS ROCK')
# [13217] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [12800] ('N306', 'R017', 'LEXINGTON AV/53')
# [11123] ('N504', 'R021', '42 ST-BRYANT PK')
# [10931] ('A025', 'R023', '34 ST-HERALD SQ')
# [9985] ('N304', 'R015', '5 AV/53 ST')
# [9771] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9728] ('N505', 'R022', '34 ST-HERALD SQ')
# [9305] ('R249', 'R179', '86 ST')
# [9091] ('N051', 'R084', '59 ST COLUMBUS')
# [8220] ('N303', 'R015', '5 AV/53 ST')
# [8043] ('N049', 'R084', '59 ST COLUMBUS')
# [7915] ('R116', 'R030', 'CHAMBERS ST')
# [7704] ('N507', 'R023', '34 ST-HERALD SQ')
# [7629] ('N305', 'R017', 'LEXINGTON AV/53')
# [7279] ('N506', 'R022', '34 ST-HERALD SQ')
# [6887] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6744] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6669] ('N501A', 'R020', '47-50 STS ROCK')
# [6596] ('N098', 'R028', 'FULTON ST')
# [6519] ('N503', 'R021', '42 ST-BRYANT PK')
# [6380] ('R243', 'R049', '51 ST')
# [6373] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6310] ('R155', 'R116', '50 ST')
# [6131] ('R501', 'R054', '5 AVE')
# [6034] ('R258', 'R132', '125 ST')
# [6020] ('R245A', 'R051', '59 ST')
# [5893] ('R206', 'R014', 'FULTON ST')
# [5877] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [5612] ('N520', 'R240', 'GRAND ST')
# [5590] ('R202', 'R042', 'BOWLING GREEN')
# [5553] ('R182', 'R035', '168 ST')
# [5382] ('A033', 'R170', '14 ST-UNION SQ')
# [5361] ('R246', 'R177', '68ST-HUNTER CO')
# [5341] ('N509', 'R203', '23 ST')
# [5266] ('R111', 'R027', 'WALL ST')
# [5095] ('R244', 'R050', '59 ST')
# [5065] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4992] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4832] ('A006', 'R079', '5 AV/59 ST')
# [4821] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4801] ('N508', 'R453', '23 ST')
# [4800] ('R550', 'R072', '34 ST-HUDSON YD')
# [4797] ('R533', 'R055', 'FLUSHING-MAIN')
# [4789] ('R204', 'R043', 'WALL ST')
# [4784] ('R113', 'R028', 'FULTON ST')
# [4771] ('N092', 'R029', 'CHAMBERS ST')
# [4742] ('R247', 'R178', '77 ST')
# [4690] ('R154', 'R116', '50 ST')
# [4687] ('A022', 'R022', '34 ST-HERALD SQ')
# [4627] ('R221', 'R170', '14 ST-UNION SQ')
# [4611] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [4562] ('R201', 'R041', 'BOWLING GREEN')
# [4559] ('A034', 'R170', '14 ST-UNION SQ')
# [4392] ('N089', 'R139', 'CANAL ST')
# [4368] ('N600', 'R302', '57 ST')
# [4354] ('N067', 'R012', '34 ST-PENN STA')
# [4342] ('R244A', 'R050', '59 ST')
# [4332] ('H009', 'R235', 'BEDFORD AV')
# [4258] ('N102', 'R127', 'JAY ST-METROTEC')
# [4181] ('N103', 'R127', 'JAY ST-METROTEC')
# [4100] ('R110', 'R027', 'WALL ST')
# [4076] ('N026', 'R102', '125 ST')
# [4048] ('R601A', 'R108', 'BOROUGH HALL')
# [4016] ('R169', 'R168', '96 ST')
# [3954] ('N700A', 'R570', '72 ST-2 AVE')
# [3924] ('N301', 'R113', '7 AV')
# [3881] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3857] ('N094', 'R029', 'WORLD TRADE CTR')
# [3814] ('R142', 'R293', '34 ST-PENN STA')
# [3788] ('N502', 'R021', '42 ST-BRYANT PK')
# [3677] ('R158', 'R084', '59 ST COLUMBUS')
# [3659] ('N700', 'R570', '72 ST-2 AVE')
# [3636] ('N091', 'R029', 'CHAMBERS ST')
# [3569] ('R242', 'R049', '51 ST')
# [3537] ('R112', 'R027', 'WALL ST')
# [3429] ('A049', 'R088', 'CORTLANDT ST')
# [3427] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3423] ('A002', 'R051', '59 ST')
# [3387] ('N060', 'R010', '42 ST-PORT AUTH')
# [3358] ('N095A', 'R014', 'FULTON ST')
# [3335] ('A060', 'R001', 'WHITEHALL S-FRY')
# [3327] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3313] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3309] ('A029', 'R082', '28 ST')
# [3277] ('A046', 'R463', 'CANAL ST')
# [3258] ('R216', 'R322', 'SPRING ST')
# [3257] ('A031', 'R083', '23 ST')
# [3244] ('A043', 'R462', 'CANAL ST')
# [3236] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [3219] ('A042', 'R086', 'PRINCE ST')
# [3212] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3205] ('N090', 'R139', 'CANAL ST')
# [3179] ('H008', 'R248', '1 AV')
# [3109] ('R526', 'R096', '82 ST-JACKSON H')
# [3101] ('N063A', 'R011', '42 ST-PORT AUTH')
# [3098] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3088] ('R516', 'R291', '33 ST-RAWSON ST')
# [3038] ('N071', 'R013', '34 ST-PENN STA')
# [2988] ('A030', 'R083', '23 ST')
# [2966] ('R200A', 'R041', 'BOWLING GREEN')
# [2933] ('R112A', 'R027', 'WALL ST')
# [2918] ('N601', 'R319', 'LEXINGTON AV/63')
# [2909] ('N078', 'R175', '14 ST')
# [2905] ('R602', 'R108', 'BOROUGH HALL')
# [2899] ('R138', 'R293', '34 ST-PENN STA')
# [2846] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2843] ('A013', 'R081', '49 ST')
# [2827] ('A015', 'R081', '49 ST')
# [2799] ('R161B', 'R452', '72 ST')
# [2789] ('A035', 'R170', '14 ST-UNION SQ')
# [2788] ('R101', 'R001', 'SOUTH FERRY')
# [2769] ('N108', 'R217', 'HOYT-SCHER')
# [2767] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2748] ('A010', 'R080', '57 ST-7 AV')
# [2740] ('R168A', 'R168', '96 ST')
# [2739] ('N020', 'R101', '145 ST')
# [2727] ('A081', 'R028', 'FULTON ST')
# [2709] ('N300', 'R113', '7 AV')
# [2684] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2678] ('N400A', 'R359', 'COURT SQ')
# [2624] ('H001', 'R175', '8 AV')
# [2577] ('R141', 'R031', '34 ST-PENN STA')
# [2570] ('R248', 'R178', '77 ST')
# [2546] ('N095', 'R014', 'FULTON ST')
# [2535] ('R226', 'R131', '23 ST')
# [2489] ('N601A', 'R319', 'LEXINGTON AV/63')
# [2468] ('R114', 'R028', 'FULTON ST')
# [2464] ('A058', 'R001', 'WHITEHALL S-FRY')
# [2457] ('R232', 'R176', '33 ST')
# [2450] ('N076', 'R111', '23 ST')
# [2447] ('A039', 'R085', '8 ST-NYU')
# [2445] ('N070', 'R012', '34 ST-PENN STA')
# [2444] ('N309A', 'R140', 'QUEENS PLAZA')
# [2334] ('A027', 'R082', '28 ST')
# [2320] ('R242A', 'R049', '51 ST')
# [2309] ('R252', 'R180', '103 ST')
# [2281] ('N069', 'R013', '34 ST-PENN STA')
# [2280] ('N046', 'R281', '72 ST')
# [2237] ('R137', 'R031', '34 ST-PENN STA')
# [2236] ('N073', 'R013', '34 ST-PENN STA')
# [2226] ('N056', 'R188', '50 ST')
# [2224] ('N512', 'R163', '14 ST')
# [2223] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2206] ('N068', 'R012', '34 ST-PENN STA')
# [2203] ('R228', 'R143', '28 ST')
# [2159] ('H007', 'R248', '1 AV')
# [2150] ('R102', 'R304', 'RECTOR ST')
# [2141] ('C008', 'R099', 'DEKALB AV')
# [2140] ('R507', 'R134', 'HUNTERS PT AV')
# [2140] ('N077', 'R111', '23 ST')
# [2117] ('R159', 'R164', '66 ST-LINCOLN')
# [2113] ('N510', 'R163', '14 ST')
# [2112] ('R534', 'R055', 'FLUSHING-MAIN')
# [2066] ('R229', 'R143', '28 ST')
# [2011] ('R261', 'R205', '149/GRAND CONC')
# [1910] ('R203', 'R043', 'WALL ST')
# [1897] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1885] ('N523', 'R300', '2 AV')
# [1878] ('A047', 'R087', 'CITY HALL')
# [1872] ('R127', 'R105', '14 ST')
# [1866] ('R208', 'R014', 'FULTON ST')
# [1846] ('R173', 'R159', '116 ST-COLUMBIA')
# [1837] ('N063', 'R011', '42 ST-PORT AUTH')
# [1811] ('A014', 'R081', '49 ST')
# [1760] ('R165', 'R167', '86 ST')
# [1751] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1743] ('R508', 'R346', 'COURT SQ')
# [1743] ('A069', 'R044', 'CHAMBERS ST')
# [1733] ('A011', 'R080', '57 ST-7 AV')
# [1713] ('A037', 'R170', '14 ST-UNION SQ')
# [1701] ('R412', 'R146', 'HUNTS POINT AV')
# [1697] ('N044', 'R187', '81 ST-MUSEUM')
# [1686] ('R161A', 'R452', '72 ST')
# [1679] ('R217A', 'R194', 'BLEECKER ST')
# [1675] ('R528', 'R097', 'JUNCTION BLVD')
# [1640] ('R124', 'R290', 'HOUSTON ST')
# [1638] ('R115', 'R029', 'PARK PLACE')
# [1633] ('C012', 'R258', '4AV-9 ST')
# [1626] ('R605', 'R456', 'HOYT ST')
# [1609] ('R609', 'R056', 'NEVINS ST')
# [1603] ('B016', 'R098', 'CHURCH AV')
# [1590] ('R135', 'R031', '34 ST-PENN STA')
# [1589] ('R245', 'R051', '59 ST')
# [1585] ('R183', 'R260', '181 ST')
# [1571] ('N072', 'R012', '34 ST-PENN STA')
# [1549] ('N511', 'R163', '14 ST')
# [1544] ('R132', 'R190', '23 ST')
# [1543] ('D002', 'R390', '8 AV')
# [1537] ('N607', 'R025', 'JAMAICA CENTER')
# [1516] ('R250', 'R179', '86 ST')
# [1513] ('R529', 'R208', '103 ST-CORONA')
# [1510] ('R523', 'R147', '61 ST WOODSIDE')
# [1499] ('R185', 'R274', '191 ST')
# [1494] ('N062', 'R011', '42 ST-PORT AUTH')
# [1480] ('A041', 'R086', 'PRINCE ST')
# [1477] ('C018', 'R197', '36 ST')
# [1468] ('R301', 'R323', 'CENTRAL PK N110')
# [1467] ('R174', 'R034', '125 ST')
# [1465] ('R251', 'R144', '96 ST')
# [1461] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1455] ('R204A', 'R043', 'WALL ST')
# [1423] ('N405', 'R239', 'GREENPOINT AV')
# [1402] ('N101', 'R252', 'HIGH ST')
# [1402] ('H005', 'R330', '3 AV')
# [1396] ('R283', 'R221', '167 ST')
# [1390] ('R311', 'R053', '3 AV-149 ST')
# [1389] ('N521', 'R300', '2 AV')
# [1379] ('R126', 'R189', 'CHRISTOPHER ST')
# [1366] ('N043', 'R186', '86 ST')
# [1357] ('R331', 'R364', 'GUN HILL RD')
# [1353] ('N701A', 'R571', '86 ST-2 AVE')
# [1352] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1337] ('R130', 'R321', '18 ST')
# [1331] ('R220', 'R160', 'ASTOR PL')
# [1329] ('A016', 'R081', '49 ST')
# [1308] ('N536', 'R270', 'SMITH-9 ST')
# [1307] ('A007', 'R079', '5 AV/59 ST')
# [1289] ('R420', 'R107', 'WESTCHESTER SQ')
# [1285] ('A050', 'R088', 'CORTLANDT ST')
# [1283] ('R518', 'R261', '40 ST LOWERY ST')
# [1278] ('B031', 'R172', 'BRIGHTON BEACH')
# [1275] ('N702', 'R572', '96 ST-2 AVE')
# [1268] ('R231', 'R176', '33 ST')
# [1262] ('R164', 'R167', '86 ST')
# [1262] ('N513', 'R163', '14 ST')
# [1261] ('R513', 'R093', '30 AV')
# [1247] ('R417', 'R222', 'PARKCHESTER')
# [1247] ('J001', 'R460', 'MARCY AV')
# [1239] ('B024', 'R211', 'KINGS HWY')
# [1235] ('A083', 'R125', 'BROAD ST')
# [1234] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1232] ('R515', 'R095', 'ASTORIA DITMARS')
# [1232] ('N124', 'R103', 'BROADWAY JCT')
# [1227] ('N040', 'R251', '96 ST')
# [1222] ('R503', 'R276', 'VERNON-JACKSON')
# [1201] ('R231A', 'R176', '33 ST')
# [1193] ('R134', 'R272', '28 ST')
# [1188] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1186] ('B024A', 'R211', 'KINGS HWY')
# [1181] ('N315', 'R238', 'STEINWAY ST')
# [1176] ('N057', 'R188', '50 ST')
# [1142] ('N539A', 'R288', '7 AV')
# [1128] ('R608', 'R056', 'NEVINS ST')
# [1118] ('R205A', 'R014', 'FULTON ST')
# [1112] ('R256', 'R182', '116 ST')
# [1103] ('J002', 'R460', 'MARCY AV')
# [1098] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1091] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1076] ('R284', 'R243', '170 ST')
# [1075] ('R128', 'R105', '14 ST')
# [1067] ('R604', 'R108', 'BOROUGH HALL')
# [1066] ('R160A', 'R164', '66 ST-LINCOLN')
# [1062] ('N310', 'R140', 'QUEENS PLAZA')
# [1061] ('R511', 'R091', '36 AV')
# [1057] ('N702A', 'R572', '96 ST-2 AVE')
# [1049] ('C003', 'R089', 'JAY ST-METROTEC')
# [1047] ('R160', 'R164', '66 ST-LINCOLN')
# [1037] ('R519', 'R223', '46 ST BLISS ST')
# [1034] ('R527', 'R122', '90 ST-ELMHURST')
# [1034] ('G009', 'R151', 'CONEY IS-STILLW')
# [1017] ('H016', 'R250', 'GRAND ST')
# [1015] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1000] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [994] ('B004', 'R171', '7 AV')
# [988] ('N327', 'R254', 'GRAND-NEWTOWN')
# [972] ('N537', 'R258', '4 AV-9 ST')
# [968] ('R629', 'R065', 'ROCKAWAY AV')
# [960] ('N422', 'R318', 'FULTON ST')
# [949] ('N330', 'R202', '63 DR-REGO PARK')
# [943] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [941] ('N535', 'R220', 'CARROLL ST')
# [939] ('N117', 'R198', 'NOSTRAND AV')
# [929] ('R120', 'R320', 'CANAL ST')
# [928] ('R253', 'R181', '110 ST')
# [921] ('R512', 'R092', 'BROADWAY')
# [921] ('N602', 'R259', 'ROOSEVELT ISLND')
# [908] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [905] ('A077', 'R028', 'FULTON ST')
# [904] ('R622', 'R123', 'FRANKLIN AV')
# [904] ('R304', 'R206', '125 ST')
# [898] ('N013', 'R035', '168 ST')
# [898] ('A064', 'R311', 'BOWERY')
# [893] ('R162', 'R166', '79 ST')
# [891] ('H014', 'R249', 'GRAHAM AV')
# [886] ('R232A', 'R176', '33 ST')
# [875] ('N339A', 'R114', 'PARSONS BLVD')
# [874] ('N604', 'R342', 'JAMAICA VAN WK')
# [871] ('N329', 'R201', 'WOODHAVEN BLVD')
# [869] ('N025', 'R102', '125 ST')
# [865] ('R530', 'R310', '111 ST')
# [864] ('C025', 'R215', '86 ST')
# [855] ('N217', 'R112', 'FORDHAM RD')
# [851] ('N120', 'R153', 'UTICA AV')
# [850] ('R171', 'R192', 'CATHEDRAL PKWY')
# [846] ('D005', 'R398', 'NEW UTRECHT AV')
# [845] ('R175', 'R169', '137 ST CITY COL')
# [837] ('N196', 'R285', 'FAR ROCKAWAY')
# [836] ('N528', 'R257', 'EAST BROADWAY')
# [833] ('R401', 'R445', '3 AV 138 ST')
# [826] ('R103', 'R304', 'RECTOR ST')
# [824] ('R634', 'R069', 'NEW LOTS AV')
# [822] ('R517', 'R291', '33 ST-RAWSON ST')
# [820] ('R336', 'R145', 'WAKEFIELD/241')
# [816] ('R254', 'R181', '110 ST')
# [812] ('A054', 'R227', 'RECTOR ST')
# [809] ('N546', 'R204', 'CHURCH AV')
# [809] ('N213', 'R154', 'TREMONT AV')
# [808] ('B029', 'R172', 'BRIGHTON BEACH')
# [806] ('N116', 'R198', 'NOSTRAND AV')
# [802] ('N100', 'R252', 'HIGH ST')
# [801] ('N333B', 'R141', 'FOREST HILLS 71')
# [792] ('H019', 'R294', 'MORGAN AV')
# [791] ('R230', 'R143', '28 ST')
# [785] ('N530', 'R301', 'YORK ST')
# [780] ('R287', 'R244', 'BURNSIDE AV')
# [777] ('R418', 'R106', 'CASTLE HILL AV')
# [773] ('R290', 'R161', 'KINGSBRIDGE RD')
# [772] ('A038', 'R085', '8 ST-NYU')
# [770] ('N526', 'R142', 'DELANCEY/ESSEX')
# [769] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [766] ('R227A', 'R131', '23 ST')
# [765] ('N701', 'R571', '86 ST-2 AVE')
# [763] ('C019', 'R232', '45 ST')
# [762] ('R310', 'R053', '3 AV-149 ST')
# [760] ('N307', 'R359', 'COURT SQ-23 ST')
# [756] ('R423', 'R429', 'PELHAM BAY PARK')
# [754] ('J020', 'R433', 'ALABAMA AV')
# [753] ('R600', 'R224', 'CLARK ST')
# [750] ('H006', 'R330', '3 AV')
# [749] ('H039', 'R375', 'NEW LOTS')
# [746] ('E004', 'R234', '50 ST')
# [745] ('N312', 'R339', '36 ST')
# [744] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [743] ('N039', 'R251', '96 ST')
# [736] ('A066', 'R118', 'CANAL ST')
# [734] ('B019', 'R149', 'NEWKIRK PLAZA')
# [730] ('R628', 'R064', 'SARATOGA AV')
# [727] ('R170', 'R191', '103 ST')
# [721] ('N086', 'R282', 'SPRING ST')
# [721] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [718] ('R514', 'R094', 'ASTORIA BLVD')
# [715] ('R635', 'R277', 'PRESIDENT ST')
# [703] ('R131', 'R190', '23 ST')
# [699] ('R323', 'R387', 'WEST FARMS SQ')
# [689] ('R624', 'R124', 'KINGSTON AV')
# [688] ('N531', 'R129', 'BERGEN ST')
# [680] ('R259', 'R307', '138/GRAND CONC')
# [678] ('N549', 'R242', '18 AV')
# [673] ('N401', 'R360', '21 ST')
# [673] ('J009', 'R378', 'MYRTLE AV')
# [670] ('N343', 'R019', 'JAMAICA 179 ST')
# [670] ('N141', 'R356', 'OZONE PK LEFFRT')
# [666] ('R285', 'R308', 'MT EDEN AV')
# [665] ('R525', 'R018', '74 ST-BROADWAY')
# [664] ('R403', 'R446', 'BROOK AV')
# [663] ('B022', 'R229', 'AVENUE M')
# [662] ('R139', 'R031', '34 ST-PENN STA')
# [656] ('N408A', 'R256', 'NASSAU AV')
# [655] ('N019', 'R101', '145 ST')
# [652] ('R186', 'R036', 'DYCKMAN ST')
# [651] ('R291', 'R183', 'BEDFORD PK BLVD')
# [651] ('N010', 'R126', '175 ST')
# [651] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [647] ('R510', 'R090', '39 AV')
# [645] ('B021', 'R228', 'AVENUE J')
# [641] ('G001', 'R151', 'CONEY IS-STILLW')
# [637] ('R129', 'R321', '18 ST')
# [633] ('H040', 'R376', 'EAST 105 ST')
# [632] ('R219', 'R160', 'ASTOR PL')
# [631] ('N409', 'R268', 'METROPOLITAN AV')
# [628] ('B012', 'R196', 'PROSPECT PARK')
# [619] ('N419', 'R287', 'CLASSON AV')
# [617] ('J007', 'R377', 'FLUSHING AV')
# [615] ('R325', 'R388', 'E 180 ST')
# [610] ('N529', 'R257', 'EAST BROADWAY')
# [608] ('R623', 'R061', 'NOSTRAND AV')
# [604] ('R625', 'R062', 'CROWN HTS-UTICA')
# [604] ('R188', 'R037', '207 ST')
# [604] ('H017', 'R265', 'MONTROSE AV')
# [598] ('R163', 'R166', '79 ST')
# [597] ('R133', 'R272', '28 ST')
# [596] ('R415', 'R120', 'MORISN AV/SNDVW')
# [590] ('B013', 'R196', 'PROSPECT PARK')
# [589] ('R606', 'R225', 'HOYT ST')
# [589] ('R215', 'R322', 'SPRING ST')
# [587] ('R414', 'R162', 'ELDER AV')
# [580] ('R118', 'R343', 'FRANKLIN ST')
# [572] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [568] ('R504', 'R276', 'VERNON-JACKSON')
# [565] ('R172', 'R192', 'CATHEDRAL PKWY')
# [565] ('E014', 'R374', 'BAY PKWY')
# [561] ('R177', 'R273', '145 ST')
# [558] ('R316', 'R407', 'INTERVALE AV')
# [558] ('N316A', 'R267', '46 ST')
# [556] ('N412', 'R299', 'BROADWAY')
# [555] ('E001', 'R368', '9 AV')
# [554] ('R524', 'R347', '69 ST')
# [547] ('R286', 'R309', '176 ST')
# [547] ('N045', 'R187', '81 ST-MUSEUM')
# [541] ('R321', 'R386', '174 ST')
# [538] ('C021', 'R212', '59 ST')
# [528] ('R309', 'R345', 'HARLEM 148 ST')
# [527] ('K019', 'R413', 'KNICKERBOCKER')
# [525] ('R532', 'R328', 'METS-WILLETS PT')
# [525] ('C017', 'R455', '25 ST')
# [519] ('N075', 'R111', '23 ST')
# [518] ('N128', 'R200', 'EUCLID AV')
# [518] ('N114', 'R297', 'FRANKLIN AV')
# [517] ('N111', 'R284', 'CLINTON-WASH AV')
# [514] ('N120A', 'R153', 'UTICA AV')
# [513] ('R176', 'R169', '137 ST CITY COL')
# [511] ('D010', 'R394', 'BAY PKWY')
# [506] ('R419', 'R326', 'ZEREGA AV')
# [504] ('N314', 'R238', 'STEINWAY ST')
# [502] ('R203A', 'R043', 'WALL ST')
# [502] ('N207', 'R104', '167 ST')
# [494] ('C011', 'R231', 'UNION ST')
# [490] ('N319', 'R298', 'NORTHERN BLVD')
# [490] ('E003', 'R369', 'FT HAMILTON PKY')
# [489] ('R405', 'R447', 'CYPRESS AV')
# [488] ('R307', 'R207', '135 ST')
# [487] ('H023', 'R236', 'DEKALB AV')
# [485] ('R411', 'R450', 'LONGWOOD AV')
# [484] ('H015', 'R250', 'GRAND ST')
# [481] ('N024', 'R332', '135 ST')
# [477] ('N340', 'R115', '169 ST')
# [475] ('R293', 'R133', 'MOSHOLU PKWY')
# [473] ('B015', 'R098', 'CHURCH AV')
# [471] ('N129', 'R382', 'GRANT AV')
# [466] ('R123', 'R290', 'HOUSTON ST')
# [459] ('R319', 'R409', 'FREEMAN ST')
# [458] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [455] ('R409', 'R449', 'E 149 ST')
# [451] ('C001', 'R108', 'BOROUGH HALL')
# [450] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [450] ('N340A', 'R115', '169 ST')
# [450] ('N318', 'R298', 'NORTHERN BLVD')
# [448] ('R521', 'R327', '52 ST')
# [447] ('N342', 'R019', 'JAMAICA 179 ST')
# [445] ('B023', 'R211', 'KINGS HWY')
# [443] ('R226A', 'R131', '23 ST')
# [443] ('N035', 'R334', 'CATHEDRAL PKWY')
# [442] ('H032', 'R295', 'WILSON AV')
# [439] ('N118', 'R199', 'KINGSTON-THROOP')
# [438] ('N532', 'R129', 'BERGEN ST')
# [437] ('A071', 'R044', 'CHAMBERS ST')
# [429] ('B009', 'R411', 'PARK PLACE')
# [427] ('R179', 'R193', '157 ST')
# [425] ('R257', 'R182', '116 ST')
# [423] ('N030', 'R333', '116 ST')
# [422] ('R416', 'R245', 'ST LAWRENCE AV')
# [420] ('N224', 'R157', 'NORWOOD 205 ST')
# [420] ('N122', 'R439', 'ROCKAWAY AV')
# [418] ('R166', 'R167', '86 ST')
# [417] ('R288', 'R275', '183 ST')
# [417] ('J024', 'R437', 'CRESCENT ST')
# [412] ('R305', 'R206', '125 ST')
# [411] ('R125', 'R189', 'CHRISTOPHER ST')
# [410] ('N331', 'R219', '67 AV')
# [409] ('D003', 'R391', 'FT HAMILTON PKY')
# [407] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [407] ('C010', 'R231', 'UNION ST')
# [401] ('R636', 'R209', 'STERLING ST')
# [400] ('R637', 'R451', 'WINTHROP ST')
# [398] ('B020', 'R263', 'AVENUE H')
# [393] ('N222', 'R156', 'BEDFORD PK BLVD')
# [392] ('R197', 'R117', 'V.CORTLANDT PK')
# [390] ('C016', 'R278', '25 ST')
# [385] ('R119', 'R320', 'CANAL ST')
# [383] ('R303', 'R324', '116 ST')
# [380] ('N333A', 'R141', 'FOREST HILLS 71')
# [379] ('N311', 'R339', '36 ST')
# [378] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [378] ('R178', 'R273', '145 ST')
# [375] ('K026', 'R100', 'METROPOLITAN AV')
# [373] ('R302', 'R324', '116 ST')
# [373] ('H038', 'R350', 'LIVONIA AV')
# [371] ('N414', 'R316', 'FLUSHING AV')
# [368] ('N555', 'R423', 'AVENUE N')
# [367] ('N112A', 'R284', 'CLINTON-WASH AV')
# [366] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [366] ('B010', 'R412', 'BOTANIC GARDEN')
# [364] ('R632', 'R067', 'PENNSYLVANIA AV')
# [364] ('N009', 'R174', '181 ST')
# [363] ('R306', 'R207', '135 ST')
# [362] ('N006A', 'R280', '190 ST')
# [362] ('K025', 'R404', 'FRESH POND RD')
# [362] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [361] ('N220', 'R155', 'KINGSBRIDGE RD')
# [360] ('R644', 'R135', 'NEWKIRK AV')
# [360] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [359] ('N191', 'R335', 'BEACH 67 ST')
# [359] ('N034', 'R334', 'CATHEDRAL PKWY')
# [356] ('J022', 'R435', 'CLEVELAND ST')
# [355] ('N113', 'R297', 'FRANKLIN AV')
# [353] ('R289', 'R119', 'FORDHAM RD')
# [351] ('R408', 'R449', 'E 149 ST')
# [346] ('R633', 'R068', 'VAN SICLEN AV')
# [346] ('N121B', 'R438', 'RALPH AV')
# [346] ('N037', 'R314', '103 ST')
# [344] ('R227', 'R131', '23 ST')
# [342] ('N023', 'R332', '135 ST')
# [339] ('R328', 'R361', 'PELHAM PKWY')
# [338] ('N414A', 'R316', 'FLUSHING AV')
# [337] ('N119', 'R199', 'KINGSTON-THROOP')
# [335] ('J023', 'R436', 'NORWOOD AV')
# [333] ('R402', 'R446', 'BROOK AV')
# [330] ('N221', 'R155', 'KINGSBRIDGE RD')
# [328] ('N557', 'R130', 'KINGS HWY')
# [328] ('J031', 'R006', 'WOODHAVEN BLVD')
# [327] ('J028', 'R004', '75 ST-ELDERTS')
# [326] ('B014', 'R148', 'PARKSIDE AV')
# [322] ('R727', 'R430', 'PELHAM PKWY')
# [322] ('E011', 'R371', '79 ST')
# [320] ('N325A', 'R218', 'ELMHURST AV')
# [320] ('C024', 'R214', '77 ST')
# [319] ('N087', 'R282', 'SPRING ST')
# [319] ('K017', 'R401', 'CENTRAL AV')
# [318] ('H037', 'R349', 'SUTTER AV')
# [308] ('N561', 'R271', 'AVENUE X')
# [305] ('R422', 'R428', 'BUHRE AV')
# [305] ('B018', 'R184', 'CORTELYOU RD')
# [303] ('D012', 'R395', 'KINGS HWY')
# [301] ('R180', 'R193', '157 ST')
# [301] ('J013', 'R380', 'GATES AV')
# [299] ('H022', 'R279', 'JEFFERSON ST')
# [296] ('J035', 'R008', '111 ST')
# [295] ('N126', 'R441', 'VAN SICLEN AVE')
# [293] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [290] ('R404', 'R447', 'CYPRESS AV')
# [289] ('N125', 'R440', 'LIBERTY AV')
# [286] ('N202', 'R315', '155 ST')
# [285] ('R413', 'R325', 'WHITLOCK AV')
# [282] ('E005', 'R247', '55 ST')
# [278] ('N556', 'R424', 'AVENUE P')
# [277] ('R618', 'R058', 'BERGEN ST')
# [276] ('R332', 'R365', '219 ST')
# [274] ('N195', 'R358', 'BEACH 25 ST')
# [273] ('N007A', 'R174', '181 ST')
# [271] ('R407', 'R448', "E 143/ST MARY'S")
# [270] ('B025', 'R150', 'AVENUE U')
# [269] ('J005', 'R353', 'LORIMER ST')
# [267] ('R294', 'R052', 'WOODLAWN')
# [265] ('J012', 'R379', 'KOSCIUSZKO ST')
# [264] ('R117', 'R343', 'FRANKLIN ST')
# [260] ('B032', 'R264', 'OCEAN PKWY')
# [258] ('H030', 'R266', 'HALSEY ST')
# [254] ('J021', 'R434', 'VAN SICLEN AV')
# [253] ('N333', 'R141', 'FOREST HILLS 71')
# [251] ('N110', 'R283', 'LAFAYETTE AV')
# [251] ('N017', 'R331', '155 ST')
# [250] ('R410', 'R450', 'LONGWOOD AV')
# [248] ('R333', 'R366', '225 ST')
# [246] ('R639', 'R109', 'CHURCH AV')
# [241] ('R617', 'R058', 'BERGEN ST')
# [241] ('N316', 'R267', '46 ST')
# [239] ('N534', 'R220', 'CARROLL ST')
# [237] ('R329', 'R362', 'ALLERTON AV')
# [237] ('N209', 'R443', '170 ST')
# [236] ('N559', 'R425', 'AVENUE U')
# [235] ('N551', 'R421', 'AVENUE I')
# [234] ('R421', 'R427', 'MIDDLETOWN RD')
# [233] ('N337', 'R255', 'BRIARWOOD')
# [230] ('R327', 'R361', 'PELHAM PKWY')
# [224] ('J016', 'R381', 'HALSEY ST')
# [222] ('N322', 'R340', '65 ST')
# [220] ('N192', 'R336', 'BEACH 60 ST')
# [220] ('B017', 'R262', 'BEVERLEY ROAD')
# [218] ('N215', 'R237', '182-183 STS')
# [217] ('N338B', 'R128', 'SUTPHIN BLVD')
# [217] ('E009', 'R370', '71 ST')
# [217] ('A055', 'R227', 'RECTOR ST')
# [210] ('R728', 'R226', 'GUN HILL RD')
# [210] ('N225', 'R157', 'NORWOOD 205 ST')
# [206] ('R312', 'R405', 'JACKSON AV')
# [206] ('N212', 'R253', '174-175 STS')
# [204] ('R334', 'R367', '233 ST')
# [204] ('R194', 'R040', '231 ST')
# [200] ('E012', 'R372', '18 AV')
# [198] ('N127', 'R442', 'SHEPHERD AV')
# [196] ('R190', 'R038', '215 ST')
# [194] ('N548', 'R420', 'DITMAS AV')
# [194] ('N134', 'R385', 'ROCKAWAY BLVD')
# [191] ('K024', 'R403', 'FOREST AVE')
# [191] ('H013', 'R249', 'GRAHAM AV')
# [188] ('N002A', 'R173', 'INWOOD-207 ST')
# [187] ('R260', 'R205', '149/GRAND CONC')
# [185] ('R335', 'R444', 'NEREID AV')
# [184] ('N001', 'R173', 'INWOOD-207 ST')
# [182] ('N208', 'R443', '170 ST')
# [177] ('R326', 'R389', 'BRONX PARK EAST')
# [173] ('H028', 'R266', 'HALSEY ST')
# [173] ('E016', 'R400', 'BAY 50 ST')
# [173] ('D015', 'R396', 'AVENUE U')
# [171] ('R315', 'R406', 'PROSPECT AV')
# [171] ('R192', 'R039', 'MARBLE HILL-225')
# [170] ('R122', 'R290', 'HOUSTON ST')
# [169] ('H035', 'R348', 'ATLANTIC AV')
# [168] ('R726', 'R329', 'MORRIS PARK')
# [165] ('J030', 'R005', '85 ST-FOREST PK')
# [162] ('K022', 'R402', 'SENECA AVE')
# [161] ('R317', 'R408', 'SIMPSON ST')
# [161] ('N012', 'R035', '168 ST')
# [158] ('J017', 'R432', 'CHAUNCEY ST')
# [157] ('E013', 'R373', '20 AV')
# [156] ('N011', 'R126', '175 ST')
# [156] ('H033', 'R313', 'BUSHWICK AV')
# [152] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [152] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [150] ('N187', 'R419', 'ROCKAWAY PARK B')
# [149] ('N553', 'R422', 'BAY PKWY')
# [147] ('N206', 'R104', '167 ST')
# [147] ('D016', 'R397', '86 ST')
# [146] ('N210', 'R253', '174-175 STS')
# [146] ('J003', 'R352', 'HEWES ST')
# [139] ('N330C', 'R202', '63 DR-REGO PARK')
# [139] ('N194', 'R338', 'BEACH 36 ST')
# [137] ('R121', 'R290', 'HOUSTON ST')
# [134] ('H012', 'R268', 'LORIMER ST')
# [134] ('C022', 'R212', '59 ST')
# [133] ('N317', 'R267', '46 ST')
# [130] ('A082', 'R028', 'FULTON ST')
# [129] ('R318', 'R408', 'SIMPSON ST')
# [125] ('N332', 'R219', '67 AV')
# [124] ('C004', 'R089', 'JAY ST-METROTEC')
# [122] ('R406', 'R448', "E 143/ST MARY'S")
# [120] ('N016A', 'R296', '163 ST-AMSTERDM')
# [118] ('N562', 'R426', 'NEPTUNE AV')
# [114] ('R641', 'R210', 'BEVERLY RD')
# [113] ('R330', 'R363', 'BURKE AV')
# [113] ('J025', 'R003', 'CYPRESS HILLS')
# [111] ('N543', 'R289', 'FT HAMILTON PKY')
# [109] ('N135', 'R385', 'ROCKAWAY BLVD')
# [104] ('R314', 'R406', 'PROSPECT AV')
# [101] ('R320', 'R409', 'FREEMAN ST')
# [99] ('N193', 'R337', 'BEACH 44 ST')
# [95] ('R322', 'R386', '174 ST')
# [94] ('B034', 'R264', 'OCEAN PKWY')
# [93] ('N181', 'R357', 'AQUEDUCT N.COND')
# [93] ('B026', 'R230', 'NECK RD')
# [91] ('R520', 'R223', '46 ST BLISS ST')
# [91] ('N533', 'R129', 'BERGEN ST')
# [86] ('N185', 'R417', 'BEACH 98 ST')
# [82] ('N545', 'R204', 'CHURCH AV')
# [81] ('E015', 'R399', '25 AV')
# [79] ('N334B', 'R341', '75 AV')
# [69] ('N420B', 'R317', 'CLINTON-WASH AV')
# [64] ('R729', 'R292', 'BAYCHESTER AV')
# [62] ('N184', 'R416', 'BEACH 90 ST')
# [61] ('N131', 'R383', '80 ST')
# [60] ('N182', 'R414', 'HOWARD BCH JFK')
# [59] ('N544', 'R289', 'FT HAMILTON PKY')
# [59] ('N186', 'R418', 'BEACH 105 ST')
# [56] ('C026', 'R215', '86 ST')
# [52] ('N558', 'R130', 'KINGS HWY')
# [52] ('N133', 'R384', '88 ST')
# [50] ('R643', 'R135', 'NEWKIRK AV')
# [50] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [44] ('N137', 'R354', '104 ST')
# [43] ('N339', 'R114', 'PARSONS BLVD')
# [41] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [40] ('N218', 'R112', 'FORDHAM RD')
# [35] ('R506', 'R276', 'VERNON-JACKSON')
# [35] ('N338', 'R128', 'SUTPHIN BLVD')
# [35] ('N003', 'R185', 'DYCKMAN ST')
# [33] ('J032', 'R006', 'WOODHAVEN BLVD')
# [31] ('R308', 'R344', '145 ST')
# [31] ('N130', 'R383', '80 ST')
# [29] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [25] ('N547', 'R420', 'DITMAS AV')
# [25] ('D009', 'R393', '20 AV')
# [24] ('J034', 'R007', '104 ST')
# [23] ('J037', 'R009', '121 ST')
# [22] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [20] ('N139', 'R355', '111 ST')
# [18] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [16] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [12] ('N022', 'R332', '135 ST')
# [11] ('A084', 'R125', 'BROAD ST')
# [10] ('R532H', 'R328', 'METS-WILLETS PT')
# [10] ('R196', 'R306', '238 ST')
# [9] ('N183', 'R415', 'BROAD CHANNEL')
# [9] ('N123B', 'R439', 'ROCKAWAY AV')
# [8] ('N138', 'R355', '111 ST')
# [6] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [6] ('N223', 'R156', 'BEDFORD PK BLVD')
# [4] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# 0 ('A085', 'R125', 'BROAD ST')
# [-7] ('D008', 'R392', '18 AV')
# [-57] ('N029', 'R333', '116 ST')
# [-1041] ('R241A', 'R048', 'GRD CNTRL-42 ST')
# [-142693] ('N606', 'R025', 'JAMAICA CENTER')

# %%
wednesday = MTA[MTA.DATE == '06/14/2017']
wednesday = wednesday.reset_index(drop=True)

wednesday_dict = {}
for i in range(len(wednesday.index)):
    mytuple = (wednesday["C/A"][i],wednesday.UNIT[i],wednesday.SCP[i],wednesday.STATION[i])
    if mytuple not in wednesday_dict.keys():
        wednesday_dict[mytuple] = [(wednesday.TIME[i],wednesday.EXITS[i])]
    else:
        wednesday_dict[mytuple].append((wednesday.TIME[i],wednesday.EXITS[i]))

wednesday_dict_diff = {}
for key,value in wednesday_dict.items():
    for i in range(1,len(value)):
        if key not in wednesday_dict_diff:
            wednesday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            wednesday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in wednesday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value

        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = wednesday[(wednesday.TIME=='05:00:00')|(wednesday.TIME=='06:00:00')|(wednesday.TIME=='07:00:00')|(wednesday.TIME=='08:00:00')|(wednesday.TIME=='09:00:00')|(wednesday.TIME=='10:00:00')|(wednesday.TIME=='11:00:00')|(wednesday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

wednesday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    wednesday_morning_passengers.append(mytuple)
wednesday_morning_passengers.sort(reverse=True)
for key,value in wednesday_morning_passengers:
    print(key,value)
# Out:
# [19062] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [17657] ('N500', 'R020', '47-50 STS ROCK')
# [14245] ('N501', 'R020', '47-50 STS ROCK')
# [13346] ('N306', 'R017', 'LEXINGTON AV/53')
# [12904] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [11509] ('N504', 'R021', '42 ST-BRYANT PK')
# [10605] ('A025', 'R023', '34 ST-HERALD SQ')
# [10356] ('N304', 'R015', '5 AV/53 ST')
# [9904] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9868] ('N505', 'R022', '34 ST-HERALD SQ')
# [9256] ('N051', 'R084', '59 ST COLUMBUS')
# [8696] ('N303', 'R015', '5 AV/53 ST')
# [8424] ('R249', 'R179', '86 ST')
# [8196] ('N049', 'R084', '59 ST COLUMBUS')
# [8070] ('R116', 'R030', 'CHAMBERS ST')
# [7908] ('N305', 'R017', 'LEXINGTON AV/53')
# [7818] ('N507', 'R023', '34 ST-HERALD SQ')
# [7376] ('N506', 'R022', '34 ST-HERALD SQ')
# [7186] ('R151', 'R033', 'TIMES SQ-42 ST')
# [7136] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6736] ('N501A', 'R020', '47-50 STS ROCK')
# [6670] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [6643] ('N503', 'R021', '42 ST-BRYANT PK')
# [6564] ('R155', 'R116', '50 ST')
# [6409] ('N098', 'R028', 'FULTON ST')
# [6249] ('R501', 'R054', '5 AVE')
# [6241] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6211] ('R243', 'R049', '51 ST')
# [5960] ('R206', 'R014', 'FULTON ST')
# [5901] ('R245A', 'R051', '59 ST')
# [5687] ('R246', 'R177', '68ST-HUNTER CO')
# [5576] ('R182', 'R035', '168 ST')
# [5496] ('N509', 'R203', '23 ST')
# [5476] ('R244', 'R050', '59 ST')
# [5472] ('R202', 'R042', 'BOWLING GREEN')
# [5358] ('N520', 'R240', 'GRAND ST')
# [5325] ('R258', 'R132', '125 ST')
# [5317] ('N092', 'R029', 'CHAMBERS ST')
# [5271] ('A033', 'R170', '14 ST-UNION SQ')
# [5187] ('N508', 'R453', '23 ST')
# [5071] ('R111', 'R027', 'WALL ST')
# [5064] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [5025] ('R550', 'R072', '34 ST-HUDSON YD')
# [4990] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4922] ('R113', 'R028', 'FULTON ST')
# [4916] ('R154', 'R116', '50 ST')
# [4890] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4868] ('R244A', 'R050', '59 ST')
# [4762] ('R201', 'R041', 'BOWLING GREEN')
# [4667] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4662] ('N089', 'R139', 'CANAL ST')
# [4650] ('A022', 'R022', '34 ST-HERALD SQ')
# [4544] ('R204', 'R043', 'WALL ST')
# [4522] ('R247', 'R178', '77 ST')
# [4395] ('N600', 'R302', '57 ST')
# [4378] ('N301', 'R113', '7 AV')
# [4366] ('N102', 'R127', 'JAY ST-METROTEC')
# [4339] ('N091', 'R029', 'CHAMBERS ST')
# [4336] ('R533', 'R055', 'FLUSHING-MAIN')
# [4332] ('A006', 'R079', '5 AV/59 ST')
# [4290] ('N103', 'R127', 'JAY ST-METROTEC')
# [4258] ('R221', 'R170', '14 ST-UNION SQ')
# [4215] ('A034', 'R170', '14 ST-UNION SQ')
# [4151] ('N067', 'R012', '34 ST-PENN STA')
# [4110] ('N026', 'R102', '125 ST')
# [4091] ('R110', 'R027', 'WALL ST')
# [4008] ('N606', 'R025', 'JAMAICA CENTER')
# [3983] ('N502', 'R021', '42 ST-BRYANT PK')
# [3968] ('N095A', 'R014', 'FULTON ST')
# [3909] ('R601A', 'R108', 'BOROUGH HALL')
# [3904] ('R158', 'R084', '59 ST COLUMBUS')
# [3859] ('N094', 'R029', 'WORLD TRADE CTR')
# [3841] ('N700A', 'R570', '72 ST-2 AVE')
# [3823] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3764] ('R169', 'R168', '96 ST')
# [3609] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3593] ('R112', 'R027', 'WALL ST')
# [3585] ('R142', 'R293', '34 ST-PENN STA')
# [3575] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3572] ('N060', 'R010', '42 ST-PORT AUTH')
# [3504] ('N700', 'R570', '72 ST-2 AVE')
# [3500] ('A002', 'R051', '59 ST')
# [3459] ('A031', 'R083', '23 ST')
# [3457] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3439] ('A029', 'R082', '28 ST')
# [3422] ('A049', 'R088', 'CORTLANDT ST')
# [3408] ('N400A', 'R359', 'COURT SQ')
# [3387] ('A060', 'R001', 'WHITEHALL S-FRY')
# [3381] ('R242', 'R049', '51 ST')
# [3277] ('N090', 'R139', 'CANAL ST')
# [3252] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3242] ('A030', 'R083', '23 ST')
# [3222] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3205] ('A042', 'R086', 'PRINCE ST')
# [3204] ('R200A', 'R041', 'BOWLING GREEN')
# [3129] ('R526', 'R096', '82 ST-JACKSON H')
# [3112] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [3101] ('H008', 'R248', '1 AV')
# [3042] ('A046', 'R463', 'CANAL ST')
# [3006] ('R602', 'R108', 'BOROUGH HALL')
# [3006] ('A013', 'R081', '49 ST')
# [3002] ('N071', 'R013', '34 ST-PENN STA')
# [2993] ('R228', 'R143', '28 ST')
# [2932] ('N601', 'R319', 'LEXINGTON AV/63')
# [2893] ('N300', 'R113', '7 AV')
# [2874] ('R216', 'R322', 'SPRING ST')
# [2864] ('R112A', 'R027', 'WALL ST')
# [2851] ('N078', 'R175', '14 ST')
# [2834] ('N108', 'R217', 'HOYT-SCHER')
# [2829] ('A043', 'R462', 'CANAL ST')
# [2828] ('N020', 'R101', '145 ST')
# [2796] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2777] ('A015', 'R081', '49 ST')
# [2748] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2742] ('A035', 'R170', '14 ST-UNION SQ')
# [2741] ('N076', 'R111', '23 ST')
# [2711] ('R138', 'R293', '34 ST-PENN STA')
# [2657] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2652] ('H001', 'R175', '8 AV')
# [2636] ('A010', 'R080', '57 ST-7 AV')
# [2615] ('R168A', 'R168', '96 ST')
# [2582] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2574] ('R161B', 'R452', '72 ST')
# [2562] ('R226', 'R131', '23 ST')
# [2555] ('R101', 'R001', 'SOUTH FERRY')
# [2529] ('R248', 'R178', '77 ST')
# [2527] ('R516', 'R291', '33 ST-RAWSON ST')
# [2495] ('N601A', 'R319', 'LEXINGTON AV/63')
# [2464] ('N069', 'R013', '34 ST-PENN STA')
# [2463] ('N070', 'R012', '34 ST-PENN STA')
# [2454] ('N077', 'R111', '23 ST')
# [2446] ('C008', 'R099', 'DEKALB AV')
# [2432] ('N095', 'R014', 'FULTON ST')
# [2405] ('A081', 'R028', 'FULTON ST')
# [2357] ('N056', 'R188', '50 ST')
# [2356] ('N309A', 'R140', 'QUEENS PLAZA')
# [2349] ('A027', 'R082', '28 ST')
# [2341] ('A058', 'R001', 'WHITEHALL S-FRY')
# [2340] ('R252', 'R180', '103 ST')
# [2336] ('R242A', 'R049', '51 ST')
# [2335] ('N512', 'R163', '14 ST')
# [2321] ('A039', 'R085', '8 ST-NYU')
# [2320] ('N046', 'R281', '72 ST')
# [2306] ('N068', 'R012', '34 ST-PENN STA')
# [2256] ('R114', 'R028', 'FULTON ST')
# [2251] ('N073', 'R013', '34 ST-PENN STA')
# [2202] ('R141', 'R031', '34 ST-PENN STA')
# [2196] ('R232', 'R176', '33 ST')
# [2182] ('R507', 'R134', 'HUNTERS PT AV')
# [2162] ('H007', 'R248', '1 AV')
# [2123] ('R261', 'R205', '149/GRAND CONC')
# [2105] ('R203', 'R043', 'WALL ST')
# [2101] ('N510', 'R163', '14 ST')
# [2079] ('N523', 'R300', '2 AV')
# [2055] ('R183', 'R260', '181 ST')
# [2047] ('R528', 'R097', 'JUNCTION BLVD')
# [2043] ('R102', 'R304', 'RECTOR ST')
# [2040] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2022] ('R229', 'R143', '28 ST')
# [2020] ('R534', 'R055', 'FLUSHING-MAIN')
# [1933] ('R137', 'R031', '34 ST-PENN STA')
# [1918] ('N063', 'R011', '42 ST-PORT AUTH')
# [1890] ('R159', 'R164', '66 ST-LINCOLN')
# [1853] ('R127', 'R105', '14 ST')
# [1847] ('A047', 'R087', 'CITY HALL')
# [1832] ('A069', 'R044', 'CHAMBERS ST')
# [1831] ('A014', 'R081', '49 ST')
# [1828] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1816] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1808] ('N072', 'R012', '34 ST-PENN STA')
# [1791] ('R208', 'R014', 'FULTON ST')
# [1779] ('R217A', 'R194', 'BLEECKER ST')
# [1776] ('R523', 'R147', '61 ST WOODSIDE')
# [1775] ('R245', 'R051', '59 ST')
# [1768] ('C012', 'R258', '4AV-9 ST')
# [1759] ('R173', 'R159', '116 ST-COLUMBIA')
# [1698] ('R412', 'R146', 'HUNTS POINT AV')
# [1696] ('A011', 'R080', '57 ST-7 AV')
# [1691] ('R165', 'R167', '86 ST')
# [1671] ('A037', 'R170', '14 ST-UNION SQ')
# [1664] ('N062', 'R011', '42 ST-PORT AUTH')
# [1645] ('R124', 'R290', 'HOUSTON ST')
# [1634] ('R508', 'R346', 'COURT SQ')
# [1617] ('R605', 'R456', 'HOYT ST')
# [1616] ('R301', 'R323', 'CENTRAL PK N110')
# [1616] ('N511', 'R163', '14 ST')
# [1605] ('R135', 'R031', '34 ST-PENN STA')
# [1588] ('R161A', 'R452', '72 ST')
# [1586] ('N101', 'R252', 'HIGH ST')
# [1575] ('R132', 'R190', '23 ST')
# [1570] ('N044', 'R187', '81 ST-MUSEUM')
# [1566] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1518] ('R174', 'R034', '125 ST')
# [1516] ('D002', 'R390', '8 AV')
# [1509] ('R518', 'R261', '40 ST LOWERY ST')
# [1506] ('R115', 'R029', 'PARK PLACE')
# [1475] ('N521', 'R300', '2 AV')
# [1452] ('R283', 'R221', '167 ST')
# [1447] ('R609', 'R056', 'NEVINS ST')
# [1445] ('R529', 'R208', '103 ST-CORONA')
# [1435] ('A016', 'R081', '49 ST')
# [1433] ('N513', 'R163', '14 ST')
# [1424] ('C018', 'R197', '36 ST')
# [1417] ('B016', 'R098', 'CHURCH AV')
# [1414] ('N536', 'R270', 'SMITH-9 ST')
# [1411] ('R220', 'R160', 'ASTOR PL')
# [1403] ('A041', 'R086', 'PRINCE ST')
# [1402] ('R130', 'R321', '18 ST')
# [1396] ('N607', 'R025', 'JAMAICA CENTER')
# [1373] ('R204A', 'R043', 'WALL ST')
# [1368] ('N405', 'R239', 'GREENPOINT AV')
# [1361] ('R250', 'R179', '86 ST')
# [1355] ('H005', 'R330', '3 AV')
# [1354] ('N057', 'R188', '50 ST')
# [1352] ('R126', 'R189', 'CHRISTOPHER ST')
# [1348] ('N040', 'R251', '96 ST')
# [1340] ('R417', 'R222', 'PARKCHESTER')
# [1305] ('A007', 'R079', '5 AV/59 ST')
# [1302] ('R185', 'R274', '191 ST')
# [1299] ('R251', 'R144', '96 ST')
# [1295] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1291] ('N124', 'R103', 'BROADWAY JCT')
# [1282] ('R527', 'R122', '90 ST-ELMHURST')
# [1275] ('R134', 'R272', '28 ST')
# [1270] ('N701A', 'R571', '86 ST-2 AVE')
# [1267] ('N043', 'R186', '86 ST')
# [1261] ('N702', 'R572', '96 ST-2 AVE')
# [1253] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1249] ('R164', 'R167', '86 ST')
# [1248] ('R331', 'R364', 'GUN HILL RD')
# [1239] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1225] ('N315', 'R238', 'STEINWAY ST')
# [1221] ('B024', 'R211', 'KINGS HWY')
# [1217] ('R519', 'R223', '46 ST BLISS ST')
# [1213] ('N409', 'R268', 'METROPOLITAN AV')
# [1200] ('R503', 'R276', 'VERNON-JACKSON')
# [1198] ('R608', 'R056', 'NEVINS ST')
# [1192] ('A083', 'R125', 'BROAD ST')
# [1188] ('A050', 'R088', 'CORTLANDT ST')
# [1178] ('N539A', 'R288', '7 AV')
# [1172] ('R231A', 'R176', '33 ST')
# [1171] ('R420', 'R107', 'WESTCHESTER SQ')
# [1170] ('R311', 'R053', '3 AV-149 ST')
# [1158] ('R231', 'R176', '33 ST')
# [1157] ('R205A', 'R014', 'FULTON ST')
# [1153] ('J001', 'R460', 'MARCY AV')
# [1127] ('J002', 'R460', 'MARCY AV')
# [1126] ('R256', 'R182', '116 ST')
# [1126] ('R160A', 'R164', '66 ST-LINCOLN')
# [1111] ('R515', 'R095', 'ASTORIA DITMARS')
# [1107] ('B024A', 'R211', 'KINGS HWY')
# [1101] ('R513', 'R093', '30 AV')
# [1079] ('R284', 'R243', '170 ST')
# [1075] ('C003', 'R089', 'JAY ST-METROTEC')
# [1064] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1047] ('R128', 'R105', '14 ST')
# [1045] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1043] ('R511', 'R091', '36 AV')
# [1026] ('G009', 'R151', 'CONEY IS-STILLW')
# [1019] ('N537', 'R258', '4 AV-9 ST')
# [1013] ('N422', 'R318', 'FULTON ST')
# [999] ('R504', 'R276', 'VERNON-JACKSON')
# [998] ('N327', 'R254', 'GRAND-NEWTOWN')
# [996] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [995] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [988] ('R160', 'R164', '66 ST-LINCOLN')
# [974] ('R530', 'R310', '111 ST')
# [972] ('R287', 'R244', 'BURNSIDE AV')
# [972] ('N310', 'R140', 'QUEENS PLAZA')
# [970] ('H016', 'R250', 'GRAND ST')
# [954] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [952] ('N702A', 'R572', '96 ST-2 AVE')
# [949] ('A077', 'R028', 'FULTON ST')
# [942] ('N330', 'R202', '63 DR-REGO PARK')
# [942] ('N117', 'R198', 'NOSTRAND AV')
# [933] ('B004', 'R171', '7 AV')
# [932] ('N339A', 'R114', 'PARSONS BLVD')
# [923] ('N528', 'R257', 'EAST BROADWAY')
# [912] ('N217', 'R112', 'FORDHAM RD')
# [896] ('A054', 'R227', 'RECTOR ST')
# [894] ('R604', 'R108', 'BOROUGH HALL')
# [891] ('A064', 'R311', 'BOWERY')
# [883] ('R120', 'R320', 'CANAL ST')
# [877] ('R232A', 'R176', '33 ST')
# [876] ('R103', 'R304', 'RECTOR ST')
# [874] ('R629', 'R065', 'ROCKAWAY AV')
# [874] ('R336', 'R145', 'WAKEFIELD/241')
# [873] ('R304', 'R206', '125 ST')
# [871] ('N196', 'R285', 'FAR ROCKAWAY')
# [862] ('N025', 'R102', '125 ST')
# [859] ('R512', 'R092', 'BROADWAY')
# [859] ('N602', 'R259', 'ROOSEVELT ISLND')
# [856] ('N013', 'R035', '168 ST')
# [846] ('B031', 'R172', 'BRIGHTON BEACH')
# [842] ('H014', 'R249', 'GRAHAM AV')
# [840] ('D005', 'R398', 'NEW UTRECHT AV')
# [831] ('N116', 'R198', 'NOSTRAND AV')
# [827] ('R259', 'R307', '138/GRAND CONC')
# [826] ('A038', 'R085', '8 ST-NYU')
# [825] ('R171', 'R192', 'CATHEDRAL PKWY')
# [822] ('N546', 'R204', 'CHURCH AV')
# [817] ('N213', 'R154', 'TREMONT AV')
# [812] ('R162', 'R166', '79 ST')
# [812] ('C025', 'R215', '86 ST')
# [811] ('N120', 'R153', 'UTICA AV')
# [804] ('R622', 'R123', 'FRANKLIN AV')
# [802] ('E004', 'R234', '50 ST')
# [799] ('N100', 'R252', 'HIGH ST')
# [797] ('N329', 'R201', 'WOODHAVEN BLVD')
# [796] ('N604', 'R342', 'JAMAICA VAN WK')
# [795] ('N701', 'R571', '86 ST-2 AVE')
# [792] ('R401', 'R445', '3 AV 138 ST')
# [789] ('N535', 'R220', 'CARROLL ST')
# [784] ('H003', 'R163', '6 AV')
# [780] ('R291', 'R183', 'BEDFORD PK BLVD')
# [779] ('H006', 'R330', '3 AV')
# [777] ('N307', 'R359', 'COURT SQ-23 ST')
# [774] ('N086', 'R282', 'SPRING ST')
# [773] ('R175', 'R169', '137 ST CITY COL')
# [772] ('R290', 'R161', 'KINGSBRIDGE RD')
# [771] ('R635', 'R277', 'PRESIDENT ST')
# [767] ('R310', 'R053', '3 AV-149 ST')
# [762] ('N549', 'R242', '18 AV')
# [759] ('H019', 'R294', 'MORGAN AV')
# [756] ('B019', 'R149', 'NEWKIRK PLAZA')
# [740] ('R230', 'R143', '28 ST')
# [737] ('H017', 'R265', 'MONTROSE AV')
# [730] ('R253', 'R181', '110 ST')
# [728] ('N312', 'R339', '36 ST')
# [725] ('R517', 'R291', '33 ST-RAWSON ST')
# [724] ('R415', 'R120', 'MORISN AV/SNDVW')
# [723] ('H015', 'R250', 'GRAND ST')
# [719] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [718] ('R170', 'R191', '103 ST')
# [718] ('R133', 'R272', '28 ST')
# [714] ('N531', 'R129', 'BERGEN ST')
# [709] ('R323', 'R387', 'WEST FARMS SQ')
# [708] ('N316A', 'R267', '46 ST')
# [707] ('N141', 'R356', 'OZONE PK LEFFRT')
# [706] ('N408A', 'R256', 'NASSAU AV')
# [703] ('R418', 'R106', 'CASTLE HILL AV')
# [703] ('N419', 'R287', 'CLASSON AV')
# [700] ('N039', 'R251', '96 ST')
# [695] ('N530', 'R301', 'YORK ST')
# [695] ('N010', 'R126', '175 ST')
# [694] ('N526', 'R142', 'DELANCEY/ESSEX')
# [693] ('N333B', 'R141', 'FOREST HILLS 71')
# [692] ('B029', 'R172', 'BRIGHTON BEACH')
# [688] ('R600', 'R224', 'CLARK ST')
# [685] ('R514', 'R094', 'ASTORIA BLVD')
# [684] ('B021', 'R228', 'AVENUE J')
# [682] ('R634', 'R069', 'NEW LOTS AV')
# [682] ('R131', 'R190', '23 ST')
# [681] ('R525', 'R018', '74 ST-BROADWAY')
# [681] ('B012', 'R196', 'PROSPECT PARK')
# [680] ('R423', 'R429', 'PELHAM BAY PARK')
# [677] ('R285', 'R308', 'MT EDEN AV')
# [673] ('H039', 'R375', 'NEW LOTS')
# [669] ('N401', 'R360', '21 ST')
# [669] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [664] ('R403', 'R446', 'BROOK AV')
# [660] ('N529', 'R257', 'EAST BROADWAY')
# [659] ('R624', 'R124', 'KINGSTON AV')
# [659] ('N412', 'R299', 'BROADWAY')
# [657] ('R628', 'R064', 'SARATOGA AV')
# [654] ('J020', 'R433', 'ALABAMA AV')
# [653] ('R219', 'R160', 'ASTOR PL')
# [652] ('A066', 'R118', 'CANAL ST')
# [651] ('N019', 'R101', '145 ST')
# [651] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [649] ('C019', 'R232', '45 ST')
# [648] ('R129', 'R321', '18 ST')
# [642] ('R203A', 'R043', 'WALL ST')
# [638] ('N343', 'R019', 'JAMAICA 179 ST')
# [636] ('J009', 'R378', 'MYRTLE AV')
# [634] ('B022', 'R229', 'AVENUE M')
# [623] ('R254', 'R181', '110 ST')
# [616] ('R186', 'R036', 'DYCKMAN ST')
# [616] ('R163', 'R166', '79 ST')
# [614] ('R625', 'R062', 'CROWN HTS-UTICA')
# [613] ('R606', 'R225', 'HOYT ST')
# [604] ('R510', 'R090', '39 AV')
# [590] ('R215', 'R322', 'SPRING ST')
# [588] ('J007', 'R377', 'FLUSHING AV')
# [580] ('H040', 'R376', 'EAST 105 ST')
# [579] ('H023', 'R236', 'DEKALB AV')
# [578] ('G001', 'R151', 'CONEY IS-STILLW')
# [573] ('R524', 'R347', '69 ST')
# [570] ('R325', 'R388', 'E 180 ST')
# [569] ('C011', 'R231', 'UNION ST')
# [567] ('N111', 'R284', 'CLINTON-WASH AV')
# [561] ('R316', 'R407', 'INTERVALE AV')
# [554] ('R623', 'R061', 'NOSTRAND AV')
# [551] ('R118', 'R343', 'FRANKLIN ST')
# [545] ('N075', 'R111', '23 ST')
# [543] ('R227A', 'R131', '23 ST')
# [541] ('R286', 'R309', '176 ST')
# [539] ('R139', 'R031', '34 ST-PENN STA')
# [536] ('N045', 'R187', '81 ST-MUSEUM')
# [534] ('E001', 'R368', '9 AV')
# [532] ('R321', 'R386', '174 ST')
# [530] ('N340', 'R115', '169 ST')
# [528] ('B013', 'R196', 'PROSPECT PARK')
# [527] ('R123', 'R290', 'HOUSTON ST')
# [523] ('R176', 'R169', '137 ST CITY COL')
# [519] ('C017', 'R455', '25 ST')
# [516] ('K019', 'R413', 'KNICKERBOCKER')
# [513] ('N207', 'R104', '167 ST')
# [512] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [506] ('R188', 'R037', '207 ST')
# [505] ('N114', 'R297', 'FRANKLIN AV')
# [504] ('R411', 'R450', 'LONGWOOD AV')
# [503] ('N024', 'R332', '135 ST')
# [490] ('R172', 'R192', 'CATHEDRAL PKWY')
# [488] ('E014', 'R374', 'BAY PKWY')
# [485] ('R177', 'R273', '145 ST')
# [484] ('N129', 'R382', 'GRANT AV')
# [484] ('N128', 'R200', 'EUCLID AV')
# [481] ('N340A', 'R115', '169 ST')
# [477] ('R405', 'R447', 'CYPRESS AV')
# [476] ('N314', 'R238', 'STEINWAY ST')
# [475] ('R414', 'R162', 'ELDER AV')
# [473] ('R409', 'R449', 'E 149 ST')
# [473] ('N120A', 'R153', 'UTICA AV')
# [472] ('R413', 'R325', 'WHITLOCK AV')
# [472] ('R293', 'R133', 'MOSHOLU PKWY')
# [472] ('R288', 'R275', '183 ST')
# [470] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [465] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [464] ('R309', 'R345', 'HARLEM 148 ST')
# [462] ('R319', 'R409', 'FREEMAN ST')
# [462] ('E003', 'R369', 'FT HAMILTON PKY')
# [460] ('N319', 'R298', 'NORTHERN BLVD')
# [458] ('R532', 'R328', 'METS-WILLETS PT')
# [458] ('B015', 'R098', 'CHURCH AV')
# [457] ('N035', 'R334', 'CATHEDRAL PKWY')
# [456] ('R125', 'R189', 'CHRISTOPHER ST')
# [456] ('H032', 'R295', 'WILSON AV')
# [456] ('C021', 'R212', '59 ST')
# [453] ('N118', 'R199', 'KINGSTON-THROOP')
# [452] ('B020', 'R263', 'AVENUE H')
# [451] ('R419', 'R326', 'ZEREGA AV')
# [450] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [449] ('R307', 'R207', '135 ST')
# [444] ('R521', 'R327', '52 ST')
# [440] ('N318', 'R298', 'NORTHERN BLVD')
# [439] ('R416', 'R245', 'ST LAWRENCE AV')
# [437] ('R226A', 'R131', '23 ST')
# [436] ('C001', 'R108', 'BOROUGH HALL')
# [436] ('B023', 'R211', 'KINGS HWY')
# [425] ('R166', 'R167', '86 ST')
# [424] ('N030', 'R333', '116 ST')
# [424] ('D010', 'R394', 'BAY PKWY')
# [423] ('B009', 'R411', 'PARK PLACE')
# [420] ('N342', 'R019', 'JAMAICA 179 ST')
# [419] ('R197', 'R117', 'V.CORTLANDT PK')
# [416] ('N023', 'R332', '135 ST')
# [415] ('R305', 'R206', '125 ST')
# [415] ('N122', 'R439', 'ROCKAWAY AV')
# [409] ('N009', 'R174', '181 ST')
# [406] ('J024', 'R437', 'CRESCENT ST')
# [403] ('N311', 'R339', '36 ST')
# [402] ('N224', 'R157', 'NORWOOD 205 ST')
# [400] ('N331', 'R219', '67 AV')
# [396] ('R257', 'R182', '116 ST')
# [395] ('R302', 'R324', '116 ST')
# [394] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [390] ('D003', 'R391', 'FT HAMILTON PKY')
# [388] ('C016', 'R278', '25 ST')
# [387] ('N037', 'R314', '103 ST')
# [386] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [381] ('R178', 'R273', '145 ST')
# [378] ('N333A', 'R141', 'FOREST HILLS 71')
# [378] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [377] ('N112A', 'R284', 'CLINTON-WASH AV')
# [373] ('N532', 'R129', 'BERGEN ST')
# [372] ('R303', 'R324', '116 ST')
# [372] ('C010', 'R231', 'UNION ST')
# [369] ('R289', 'R119', 'FORDHAM RD')
# [369] ('N087', 'R282', 'SPRING ST')
# [366] ('H013', 'R249', 'GRAHAM AV')
# [365] ('R637', 'R451', 'WINTHROP ST')
# [365] ('N557', 'R130', 'KINGS HWY')
# [365] ('N034', 'R334', 'CATHEDRAL PKWY')
# [363] ('R636', 'R209', 'STERLING ST')
# [363] ('N220', 'R155', 'KINGSBRIDGE RD')
# [362] ('R328', 'R361', 'PELHAM PKWY')
# [361] ('K026', 'R100', 'METROPOLITAN AV')
# [358] ('A071', 'R044', 'CHAMBERS ST')
# [357] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [356] ('N222', 'R156', 'BEDFORD PK BLVD')
# [352] ('R179', 'R193', '157 ST')
# [351] ('N113', 'R297', 'FRANKLIN AV')
# [351] ('B010', 'R412', 'BOTANIC GARDEN')
# [349] ('H038', 'R350', 'LIVONIA AV')
# [348] ('J022', 'R435', 'CLEVELAND ST')
# [348] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [346] ('E011', 'R371', '79 ST')
# [344] ('K025', 'R404', 'FRESH POND RD')
# [342] ('R633', 'R068', 'VAN SICLEN AV')
# [339] ('N121B', 'R438', 'RALPH AV')
# [337] ('N414', 'R316', 'FLUSHING AV')
# [337] ('N006A', 'R280', '190 ST')
# [332] ('R408', 'R449', 'E 149 ST')
# [332] ('R306', 'R207', '135 ST')
# [330] ('N119', 'R199', 'KINGSTON-THROOP')
# [326] ('R644', 'R135', 'NEWKIRK AV')
# [325] ('N325A', 'R218', 'ELMHURST AV')
# [322] ('N414A', 'R316', 'FLUSHING AV')
# [321] ('N555', 'R423', 'AVENUE N')
# [320] ('R402', 'R446', 'BROOK AV')
# [320] ('D012', 'R395', 'KINGS HWY')
# [319] ('J028', 'R004', '75 ST-ELDERTS')
# [319] ('J023', 'R436', 'NORWOOD AV')
# [316] ('R180', 'R193', '157 ST')
# [314] ('N221', 'R155', 'KINGSBRIDGE RD')
# [312] ('R332', 'R365', '219 ST')
# [310] ('B014', 'R148', 'PARKSIDE AV')
# [308] ('H022', 'R279', 'JEFFERSON ST')
# [304] ('R119', 'R320', 'CANAL ST')
# [303] ('J005', 'R353', 'LORIMER ST')
# [300] ('N561', 'R271', 'AVENUE X')
# [299] ('J031', 'R006', 'WOODHAVEN BLVD')
# [296] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [296] ('N126', 'R441', 'VAN SICLEN AVE')
# [294] ('R632', 'R067', 'PENNSYLVANIA AV')
# [292] ('N194', 'R338', 'BEACH 36 ST')
# [287] ('R727', 'R430', 'PELHAM PKWY')
# [287] ('K017', 'R401', 'CENTRAL AV')
# [284] ('R227', 'R131', '23 ST')
# [280] ('C024', 'R214', '77 ST')
# [278] ('H037', 'R349', 'SUTTER AV')
# [278] ('E005', 'R247', '55 ST')
# [277] ('N125', 'R440', 'LIBERTY AV')
# [277] ('J021', 'R434', 'VAN SICLEN AV')
# [277] ('B018', 'R184', 'CORTELYOU RD')
# [275] ('J035', 'R008', '111 ST')
# [273] ('N202', 'R315', '155 ST')
# [272] ('N007A', 'R174', '181 ST')
# [270] ('J012', 'R379', 'KOSCIUSZKO ST')
# [269] ('R407', 'R448', "E 143/ST MARY'S")
# [267] ('R422', 'R428', 'BUHRE AV')
# [265] ('N209', 'R443', '170 ST')
# [262] ('R639', 'R109', 'CHURCH AV')
# [260] ('R618', 'R058', 'BERGEN ST')
# [260] ('R404', 'R447', 'CYPRESS AV')
# [260] ('R117', 'R343', 'FRANKLIN ST')
# [260] ('N556', 'R424', 'AVENUE P')
# [259] ('N195', 'R358', 'BEACH 25 ST')
# [250] ('B017', 'R262', 'BEVERLEY ROAD')
# [246] ('N316', 'R267', '46 ST')
# [244] ('N191', 'R335', 'BEACH 67 ST')
# [244] ('A055', 'R227', 'RECTOR ST')
# [243] ('N559', 'R425', 'AVENUE U')
# [242] ('J016', 'R381', 'HALSEY ST')
# [242] ('H030', 'R266', 'HALSEY ST')
# [238] ('N534', 'R220', 'CARROLL ST')
# [234] ('R329', 'R362', 'ALLERTON AV')
# [233] ('N551', 'R421', 'AVENUE I')
# [233] ('H012', 'R268', 'LORIMER ST')
# [232] ('N017', 'R331', '155 ST')
# [232] ('E009', 'R370', '71 ST')
# [230] ('N212', 'R253', '174-175 STS')
# [229] ('N192', 'R336', 'BEACH 60 ST')
# [228] ('J013', 'R380', 'GATES AV')
# [228] ('B032', 'R264', 'OCEAN PKWY')
# [227] ('R421', 'R427', 'MIDDLETOWN RD')
# [227] ('N337', 'R255', 'BRIARWOOD')
# [227] ('E012', 'R372', '18 AV')
# [223] ('R410', 'R450', 'LONGWOOD AV')
# [223] ('N110', 'R283', 'LAFAYETTE AV')
# [222] ('R260', 'R205', '149/GRAND CONC')
# [222] ('N215', 'R237', '182-183 STS')
# [221] ('R333', 'R366', '225 ST')
# [220] ('N338B', 'R128', 'SUTPHIN BLVD')
# [219] ('N548', 'R420', 'DITMAS AV')
# [214] ('N322', 'R340', '65 ST')
# [214] ('N127', 'R442', 'SHEPHERD AV')
# [213] ('N333', 'R141', 'FOREST HILLS 71')
# [213] ('N225', 'R157', 'NORWOOD 205 ST')
# [212] ('R294', 'R052', 'WOODLAWN')
# [209] ('R312', 'R405', 'JACKSON AV')
# [206] ('B025', 'R150', 'AVENUE U')
# [202] ('N134', 'R385', 'ROCKAWAY BLVD')
# [199] ('D015', 'R396', 'AVENUE U')
# [196] ('R617', 'R058', 'BERGEN ST')
# [196] ('R326', 'R389', 'BRONX PARK EAST')
# [192] ('R122', 'R290', 'HOUSTON ST')
# [188] ('R728', 'R226', 'GUN HILL RD')
# [188] ('J030', 'R005', '85 ST-FOREST PK')
# [187] ('R334', 'R367', '233 ST')
# [186] ('N011', 'R126', '175 ST')
# [185] ('R327', 'R361', 'PELHAM PKWY')
# [185] ('H028', 'R266', 'HALSEY ST')
# [184] ('R335', 'R444', 'NEREID AV')
# [181] ('R194', 'R040', '231 ST')
# [179] ('R726', 'R329', 'MORRIS PARK')
# [178] ('R190', 'R038', '215 ST')
# [178] ('N002A', 'R173', 'INWOOD-207 ST')
# [176] ('E013', 'R373', '20 AV')
# [175] ('K024', 'R403', 'FOREST AVE')
# [174] ('N208', 'R443', '170 ST')
# [173] ('R121', 'R290', 'HOUSTON ST')
# [169] ('J003', 'R352', 'HEWES ST')
# [169] ('H033', 'R313', 'BUSHWICK AV')
# [167] ('R315', 'R406', 'PROSPECT AV')
# [167] ('R192', 'R039', 'MARBLE HILL-225')
# [167] ('C022', 'R212', '59 ST')
# [166] ('N012', 'R035', '168 ST')
# [161] ('K022', 'R402', 'SENECA AVE')
# [156] ('J017', 'R432', 'CHAUNCEY ST')
# [156] ('H035', 'R348', 'ATLANTIC AV')
# [154] ('E016', 'R400', 'BAY 50 ST')
# [153] ('N210', 'R253', '174-175 STS')
# [152] ('N553', 'R422', 'BAY PKWY')
# [152] ('N206', 'R104', '167 ST')
# [152] ('C004', 'R089', 'JAY ST-METROTEC')
# [148] ('D016', 'R397', '86 ST')
# [144] ('A082', 'R028', 'FULTON ST')
# [143] ('N330C', 'R202', '63 DR-REGO PARK')
# [140] ('N001', 'R173', 'INWOOD-207 ST')
# [130] ('R317', 'R408', 'SIMPSON ST')
# [128] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [127] ('N187', 'R419', 'ROCKAWAY PARK B')
# [126] ('J025', 'R003', 'CYPRESS HILLS')
# [124] ('N332', 'R219', '67 AV')
# [123] ('N016A', 'R296', '163 ST-AMSTERDM')
# [122] ('R506', 'R276', 'VERNON-JACKSON')
# [121] ('R520', 'R223', '46 ST BLISS ST')
# [117] ('N317', 'R267', '46 ST')
# [117] ('N135', 'R385', 'ROCKAWAY BLVD')
# [111] ('R314', 'R406', 'PROSPECT AV')
# [109] ('R406', 'R448', "E 143/ST MARY'S")
# [109] ('N562', 'R426', 'NEPTUNE AV')
# [106] ('R318', 'R408', 'SIMPSON ST')
# [105] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [101] ('R330', 'R363', 'BURKE AV')
# [98] ('R641', 'R210', 'BEVERLY RD')
# [96] ('N533', 'R129', 'BERGEN ST')
# [93] ('N545', 'R204', 'CHURCH AV')
# [90] ('N543', 'R289', 'FT HAMILTON PKY')
# [90] ('N181', 'R357', 'AQUEDUCT N.COND')
# [85] ('B034', 'R264', 'OCEAN PKWY')
# [78] ('N193', 'R337', 'BEACH 44 ST')
# [78] ('B026', 'R230', 'NECK RD')
# [74] ('N334B', 'R341', '75 AV')
# [72] ('J032', 'R006', 'WOODHAVEN BLVD')
# [71] ('N131', 'R383', '80 ST')
# [71] ('E015', 'R399', '25 AV')
# [70] ('N137', 'R354', '104 ST')
# [65] ('R320', 'R409', 'FREEMAN ST')
# [64] ('N420B', 'R317', 'CLINTON-WASH AV')
# [61] ('R322', 'R386', '174 ST')
# [58] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [58] ('D008', 'R392', '18 AV')
# [57] ('N218', 'R112', 'FORDHAM RD')
# [57] ('N185', 'R417', 'BEACH 98 ST')
# [55] ('N182', 'R414', 'HOWARD BCH JFK')
# [52] ('N186', 'R418', 'BEACH 105 ST')
# [51] ('N558', 'R130', 'KINGS HWY')
# [51] ('N133', 'R384', '88 ST')
# [48] ('C026', 'R215', '86 ST')
# [45] ('R729', 'R292', 'BAYCHESTER AV')
# [45] ('R643', 'R135', 'NEWKIRK AV')
# [42] ('N130', 'R383', '80 ST')
# [41] ('N544', 'R289', 'FT HAMILTON PKY')
# [41] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [39] ('D009', 'R393', '20 AV')
# [35] ('N184', 'R416', 'BEACH 90 ST')
# [34] ('N547', 'R420', 'DITMAS AV')
# [34] ('N338', 'R128', 'SUTPHIN BLVD')
# [34] ('N003', 'R185', 'DYCKMAN ST')
# [33] ('N339', 'R114', 'PARSONS BLVD')
# [29] ('R532H', 'R328', 'METS-WILLETS PT')
# [29] ('J037', 'R009', '121 ST')
# [27] ('N139', 'R355', '111 ST')
# [26] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [24] ('J034', 'R007', '104 ST')
# [23] ('R308', 'R344', '145 ST')
# [23] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [22] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [17] ('A084', 'R125', 'BROAD ST')
# [15] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [14] ('N022', 'R332', '135 ST')
# [13] ('R196', 'R306', '238 ST')
# [12] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [11] ('N138', 'R355', '111 ST')
# [9] ('N223', 'R156', 'BEDFORD PK BLVD')
# [9] ('N183', 'R415', 'BROAD CHANNEL')
# [6] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# [0] ('N123B', 'R439', 'ROCKAWAY AV')
# 0 ('A085', 'R125', 'BROAD ST')
# [-52] ('N029', 'R333', '116 ST')
# [-1250] ('R241A', 'R048', 'GRD CNTRL-42 ST')
# [-124372] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [-713743] ('H009', 'R235', 'BEDFORD AV')

# %%
thursday = MTA[MTA.DATE == '06/15/2017']
thursday = thursday.reset_index(drop=True)

thursday_dict = {}
for i in range(len(thursday.index)):
    mytuple = (thursday["C/A"][i],thursday.UNIT[i],thursday.SCP[i],thursday.STATION[i])
    if mytuple not in thursday_dict.keys():
        thursday_dict[mytuple] = [(thursday.TIME[i],thursday.EXITS[i])]
    else:
        thursday_dict[mytuple].append((thursday.TIME[i],thursday.EXITS[i]))

thursday_dict_diff = {}
for key,value in thursday_dict.items():
    for i in range(1,len(value)):
        if key not in thursday_dict_diff:
            thursday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            thursday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in thursday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value

        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = thursday[(thursday.TIME=='05:00:00')|(thursday.TIME=='06:00:00')|(thursday.TIME=='07:00:00')|(thursday.TIME=='08:00:00')|(thursday.TIME=='09:00:00')|(thursday.TIME=='10:00:00')|(thursday.TIME=='11:00:00')|(thursday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

thursday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    thursday_morning_passengers.append(mytuple)
thursday_morning_passengers.sort(reverse=True)
for key,value in thursday_morning_passengers:
    print(key,value)
# Out:
# [18350] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [16519] ('N500', 'R020', '47-50 STS ROCK')
# [13681] ('N501', 'R020', '47-50 STS ROCK')
# [13022] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [12690] ('N306', 'R017', 'LEXINGTON AV/53')
# [11163] ('N504', 'R021', '42 ST-BRYANT PK')
# [10432] ('A025', 'R023', '34 ST-HERALD SQ')
# [9866] ('A021', 'R032', 'TIMES SQ-42 ST')
# [9702] ('N304', 'R015', '5 AV/53 ST')
# [9619] ('N505', 'R022', '34 ST-HERALD SQ')
# [9247] ('R249', 'R179', '86 ST')
# [9141] ('N051', 'R084', '59 ST COLUMBUS')
# [8701] ('N049', 'R084', '59 ST COLUMBUS')
# [8193] ('N303', 'R015', '5 AV/53 ST')
# [7981] ('R116', 'R030', 'CHAMBERS ST')
# [7581] ('N507', 'R023', '34 ST-HERALD SQ')
# [7432] ('N305', 'R017', 'LEXINGTON AV/53')
# [7337] ('N506', 'R022', '34 ST-HERALD SQ')
# [7110] ('R143', 'R032', 'TIMES SQ-42 ST')
# [7007] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6635] ('R145', 'R032', 'TIMES SQ-42 ST')
# [6631] ('N501A', 'R020', '47-50 STS ROCK')
# [6498] ('N503', 'R021', '42 ST-BRYANT PK')
# [6246] ('R243', 'R049', '51 ST')
# [6149] ('R155', 'R116', '50 ST')
# [6098] ('R245A', 'R051', '59 ST')
# [6041] ('R501', 'R054', '5 AVE')
# [5996] ('R206', 'R014', 'FULTON ST')
# [5953] ('R258', 'R132', '125 ST')
# [5901] ('N098', 'R028', 'FULTON ST')
# [5750] ('R202', 'R042', 'BOWLING GREEN')
# [5555] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [5508] ('R182', 'R035', '168 ST')
# [5407] ('N520', 'R240', 'GRAND ST')
# [5398] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [5276] ('R246', 'R177', '68ST-HUNTER CO')
# [5187] ('R244', 'R050', '59 ST')
# [5178] ('A033', 'R170', '14 ST-UNION SQ')
# [5171] ('N508', 'R453', '23 ST')
# [5091] ('R550', 'R072', '34 ST-HUDSON YD')
# [5077] ('N509', 'R203', '23 ST')
# [4933] ('R111', 'R027', 'WALL ST')
# [4839] ('R154', 'R116', '50 ST')
# [4816] ('R204', 'R043', 'WALL ST')
# [4804] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4690] ('R113', 'R028', 'FULTON ST')
# [4629] ('R201', 'R041', 'BOWLING GREEN')
# [4600] ('R533', 'R055', 'FLUSHING-MAIN')
# [4582] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [4582] ('N092', 'R029', 'CHAMBERS ST')
# [4581] ('A022', 'R022', '34 ST-HERALD SQ')
# [4574] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4420] ('R244A', 'R050', '59 ST')
# [4412] ('H009', 'R235', 'BEDFORD AV')
# [4381] ('R247', 'R178', '77 ST')
# [4355] ('R221', 'R170', '14 ST-UNION SQ')
# [4339] ('A034', 'R170', '14 ST-UNION SQ')
# [4285] ('A006', 'R079', '5 AV/59 ST')
# [4262] ('N089', 'R139', 'CANAL ST')
# [4258] ('N102', 'R127', 'JAY ST-METROTEC')
# [4214] ('N600', 'R302', '57 ST')
# [4023] ('R142', 'R293', '34 ST-PENN STA')
# [4003] ('R169', 'R168', '96 ST')
# [3994] ('N103', 'R127', 'JAY ST-METROTEC')
# [3985] ('R158', 'R084', '59 ST COLUMBUS')
# [3897] ('R110', 'R027', 'WALL ST')
# [3892] ('N606', 'R025', 'JAMAICA CENTER')
# [3890] ('N700A', 'R570', '72 ST-2 AVE')
# [3858] ('N301', 'R113', '7 AV')
# [3854] ('N026', 'R102', '125 ST')
# [3824] ('N067', 'R012', '34 ST-PENN STA')
# [3797] ('N502', 'R021', '42 ST-BRYANT PK')
# [3766] ('N094', 'R029', 'WORLD TRADE CTR')
# [3756] ('R601A', 'R108', 'BOROUGH HALL')
# [3693] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3599] ('R242', 'R049', '51 ST')
# [3555] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3530] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3505] ('N700', 'R570', '72 ST-2 AVE')
# [3499] ('R148', 'R033', 'TIMES SQ-42 ST')
# [3486] ('N091', 'R029', 'CHAMBERS ST')
# [3477] ('R112', 'R027', 'WALL ST')
# [3369] ('A002', 'R051', '59 ST')
# [3362] ('N060', 'R010', '42 ST-PORT AUTH')
# [3334] ('A031', 'R083', '23 ST')
# [3296] ('A029', 'R082', '28 ST')
# [3277] ('A043', 'R462', 'CANAL ST')
# [3240] ('R216', 'R322', 'SPRING ST')
# [3240] ('R200A', 'R041', 'BOWLING GREEN')
# [3233] ('A042', 'R086', 'PRINCE ST')
# [3173] ('A060', 'R001', 'WHITEHALL S-FRY')
# [3167] ('N400A', 'R359', 'COURT SQ')
# [3157] ('N090', 'R139', 'CANAL ST')
# [3135] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3130] ('A049', 'R088', 'CORTLANDT ST')
# [3112] ('R602', 'R108', 'BOROUGH HALL')
# [3089] ('A046', 'R463', 'CANAL ST')
# [3076] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [3074] ('H008', 'R248', '1 AV')
# [3066] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3058] ('N095A', 'R014', 'FULTON ST')
# [3034] ('A030', 'R083', '23 ST')
# [3032] ('R228', 'R143', '28 ST')
# [3008] ('R526', 'R096', '82 ST-JACKSON H')
# [2965] ('N071', 'R013', '34 ST-PENN STA')
# [2933] ('N108', 'R217', 'HOYT-SCHER')
# [2891] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2883] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2853] ('A013', 'R081', '49 ST')
# [2851] ('R112A', 'R027', 'WALL ST')
# [2823] ('A010', 'R080', '57 ST-7 AV')
# [2787] ('N078', 'R175', '14 ST')
# [2755] ('N601', 'R319', 'LEXINGTON AV/63')
# [2754] ('R226', 'R131', '23 ST')
# [2752] ('R101', 'R001', 'SOUTH FERRY')
# [2740] ('A015', 'R081', '49 ST')
# [2732] ('N020', 'R101', '145 ST')
# [2731] ('N070', 'R012', '34 ST-PENN STA')
# [2726] ('R161B', 'R452', '72 ST')
# [2724] ('R168A', 'R168', '96 ST')
# [2710] ('R138', 'R293', '34 ST-PENN STA')
# [2680] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2671] ('A081', 'R028', 'FULTON ST')
# [2663] ('N076', 'R111', '23 ST')
# [2640] ('N095', 'R014', 'FULTON ST')
# [2631] ('N300', 'R113', '7 AV')
# [2590] ('N046', 'R281', '72 ST')
# [2568] ('R114', 'R028', 'FULTON ST')
# [2566] ('N601A', 'R319', 'LEXINGTON AV/63')
# [2563] ('N068', 'R012', '34 ST-PENN STA')
# [2558] ('R141', 'R031', '34 ST-PENN STA')
# [2545] ('A058', 'R001', 'WHITEHALL S-FRY')
# [2539] ('A035', 'R170', '14 ST-UNION SQ')
# [2538] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2519] ('R248', 'R178', '77 ST')
# [2451] ('R516', 'R291', '33 ST-RAWSON ST')
# [2392] ('R232', 'R176', '33 ST')
# [2366] ('C008', 'R099', 'DEKALB AV')
# [2358] ('H001', 'R175', '8 AV')
# [2338] ('A027', 'R082', '28 ST')
# [2336] ('N309A', 'R140', 'QUEENS PLAZA')
# [2315] ('A039', 'R085', '8 ST-NYU')
# [2301] ('N512', 'R163', '14 ST')
# [2297] ('R242A', 'R049', '51 ST')
# [2297] ('N073', 'R013', '34 ST-PENN STA')
# [2289] ('R252', 'R180', '103 ST')
# [2250] ('H007', 'R248', '1 AV')
# [2238] ('R261', 'R205', '149/GRAND CONC')
# [2236] ('N056', 'R188', '50 ST')
# [2222] ('R507', 'R134', 'HUNTERS PT AV')
# [2213] ('N069', 'R013', '34 ST-PENN STA')
# [2186] ('N077', 'R111', '23 ST')
# [2171] ('R203', 'R043', 'WALL ST')
# [2121] ('R183', 'R260', '181 ST')
# [2114] ('R534', 'R055', 'FLUSHING-MAIN')
# [2098] ('R137', 'R031', '34 ST-PENN STA')
# [2067] ('N523', 'R300', '2 AV')
# [2053] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [2048] ('R102', 'R304', 'RECTOR ST')
# [2043] ('R229', 'R143', '28 ST')
# [2026] ('N510', 'R163', '14 ST')
# [2002] ('R245', 'R051', '59 ST')
# [1983] ('N072', 'R012', '34 ST-PENN STA')
# [1977] ('R208', 'R014', 'FULTON ST')
# [1888] ('A069', 'R044', 'CHAMBERS ST')
# [1836] ('R135', 'R031', '34 ST-PENN STA')
# [1820] ('R523', 'R147', '61 ST WOODSIDE')
# [1820] ('R132', 'R190', '23 ST')
# [1819] ('A014', 'R081', '49 ST')
# [1813] ('A047', 'R087', 'CITY HALL')
# [1809] ('R159', 'R164', '66 ST-LINCOLN')
# [1800] ('R127', 'R105', '14 ST')
# [1793] ('R173', 'R159', '116 ST-COLUMBIA')
# [1784] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1782] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1729] ('R124', 'R290', 'HOUSTON ST')
# [1723] ('R508', 'R346', 'COURT SQ')
# [1700] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1700] ('A011', 'R080', '57 ST-7 AV')
# [1690] ('N063', 'R011', '42 ST-PORT AUTH')
# [1689] ('N044', 'R187', '81 ST-MUSEUM')
# [1681] ('R605', 'R456', 'HOYT ST')
# [1678] ('R165', 'R167', '86 ST')
# [1676] ('R412', 'R146', 'HUNTS POINT AV')
# [1652] ('R217A', 'R194', 'BLEECKER ST')
# [1651] ('R220', 'R160', 'ASTOR PL')
# [1646] ('R115', 'R029', 'PARK PLACE')
# [1637] ('R301', 'R323', 'CENTRAL PK N110')
# [1630] ('A037', 'R170', '14 ST-UNION SQ')
# [1605] ('B016', 'R098', 'CHURCH AV')
# [1588] ('C012', 'R258', '4AV-9 ST')
# [1583] ('D002', 'R390', '8 AV')
# [1552] ('N511', 'R163', '14 ST')
# [1533] ('R174', 'R034', '125 ST')
# [1532] ('R126', 'R189', 'CHRISTOPHER ST')
# [1507] ('R161A', 'R452', '72 ST')
# [1468] ('N062', 'R011', '42 ST-PORT AUTH')
# [1457] ('R609', 'R056', 'NEVINS ST')
# [1449] ('R528', 'R097', 'JUNCTION BLVD')
# [1431] ('R250', 'R179', '86 ST')
# [1420] ('N040', 'R251', '96 ST')
# [1414] ('C018', 'R197', '36 ST')
# [1411] ('N607', 'R025', 'JAMAICA CENTER')
# [1410] ('R529', 'R208', '103 ST-CORONA')
# [1408] ('A016', 'R081', '49 ST')
# [1406] ('R204A', 'R043', 'WALL ST')
# [1400] ('R185', 'R274', '191 ST')
# [1396] ('R283', 'R221', '167 ST')
# [1384] ('A041', 'R086', 'PRINCE ST')
# [1378] ('R130', 'R321', '18 ST')
# [1376] ('N405', 'R239', 'GREENPOINT AV')
# [1371] ('H005', 'R330', '3 AV')
# [1370] ('N536', 'R270', 'SMITH-9 ST')
# [1366] ('A050', 'R088', 'CORTLANDT ST')
# [1360] ('N043', 'R186', '86 ST')
# [1353] ('R134', 'R272', '28 ST')
# [1351] ('N521', 'R300', '2 AV')
# [1347] ('R518', 'R261', '40 ST LOWERY ST')
# [1342] ('N124', 'R103', 'BROADWAY JCT')
# [1320] ('R417', 'R222', 'PARKCHESTER')
# [1319] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1318] ('R251', 'R144', '96 ST')
# [1315] ('R331', 'R364', 'GUN HILL RD')
# [1306] ('R420', 'R107', 'WESTCHESTER SQ')
# [1303] ('R231', 'R176', '33 ST')
# [1300] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1298] ('R164', 'R167', '86 ST')
# [1296] ('N101', 'R252', 'HIGH ST')
# [1287] ('R503', 'R276', 'VERNON-JACKSON')
# [1286] ('R311', 'R053', '3 AV-149 ST')
# [1283] ('N701A', 'R571', '86 ST-2 AVE')
# [1269] ('N702', 'R572', '96 ST-2 AVE')
# [1266] ('N057', 'R188', '50 ST')
# [1258] ('N315', 'R238', 'STEINWAY ST')
# [1253] ('A007', 'R079', '5 AV/59 ST')
# [1238] ('R205A', 'R014', 'FULTON ST')
# [1221] ('N513', 'R163', '14 ST')
# [1221] ('J001', 'R460', 'MARCY AV')
# [1205] ('N539A', 'R288', '7 AV')
# [1203] ('R231A', 'R176', '33 ST')
# [1184] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1181] ('N701', 'R571', '86 ST-2 AVE')
# [1180] ('R608', 'R056', 'NEVINS ST')
# [1162] ('R256', 'R182', '116 ST')
# [1159] ('R128', 'R105', '14 ST')
# [1150] ('R284', 'R243', '170 ST')
# [1141] ('R160A', 'R164', '66 ST-LINCOLN')
# [1115] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [1112] ('J002', 'R460', 'MARCY AV')
# [1109] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1101] ('B024', 'R211', 'KINGS HWY')
# [1097] ('R527', 'R122', '90 ST-ELMHURST')
# [1096] ('R519', 'R223', '46 ST BLISS ST')
# [1087] ('H016', 'R250', 'GRAND ST')
# [1070] ('C003', 'R089', 'JAY ST-METROTEC')
# [1054] ('R513', 'R093', '30 AV')
# [1047] ('R515', 'R095', 'ASTORIA DITMARS')
# [1046] ('N327', 'R254', 'GRAND-NEWTOWN')
# [1042] ('R604', 'R108', 'BOROUGH HALL')
# [1033] ('G009', 'R151', 'CONEY IS-STILLW')
# [1030] ('R120', 'R320', 'CANAL ST')
# [1028] ('R160', 'R164', '66 ST-LINCOLN')
# [1028] ('A083', 'R125', 'BROAD ST')
# [1027] ('N117', 'R198', 'NOSTRAND AV')
# [1021] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1014] ('R509', 'R121', 'QUEENSBORO PLZ')
# [981] ('N537', 'R258', '4 AV-9 ST')
# [979] ('N702A', 'R572', '96 ST-2 AVE')
# [978] ('N330', 'R202', '63 DR-REGO PARK')
# [976] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [975] ('R253', 'R181', '110 ST')
# [970] ('R511', 'R091', '36 AV')
# [967] ('B004', 'R171', '7 AV')
# [962] ('R232A', 'R176', '33 ST')
# [959] ('N310', 'R140', 'QUEENS PLAZA')
# [959] ('D005', 'R398', 'NEW UTRECHT AV')
# [957] ('N422', 'R318', 'FULTON ST')
# [955] ('R287', 'R244', 'BURNSIDE AV')
# [943] ('R629', 'R065', 'ROCKAWAY AV')
# [943] ('R304', 'R206', '125 ST')
# [924] ('R423', 'R429', 'PELHAM BAY PARK')
# [919] ('C025', 'R215', '86 ST')
# [916] ('N528', 'R257', 'EAST BROADWAY')
# [894] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [890] ('R336', 'R145', 'WAKEFIELD/241')
# [885] ('N116', 'R198', 'NOSTRAND AV')
# [883] ('N602', 'R259', 'ROOSEVELT ISLND')
# [868] ('R512', 'R092', 'BROADWAY')
# [868] ('N120', 'R153', 'UTICA AV')
# [866] ('A064', 'R311', 'BOWERY')
# [865] ('N339A', 'R114', 'PARSONS BLVD')
# [862] ('N013', 'R035', '168 ST')
# [861] ('R401', 'R445', '3 AV 138 ST')
# [860] ('N329', 'R201', 'WOODHAVEN BLVD')
# [859] ('H014', 'R249', 'GRAHAM AV')
# [854] ('N535', 'R220', 'CARROLL ST')
# [851] ('N213', 'R154', 'TREMONT AV')
# [849] ('E004', 'R234', '50 ST')
# [847] ('N530', 'R301', 'YORK ST')
# [845] ('N604', 'R342', 'JAMAICA VAN WK')
# [844] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [841] ('N546', 'R204', 'CHURCH AV')
# [836] ('B024A', 'R211', 'KINGS HWY')
# [835] ('R162', 'R166', '79 ST')
# [833] ('H003', 'R163', '6 AV')
# [823] ('B031', 'R172', 'BRIGHTON BEACH')
# [821] ('N217', 'R112', 'FORDHAM RD')
# [814] ('A077', 'R028', 'FULTON ST')
# [811] ('B019', 'R149', 'NEWKIRK PLAZA')
# [810] ('N196', 'R285', 'FAR ROCKAWAY')
# [806] ('R622', 'R123', 'FRANKLIN AV')
# [806] ('R175', 'R169', '137 ST CITY COL')
# [804] ('R103', 'R304', 'RECTOR ST')
# [787] ('R291', 'R183', 'BEDFORD PK BLVD')
# [782] ('R254', 'R181', '110 ST')
# [782] ('R227A', 'R131', '23 ST')
# [776] ('R230', 'R143', '28 ST')
# [772] ('R310', 'R053', '3 AV-149 ST')
# [771] ('A054', 'R227', 'RECTOR ST')
# [770] ('N010', 'R126', '175 ST')
# [769] ('R600', 'R224', 'CLARK ST')
# [766] ('N307', 'R359', 'COURT SQ-23 ST')
# [758] ('R171', 'R192', 'CATHEDRAL PKWY')
# [756] ('N529', 'R257', 'EAST BROADWAY')
# [755] ('N549', 'R242', '18 AV')
# [754] ('R634', 'R069', 'NEW LOTS AV')
# [754] ('R290', 'R161', 'KINGSBRIDGE RD')
# [754] ('C019', 'R232', '45 ST')
# [750] ('R170', 'R191', '103 ST')
# [750] ('N419', 'R287', 'CLASSON AV')
# [750] ('H006', 'R330', '3 AV')
# [742] ('R418', 'R106', 'CASTLE HILL AV')
# [732] ('A038', 'R085', '8 ST-NYU')
# [730] ('R323', 'R387', 'WEST FARMS SQ')
# [725] ('N408A', 'R256', 'NASSAU AV')
# [722] ('N019', 'R101', '145 ST')
# [717] ('R635', 'R277', 'PRESIDENT ST')
# [716] ('J007', 'R377', 'FLUSHING AV')
# [710] ('N333B', 'R141', 'FOREST HILLS 71')
# [709] ('H019', 'R294', 'MORGAN AV')
# [708] ('N312', 'R339', '36 ST')
# [708] ('N039', 'R251', '96 ST')
# [708] ('B022', 'R229', 'AVENUE M')
# [706] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [706] ('R514', 'R094', 'ASTORIA BLVD')
# [704] ('R628', 'R064', 'SARATOGA AV')
# [699] ('H039', 'R375', 'NEW LOTS')
# [698] ('J020', 'R433', 'ALABAMA AV')
# [696] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [695] ('J009', 'R378', 'MYRTLE AV')
# [691] ('N526', 'R142', 'DELANCEY/ESSEX')
# [690] ('R131', 'R190', '23 ST')
# [679] ('A066', 'R118', 'CANAL ST')
# [676] ('R285', 'R308', 'MT EDEN AV')
# [673] ('H017', 'R265', 'MONTROSE AV')
# [672] ('R530', 'R310', '111 ST')
# [671] ('N025', 'R102', '125 ST')
# [668] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [666] ('N412', 'R299', 'BROADWAY')
# [665] ('N401', 'R360', '21 ST')
# [661] ('R259', 'R307', '138/GRAND CONC')
# [659] ('R517', 'R291', '33 ST-RAWSON ST')
# [653] ('R133', 'R272', '28 ST')
# [653] ('B029', 'R172', 'BRIGHTON BEACH')
# [650] ('R510', 'R090', '39 AV')
# [644] ('R129', 'R321', '18 ST')
# [644] ('G001', 'R151', 'CONEY IS-STILLW')
# [642] ('R625', 'R062', 'CROWN HTS-UTICA')
# [642] ('R403', 'R446', 'BROOK AV')
# [640] ('N409', 'R268', 'METROPOLITAN AV')
# [640] ('B012', 'R196', 'PROSPECT PARK')
# [639] ('N531', 'R129', 'BERGEN ST')
# [638] ('R118', 'R343', 'FRANKLIN ST')
# [635] ('N100', 'R252', 'HIGH ST')
# [632] ('R186', 'R036', 'DYCKMAN ST')
# [627] ('H040', 'R376', 'EAST 105 ST')
# [619] ('R525', 'R018', '74 ST-BROADWAY')
# [617] ('R606', 'R225', 'HOYT ST')
# [615] ('N045', 'R187', '81 ST-MUSEUM')
# [613] ('N141', 'R356', 'OZONE PK LEFFRT')
# [610] ('H015', 'R250', 'GRAND ST')
# [609] ('R624', 'R124', 'KINGSTON AV')
# [604] ('R219', 'R160', 'ASTOR PL')
# [600] ('E001', 'R368', '9 AV')
# [597] ('R188', 'R037', '207 ST')
# [596] ('R163', 'R166', '79 ST')
# [591] ('R415', 'R120', 'MORISN AV/SNDVW')
# [586] ('R215', 'R322', 'SPRING ST')
# [584] ('R623', 'R061', 'NOSTRAND AV')
# [582] ('N343', 'R019', 'JAMAICA 179 ST')
# [581] ('R414', 'R162', 'ELDER AV')
# [581] ('R139', 'R031', '34 ST-PENN STA')
# [580] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [578] ('R325', 'R388', 'E 180 ST')
# [573] ('R524', 'R347', '69 ST')
# [563] ('R316', 'R407', 'INTERVALE AV')
# [557] ('R177', 'R273', '145 ST')
# [556] ('E014', 'R374', 'BAY PKWY')
# [553] ('R321', 'R386', '174 ST')
# [547] ('B021', 'R228', 'AVENUE J')
# [546] ('N024', 'R332', '135 ST')
# [545] ('N114', 'R297', 'FRANKLIN AV')
# [543] ('R532', 'R328', 'METS-WILLETS PT')
# [542] ('R504', 'R276', 'VERNON-JACKSON')
# [530] ('R203A', 'R043', 'WALL ST')
# [529] ('N316A', 'R267', '46 ST')
# [528] ('R286', 'R309', '176 ST')
# [528] ('N111', 'R284', 'CLINTON-WASH AV')
# [526] ('C011', 'R231', 'UNION ST')
# [525] ('C021', 'R212', '59 ST')
# [524] ('R411', 'R450', 'LONGWOOD AV')
# [524] ('R123', 'R290', 'HOUSTON ST')
# [523] ('C017', 'R455', '25 ST')
# [522] ('N207', 'R104', '167 ST')
# [513] ('N075', 'R111', '23 ST')
# [509] ('B013', 'R196', 'PROSPECT PARK')
# [506] ('K019', 'R413', 'KNICKERBOCKER')
# [506] ('B015', 'R098', 'CHURCH AV')
# [503] ('R307', 'R207', '135 ST')
# [503] ('N086', 'R282', 'SPRING ST')
# [500] ('R226A', 'R131', '23 ST')
# [487] ('R419', 'R326', 'ZEREGA AV')
# [486] ('R405', 'R447', 'CYPRESS AV')
# [484] ('R319', 'R409', 'FREEMAN ST')
# [484] ('R305', 'R206', '125 ST')
# [484] ('D010', 'R394', 'BAY PKWY')
# [483] ('N128', 'R200', 'EUCLID AV')
# [480] ('N120A', 'R153', 'UTICA AV')
# [476] ('R172', 'R192', 'CATHEDRAL PKWY')
# [475] ('N532', 'R129', 'BERGEN ST')
# [475] ('H032', 'R295', 'WILSON AV')
# [474] ('N340', 'R115', '169 ST')
# [473] ('J024', 'R437', 'CRESCENT ST')
# [471] ('R176', 'R169', '137 ST CITY COL')
# [470] ('N319', 'R298', 'NORTHERN BLVD')
# [468] ('N340A', 'R115', '169 ST')
# [468] ('N129', 'R382', 'GRANT AV')
# [462] ('E003', 'R369', 'FT HAMILTON PKY')
# [460] ('N118', 'R199', 'KINGSTON-THROOP')
# [457] ('R166', 'R167', '86 ST')
# [456] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [451] ('R288', 'R275', '183 ST')
# [450] ('R293', 'R133', 'MOSHOLU PKWY')
# [446] ('N035', 'R334', 'CATHEDRAL PKWY')
# [445] ('C001', 'R108', 'BOROUGH HALL')
# [442] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [440] ('N314', 'R238', 'STEINWAY ST')
# [438] ('H023', 'R236', 'DEKALB AV')
# [435] ('R409', 'R449', 'E 149 ST')
# [432] ('R637', 'R451', 'WINTHROP ST')
# [431] ('R521', 'R327', '52 ST')
# [429] ('R197', 'R117', 'V.CORTLANDT PK')
# [429] ('N122', 'R439', 'ROCKAWAY AV')
# [427] ('D003', 'R391', 'FT HAMILTON PKY')
# [425] ('N318', 'R298', 'NORTHERN BLVD')
# [424] ('R416', 'R245', 'ST LAWRENCE AV')
# [424] ('R309', 'R345', 'HARLEM 148 ST')
# [423] ('N333A', 'R141', 'FOREST HILLS 71')
# [423] ('N222', 'R156', 'BEDFORD PK BLVD')
# [421] ('N557', 'R130', 'KINGS HWY')
# [421] ('N311', 'R339', '36 ST')
# [420] ('N023', 'R332', '135 ST')
# [414] ('R257', 'R182', '116 ST')
# [409] ('N220', 'R155', 'KINGSBRIDGE RD')
# [402] ('A071', 'R044', 'CHAMBERS ST')
# [395] ('N342', 'R019', 'JAMAICA 179 ST')
# [395] ('B010', 'R412', 'BOTANIC GARDEN')
# [393] ('N331', 'R219', '67 AV')
# [393] ('B023', 'R211', 'KINGS HWY')
# [392] ('R125', 'R189', 'CHRISTOPHER ST')
# [390] ('R179', 'R193', '157 ST')
# [388] ('N009', 'R174', '181 ST')
# [388] ('B009', 'R411', 'PARK PLACE')
# [385] ('N224', 'R157', 'NORWOOD 205 ST')
# [383] ('N037', 'R314', '103 ST')
# [383] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [383] ('C016', 'R278', '25 ST')
# [382] ('R644', 'R135', 'NEWKIRK AV')
# [381] ('N414', 'R316', 'FLUSHING AV')
# [381] ('B020', 'R263', 'AVENUE H')
# [380] ('J023', 'R436', 'NORWOOD AV')
# [377] ('N030', 'R333', '116 ST')
# [376] ('N121B', 'R438', 'RALPH AV')
# [372] ('R178', 'R273', '145 ST')
# [370] ('R289', 'R119', 'FORDHAM RD')
# [365] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [359] ('R636', 'R209', 'STERLING ST')
# [353] ('R632', 'R067', 'PENNSYLVANIA AV')
# [351] ('R227', 'R131', '23 ST')
# [351] ('N555', 'R423', 'AVENUE N')
# [351] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [350] ('K025', 'R404', 'FRESH POND RD')
# [349] ('R180', 'R193', '157 ST')
# [347] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [346] ('R328', 'R361', 'PELHAM PKWY')
# [345] ('N087', 'R282', 'SPRING ST')
# [343] ('R303', 'R324', '116 ST')
# [343] ('N325A', 'R218', 'ELMHURST AV')
# [340] ('N112A', 'R284', 'CLINTON-WASH AV')
# [340] ('C010', 'R231', 'UNION ST')
# [339] ('J028', 'R004', '75 ST-ELDERTS')
# [336] ('N414A', 'R316', 'FLUSHING AV')
# [336] ('J035', 'R008', '111 ST')
# [336] ('J022', 'R435', 'CLEVELAND ST')
# [334] ('N119', 'R199', 'KINGSTON-THROOP')
# [334] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [333] ('R408', 'R449', 'E 149 ST')
# [331] ('H038', 'R350', 'LIVONIA AV')
# [330] ('R119', 'R320', 'CANAL ST')
# [330] ('C024', 'R214', '77 ST')
# [326] ('R633', 'R068', 'VAN SICLEN AV')
# [326] ('N113', 'R297', 'FRANKLIN AV')
# [323] ('H022', 'R279', 'JEFFERSON ST')
# [321] ('E005', 'R247', '55 ST')
# [319] ('R302', 'R324', '116 ST')
# [319] ('K026', 'R100', 'METROPOLITAN AV')
# [318] ('K017', 'R401', 'CENTRAL AV')
# [317] ('R402', 'R446', 'BROOK AV')
# [313] ('J031', 'R006', 'WOODHAVEN BLVD')
# [312] ('J013', 'R380', 'GATES AV')
# [303] ('N006A', 'R280', '190 ST')
# [302] ('J005', 'R353', 'LORIMER ST')
# [301] ('D012', 'R395', 'KINGS HWY')
# [300] ('N034', 'R334', 'CATHEDRAL PKWY')
# [298] ('R407', 'R448', "E 143/ST MARY'S")
# [298] ('E011', 'R371', '79 ST')
# [294] ('J012', 'R379', 'KOSCIUSZKO ST')
# [293] ('N221', 'R155', 'KINGSBRIDGE RD')
# [289] ('R332', 'R365', '219 ST')
# [289] ('B018', 'R184', 'CORTELYOU RD')
# [288] ('R306', 'R207', '135 ST')
# [287] ('R404', 'R447', 'CYPRESS AV')
# [287] ('H037', 'R349', 'SUTTER AV')
# [285] ('R413', 'R325', 'WHITLOCK AV')
# [280] ('N534', 'R220', 'CARROLL ST')
# [278] ('R727', 'R430', 'PELHAM PKWY')
# [278] ('R422', 'R428', 'BUHRE AV')
# [274] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [273] ('N202', 'R315', '155 ST')
# [271] ('N561', 'R271', 'AVENUE X')
# [266] ('R639', 'R109', 'CHURCH AV')
# [265] ('R329', 'R362', 'ALLERTON AV')
# [264] ('R421', 'R427', 'MIDDLETOWN RD')
# [264] ('J021', 'R434', 'VAN SICLEN AV')
# [261] ('N125', 'R440', 'LIBERTY AV')
# [260] ('R618', 'R058', 'BERGEN ST')
# [260] ('N007A', 'R174', '181 ST')
# [257] ('R410', 'R450', 'LONGWOOD AV')
# [257] ('N110', 'R283', 'LAFAYETTE AV')
# [256] ('H030', 'R266', 'HALSEY ST')
# [256] ('B032', 'R264', 'OCEAN PKWY')
# [255] ('R617', 'R058', 'BERGEN ST')
# [255] ('N551', 'R421', 'AVENUE I')
# [255] ('N191', 'R335', 'BEACH 67 ST')
# [253] ('B017', 'R262', 'BEVERLEY ROAD')
# [251] ('N556', 'R424', 'AVENUE P')
# [251] ('N195', 'R358', 'BEACH 25 ST')
# [249] ('R117', 'R343', 'FRANKLIN ST')
# [247] ('H013', 'R249', 'GRAHAM AV')
# [243] ('N316', 'R267', '46 ST')
# [235] ('E012', 'R372', '18 AV')
# [233] ('N126', 'R441', 'VAN SICLEN AVE')
# [232] ('J030', 'R005', '85 ST-FOREST PK')
# [232] ('B025', 'R150', 'AVENUE U')
# [231] ('N333', 'R141', 'FOREST HILLS 71')
# [231] ('N017', 'R331', '155 ST')
# [230] ('R327', 'R361', 'PELHAM PKWY')
# [229] ('N215', 'R237', '182-183 STS')
# [228] ('J016', 'R381', 'HALSEY ST')
# [227] ('N338B', 'R128', 'SUTPHIN BLVD')
# [226] ('H028', 'R266', 'HALSEY ST')
# [224] ('A055', 'R227', 'RECTOR ST')
# [222] ('N212', 'R253', '174-175 STS')
# [221] ('N337', 'R255', 'BRIARWOOD')
# [220] ('R334', 'R367', '233 ST')
# [220] ('D015', 'R396', 'AVENUE U')
# [218] ('N559', 'R425', 'AVENUE U')
# [218] ('N209', 'R443', '170 ST')
# [217] ('R260', 'R205', '149/GRAND CONC')
# [217] ('R190', 'R038', '215 ST')
# [216] ('N225', 'R157', 'NORWOOD 205 ST')
# [214] ('N322', 'R340', '65 ST')
# [212] ('N548', 'R420', 'DITMAS AV')
# [211] ('R294', 'R052', 'WOODLAWN')
# [206] ('N001', 'R173', 'INWOOD-207 ST')
# [205] ('J025', 'R003', 'CYPRESS HILLS')
# [199] ('N134', 'R385', 'ROCKAWAY BLVD')
# [198] ('N192', 'R336', 'BEACH 60 ST')
# [197] ('R121', 'R290', 'HOUSTON ST')
# [197] ('E016', 'R400', 'BAY 50 ST')
# [194] ('N127', 'R442', 'SHEPHERD AV')
# [193] ('R194', 'R040', '231 ST')
# [193] ('N002A', 'R173', 'INWOOD-207 ST')
# [191] ('R333', 'R366', '225 ST')
# [191] ('E009', 'R370', '71 ST')
# [190] ('K024', 'R403', 'FOREST AVE')
# [186] ('R728', 'R226', 'GUN HILL RD')
# [183] ('R312', 'R405', 'JACKSON AV')
# [182] ('N208', 'R443', '170 ST')
# [181] ('R335', 'R444', 'NEREID AV')
# [181] ('H035', 'R348', 'ATLANTIC AV')
# [179] ('R192', 'R039', 'MARBLE HILL-225')
# [178] ('R326', 'R389', 'BRONX PARK EAST')
# [177] ('N553', 'R422', 'BAY PKWY')
# [176] ('J003', 'R352', 'HEWES ST')
# [167] ('E013', 'R373', '20 AV')
# [164] ('N011', 'R126', '175 ST')
# [163] ('R315', 'R406', 'PROSPECT AV')
# [162] ('R122', 'R290', 'HOUSTON ST')
# [159] ('N012', 'R035', '168 ST')
# [158] ('H033', 'R313', 'BUSHWICK AV')
# [154] ('K022', 'R402', 'SENECA AVE')
# [151] ('A082', 'R028', 'FULTON ST')
# [148] ('N210', 'R253', '174-175 STS')
# [148] ('C022', 'R212', '59 ST')
# [146] ('J017', 'R432', 'CHAUNCEY ST')
# [146] ('C004', 'R089', 'JAY ST-METROTEC')
# [145] ('R726', 'R329', 'MORRIS PARK')
# [143] ('R318', 'R408', 'SIMPSON ST')
# [136] ('N332', 'R219', '67 AV')
# [135] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [133] ('N206', 'R104', '167 ST')
# [131] ('N330C', 'R202', '63 DR-REGO PARK')
# [128] ('N562', 'R426', 'NEPTUNE AV')
# [127] ('N317', 'R267', '46 ST')
# [125] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [124] ('R317', 'R408', 'SIMPSON ST')
# [122] ('D016', 'R397', '86 ST')
# [120] ('H012', 'R268', 'LORIMER ST')
# [118] ('N187', 'R419', 'ROCKAWAY PARK B')
# [114] ('N194', 'R338', 'BEACH 36 ST')
# [107] ('N334B', 'R341', '75 AV')
# [106] ('R520', 'R223', '46 ST BLISS ST')
# [104] ('R314', 'R406', 'PROSPECT AV')
# [101] ('N135', 'R385', 'ROCKAWAY BLVD')
# [100] ('N181', 'R357', 'AQUEDUCT N.COND')
# [100] ('N137', 'R354', '104 ST')
# [98] ('R641', 'R210', 'BEVERLY RD')
# [97] ('N543', 'R289', 'FT HAMILTON PKY')
# [96] ('B026', 'R230', 'NECK RD')
# [95] ('R330', 'R363', 'BURKE AV')
# [94] ('R406', 'R448', "E 143/ST MARY'S")
# [93] ('B034', 'R264', 'OCEAN PKWY')
# [92] ('R627', 'R063', 'SUTTER AV-RUTLD')
# [88] ('N533', 'R129', 'BERGEN ST')
# [87] ('R322', 'R386', '174 ST')
# [84] ('N016A', 'R296', '163 ST-AMSTERDM')
# [79] ('N545', 'R204', 'CHURCH AV')
# [78] ('N193', 'R337', 'BEACH 44 ST')
# [77] ('E015', 'R399', '25 AV')
# [75] ('N131', 'R383', '80 ST')
# [73] ('N558', 'R130', 'KINGS HWY')
# [71] ('R320', 'R409', 'FREEMAN ST')
# [71] ('N420B', 'R317', 'CLINTON-WASH AV')
# [69] ('J037', 'R009', '121 ST')
# [63] ('N185', 'R417', 'BEACH 98 ST')
# [59] ('J032', 'R006', 'WOODHAVEN BLVD')
# [58] ('R729', 'R292', 'BAYCHESTER AV')
# [57] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [56] ('C026', 'R215', '86 ST')
# [54] ('R643', 'R135', 'NEWKIRK AV')
# [52] ('N186', 'R418', 'BEACH 105 ST')
# [51] ('N133', 'R384', '88 ST')
# [49] ('N544', 'R289', 'FT HAMILTON PKY')
# [47] ('N184', 'R416', 'BEACH 90 ST')
# [46] ('N218', 'R112', 'FORDHAM RD')
# [46] ('N139', 'R355', '111 ST')
# [44] ('N182', 'R414', 'HOWARD BCH JFK')
# [43] ('N547', 'R420', 'DITMAS AV')
# [42] ('D009', 'R393', '20 AV')
# [40] ('N339', 'R114', 'PARSONS BLVD')
# [39] ('N338', 'R128', 'SUTPHIN BLVD')
# [36] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [36] ('D008', 'R392', '18 AV')
# [35] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [33] ('N130', 'R383', '80 ST')
# [32] ('R308', 'R344', '145 ST')
# [30] ('R506', 'R276', 'VERNON-JACKSON')
# [24] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [23] ('N138', 'R355', '111 ST')
# [22] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [20] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [15] ('R196', 'R306', '238 ST')
# [15] ('N003', 'R185', 'DYCKMAN ST')
# [11] ('N022', 'R332', '135 ST')
# [10] ('R532H', 'R328', 'METS-WILLETS PT')
# [10] ('N183', 'R415', 'BROAD CHANNEL')
# [8] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [7] ('N123B', 'R439', 'ROCKAWAY AV')
# [7] ('A084', 'R125', 'BROAD ST')
# [5] ('N223', 'R156', 'BEDFORD PK BLVD')
# [4] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [1] ('J034', 'R007', '104 ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# 0 ('A085', 'R125', 'BROAD ST')
# [-49] ('N029', 'R333', '116 ST')
# [-1479] ('R241A', 'R048', 'GRD CNTRL-42 ST')

# %%
friday = MTA[MTA.DATE == '06/16/2017']
friday = friday.reset_index(drop=True)

friday_dict = {}
for i in range(len(friday.index)):
    mytuple = (friday["C/A"][i],friday.UNIT[i],friday.SCP[i],friday.STATION[i])
    if mytuple not in friday_dict.keys():
        friday_dict[mytuple] = [(friday.TIME[i],friday.EXITS[i])]
    else:
        friday_dict[mytuple].append((friday.TIME[i],friday.EXITS[i]))

friday_dict_diff = {}
for key,value in friday_dict.items():
    for i in range(1,len(value)):
        if key not in friday_dict_diff:
            friday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            friday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in friday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value

        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = friday[(friday.TIME=='05:00:00')|(friday.TIME=='06:00:00')|(friday.TIME=='07:00:00')|(friday.TIME=='08:00:00')|(friday.TIME=='09:00:00')|(friday.TIME=='10:00:00')|(friday.TIME=='11:00:00')|(friday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

friday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    friday_morning_passengers.append(mytuple)
friday_morning_passengers.sort(reverse=True)
for key,value in friday_morning_passengers:
    print(key,value)
# Out:
# [17075] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [14822] ('N500', 'R020', '47-50 STS ROCK')
# [12297] ('N501', 'R020', '47-50 STS ROCK')
# [11596] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [11177] ('N306', 'R017', 'LEXINGTON AV/53')
# [10098] ('N504', 'R021', '42 ST-BRYANT PK')
# [10072] ('A025', 'R023', '34 ST-HERALD SQ')
# [9446] ('R249', 'R179', '86 ST')
# [8972] ('A021', 'R032', 'TIMES SQ-42 ST')
# [8939] ('N505', 'R022', '34 ST-HERALD SQ')
# [8480] ('N304', 'R015', '5 AV/53 ST')
# [8245] ('N051', 'R084', '59 ST COLUMBUS')
# [7595] ('N506', 'R022', '34 ST-HERALD SQ')
# [7301] ('N049', 'R084', '59 ST COLUMBUS')
# [7032] ('N507', 'R023', '34 ST-HERALD SQ')
# [6714] ('R116', 'R030', 'CHAMBERS ST')
# [6550] ('N305', 'R017', 'LEXINGTON AV/53')
# [6503] ('R151', 'R033', 'TIMES SQ-42 ST')
# [6306] ('R143', 'R032', 'TIMES SQ-42 ST')
# [6188] ('N303', 'R015', '5 AV/53 ST')
# [6086] ('N501A', 'R020', '47-50 STS ROCK')
# [6031] ('R145', 'R032', 'TIMES SQ-42 ST')
# [5878] ('N098', 'R028', 'FULTON ST')
# [5870] ('R243', 'R049', '51 ST')
# [5764] ('N503', 'R021', '42 ST-BRYANT PK')
# [5684] ('R245A', 'R051', '59 ST')
# [5561] ('R155', 'R116', '50 ST')
# [5559] ('N520', 'R240', 'GRAND ST')
# [5504] ('R258', 'R132', '125 ST')
# [5215] ('R501', 'R054', '5 AVE')
# [5109] ('R206', 'R014', 'FULTON ST')
# [5008] ('R182', 'R035', '168 ST')
# [4951] ('A033', 'R170', '14 ST-UNION SQ')
# [4914] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [4807] ('R533', 'R055', 'FLUSHING-MAIN')
# [4802] ('R244', 'R050', '59 ST')
# [4778] ('N508', 'R453', '23 ST')
# [4740] ('R246', 'R177', '68ST-HUNTER CO')
# [4712] ('R202', 'R042', 'BOWLING GREEN')
# [4561] ('N305A', 'R016', 'LEXINGTON AV/53')
# [4474] ('R154', 'R116', '50 ST')
# [4471] ('N509', 'R203', '23 ST')
# [4451] ('R247', 'R178', '77 ST')
# [4439] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [4418] ('R111', 'R027', 'WALL ST')
# [4413] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [4313] ('H009', 'R235', 'BEDFORD AV')
# [4255] ('N067', 'R012', '34 ST-PENN STA')
# [4230] ('R201', 'R041', 'BOWLING GREEN')
# [4219] ('R204', 'R043', 'WALL ST')
# [4198] ('R221', 'R170', '14 ST-UNION SQ')
# [4166] ('R550', 'R072', '34 ST-HUDSON YD')
# [4146] ('R113', 'R028', 'FULTON ST')
# [4145] ('A034', 'R170', '14 ST-UNION SQ')
# [4095] ('R244A', 'R050', '59 ST')
# [4080] ('N026', 'R102', '125 ST')
# [4059] ('N089', 'R139', 'CANAL ST')
# [4033] ('N092', 'R029', 'CHAMBERS ST')
# [4016] ('A022', 'R022', '34 ST-HERALD SQ')
# [3991] ('R169', 'R168', '96 ST')
# [3953] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [3833] ('A006', 'R079', '5 AV/59 ST')
# [3784] ('N606', 'R025', 'JAMAICA CENTER')
# [3744] ('N103', 'R127', 'JAY ST-METROTEC')
# [3721] ('N600', 'R302', '57 ST')
# [3695] ('A069', 'R044', 'CHAMBERS ST')
# [3647] ('N102', 'R127', 'JAY ST-METROTEC')
# [3623] ('R142', 'R293', '34 ST-PENN STA')
# [3602] ('N062A', 'R010', '42 ST-PORT AUTH')
# [3600] ('N700A', 'R570', '72 ST-2 AVE')
# [3592] ('N301', 'R113', '7 AV')
# [3500] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [3457] ('R601A', 'R108', 'BOROUGH HALL')
# [3393] ('N063A', 'R011', '42 ST-PORT AUTH')
# [3386] ('R147', 'R033', 'TIMES SQ-42 ST')
# [3370] ('R242', 'R049', '51 ST')
# [3358] ('N094', 'R029', 'WORLD TRADE CTR')
# [3338] ('R110', 'R027', 'WALL ST')
# [3309] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [3289] ('R158', 'R084', '59 ST COLUMBUS')
# [3273] ('N502', 'R021', '42 ST-BRYANT PK')
# [3261] ('N700', 'R570', '72 ST-2 AVE')
# [3238] ('N091', 'R029', 'CHAMBERS ST')
# [3235] ('A002', 'R051', '59 ST')
# [3218] ('A029', 'R082', '28 ST')
# [3187] ('R610', 'R057', 'ATL AV-BARCLAY')
# [3084] ('R216', 'R322', 'SPRING ST')
# [3082] ('N060', 'R010', '42 ST-PORT AUTH')
# [3041] ('A042', 'R086', 'PRINCE ST')
# [3022] ('R200A', 'R041', 'BOWLING GREEN')
# [3009] ('H008', 'R248', '1 AV')
# [2987] ('N071', 'R013', '34 ST-PENN STA')
# [2977] ('A046', 'R463', 'CANAL ST')
# [2950] ('A043', 'R462', 'CANAL ST')
# [2932] ('R526', 'R096', '82 ST-JACKSON H')
# [2928] ('R148', 'R033', 'TIMES SQ-42 ST')
# [2905] ('R228', 'R143', '28 ST')
# [2898] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [2895] ('A030', 'R083', '23 ST')
# [2889] ('R602', 'R108', 'BOROUGH HALL')
# [2866] ('R112', 'R027', 'WALL ST')
# [2857] ('N095A', 'R014', 'FULTON ST')
# [2828] ('N108', 'R217', 'HOYT-SCHER')
# [2828] ('A060', 'R001', 'WHITEHALL S-FRY')
# [2808] ('N090', 'R139', 'CANAL ST')
# [2786] ('A031', 'R083', '23 ST')
# [2736] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2723] ('R138', 'R293', '34 ST-PENN STA')
# [2723] ('A013', 'R081', '49 ST')
# [2708] ('N078', 'R175', '14 ST')
# [2694] ('R161B', 'R452', '72 ST')
# [2621] ('N601', 'R319', 'LEXINGTON AV/63')
# [2560] ('R168A', 'R168', '96 ST')
# [2554] ('N076', 'R111', '23 ST')
# [2553] ('R141', 'R031', '34 ST-PENN STA')
# [2538] ('A049', 'R088', 'CORTLANDT ST')
# [2522] ('R112A', 'R027', 'WALL ST')
# [2518] ('N070', 'R012', '34 ST-PENN STA')
# [2508] ('R226', 'R131', '23 ST')
# [2505] ('A010', 'R080', '57 ST-7 AV')
# [2500] ('A015', 'R081', '49 ST')
# [2498] ('R248', 'R178', '77 ST')
# [2473] ('C008', 'R099', 'DEKALB AV')
# [2461] ('R101', 'R001', 'SOUTH FERRY')
# [2446] ('A081', 'R028', 'FULTON ST')
# [2406] ('H001', 'R175', '8 AV')
# [2398] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [2380] ('N300', 'R113', '7 AV')
# [2375] ('A035', 'R170', '14 ST-UNION SQ')
# [2350] ('N095', 'R014', 'FULTON ST')
# [2330] ('N601A', 'R319', 'LEXINGTON AV/63')
# [2328] ('R232', 'R176', '33 ST')
# [2274] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [2258] ('H007', 'R248', '1 AV')
# [2241] ('R114', 'R028', 'FULTON ST')
# [2238] ('N020', 'R101', '145 ST')
# [2233] ('N073', 'R013', '34 ST-PENN STA')
# [2208] ('R516', 'R291', '33 ST-RAWSON ST')
# [2206] ('N309A', 'R140', 'QUEENS PLAZA')
# [2196] ('N512', 'R163', '14 ST')
# [2196] ('N056', 'R188', '50 ST')
# [2194] ('R135', 'R031', '34 ST-PENN STA')
# [2169] ('N046', 'R281', '72 ST')
# [2156] ('N077', 'R111', '23 ST')
# [2148] ('N069', 'R013', '34 ST-PENN STA')
# [2128] ('N068', 'R012', '34 ST-PENN STA')
# [2115] ('R534', 'R055', 'FLUSHING-MAIN')
# [2109] ('N400A', 'R359', 'COURT SQ')
# [2109] ('A027', 'R082', '28 ST')
# [2090] ('R507', 'R134', 'HUNTERS PT AV')
# [2086] ('R252', 'R180', '103 ST')
# [2083] ('R242A', 'R049', '51 ST')
# [2075] ('A039', 'R085', '8 ST-NYU')
# [2034] ('R137', 'R031', '34 ST-PENN STA')
# [2013] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [1972] ('N523', 'R300', '2 AV')
# [1957] ('A058', 'R001', 'WHITEHALL S-FRY')
# [1901] ('R229', 'R143', '28 ST')
# [1858] ('R203', 'R043', 'WALL ST')
# [1857] ('R183', 'R260', '181 ST')
# [1849] ('N072', 'R012', '34 ST-PENN STA')
# [1846] ('R261', 'R205', '149/GRAND CONC')
# [1788] ('N510', 'R163', '14 ST')
# [1787] ('C012', 'R258', '4AV-9 ST')
# [1751] ('R102', 'R304', 'RECTOR ST')
# [1737] ('R523', 'R147', '61 ST WOODSIDE')
# [1718] ('R161A', 'R452', '72 ST')
# [1698] ('N063', 'R011', '42 ST-PORT AUTH')
# [1689] ('R217A', 'R194', 'BLEECKER ST')
# [1689] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [1689] ('B016', 'R098', 'CHURCH AV')
# [1686] ('N062', 'R011', '42 ST-PORT AUTH')
# [1682] ('A047', 'R087', 'CITY HALL')
# [1670] ('R127', 'R105', '14 ST')
# [1654] ('A061', 'R142', 'DELANCEY/ESSEX')
# [1652] ('R208', 'R014', 'FULTON ST')
# [1651] ('R528', 'R097', 'JUNCTION BLVD')
# [1620] ('R412', 'R146', 'HUNTS POINT AV')
# [1618] ('A014', 'R081', '49 ST')
# [1605] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1605] ('N044', 'R187', '81 ST-MUSEUM')
# [1574] ('R605', 'R456', 'HOYT ST')
# [1566] ('R132', 'R190', '23 ST')
# [1562] ('R124', 'R290', 'HOUSTON ST')
# [1557] ('R220', 'R160', 'ASTOR PL')
# [1550] ('R609', 'R056', 'NEVINS ST')
# [1548] ('R159', 'R164', '66 ST-LINCOLN')
# [1544] ('R165', 'R167', '86 ST')
# [1539] ('A011', 'R080', '57 ST-7 AV')
# [1530] ('R173', 'R159', '116 ST-COLUMBIA')
# [1501] ('D002', 'R390', '8 AV')
# [1470] ('R508', 'R346', 'COURT SQ')
# [1461] ('R174', 'R034', '125 ST')
# [1452] ('N511', 'R163', '14 ST')
# [1451] ('R245', 'R051', '59 ST')
# [1448] ('R283', 'R221', '167 ST')
# [1414] ('R115', 'R029', 'PARK PLACE')
# [1410] ('N607', 'R025', 'JAMAICA CENTER')
# [1400] ('R301', 'R323', 'CENTRAL PK N110')
# [1398] ('R126', 'R189', 'CHRISTOPHER ST')
# [1390] ('C018', 'R197', '36 ST')
# [1389] ('R612', 'R057', 'ATL AV-BARCLAY')
# [1375] ('N405', 'R239', 'GREENPOINT AV')
# [1370] ('N521', 'R300', '2 AV')
# [1364] ('R250', 'R179', '86 ST')
# [1361] ('R529', 'R208', '103 ST-CORONA')
# [1358] ('A041', 'R086', 'PRINCE ST')
# [1345] ('N315', 'R238', 'STEINWAY ST')
# [1340] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [1338] ('H005', 'R330', '3 AV')
# [1332] ('N040', 'R251', '96 ST')
# [1327] ('R503', 'R276', 'VERNON-JACKSON')
# [1324] ('R251', 'R144', '96 ST')
# [1317] ('R518', 'R261', '40 ST LOWERY ST')
# [1301] ('N536', 'R270', 'SMITH-9 ST')
# [1299] ('R204A', 'R043', 'WALL ST')
# [1276] ('N124', 'R103', 'BROADWAY JCT')
# [1257] ('R134', 'R272', '28 ST')
# [1248] ('R185', 'R274', '191 ST')
# [1246] ('N702', 'R572', '96 ST-2 AVE')
# [1241] ('N057', 'R188', '50 ST')
# [1241] ('A016', 'R081', '49 ST')
# [1239] ('R311', 'R053', '3 AV-149 ST')
# [1234] ('R417', 'R222', 'PARKCHESTER')
# [1225] ('R420', 'R107', 'WESTCHESTER SQ')
# [1222] ('N701A', 'R571', '86 ST-2 AVE')
# [1216] ('R515', 'R095', 'ASTORIA DITMARS')
# [1213] ('R608', 'R056', 'NEVINS ST')
# [1212] ('R130', 'R321', '18 ST')
# [1209] ('N539A', 'R288', '7 AV')
# [1201] ('N513', 'R163', '14 ST')
# [1195] ('N525', 'R142', 'DELANCEY/ESSEX')
# [1194] ('N043', 'R186', '86 ST')
# [1191] ('J001', 'R460', 'MARCY AV')
# [1164] ('R519', 'R223', '46 ST BLISS ST')
# [1153] ('N528', 'R257', 'EAST BROADWAY')
# [1153] ('A007', 'R079', '5 AV/59 ST')
# [1152] ('R331', 'R364', 'GUN HILL RD')
# [1130] ('B024', 'R211', 'KINGS HWY')
# [1126] ('A037', 'R170', '14 ST-UNION SQ')
# [1107] ('R231A', 'R176', '33 ST')
# [1106] ('N327', 'R254', 'GRAND-NEWTOWN')
# [1103] ('R231', 'R176', '33 ST')
# [1090] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [1089] ('R256', 'R182', '116 ST')
# [1088] ('R164', 'R167', '86 ST')
# [1087] ('N101', 'R252', 'HIGH ST')
# [1075] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [1074] ('J002', 'R460', 'MARCY AV')
# [1074] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [1060] ('B024A', 'R211', 'KINGS HWY')
# [1048] ('R205A', 'R014', 'FULTON ST')
# [1045] ('R509', 'R121', 'QUEENSBORO PLZ')
# [1040] ('G009', 'R151', 'CONEY IS-STILLW')
# [1039] ('R284', 'R243', '170 ST')
# [1037] ('R527', 'R122', '90 ST-ELMHURST')
# [1036] ('R128', 'R105', '14 ST')
# [1025] ('R511', 'R091', '36 AV')
# [1007] ('A083', 'R125', 'BROAD ST')
# [1003] ('A050', 'R088', 'CORTLANDT ST')
# [985] ('N330', 'R202', '63 DR-REGO PARK')
# [969] ('N117', 'R198', 'NOSTRAND AV')
# [962] ('R160A', 'R164', '66 ST-LINCOLN')
# [959] ('R629', 'R065', 'ROCKAWAY AV')
# [946] ('B004', 'R171', '7 AV')
# [941] ('H016', 'R250', 'GRAND ST')
# [937] ('N702A', 'R572', '96 ST-2 AVE')
# [927] ('N310', 'R140', 'QUEENS PLAZA')
# [925] ('R253', 'R181', '110 ST')
# [921] ('R604', 'R108', 'BOROUGH HALL')
# [902] ('R120', 'R320', 'CANAL ST')
# [902] ('N422', 'R318', 'FULTON ST')
# [900] ('C003', 'R089', 'JAY ST-METROTEC')
# [899] ('N339A', 'R114', 'PARSONS BLVD')
# [896] ('R160', 'R164', '66 ST-LINCOLN')
# [895] ('N217', 'R112', 'FORDHAM RD')
# [884] ('A054', 'R227', 'RECTOR ST')
# [882] ('N549', 'R242', '18 AV')
# [874] ('R512', 'R092', 'BROADWAY')
# [873] ('R232A', 'R176', '33 ST')
# [869] ('H003', 'R163', '6 AV')
# [867] ('N329', 'R201', 'WOODHAVEN BLVD')
# [867] ('C025', 'R215', '86 ST')
# [865] ('N535', 'R220', 'CARROLL ST')
# [865] ('N116', 'R198', 'NOSTRAND AV')
# [863] ('N025', 'R102', '125 ST')
# [862] ('N537', 'R258', '4 AV-9 ST')
# [858] ('N120', 'R153', 'UTICA AV')
# [850] ('N602', 'R259', 'ROOSEVELT ISLND')
# [848] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [848] ('R423', 'R429', 'PELHAM BAY PARK')
# [844] ('R304', 'R206', '125 ST')
# [837] ('R336', 'R145', 'WAKEFIELD/241')
# [837] ('R287', 'R244', 'BURNSIDE AV')
# [831] ('N701', 'R571', '86 ST-2 AVE')
# [828] ('D005', 'R398', 'NEW UTRECHT AV')
# [824] ('H014', 'R249', 'GRAHAM AV')
# [819] ('R162', 'R166', '79 ST')
# [816] ('R103', 'R304', 'RECTOR ST')
# [814] ('N196', 'R285', 'FAR ROCKAWAY')
# [813] ('N604', 'R342', 'JAMAICA VAN WK')
# [808] ('A064', 'R311', 'BOWERY')
# [806] ('E004', 'R234', '50 ST')
# [794] ('B019', 'R149', 'NEWKIRK PLAZA')
# [793] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [792] ('R401', 'R445', '3 AV 138 ST')
# [791] ('N213', 'R154', 'TREMONT AV')
# [787] ('N013', 'R035', '168 ST')
# [786] ('A077', 'R028', 'FULTON ST')
# [782] ('B031', 'R172', 'BRIGHTON BEACH')
# [770] ('N530', 'R301', 'YORK ST')
# [769] ('R530', 'R310', '111 ST')
# [766] ('R514', 'R094', 'ASTORIA BLVD')
# [764] ('R525', 'R018', '74 ST-BROADWAY')
# [759] ('R634', 'R069', 'NEW LOTS AV')
# [751] ('N546', 'R204', 'CHURCH AV')
# [749] ('N010', 'R126', '175 ST')
# [739] ('R171', 'R192', 'CATHEDRAL PKWY')
# [738] ('R310', 'R053', '3 AV-149 ST')
# [737] ('N312', 'R339', '36 ST')
# [737] ('J020', 'R433', 'ALABAMA AV')
# [732] ('R291', 'R183', 'BEDFORD PK BLVD')
# [729] ('R418', 'R106', 'CASTLE HILL AV')
# [725] ('N408A', 'R256', 'NASSAU AV')
# [722] ('N333B', 'R141', 'FOREST HILLS 71')
# [719] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [717] ('C019', 'R232', '45 ST')
# [716] ('N526', 'R142', 'DELANCEY/ESSEX')
# [713] ('R227A', 'R131', '23 ST')
# [708] ('R254', 'R181', '110 ST')
# [705] ('N307', 'R359', 'COURT SQ-23 ST')
# [698] ('J007', 'R377', 'FLUSHING AV')
# [696] ('R622', 'R123', 'FRANKLIN AV')
# [694] ('R175', 'R169', '137 ST CITY COL')
# [693] ('J009', 'R378', 'MYRTLE AV')
# [689] ('H019', 'R294', 'MORGAN AV')
# [688] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [676] ('N141', 'R356', 'OZONE PK LEFFRT')
# [675] ('R517', 'R291', '33 ST-RAWSON ST')
# [675] ('R230', 'R143', '28 ST')
# [674] ('N419', 'R287', 'CLASSON AV')
# [672] ('H039', 'R375', 'NEW LOTS')
# [671] ('A038', 'R085', '8 ST-NYU')
# [668] ('N412', 'R299', 'BROADWAY')
# [667] ('R635', 'R277', 'PRESIDENT ST')
# [666] ('R628', 'R064', 'SARATOGA AV')
# [666] ('A066', 'R118', 'CANAL ST')
# [662] ('R625', 'R062', 'CROWN HTS-UTICA')
# [662] ('R624', 'R124', 'KINGSTON AV')
# [661] ('B012', 'R196', 'PROSPECT PARK')
# [655] ('R323', 'R387', 'WEST FARMS SQ')
# [650] ('H017', 'R265', 'MONTROSE AV')
# [649] ('N019', 'R101', '145 ST')
# [645] ('N039', 'R251', '96 ST')
# [644] ('G001', 'R151', 'CONEY IS-STILLW')
# [642] ('R290', 'R161', 'KINGSBRIDGE RD')
# [641] ('H040', 'R376', 'EAST 105 ST')
# [639] ('R259', 'R307', '138/GRAND CONC')
# [636] ('R606', 'R225', 'HOYT ST')
# [636] ('R170', 'R191', '103 ST')
# [628] ('R403', 'R446', 'BROOK AV')
# [628] ('R139', 'R031', '34 ST-PENN STA')
# [627] ('N401', 'R360', '21 ST')
# [626] ('R285', 'R308', 'MT EDEN AV')
# [620] ('B022', 'R229', 'AVENUE M')
# [619] ('B021', 'R228', 'AVENUE J')
# [613] ('R415', 'R120', 'MORISN AV/SNDVW')
# [612] ('N086', 'R282', 'SPRING ST')
# [611] ('R504', 'R276', 'VERNON-JACKSON')
# [605] ('R219', 'R160', 'ASTOR PL')
# [601] ('N343', 'R019', 'JAMAICA 179 ST')
# [599] ('R623', 'R061', 'NOSTRAND AV')
# [599] ('R131', 'R190', '23 ST')
# [599] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [598] ('N531', 'R129', 'BERGEN ST')
# [595] ('N100', 'R252', 'HIGH ST')
# [591] ('R133', 'R272', '28 ST')
# [590] ('H006', 'R330', '3 AV')
# [589] ('N529', 'R257', 'EAST BROADWAY')
# [589] ('N409', 'R268', 'METROPOLITAN AV')
# [586] ('R186', 'R036', 'DYCKMAN ST')
# [578] ('C011', 'R231', 'UNION ST')
# [577] ('R129', 'R321', '18 ST')
# [572] ('R215', 'R322', 'SPRING ST')
# [571] ('R524', 'R347', '69 ST')
# [570] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [568] ('R600', 'R224', 'CLARK ST')
# [566] ('R510', 'R090', '39 AV')
# [565] ('B029', 'R172', 'BRIGHTON BEACH')
# [549] ('R177', 'R273', '145 ST')
# [545] ('R414', 'R162', 'ELDER AV')
# [543] ('R163', 'R166', '79 ST')
# [540] ('R286', 'R309', '176 ST')
# [528] ('N340A', 'R115', '169 ST')
# [526] ('R316', 'R407', 'INTERVALE AV')
# [524] ('N316A', 'R267', '46 ST')
# [522] ('R532', 'R328', 'METS-WILLETS PT')
# [519] ('N207', 'R104', '167 ST')
# [518] ('N128', 'R200', 'EUCLID AV')
# [515] ('N114', 'R297', 'FRANKLIN AV')
# [513] ('E014', 'R374', 'BAY PKWY')
# [511] ('R203A', 'R043', 'WALL ST')
# [511] ('E001', 'R368', '9 AV')
# [510] ('R325', 'R388', 'E 180 ST')
# [509] ('N045', 'R187', '81 ST-MUSEUM')
# [508] ('N314', 'R238', 'STEINWAY ST')
# [508] ('N075', 'R111', '23 ST')
# [503] ('R118', 'R343', 'FRANKLIN ST')
# [501] ('E003', 'R369', 'FT HAMILTON PKY')
# [499] ('R321', 'R386', '174 ST')
# [499] ('B013', 'R196', 'PROSPECT PARK')
# [491] ('C021', 'R212', '59 ST')
# [487] ('N129', 'R382', 'GRANT AV')
# [484] ('R411', 'R450', 'LONGWOOD AV')
# [479] ('R172', 'R192', 'CATHEDRAL PKWY')
# [478] ('H023', 'R236', 'DEKALB AV')
# [477] ('N340', 'R115', '169 ST')
# [474] ('R288', 'R275', '183 ST')
# [473] ('C017', 'R455', '25 ST')
# [469] ('R123', 'R290', 'HOUSTON ST')
# [469] ('B015', 'R098', 'CHURCH AV')
# [468] ('R409', 'R449', 'E 149 ST')
# [467] ('R307', 'R207', '135 ST')
# [466] ('N111', 'R284', 'CLINTON-WASH AV')
# [465] ('R309', 'R345', 'HARLEM 148 ST')
# [462] ('N319', 'R298', 'NORTHERN BLVD')
# [461] ('N331', 'R219', '67 AV')
# [457] ('R188', 'R037', '207 ST')
# [456] ('H032', 'R295', 'WILSON AV')
# [455] ('R419', 'R326', 'ZEREGA AV')
# [454] ('B023', 'R211', 'KINGS HWY')
# [451] ('R405', 'R447', 'CYPRESS AV')
# [448] ('K019', 'R413', 'KNICKERBOCKER')
# [447] ('N024', 'R332', '135 ST')
# [446] ('R319', 'R409', 'FREEMAN ST')
# [446] ('R176', 'R169', '137 ST CITY COL')
# [440] ('H015', 'R250', 'GRAND ST')
# [437] ('R416', 'R245', 'ST LAWRENCE AV')
# [437] ('N118', 'R199', 'KINGSTON-THROOP')
# [435] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [435] ('N122', 'R439', 'ROCKAWAY AV')
# [435] ('C001', 'R108', 'BOROUGH HALL')
# [433] ('N035', 'R334', 'CATHEDRAL PKWY')
# [430] ('J024', 'R437', 'CRESCENT ST')
# [428] ('N120A', 'R153', 'UTICA AV')
# [426] ('R293', 'R133', 'MOSHOLU PKWY')
# [424] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [421] ('R521', 'R327', '52 ST')
# [415] ('R305', 'R206', '125 ST')
# [415] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [414] ('R226A', 'R131', '23 ST')
# [411] ('R257', 'R182', '116 ST')
# [411] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [410] ('N333A', 'R141', 'FOREST HILLS 71')
# [409] ('N112A', 'R284', 'CLINTON-WASH AV')
# [408] ('R197', 'R117', 'V.CORTLANDT PK')
# [406] ('N030', 'R333', '116 ST')
# [401] ('N220', 'R155', 'KINGSBRIDGE RD')
# [399] ('R125', 'R189', 'CHRISTOPHER ST')
# [392] ('N222', 'R156', 'BEDFORD PK BLVD')
# [385] ('N224', 'R157', 'NORWOOD 205 ST')
# [384] ('N311', 'R339', '36 ST')
# [381] ('E011', 'R371', '79 ST')
# [380] ('N342', 'R019', 'JAMAICA 179 ST')
# [372] ('R637', 'R451', 'WINTHROP ST')
# [372] ('D003', 'R391', 'FT HAMILTON PKY')
# [371] ('R178', 'R273', '145 ST')
# [370] ('N009', 'R174', '181 ST')
# [369] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [366] ('N318', 'R298', 'NORTHERN BLVD')
# [366] ('B009', 'R411', 'PARK PLACE')
# [363] ('N532', 'R129', 'BERGEN ST')
# [363] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [358] ('R644', 'R135', 'NEWKIRK AV')
# [358] ('N037', 'R314', '103 ST')
# [357] ('N414', 'R316', 'FLUSHING AV')
# [357] ('N121B', 'R438', 'RALPH AV')
# [357] ('N023', 'R332', '135 ST')
# [356] ('R289', 'R119', 'FORDHAM RD')
# [354] ('C016', 'R278', '25 ST')
# [353] ('K025', 'R404', 'FRESH POND RD')
# [353] ('J005', 'R353', 'LORIMER ST')
# [353] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [351] ('R166', 'R167', '86 ST')
# [350] ('R328', 'R361', 'PELHAM PKWY')
# [349] ('K026', 'R100', 'METROPOLITAN AV')
# [349] ('C010', 'R231', 'UNION ST')
# [346] ('H038', 'R350', 'LIVONIA AV')
# [345] ('R303', 'R324', '116 ST')
# [344] ('R179', 'R193', '157 ST')
# [342] ('N557', 'R130', 'KINGS HWY')
# [341] ('N534', 'R220', 'CARROLL ST')
# [338] ('R636', 'R209', 'STERLING ST')
# [338] ('R408', 'R449', 'E 149 ST')
# [337] ('N325A', 'R218', 'ELMHURST AV')
# [334] ('J022', 'R435', 'CLEVELAND ST')
# [333] ('A071', 'R044', 'CHAMBERS ST')
# [328] ('B018', 'R184', 'CORTELYOU RD')
# [326] ('R180', 'R193', '157 ST')
# [321] ('H037', 'R349', 'SUTTER AV')
# [320] ('R306', 'R207', '135 ST')
# [320] ('R302', 'R324', '116 ST')
# [320] ('D012', 'R395', 'KINGS HWY')
# [318] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [318] ('K017', 'R401', 'CENTRAL AV')
# [317] ('N555', 'R423', 'AVENUE N')
# [314] ('N119', 'R199', 'KINGSTON-THROOP')
# [313] ('B014', 'R148', 'PARKSIDE AV')
# [310] ('R632', 'R067', 'PENNSYLVANIA AV')
# [308] ('R633', 'R068', 'VAN SICLEN AV')
# [308] ('N414A', 'R316', 'FLUSHING AV')
# [305] ('N006A', 'R280', '190 ST')
# [300] ('N561', 'R271', 'AVENUE X')
# [299] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [297] ('R119', 'R320', 'CANAL ST')
# [293] ('H022', 'R279', 'JEFFERSON ST')
# [290] ('E005', 'R247', '55 ST')
# [287] ('N126', 'R441', 'VAN SICLEN AVE')
# [282] ('R332', 'R365', '219 ST')
# [282] ('N034', 'R334', 'CATHEDRAL PKWY')
# [282] ('J031', 'R006', 'WOODHAVEN BLVD')
# [280] ('C024', 'R214', '77 ST')
# [280] ('B020', 'R263', 'AVENUE H')
# [279] ('R422', 'R428', 'BUHRE AV')
# [279] ('N113', 'R297', 'FRANKLIN AV')
# [278] ('R727', 'R430', 'PELHAM PKWY')
# [278] ('B010', 'R412', 'BOTANIC GARDEN')
# [277] ('J023', 'R436', 'NORWOOD AV')
# [275] ('R402', 'R446', 'BROOK AV')
# [274] ('R407', 'R448', "E 143/ST MARY'S")
# [270] ('N202', 'R315', '155 ST')
# [270] ('J035', 'R008', '111 ST')
# [268] ('N007A', 'R174', '181 ST')
# [268] ('H030', 'R266', 'HALSEY ST')
# [265] ('J028', 'R004', '75 ST-ELDERTS')
# [263] ('R639', 'R109', 'CHURCH AV')
# [263] ('B025', 'R150', 'AVENUE U')
# [261] ('N125', 'R440', 'LIBERTY AV')
# [258] ('R404', 'R447', 'CYPRESS AV')
# [258] ('N316', 'R267', '46 ST')
# [256] ('R329', 'R362', 'ALLERTON AV')
# [256] ('J012', 'R379', 'KOSCIUSZKO ST')
# [255] ('N110', 'R283', 'LAFAYETTE AV')
# [254] ('R618', 'R058', 'BERGEN ST')
# [254] ('R410', 'R450', 'LONGWOOD AV')
# [253] ('J021', 'R434', 'VAN SICLEN AV')
# [250] ('R413', 'R325', 'WHITLOCK AV')
# [250] ('N337', 'R255', 'BRIARWOOD')
# [249] ('N556', 'R424', 'AVENUE P')
# [249] ('N551', 'R421', 'AVENUE I')
# [246] ('R421', 'R427', 'MIDDLETOWN RD')
# [245] ('J013', 'R380', 'GATES AV')
# [244] ('E012', 'R372', '18 AV')
# [244] ('B017', 'R262', 'BEVERLEY ROAD')
# [242] ('N333', 'R141', 'FOREST HILLS 71')
# [241] ('N221', 'R155', 'KINGSBRIDGE RD')
# [236] ('N212', 'R253', '174-175 STS')
# [235] ('N215', 'R237', '182-183 STS')
# [235] ('N087', 'R282', 'SPRING ST')
# [234] ('R227', 'R131', '23 ST')
# [233] ('R617', 'R058', 'BERGEN ST')
# [233] ('N195', 'R358', 'BEACH 25 ST')
# [229] ('N209', 'R443', '170 ST')
# [229] ('H013', 'R249', 'GRAHAM AV')
# [229] ('A055', 'R227', 'RECTOR ST')
# [219] ('N017', 'R331', '155 ST')
# [218] ('J016', 'R381', 'HALSEY ST')
# [216] ('B032', 'R264', 'OCEAN PKWY')
# [213] ('R117', 'R343', 'FRANKLIN ST')
# [213] ('N559', 'R425', 'AVENUE U')
# [210] ('N338B', 'R128', 'SUTPHIN BLVD')
# [206] ('R327', 'R361', 'PELHAM PKWY')
# [204] ('R728', 'R226', 'GUN HILL RD')
# [202] ('N322', 'R340', '65 ST')
# [201] ('R294', 'R052', 'WOODLAWN')
# [200] ('N191', 'R335', 'BEACH 67 ST')
# [200] ('H028', 'R266', 'HALSEY ST')
# [198] ('D015', 'R396', 'AVENUE U')
# [193] ('N548', 'R420', 'DITMAS AV')
# [192] ('R333', 'R366', '225 ST')
# [192] ('N225', 'R157', 'NORWOOD 205 ST')
# [191] ('N127', 'R442', 'SHEPHERD AV')
# [188] ('N012', 'R035', '168 ST')
# [187] ('N134', 'R385', 'ROCKAWAY BLVD')
# [187] ('E016', 'R400', 'BAY 50 ST')
# [186] ('R260', 'R205', '149/GRAND CONC')
# [184] ('N192', 'R336', 'BEACH 60 ST')
# [184] ('N001', 'R173', 'INWOOD-207 ST')
# [182] ('R194', 'R040', '231 ST')
# [181] ('J003', 'R352', 'HEWES ST')
# [179] ('R190', 'R038', '215 ST')
# [179] ('K024', 'R403', 'FOREST AVE')
# [176] ('R335', 'R444', 'NEREID AV')
# [176] ('N002A', 'R173', 'INWOOD-207 ST')
# [170] ('R122', 'R290', 'HOUSTON ST')
# [168] ('N011', 'R126', '175 ST')
# [168] ('H035', 'R348', 'ATLANTIC AV')
# [165] ('R334', 'R367', '233 ST')
# [164] ('E009', 'R370', '71 ST')
# [161] ('R121', 'R290', 'HOUSTON ST')
# [159] ('R312', 'R405', 'JACKSON AV')
# [157] ('R326', 'R389', 'BRONX PARK EAST')
# [157] ('R315', 'R406', 'PROSPECT AV')
# [157] ('N208', 'R443', '170 ST')
# [157] ('N206', 'R104', '167 ST')
# [156] ('K022', 'R402', 'SENECA AVE')
# [156] ('J030', 'R005', '85 ST-FOREST PK')
# [156] ('E013', 'R373', '20 AV')
# [155] ('C022', 'R212', '59 ST')
# [154] ('H033', 'R313', 'BUSHWICK AV')
# [153] ('J017', 'R432', 'CHAUNCEY ST')
# [152] ('N553', 'R422', 'BAY PKWY')
# [148] ('C004', 'R089', 'JAY ST-METROTEC')
# [146] ('R317', 'R408', 'SIMPSON ST')
# [143] ('J025', 'R003', 'CYPRESS HILLS')
# [140] ('R192', 'R039', 'MARBLE HILL-225')
# [139] ('R726', 'R329', 'MORRIS PARK')
# [139] ('N135', 'R385', 'ROCKAWAY BLVD')
# [138] ('N332', 'R219', '67 AV')
# [132] ('N317', 'R267', '46 ST')
# [132] ('N210', 'R253', '174-175 STS')
# [127] ('H012', 'R268', 'LORIMER ST')
# [127] ('D016', 'R397', '86 ST')
# [124] ('R318', 'R408', 'SIMPSON ST')
# [121] ('N330C', 'R202', '63 DR-REGO PARK')
# [121] ('N187', 'R419', 'ROCKAWAY PARK B')
# [119] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [118] ('R641', 'R210', 'BEVERLY RD')
# [118] ('A082', 'R028', 'FULTON ST')
# [116] ('N562', 'R426', 'NEPTUNE AV')
# [111] ('N533', 'R129', 'BERGEN ST')
# [109] ('N543', 'R289', 'FT HAMILTON PKY')
# [107] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [106] ('N181', 'R357', 'AQUEDUCT N.COND')
# [105] ('N194', 'R338', 'BEACH 36 ST')
# [101] ('R330', 'R363', 'BURKE AV')
# [100] ('R406', 'R448', "E 143/ST MARY'S")
# [98] ('R314', 'R406', 'PROSPECT AV')
# [92] ('R520', 'R223', '46 ST BLISS ST')
# [88] ('N545', 'R204', 'CHURCH AV')
# [87] ('R729', 'R292', 'BAYCHESTER AV')
# [82] ('B034', 'R264', 'OCEAN PKWY')
# [79] ('E015', 'R399', '25 AV')
# [78] ('N558', 'R130', 'KINGS HWY')
# 76 ('D010', 'R394', 'BAY PKWY')
# [74] ('N016A', 'R296', '163 ST-AMSTERDM')
# [70] ('N131', 'R383', '80 ST')
# [69] ('N334B', 'R341', '75 AV')
# [68] ('R322', 'R386', '174 ST')
# [68] ('B026', 'R230', 'NECK RD')
# [67] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [66] ('N420B', 'R317', 'CLINTON-WASH AV')
# [66] ('N193', 'R337', 'BEACH 44 ST')
# [62] ('R643', 'R135', 'NEWKIRK AV')
# [62] ('R320', 'R409', 'FREEMAN ST')
# [62] ('N186', 'R418', 'BEACH 105 ST')
# [62] ('N184', 'R416', 'BEACH 90 ST')
# [56] ('R630', 'R066', 'JUNIUS ST')
# [55] ('N544', 'R289', 'FT HAMILTON PKY')
# [54] ('N185', 'R417', 'BEACH 98 ST')
# [54] ('C026', 'R215', '86 ST')
# 53 ('R627', 'R063', 'SUTTER AV-RUTLD')
# [53] ('N133', 'R384', '88 ST')
# [53] ('J037', 'R009', '121 ST')
# [50] ('J032', 'R006', 'WOODHAVEN BLVD')
# [47] ('N137', 'R354', '104 ST')
# [44] ('N338', 'R128', 'SUTPHIN BLVD')
# [44] ('N182', 'R414', 'HOWARD BCH JFK')
# [43] ('N218', 'R112', 'FORDHAM RD')
# [41] ('N339', 'R114', 'PARSONS BLVD')
# [40] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [39] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [36] ('D008', 'R392', '18 AV')
# [33] ('D009', 'R393', '20 AV')
# [32] ('N547', 'R420', 'DITMAS AV')
# [30] ('R308', 'R344', '145 ST')
# [30] ('N130', 'R383', '80 ST')
# [29] ('R506', 'R276', 'VERNON-JACKSON')
# [27] ('N139', 'R355', '111 ST')
# [22] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [20] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [18] ('J034', 'R007', '104 ST')
# [17] ('N003', 'R185', 'DYCKMAN ST')
# [15] ('N123B', 'R439', 'ROCKAWAY AV')
# [12] ('R196', 'R306', '238 ST')
# [11] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [11] ('N183', 'R415', 'BROAD CHANNEL')
# [11] ('N138', 'R355', '111 ST')
# [9] ('N022', 'R332', '135 ST')
# [5] ('N223', 'R156', 'BEDFORD PK BLVD')
# [4] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [4] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [4] ('R532H', 'R328', 'METS-WILLETS PT')
# [4] ('A084', 'R125', 'BROAD ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# 0 ('A085', 'R125', 'BROAD ST')
# [-73] ('N029', 'R333', '116 ST')
# [-1534] ('R241A', 'R048', 'GRD CNTRL-42 ST')

# %%
saturday = MTA[MTA.DATE == '06/10/2017']
saturday = saturday.reset_index(drop=True)

saturday_dict = {}
for i in range(len(saturday.index)):
    mytuple = (saturday["C/A"][i],saturday.UNIT[i],saturday.SCP[i],saturday.STATION[i])
    if mytuple not in saturday_dict.keys():
        saturday_dict[mytuple] = [(saturday.TIME[i],saturday.EXITS[i])]
    else:
        saturday_dict[mytuple].append((saturday.TIME[i],saturday.EXITS[i]))

saturday_dict_diff = {}
for key,value in saturday_dict.items():
    for i in range(1,len(value)):
        if key not in saturday_dict_diff:
            saturday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            saturday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in saturday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value

        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = saturday[(saturday.TIME=='05:00:00')|(saturday.TIME=='06:00:00')|(saturday.TIME=='07:00:00')|(saturday.TIME=='08:00:00')|(saturday.TIME=='09:00:00')|(saturday.TIME=='10:00:00')|(saturday.TIME=='11:00:00')|(saturday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

saturday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    saturday_morning_passengers.append(mytuple)
saturday_morning_passengers.sort(reverse=True)
for key,value in saturday_morning_passengers:
    print(key,value)
# Out:
# [6141] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [5473] ('H009', 'R235', 'BEDFORD AV')
# [5110] ('N506', 'R022', '34 ST-HERALD SQ')
# [4747] ('R533', 'R055', 'FLUSHING-MAIN')
# [4175] ('A025', 'R023', '34 ST-HERALD SQ')
# [4082] ('N049', 'R084', '59 ST COLUMBUS')
# [3930] ('R249', 'R179', '86 ST')
# [3688] ('R116', 'R030', 'CHAMBERS ST')
# [3584] ('R151', 'R033', 'TIMES SQ-42 ST')
# [3409] ('N520', 'R240', 'GRAND ST')
# [3401] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2995] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [2925] ('N026', 'R102', '125 ST')
# [2756] ('R135', 'R031', '34 ST-PENN STA')
# [2590] ('R258', 'R132', '125 ST')
# [2568] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [2556] ('N051', 'R084', '59 ST COLUMBUS')
# [2486] ('A021', 'R032', 'TIMES SQ-42 ST')
# [2468] ('N507', 'R023', '34 ST-HERALD SQ')
# [2393] ('R526', 'R096', '82 ST-JACKSON H')
# [2348] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [2224] ('N505', 'R022', '34 ST-HERALD SQ')
# [2196] ('R610', 'R057', 'ATL AV-BARCLAY')
# [2145] ('N606', 'R025', 'JAMAICA CENTER')
# [2111] ('R111', 'R027', 'WALL ST')
# [2088] ('R244', 'R050', '59 ST')
# [2042] ('C009', 'R057', 'ATL AV-BARCLAY')
# [2009] ('R138', 'R293', '34 ST-PENN STA')
# [1994] ('R601A', 'R108', 'BOROUGH HALL')
# [1985] ('A042', 'R086', 'PRINCE ST')
# [1896] ('R216', 'R322', 'SPRING ST')
# [1887] ('N073', 'R013', '34 ST-PENN STA')
# [1859] ('R145', 'R032', 'TIMES SQ-42 ST')
# [1829] ('R550', 'R072', '34 ST-HUDSON YD')
# [1817] ('N500', 'R020', '47-50 STS ROCK')
# [1812] ('R534', 'R055', 'FLUSHING-MAIN')
# [1794] ('N503', 'R021', '42 ST-BRYANT PK')
# [1734] ('N072', 'R012', '34 ST-PENN STA')
# [1714] ('R528', 'R097', 'JUNCTION BLVD')
# [1695] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1646] ('H008', 'R248', '1 AV')
# [1644] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [1627] ('N020', 'R101', '145 ST')
# [1621] ('R143', 'R032', 'TIMES SQ-42 ST')
# [1618] ('N504', 'R021', '42 ST-BRYANT PK')
# [1613] ('N094', 'R029', 'WORLD TRADE CTR')
# [1604] ('N067', 'R012', '34 ST-PENN STA')
# [1597] ('N103', 'R127', 'JAY ST-METROTEC')
# [1571] ('N062', 'R011', '42 ST-PORT AUTH')
# [1565] ('N306', 'R017', 'LEXINGTON AV/53')
# [1560] ('R250', 'R179', '86 ST')
# [1556] ('R246', 'R177', '68ST-HUNTER CO')
# [1549] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [1536] ('R183', 'R260', '181 ST')
# [1534] ('R169', 'R168', '96 ST')
# [1527] ('N071', 'R013', '34 ST-PENN STA')
# [1513] ('R523', 'R147', '61 ST WOODSIDE')
# [1512] ('N077', 'R111', '23 ST')
# [1503] ('R501', 'R054', '5 AVE')
# [1496] ('R529', 'R208', '103 ST-CORONA')
# [1465] ('N501', 'R020', '47-50 STS ROCK')
# [1447] ('R221', 'R170', '14 ST-UNION SQ')
# [1443] ('A022', 'R022', '34 ST-HERALD SQ')
# [1435] ('N523', 'R300', '2 AV')
# [1434] ('A046', 'R463', 'CANAL ST')
# [1426] ('R158', 'R084', '59 ST COLUMBUS')
# [1423] ('N062A', 'R010', '42 ST-PORT AUTH')
# [1422] ('R154', 'R116', '50 ST')
# [1387] ('H007', 'R248', '1 AV')
# [1384] ('N092', 'R029', 'CHAMBERS ST')
# [1362] ('N600', 'R302', '57 ST')
# [1343] ('A034', 'R170', '14 ST-UNION SQ')
# [1337] ('B016', 'R098', 'CHURCH AV')
# [1326] ('A033', 'R170', '14 ST-UNION SQ')
# [1321] ('A029', 'R082', '28 ST')
# [1314] ('N108', 'R217', 'HOYT-SCHER')
# [1298] ('N303', 'R015', '5 AV/53 ST')
# [1295] ('R161B', 'R452', '72 ST')
# [1290] ('R244A', 'R050', '59 ST')
# [1290] ('A031', 'R083', '23 ST')
# [1285] ('R247', 'R178', '77 ST')
# [1267] ('A010', 'R080', '57 ST-7 AV')
# [1252] ('N601', 'R319', 'LEXINGTON AV/63')
# [1242] ('R127', 'R105', '14 ST')
# [1232] ('N076', 'R111', '23 ST')
# [1232] ('A002', 'R051', '59 ST')
# [1214] ('A006', 'R079', '5 AV/59 ST')
# [1180] ('N060', 'R010', '42 ST-PORT AUTH')
# [1168] ('N400A', 'R359', 'COURT SQ')
# [1107] ('N046', 'R281', '72 ST')
# [1104] ('R101', 'R001', 'SOUTH FERRY')
# [1100] ('A030', 'R083', '23 ST')
# [1099] ('R242', 'R049', '51 ST')
# [1093] ('N070', 'R012', '34 ST-PENN STA')
# [1083] ('C008', 'R099', 'DEKALB AV')
# [1077] ('N509', 'R203', '23 ST')
# [1075] ('R301', 'R323', 'CENTRAL PK N110')
# [1069] ('R147', 'R033', 'TIMES SQ-42 ST')
# [1054] ('A039', 'R085', '8 ST-NYU')
# [1045] ('R228', 'R143', '28 ST')
# [1033] ('N601A', 'R319', 'LEXINGTON AV/63')
# [1021] ('R515', 'R095', 'ASTORIA DITMARS')
# [1018] ('R261', 'R205', '149/GRAND CONC')
# [1017] ('N521', 'R300', '2 AV')
# [1007] ('H001', 'R175', '8 AV')
# [1003] ('A041', 'R086', 'PRINCE ST')
# [998] ('R142', 'R293', '34 ST-PENN STA')
# [996] ('R182', 'R035', '168 ST')
# [988] ('R243', 'R049', '51 ST')
# [985] ('R527', 'R122', '90 ST-ELMHURST')
# [985] ('D002', 'R390', '8 AV')
# [983] ('R311', 'R053', '3 AV-149 ST')
# [981] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [979] ('N305', 'R017', 'LEXINGTON AV/53')
# [979] ('C012', 'R258', '4AV-9 ST')
# [971] ('R185', 'R274', '191 ST')
# [969] ('N124', 'R103', 'BROADWAY JCT')
# [969] ('A081', 'R028', 'FULTON ST')
# [941] ('N098', 'R028', 'FULTON ST')
# [935] ('R605', 'R456', 'HOYT ST')
# [933] ('N056', 'R188', '50 ST')
# [926] ('R148', 'R033', 'TIMES SQ-42 ST')
# [914] ('N116', 'R198', 'NOSTRAND AV')
# [914] ('N069', 'R013', '34 ST-PENN STA')
# [907] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [903] ('A043', 'R462', 'CANAL ST')
# [900] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [897] ('R513', 'R093', '30 AV')
# [895] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [891] ('R161A', 'R452', '72 ST')
# [887] ('A027', 'R082', '28 ST')
# [883] ('N501A', 'R020', '47-50 STS ROCK')
# [879] ('N536', 'R270', 'SMITH-9 ST')
# [877] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [873] ('R512', 'R092', 'BROADWAY')
# [872] ('R245A', 'R051', '59 ST')
# [861] ('R126', 'R189', 'CHRISTOPHER ST')
# [857] ('N089', 'R139', 'CANAL ST')
# [856] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [854] ('A064', 'R311', 'BOWERY')
# [850] ('R226', 'R131', '23 ST')
# [849] ('R141', 'R031', '34 ST-PENN STA')
# [848] ('N102', 'R127', 'JAY ST-METROTEC')
# [845] ('N063', 'R011', '42 ST-PORT AUTH')
# [843] ('C018', 'R197', '36 ST')
# [841] ('N078', 'R175', '14 ST')
# [841] ('A060', 'R001', 'WHITEHALL S-FRY')
# [838] ('R612', 'R057', 'ATL AV-BARCLAY')
# [836] ('R248', 'R178', '77 ST')
# [835] ('R503', 'R276', 'VERNON-JACKSON')
# [828] ('R423', 'R429', 'PELHAM BAY PARK')
# [828] ('N528', 'R257', 'EAST BROADWAY')
# [824] ('R283', 'R221', '167 ST')
# [806] ('N700', 'R570', '72 ST-2 AVE')
# [803] ('R252', 'R180', '103 ST')
# [801] ('R174', 'R034', '125 ST')
# [798] ('R417', 'R222', 'PARKCHESTER')
# [798] ('N068', 'R012', '34 ST-PENN STA')
# [797] ('R518', 'R261', '40 ST LOWERY ST')
# [796] ('N057', 'R188', '50 ST')
# [792] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [790] ('R516', 'R291', '33 ST-RAWSON ST')
# [790] ('R128', 'R105', '14 ST')
# [786] ('N309A', 'R140', 'QUEENS PLAZA')
# [785] ('N607', 'R025', 'JAMAICA CENTER')
# [784] ('N327', 'R254', 'GRAND-NEWTOWN')
# [784] ('A015', 'R081', '49 ST')
# [780] ('R284', 'R243', '170 ST')
# [773] ('R114', 'R028', 'FULTON ST')
# [771] ('R253', 'R181', '110 ST')
# [764] ('E014', 'R374', 'BAY PKWY')
# [756] ('N301', 'R113', '7 AV')
# [752] ('R525', 'R018', '74 ST-BROADWAY')
# [744] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [739] ('R508', 'R346', 'COURT SQ')
# [739] ('R217A', 'R194', 'BLEECKER ST')
# [731] ('R420', 'R107', 'WESTCHESTER SQ')
# [729] ('N315', 'R238', 'STEINWAY ST')
# [728] ('R110', 'R027', 'WALL ST')
# [723] ('A038', 'R085', '8 ST-NYU')
# [720] ('B031', 'R172', 'BRIGHTON BEACH')
# [714] ('N700A', 'R570', '72 ST-2 AVE')
# [714] ('A013', 'R081', '49 ST')
# [713] ('N117', 'R198', 'NOSTRAND AV')
# [709] ('R530', 'R310', '111 ST')
# [707] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [705] ('R609', 'R056', 'NEVINS ST')
# [690] ('B012', 'R196', 'PROSPECT PARK')
# [686] ('N217', 'R112', 'FORDHAM RD')
# [683] ('R418', 'R106', 'CASTLE HILL AV')
# [674] ('R168A', 'R168', '96 ST')
# [668] ('N529', 'R257', 'EAST BROADWAY')
# [668] ('A014', 'R081', '49 ST')
# [664] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [657] ('H005', 'R330', '3 AV')
# [656] ('N537', 'R258', '4 AV-9 ST')
# [654] ('A069', 'R044', 'CHAMBERS ST')
# [645] ('R519', 'R223', '46 ST BLISS ST')
# [637] ('R600', 'R224', 'CLARK ST')
# [626] ('C025', 'R215', '86 ST')
# [622] ('N512', 'R163', '14 ST')
# [618] ('R177', 'R273', '145 ST')
# [615] ('R310', 'R053', '3 AV-149 ST')
# [610] ('R155', 'R116', '50 ST')
# [601] ('B024', 'R211', 'KINGS HWY')
# [599] ('R514', 'R094', 'ASTORIA BLVD')
# [599] ('N305A', 'R016', 'LEXINGTON AV/53')
# [591] ('R287', 'R244', 'BURNSIDE AV')
# [589] ('N530', 'R301', 'YORK ST')
# [584] ('R245', 'R051', '59 ST')
# [583] ('N513', 'R163', '14 ST')
# [580] ('R254', 'R181', '110 ST')
# [579] ('J009', 'R378', 'MYRTLE AV')
# [578] ('H014', 'R249', 'GRAHAM AV')
# [575] ('R232', 'R176', '33 ST')
# [573] ('R130', 'R321', '18 ST')
# [570] ('N602', 'R259', 'ROOSEVELT ISLND')
# [563] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [561] ('C021', 'R212', '59 ST')
# [560] ('R139', 'R031', '34 ST-PENN STA')
# [560] ('N510', 'R163', '14 ST')
# [559] ('R412', 'R146', 'HUNTS POINT AV')
# [559] ('R165', 'R167', '86 ST')
# [556] ('R331', 'R364', 'GUN HILL RD')
# [556] ('N339A', 'R114', 'PARSONS BLVD')
# [556] ('C019', 'R232', '45 ST')
# [554] ('N043', 'R186', '86 ST')
# [548] ('R511', 'R091', '36 AV')
# [548] ('A058', 'R001', 'WHITEHALL S-FRY')
# [545] ('N010', 'R126', '175 ST')
# [542] ('R504', 'R276', 'VERNON-JACKSON')
# [542] ('R220', 'R160', 'ASTOR PL')
# [539] ('H016', 'R250', 'GRAND ST')
# [537] ('A047', 'R087', 'CITY HALL')
# [534] ('A061', 'R142', 'DELANCEY/ESSEX')
# [530] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [529] ('N300', 'R113', '7 AV')
# [529] ('N120', 'R153', 'UTICA AV')
# [525] ('R132', 'R190', '23 ST')
# [524] ('N090', 'R139', 'CANAL ST')
# [524] ('B029', 'R172', 'BRIGHTON BEACH')
# [522] ('N422', 'R318', 'FULTON ST')
# [521] ('R415', 'R120', 'MORISN AV/SNDVW')
# [521] ('A007', 'R079', '5 AV/59 ST')
# [519] ('R623', 'R061', 'NOSTRAND AV')
# [511] ('N019', 'R101', '145 ST')
# [509] ('N701', 'R571', '86 ST-2 AVE')
# [507] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [505] ('R325', 'R388', 'E 180 ST')
# [505] ('N196', 'R285', 'FAR ROCKAWAY')
# [501] ('C011', 'R231', 'UNION ST')
# [499] ('N525', 'R142', 'DELANCEY/ESSEX')
# [498] ('R336', 'R145', 'WAKEFIELD/241')
# [497] ('N141', 'R356', 'OZONE PK LEFFRT')
# [496] ('N040', 'R251', '96 ST')
# [496] ('N025', 'R102', '125 ST')
# [494] ('R256', 'R182', '116 ST')
# [494] ('N333B', 'R141', 'FOREST HILLS 71')
# [493] ('H017', 'R265', 'MONTROSE AV')
# [490] ('A037', 'R170', '14 ST-UNION SQ')
# [489] ('N343', 'R019', 'JAMAICA 179 ST')
# [480] ('R113', 'R028', 'FULTON ST')
# [478] ('H019', 'R294', 'MORGAN AV')
# [478] ('B013', 'R196', 'PROSPECT PARK')
# [476] ('A016', 'R081', '49 ST')
# [466] ('R186', 'R036', 'DYCKMAN ST')
# [466] ('B015', 'R098', 'CHURCH AV')
# [465] ('R164', 'R167', '86 ST')
# [462] ('N409', 'R268', 'METROPOLITAN AV')
# [462] ('A049', 'R088', 'CORTLANDT ST')
# [461] ('R291', 'R183', 'BEDFORD PK BLVD')
# [450] ('N535', 'R220', 'CARROLL ST')
# [450] ('N502', 'R021', '42 ST-BRYANT PK')
# [449] ('B024A', 'R211', 'KINGS HWY')
# [448] ('R509', 'R121', 'QUEENSBORO PLZ')
# [444] ('R507', 'R134', 'HUNTERS PT AV')
# [442] ('H003', 'R163', '6 AV')
# [439] ('N702', 'R572', '96 ST-2 AVE')
# [437] ('J001', 'R460', 'MARCY AV')
# [435] ('N128', 'R200', 'EUCLID AV')
# [430] ('N213', 'R154', 'TREMONT AV')
# [430] ('A035', 'R170', '14 ST-UNION SQ')
# [428] ('R188', 'R037', '207 ST')
# [427] ('R285', 'R308', 'MT EDEN AV')
# [424] ('A011', 'R080', '57 ST-7 AV')
# [423] ('R251', 'R144', '96 ST')
# [420] ('R159', 'R164', '66 ST-LINCOLN')
# [420] ('G001', 'R151', 'CONEY IS-STILLW')
# [417] ('N342', 'R019', 'JAMAICA 179 ST')
# [416] ('N546', 'R204', 'CHURCH AV')
# [415] ('R259', 'R307', '138/GRAND CONC')
# [413] ('R197', 'R117', 'V.CORTLANDT PK')
# [412] ('N013', 'R035', '168 ST')
# [411] ('N044', 'R187', '81 ST-MUSEUM')
# [406] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [403] ('G009', 'R151', 'CONEY IS-STILLW')
# [402] ('N701A', 'R571', '86 ST-2 AVE')
# [402] ('N314', 'R238', 'STEINWAY ST')
# [399] ('R622', 'R123', 'FRANKLIN AV')
# [399] ('R103', 'R304', 'RECTOR ST')
# [394] ('N207', 'R104', '167 ST')
# [393] ('N129', 'R382', 'GRANT AV')
# [391] ('N039', 'R251', '96 ST')
# [387] ('R532', 'R328', 'METS-WILLETS PT')
# [386] ('R115', 'R029', 'PARK PLACE')
# [383] ('N539A', 'R288', '7 AV')
# [378] ('R606', 'R225', 'HOYT ST')
# [377] ('R635', 'R277', 'PRESIDENT ST')
# [377] ('H039', 'R375', 'NEW LOTS')
# [374] ('R170', 'R191', '103 ST')
# [373] ('R229', 'R143', '28 ST')
# [371] ('B004', 'R171', '7 AV')
# [370] ('N191', 'R335', 'BEACH 67 ST')
# [366] ('R162', 'R166', '79 ST')
# [363] ('R414', 'R162', 'ELDER AV')
# [362] ('H023', 'R236', 'DEKALB AV')
# [358] ('R173', 'R159', '116 ST-COLUMBIA')
# [357] ('R286', 'R309', '176 ST')
# [355] ('R416', 'R245', 'ST LAWRENCE AV')
# [354] ('R178', 'R273', '145 ST')
# [350] ('N526', 'R142', 'DELANCEY/ESSEX')
# [349] ('R517', 'R291', '33 ST-RAWSON ST')
# [347] ('H015', 'R250', 'GRAND ST')
# [346] ('N329', 'R201', 'WOODHAVEN BLVD')
# [345] ('R309', 'R345', 'HARLEM 148 ST')
# [344] ('N006A', 'R280', '190 ST')
# [343] ('R624', 'R124', 'KINGSTON AV')
# [343] ('R290', 'R161', 'KINGSBRIDGE RD')
# [342] ('J002', 'R460', 'MARCY AV')
# [341] ('R323', 'R387', 'WEST FARMS SQ')
# [333] ('R134', 'R272', '28 ST')
# [332] ('R608', 'R056', 'NEVINS ST')
# [332] ('R288', 'R275', '183 ST')
# [331] ('B019', 'R149', 'NEWKIRK PLAZA')
# [327] ('N340A', 'R115', '169 ST')
# [322] ('R307', 'R207', '135 ST')
# [319] ('R625', 'R062', 'CROWN HTS-UTICA')
# [318] ('N604', 'R342', 'JAMAICA VAN WK')
# [316] ('R102', 'R304', 'RECTOR ST')
# [315] ('R160A', 'R164', '66 ST-LINCOLN')
# [314] ('C017', 'R455', '25 ST')
# [313] ('R524', 'R347', '69 ST')
# [313] ('R401', 'R445', '3 AV 138 ST')
# [313] ('R175', 'R169', '137 ST CITY COL')
# [313] ('N340', 'R115', '169 ST')
# [311] ('A054', 'R227', 'RECTOR ST')
# [308] ('R160', 'R164', '66 ST-LINCOLN')
# [303] ('R403', 'R446', 'BROOK AV')
# [299] ('R289', 'R119', 'FORDHAM RD')
# [297] ('N419', 'R287', 'CLASSON AV')
# [296] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [296] ('J028', 'R004', '75 ST-ELDERTS')
# [295] ('J020', 'R433', 'ALABAMA AV')
# [288] ('N330', 'R202', '63 DR-REGO PARK')
# [287] ('A066', 'R118', 'CANAL ST')
# [286] ('R306', 'R207', '135 ST')
# [286] ('H006', 'R330', '3 AV')
# [286] ('D003', 'R391', 'FT HAMILTON PKY')
# [286] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [279] ('N118', 'R199', 'KINGSTON-THROOP')
# [276] ('R304', 'R206', '125 ST')
# [276] ('H037', 'R349', 'SUTTER AV')
# [276] ('C003', 'R089', 'JAY ST-METROTEC')
# [271] ('K026', 'R100', 'METROPOLITAN AV')
# [270] ('B023', 'R211', 'KINGS HWY')
# [269] ('H040', 'R376', 'EAST 105 ST')
# [268] ('H032', 'R295', 'WILSON AV')
# [268] ('D010', 'R394', 'BAY PKWY')
# [262] ('N702A', 'R572', '96 ST-2 AVE')
# [259] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [258] ('R257', 'R182', '116 ST')
# [257] ('R636', 'R209', 'STERLING ST')
# [257] ('R231', 'R176', '33 ST')
# [257] ('N307', 'R359', 'COURT SQ-23 ST')
# [256] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [255] ('N111', 'R284', 'CLINTON-WASH AV')
# [253] ('J024', 'R437', 'CRESCENT ST')
# [251] ('N222', 'R156', 'BEDFORD PK BLVD')
# [249] ('D016', 'R397', '86 ST')
# [248] ('N310', 'R140', 'QUEENS PLAZA')
# [245] ('N549', 'R242', '18 AV')
# [244] ('N075', 'R111', '23 ST')
# [240] ('C001', 'R108', 'BOROUGH HALL')
# [239] ('B018', 'R184', 'CORTELYOU RD')
# [236] ('R171', 'R192', 'CATHEDRAL PKWY')
# [236] ('N333A', 'R141', 'FOREST HILLS 71')
# [235] ('C024', 'R214', '77 ST')
# [235] ('B017', 'R262', 'BEVERLEY ROAD')
# [232] ('N220', 'R155', 'KINGSBRIDGE RD')
# [231] ('R294', 'R052', 'WOODLAWN')
# [231] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [229] ('R602', 'R108', 'BOROUGH HALL')
# [225] ('R172', 'R192', 'CATHEDRAL PKWY')
# [225] ('H030', 'R266', 'HALSEY ST')
# [224] ('R179', 'R193', '157 ST')
# [224] ('D005', 'R398', 'NEW UTRECHT AV')
# [223] ('R316', 'R407', 'INTERVALE AV')
# [222] ('B014', 'R148', 'PARKSIDE AV')
# [221] ('R411', 'R450', 'LONGWOOD AV')
# [221] ('E001', 'R368', '9 AV')
# [219] ('R124', 'R290', 'HOUSTON ST')
# [219] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [215] ('N120A', 'R153', 'UTICA AV')
# [215] ('B021', 'R228', 'AVENUE J')
# [213] ('R226A', 'R131', '23 ST')
# [212] ('N119', 'R199', 'KINGSTON-THROOP')
# [211] ('R618', 'R058', 'BERGEN ST')
# [211] ('E004', 'R234', '50 ST')
# [210] ('R305', 'R206', '125 ST')
# [210] ('N114', 'R297', 'FRANKLIN AV')
# [209] ('R163', 'R166', '79 ST')
# [207] ('N224', 'R157', 'NORWOOD 205 ST')
# [207] ('J023', 'R436', 'NORWOOD AV')
# [207] ('H022', 'R279', 'JEFFERSON ST')
# [207] ('B022', 'R229', 'AVENUE M')
# [206] ('N333', 'R141', 'FOREST HILLS 71')
# [205] ('N319', 'R298', 'NORTHERN BLVD')
# [201] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [201] ('N112A', 'R284', 'CLINTON-WASH AV')
# [198] ('B032', 'R264', 'OCEAN PKWY')
# [197] ('R510', 'R090', '39 AV')
# [197] ('N095A', 'R014', 'FULTON ST')
# [196] ('H038', 'R350', 'LIVONIA AV')
# [192] ('N534', 'R220', 'CARROLL ST')
# [191] ('R328', 'R361', 'PELHAM PKWY')
# [191] ('A083', 'R125', 'BROAD ST')
# [187] ('R617', 'R058', 'BERGEN ST')
# [187] ('R409', 'R449', 'E 149 ST')
# [187] ('R176', 'R169', '137 ST CITY COL')
# [186] ('R405', 'R447', 'CYPRESS AV')
# [186] ('N311', 'R339', '36 ST')
# [185] ('R413', 'R325', 'WHITLOCK AV')
# [184] ('R419', 'R326', 'ZEREGA AV')
# [180] ('R232A', 'R176', '33 ST')
# [180] ('R120', 'R320', 'CANAL ST')
# [179] ('N009', 'R174', '181 ST')
# [178] ('J031', 'R006', 'WOODHAVEN BLVD')
# [178] ('H013', 'R249', 'GRAHAM AV')
# [176] ('R293', 'R133', 'MOSHOLU PKWY')
# [175] ('R408', 'R449', 'E 149 ST')
# [174] ('N557', 'R130', 'KINGS HWY')
# [174] ('J035', 'R008', '111 ST')
# [172] ('R215', 'R322', 'SPRING ST')
# [171] ('R521', 'R327', '52 ST')
# [170] ('J007', 'R377', 'FLUSHING AV')
# [169] ('R219', 'R160', 'ASTOR PL')
# [167] ('N221', 'R155', 'KINGSBRIDGE RD')
# [167] ('C022', 'R212', '59 ST')
# [164] ('R260', 'R205', '149/GRAND CONC')
# [164] ('B020', 'R263', 'AVENUE H')
# [162] ('R422', 'R428', 'BUHRE AV')
# [162] ('K025', 'R404', 'FRESH POND RD')
# [162] ('H028', 'R266', 'HALSEY ST')
# [159] ('N531', 'R129', 'BERGEN ST')
# [159] ('N037', 'R314', '103 ST')
# [159] ('J022', 'R435', 'CLEVELAND ST')
# [159] ('A050', 'R088', 'CORTLANDT ST')
# [158] ('R302', 'R324', '116 ST')
# [157] ('R166', 'R167', '86 ST')
# [156] ('R190', 'R038', '215 ST')
# [156] ('N121B', 'R438', 'RALPH AV')
# [155] ('R404', 'R447', 'CYPRESS AV')
# [154] ('R644', 'R135', 'NEWKIRK AV')
# [154] ('N195', 'R358', 'BEACH 25 ST')
# [152] ('R194', 'R040', '231 ST')
# [151] ('R231A', 'R176', '33 ST')
# [150] ('N126', 'R441', 'VAN SICLEN AVE')
# [150] ('N030', 'R333', '116 ST')
# [149] ('N215', 'R237', '182-183 STS')
# [149] ('N192', 'R336', 'BEACH 60 ST')
# [148] ('R329', 'R362', 'ALLERTON AV')
# [148] ('J021', 'R434', 'VAN SICLEN AV')
# [147] ('R303', 'R324', '116 ST')
# [147] ('N110', 'R283', 'LAFAYETTE AV')
# [143] ('N225', 'R157', 'NORWOOD 205 ST')
# [142] ('N317', 'R267', '46 ST')
# [142] ('N181', 'R357', 'AQUEDUCT N.COND')
# [142] ('E011', 'R371', '79 ST')
# [141] ('J013', 'R380', 'GATES AV')
# [140] ('N561', 'R271', 'AVENUE X')
# [138] ('R320', 'R409', 'FREEMAN ST')
# [138] ('N122', 'R439', 'ROCKAWAY AV')
# [138] ('N002A', 'R173', 'INWOOD-207 ST')
# [136] ('N331', 'R219', '67 AV')
# [134] ('N337', 'R255', 'BRIARWOOD')
# [134] ('N113', 'R297', 'FRANKLIN AV')
# [132] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [131] ('R639', 'R109', 'CHURCH AV')
# [131] ('B025', 'R150', 'AVENUE U')
# [130] ('R180', 'R193', '157 ST')
# [130] ('E009', 'R370', '71 ST')
# [130] ('D015', 'R396', 'AVENUE U')
# [129] ('N202', 'R315', '155 ST')
# [129] ('J030', 'R005', '85 ST-FOREST PK')
# [127] ('N316A', 'R267', '46 ST')
# [126] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [126] ('R402', 'R446', 'BROOK AV')
# [126] ('E012', 'R372', '18 AV')
# [126] ('E003', 'R369', 'FT HAMILTON PKY')
# [126] ('D012', 'R395', 'KINGS HWY')
# [125] ('H033', 'R313', 'BUSHWICK AV')
# [122] ('N556', 'R424', 'AVENUE P')
# [122] ('N045', 'R187', '81 ST-MUSEUM')
# [122] ('B010', 'R412', 'BOTANIC GARDEN')
# [121] ('R728', 'R226', 'GUN HILL RD')
# [121] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [119] ('N127', 'R442', 'SHEPHERD AV')
# [117] ('R334', 'R367', '233 ST')
# [117] ('J016', 'R381', 'HALSEY ST')
# [116] ('E013', 'R373', '20 AV')
# [112] ('R641', 'R210', 'BEVERLY RD')
# [112] ('R327', 'R361', 'PELHAM PKWY')
# [111] ('N338B', 'R128', 'SUTPHIN BLVD')
# [111] ('N012', 'R035', '168 ST')
# [110] ('R407', 'R448', "E 143/ST MARY'S")
# [110] ('N532', 'R129', 'BERGEN ST')
# [110] ('N322', 'R340', '65 ST')
# [109] ('R227A', 'R131', '23 ST')
# [109] ('B009', 'R411', 'PARK PLACE')
# [107] ('R333', 'R366', '225 ST')
# [107] ('N007A', 'R174', '181 ST')
# [105] ('R318', 'R408', 'SIMPSON ST')
# [105] ('J012', 'R379', 'KOSCIUSZKO ST')
# [104] ('N035', 'R334', 'CATHEDRAL PKWY')
# [103] ('N125', 'R440', 'LIBERTY AV')
# [103] ('N086', 'R282', 'SPRING ST')
# [102] ('R520', 'R223', '46 ST BLISS ST')
# [101] ('N209', 'R443', '170 ST')
# [100] ('J005', 'R353', 'LORIMER ST')
# [99] ('R118', 'R343', 'FRANKLIN ST')
# [99] ('N325A', 'R218', 'ELMHURST AV')
# [98] ('R727', 'R430', 'PELHAM PKWY')
# [98] ('R335', 'R444', 'NEREID AV')
# [98] ('N194', 'R338', 'BEACH 36 ST')
# [98] ('B034', 'R264', 'OCEAN PKWY')
# [96] ('N024', 'R332', '135 ST')
# [95] ('R421', 'R427', 'MIDDLETOWN RD')
# [95] ('N208', 'R443', '170 ST')
# [93] ('N212', 'R253', '174-175 STS')
# [93] ('A071', 'R044', 'CHAMBERS ST')
# [91] ('R332', 'R365', '219 ST')
# [90] ('N134', 'R385', 'ROCKAWAY BLVD')
# [88] ('N034', 'R334', 'CATHEDRAL PKWY')
# [88] ('K019', 'R413', 'KNICKERBOCKER')
# [86] ('N001', 'R173', 'INWOOD-207 ST')
# [85] ('N011', 'R126', '175 ST')
# [84] ('H035', 'R348', 'ATLANTIC AV')
# [83] ('R192', 'R039', 'MARBLE HILL-225')
# [82] ('R326', 'R389', 'BRONX PARK EAST')
# [82] ('N559', 'R425', 'AVENUE U')
# [82] ('K024', 'R403', 'FOREST AVE')
# [81] ('N187', 'R419', 'ROCKAWAY PARK B')
# [79] ('N210', 'R253', '174-175 STS')
# [79] ('H012', 'R268', 'LORIMER ST')
# [77] ('J017', 'R432', 'CHAUNCEY ST')
# [76] ('R637', 'R451', 'WINTHROP ST')
# [76] ('E005', 'R247', '55 ST')
# [75] ('N095', 'R014', 'FULTON ST')
# [71] ('R314', 'R406', 'PROSPECT AV')
# [71] ('N193', 'R337', 'BEACH 44 ST')
# [70] ('N545', 'R204', 'CHURCH AV')
# [70] ('N332', 'R219', '67 AV')
# [70] ('N184', 'R416', 'BEACH 90 ST')
# [69] ('J025', 'R003', 'CYPRESS HILLS')
# [68] ('N087', 'R282', 'SPRING ST')
# [67] ('R726', 'R329', 'MORRIS PARK')
# [67] ('R330', 'R363', 'BURKE AV')
# [67] ('R321', 'R386', '174 ST')
# [66] ('N511', 'R163', '14 ST')
# [66] ('K017', 'R401', 'CENTRAL AV')
# [64] ('R410', 'R450', 'LONGWOOD AV')
# [64] ('N555', 'R423', 'AVENUE N')
# [64] ('N135', 'R385', 'ROCKAWAY BLVD')
# [63] ('N551', 'R421', 'AVENUE I')
# [63] ('A055', 'R227', 'RECTOR ST')
# [62] ('N553', 'R422', 'BAY PKWY')
# [61] ('N548', 'R420', 'DITMAS AV')
# [60] ('N543', 'R289', 'FT HAMILTON PKY')
# [57] ('R604', 'R108', 'BOROUGH HALL')
# [56] ('N017', 'R331', '155 ST')
# [53] ('R122', 'R290', 'HOUSTON ST')
# [53] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [49] ('N137', 'R354', '104 ST')
# [49] ('B026', 'R230', 'NECK RD')
# [47] ('R322', 'R386', '174 ST')
# [47] ('K022', 'R402', 'SENECA AVE')
# [47] ('C004', 'R089', 'JAY ST-METROTEC')
# [46] ('N206', 'R104', '167 ST')
# [45] ('N218', 'R112', 'FORDHAM RD')
# [42] ('N562', 'R426', 'NEPTUNE AV')
# [41] ('N131', 'R383', '80 ST')
# [40] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [40] ('J037', 'R009', '121 ST')
# [38] ('R312', 'R405', 'JACKSON AV')
# [38] ('N339', 'R114', 'PARSONS BLVD')
# [37] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [37] ('J032', 'R006', 'WOODHAVEN BLVD')
# [36] ('N133', 'R384', '88 ST')
# [34] ('N533', 'R129', 'BERGEN ST')
# [33] ('R643', 'R135', 'NEWKIRK AV')
# [33] ('R227', 'R131', '23 ST')
# [33] ('N420B', 'R317', 'CLINTON-WASH AV')
# [33] ('J003', 'R352', 'HEWES ST')
# [32] ('N330C', 'R202', '63 DR-REGO PARK')
# [32] ('N182', 'R414', 'HOWARD BCH JFK')
# [32] ('N130', 'R383', '80 ST')
# [31] ('R308', 'R344', '145 ST')
# [30] ('R506', 'R276', 'VERNON-JACKSON')
# [30] ('R406', 'R448', "E 143/ST MARY'S")
# [29] ('N023', 'R332', '135 ST')
# [28] ('N185', 'R417', 'BEACH 98 ST')
# [27] ('N558', 'R130', 'KINGS HWY')
# [27] ('D009', 'R393', '20 AV')
# [26] ('R319', 'R409', 'FREEMAN ST')
# [26] ('A082', 'R028', 'FULTON ST')
# [25] ('N544', 'R289', 'FT HAMILTON PKY')
# [25] ('N338', 'R128', 'SUTPHIN BLVD')
# [24] ('N139', 'R355', '111 ST')
# [24] ('C026', 'R215', '86 ST')
# [23] ('N016A', 'R296', '163 ST-AMSTERDM')
# [22] ('A077', 'R028', 'FULTON ST')
# [21] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [20] ('R729', 'R292', 'BAYCHESTER AV')
# [20] ('N312', 'R339', '36 ST')
# [17] ('N022', 'R332', '135 ST')
# [16] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [15] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [14] ('R532H', 'R328', 'METS-WILLETS PT')
# [14] ('D008', 'R392', '18 AV')
# [13] ('N223', 'R156', 'BEDFORD PK BLVD')
# [13] ('J034', 'R007', '104 ST')
# [12] ('N183', 'R415', 'BROAD CHANNEL')
# [12] ('E016', 'R400', 'BAY 50 ST')
# [11] ('N547', 'R420', 'DITMAS AV')
# [10] ('R196', 'R306', '238 ST')
# [10] ('N003', 'R185', 'DYCKMAN ST')
# [9] ('R628', 'R064', 'SARATOGA AV')
# [8] ('N186', 'R418', 'BEACH 105 ST')
# [7] ('R629', 'R065', 'ROCKAWAY AV')
# [6] ('R201', 'R041', 'BOWLING GREEN')
# [5] ('R200A', 'R041', 'BOWLING GREEN')
# [5] ('N508', 'R453', '23 ST')
# [5] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [4] ('R125', 'R189', 'CHRISTOPHER ST')
# [4] ('R119', 'R320', 'CANAL ST')
# [4] ('N405', 'R239', 'GREENPOINT AV')
# [4] ('N318', 'R298', 'NORTHERN BLVD')
# [4] ('N138', 'R355', '111 ST')
# [4] ('N123B', 'R439', 'ROCKAWAY AV')
# [4] ('A084', 'R125', 'BROAD ST')
# [3] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [3] ('R317', 'R408', 'SIMPSON ST')
# [3] ('R208', 'R014', 'FULTON ST')
# [3] ('R121', 'R290', 'HOUSTON ST')
# [3] ('R117', 'R343', 'FRANKLIN ST')
# [3] ('N414A', 'R316', 'FLUSHING AV')
# [2] ('R633', 'R068', 'VAN SICLEN AV')
# [2] ('R204', 'R043', 'WALL ST')
# [2] ('R202', 'R042', 'BOWLING GREEN')
# [2] ('R133', 'R272', '28 ST')
# [2] ('R129', 'R321', '18 ST')
# [2] ('R123', 'R290', 'HOUSTON ST')
# [2] ('N414', 'R316', 'FLUSHING AV')
# [2] ('N408A', 'R256', 'NASSAU AV')
# [1] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [1] ('R632', 'R067', 'PENNSYLVANIA AV')
# [1] ('N412', 'R299', 'BROADWAY')
# [1] ('E015', 'R399', '25 AV')
# [1] ('C010', 'R231', 'UNION ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('R634', 'R069', 'NEW LOTS AV')
# [0] ('R315', 'R406', 'PROSPECT AV')
# [0] ('R242A', 'R049', '51 ST')
# [0] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [0] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [0] ('R230', 'R143', '28 ST')
# [0] ('R206', 'R014', 'FULTON ST')
# [0] ('R205A', 'R014', 'FULTON ST')
# [0] ('R204A', 'R043', 'WALL ST')
# [0] ('R203A', 'R043', 'WALL ST')
# [0] ('R203', 'R043', 'WALL ST')
# [0] ('R137', 'R031', '34 ST-PENN STA')
# [0] ('R131', 'R190', '23 ST')
# [0] ('R112A', 'R027', 'WALL ST')
# [0] ('R112', 'R027', 'WALL ST')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# [0] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [0] ('N401', 'R360', '21 ST')
# [0] ('N316', 'R267', '46 ST')
# [0] ('N304', 'R015', '5 AV/53 ST')
# [0] ('N101', 'R252', 'HIGH ST')
# [0] ('N091', 'R029', 'CHAMBERS ST')
# [0] ('C016', 'R278', '25 ST')
# 0 ('A085', 'R125', 'BROAD ST')
# [-1] ('N100', 'R252', 'HIGH ST')
# [-26] ('N334B', 'R341', '75 AV')
# [-32] ('N029', 'R333', '116 ST')
# [-384] ('R241A', 'R048', 'GRD CNTRL-42 ST')

# %%
sunday = MTA[MTA.DATE == '06/11/2017']
sunday = sunday.reset_index(drop=True)

sunday_dict = {}
for i in range(len(sunday.index)):
    mytuple = (sunday["C/A"][i],sunday.UNIT[i],sunday.SCP[i],sunday.STATION[i])
    if mytuple not in sunday_dict.keys():
        sunday_dict[mytuple] = [(sunday.TIME[i],sunday.EXITS[i])]
    else:
        sunday_dict[mytuple].append((sunday.TIME[i],sunday.EXITS[i]))

sunday_dict_diff = {}
for key,value in sunday_dict.items():
    for i in range(1,len(value)):
        if key not in sunday_dict_diff:
            sunday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            sunday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))

total_turnstile = {}
for key,value in sunday_dict_diff.items():
    for i in range(0,len(value)):
        total_turnstile[key] = total_turnstile.get(key,0)+value[i][1]

total_riders = {}
for key,value in total_turnstile.items():
    new_key = (key[0],key[1],key[3])
    total_riders[new_key] = total_riders.get(new_key,0)+value

        
tuple_list = []
for key,value in total_riders.items():
    mytuple = (value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)

#come back here and delete the super negative/buggy data

morning = sunday[(sunday.TIME=='05:00:00')|(sunday.TIME=='06:00:00')|(sunday.TIME=='07:00:00')|(sunday.TIME=='08:00:00')|(sunday.TIME=='09:00:00')|(sunday.TIME=='10:00:00')|(sunday.TIME=='11:00:00')|(sunday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
        
morning_dict = {}
for i in range(len(morning.index)):
    mytuple = (morning['C/A'][i],morning.UNIT[i],morning.SCP[i],morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]

bad_key = []
for key,value in morning_dict.items():
    if len(morning_dict[key]) != 2:
        bad_key.append(key)

for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]

morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0],turnstile[1],turnstile[3])
    count = 0
    for time,exit in times.items():
        count=exit-count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=[count]

total_morning_diff = {}
for key,value in morning_differences.items():
    for val in value.values():
        mytuple = (key[0],key[1],key[2])
        total_morning_diff[mytuple]=total_morning_diff.get(mytuple,0)+val

sunday_morning_passengers = []
for key,value in total_morning_diff.items():
    mytuple=(value,key)
    sunday_morning_passengers.append(mytuple)
sunday_morning_passengers.sort(reverse=True)
for key,value in sunday_morning_passengers:
    print(key,value)
# Out:
# [2038815470] ('N506', 'R022', '34 ST-HERALD SQ')
# [5396] ('R238', 'R046', 'GRD CNTRL-42 ST')
# [3985] ('R533', 'R055', 'FLUSHING-MAIN')
# [3486] ('H009', 'R235', 'BEDFORD AV')
# [3480] ('N049', 'R084', '59 ST COLUMBUS')
# [3436] ('R249', 'R179', '86 ST')
# [3135] ('A025', 'R023', '34 ST-HERALD SQ')
# [3085] ('R151', 'R033', 'TIMES SQ-42 ST')
# [2973] ('N520', 'R240', 'GRAND ST')
# [2545] ('N067', 'R012', '34 ST-PENN STA')
# [2470] ('N063A', 'R011', '42 ST-PORT AUTH')
# [2383] ('N026', 'R102', '125 ST')
# [2313] ('R116', 'R030', 'CHAMBERS ST')
# [2276] ('N324', 'R018', 'JKSN HT-ROOSVLT')
# [2175] ('N051', 'R084', '59 ST COLUMBUS')
# [2079] ('R135', 'R031', '34 ST-PENN STA')
# [1903] ('R244', 'R050', '59 ST')
# [1900] ('N605', 'R024', 'SUTPHIN-ARCHER')
# [1863] ('N500', 'R020', '47-50 STS ROCK')
# [1733] ('N507', 'R023', '34 ST-HERALD SQ')
# [1710] ('R111', 'R027', 'WALL ST')
# [1690] ('R202', 'R042', 'BOWLING GREEN')
# [1685] ('R138', 'R293', '34 ST-PENN STA')
# [1632] ('A021', 'R032', 'TIMES SQ-42 ST')
# [1626] ('R626', 'R062', 'CROWN HTS-UTICA')
# [1590] ('N505', 'R022', '34 ST-HERALD SQ')
# [1583] ('A042', 'R086', 'PRINCE ST')
# [1579] ('N606', 'R025', 'JAMAICA CENTER')
# [1573] ('R526', 'R096', '82 ST-JACKSON H')
# [1572] ('R145', 'R032', 'TIMES SQ-42 ST')
# [1533] ('R610', 'R057', 'ATL AV-BARCLAY')
# [1497] ('C009', 'R057', 'ATL AV-BARCLAY')
# [1460] ('R528', 'R097', 'JUNCTION BLVD')
# [1460] ('R258', 'R132', '125 ST')
# [1426] ('N503', 'R021', '42 ST-BRYANT PK')
# [1373] ('R154', 'R116', '50 ST')
# [1370] ('R250', 'R179', '86 ST')
# [1361] ('R534', 'R055', 'FLUSHING-MAIN')
# [1343] ('R216', 'R322', 'SPRING ST')
# [1302] ('N071', 'R013', '34 ST-PENN STA')
# [1287] ('R529', 'R208', '103 ST-CORONA')
# [1283] ('R550', 'R072', '34 ST-HUDSON YD')
# [1203] ('N062', 'R011', '42 ST-PORT AUTH')
# [1193] ('R501', 'R054', '5 AVE')
# [1188] ('R158', 'R084', '59 ST COLUMBUS')
# [1174] ('R244A', 'R050', '59 ST')
# [1174] ('R169', 'R168', '96 ST')
# [1171] ('R240', 'R047', 'GRD CNTRL-42 ST')
# [1171] ('R143', 'R032', 'TIMES SQ-42 ST')
# [1169] ('R147', 'R033', 'TIMES SQ-42 ST')
# [1155] ('N504', 'R021', '42 ST-BRYANT PK')
# [1116] ('N103', 'R127', 'JAY ST-METROTEC')
# [1110] ('R210', 'R044', 'BROOKLYN BRIDGE')
# [1108] ('R221', 'R170', '14 ST-UNION SQ')
# [1088] ('N306', 'R017', 'LEXINGTON AV/53')
# [1087] ('N089', 'R139', 'CANAL ST')
# [1087] ('H008', 'R248', '1 AV')
# [1083] ('N523', 'R300', '2 AV')
# [1079] ('A022', 'R022', '34 ST-HERALD SQ')
# [1067] ('N094', 'R029', 'WORLD TRADE CTR')
# [1066] ('N020', 'R101', '145 ST')
# [1051] ('B016', 'R098', 'CHURCH AV')
# [1047] ('N108', 'R217', 'HOYT-SCHER')
# [1037] ('R601A', 'R108', 'BOROUGH HALL')
# [1037] ('N073', 'R013', '34 ST-PENN STA')
# [1033] ('A046', 'R463', 'CANAL ST')
# [1021] ('R183', 'R260', '181 ST')
# [987] ('B031', 'R172', 'BRIGHTON BEACH')
# [985] ('N501A', 'R020', '47-50 STS ROCK')
# [970] ('N077', 'R111', '23 ST')
# [968] ('N601', 'R319', 'LEXINGTON AV/63')
# [968] ('H007', 'R248', '1 AV')
# [957] ('A010', 'R080', '57 ST-7 AV')
# [954] ('N060', 'R010', '42 ST-PORT AUTH')
# [951] ('N417', 'R269', 'BEDFORD-NOSTRAN')
# [943] ('N092', 'R029', 'CHAMBERS ST')
# [941] ('R245A', 'R051', '59 ST')
# [937] ('N062A', 'R010', '42 ST-PORT AUTH')
# [937] ('A029', 'R082', '28 ST')
# [934] ('N509', 'R203', '23 ST')
# [929] ('R243', 'R049', '51 ST')
# [924] ('N600', 'R302', '57 ST')
# [910] ('N046', 'R281', '72 ST')
# [910] ('A031', 'R083', '23 ST')
# [906] ('R127', 'R105', '14 ST')
# [890] ('A002', 'R051', '59 ST')
# [888] ('N083', 'R138', 'W 4 ST-WASH SQ')
# [872] ('R161B', 'R452', '72 ST')
# [860] ('N601A', 'R319', 'LEXINGTON AV/63')
# [858] ('N072', 'R012', '34 ST-PENN STA')
# [853] ('A034', 'R170', '14 ST-UNION SQ')
# [852] ('R523', 'R147', '61 ST WOODSIDE')
# [849] ('G011', 'R312', 'W 8 ST-AQUARIUM')
# [835] ('N124', 'R103', 'BROADWAY JCT')
# [833] ('N303', 'R015', '5 AV/53 ST')
# [826] ('D002', 'R390', '8 AV')
# [823] ('A015', 'R081', '49 ST')
# [820] ('A039', 'R085', '8 ST-NYU')
# [819] ('R242', 'R049', '51 ST')
# [810] ('R605', 'R456', 'HOYT ST')
# [807] ('JFK03', 'R536', 'JFK JAMAICA CT1')
# [805] ('N070', 'R012', '34 ST-PENN STA')
# [795] ('R101', 'R001', 'SOUTH FERRY')
# [790] ('A030', 'R083', '23 ST')
# [781] ('R261', 'R205', '149/GRAND CONC')
# [770] ('R519', 'R223', '46 ST BLISS ST')
# [762] ('N098', 'R028', 'FULTON ST')
# [759] ('R527', 'R122', '90 ST-ELMHURST')
# [757] ('R148', 'R033', 'TIMES SQ-42 ST')
# [744] ('R301', 'R323', 'CENTRAL PK N110')
# [743] ('R247', 'R178', '77 ST')
# [742] ('N323', 'R018', 'JKSN HT-ROOSVLT')
# [741] ('C008', 'R099', 'DEKALB AV')
# [737] ('N521', 'R300', '2 AV')
# [737] ('A064', 'R311', 'BOWERY')
# [731] ('R155', 'R116', '50 ST')
# [721] ('R141', 'R031', '34 ST-PENN STA')
# [719] ('A033', 'R170', '14 ST-UNION SQ')
# [704] ('R126', 'R189', 'CHRISTOPHER ST')
# [701] ('R246', 'R177', '68ST-HUNTER CO')
# [700] ('A041', 'R086', 'PRINCE ST')
# [700] ('A006', 'R079', '5 AV/59 ST')
# [694] ('H001', 'R175', '8 AV')
# [686] ('B012', 'R196', 'PROSPECT PARK')
# [682] ('N116', 'R198', 'NOSTRAND AV')
# [675] ('R530', 'R310', '111 ST')
# [671] ('R182', 'R035', '168 ST')
# [667] ('R515', 'R095', 'ASTORIA DITMARS')
# [662] ('R174', 'R034', '125 ST')
# [656] ('N076', 'R111', '23 ST')
# [649] ('A013', 'R081', '49 ST')
# [644] ('N603', 'R303', '21 ST-QNSBRIDGE')
# [643] ('N056', 'R188', '50 ST')
# [641] ('N063', 'R011', '42 ST-PORT AUTH')
# [639] ('N400A', 'R359', 'COURT SQ')
# [631] ('R142', 'R293', '34 ST-PENN STA')
# [630] ('R518', 'R261', '40 ST LOWERY ST')
# [630] ('N305', 'R017', 'LEXINGTON AV/53')
# [628] ('N528', 'R257', 'EAST BROADWAY')
# [628] ('B013', 'R196', 'PROSPECT PARK')
# [624] ('C012', 'R258', '4AV-9 ST')
# [623] ('R600', 'R224', 'CLARK ST')
# [622] ('R423', 'R429', 'PELHAM BAY PARK')
# [615] ('R512', 'R092', 'BROADWAY')
# [606] ('R161A', 'R452', '72 ST')
# [599] ('R503', 'R276', 'VERNON-JACKSON')
# [594] ('H026', 'R137', 'MYRTLE-WYCKOFF')
# [592] ('N301', 'R113', '7 AV')
# [582] ('R228', 'R143', '28 ST')
# [581] ('B024', 'R211', 'KINGS HWY')
# [580] ('N607', 'R025', 'JAMAICA CENTER')
# [579] ('R283', 'R221', '167 ST')
# [576] ('R128', 'R105', '14 ST')
# [573] ('A027', 'R082', '28 ST')
# [571] ('R513', 'R093', '30 AV')
# [566] ('R508', 'R346', 'COURT SQ')
# [566] ('N043', 'R186', '86 ST')
# [565] ('R185', 'R274', '191 ST')
# [563] ('R168A', 'R168', '96 ST')
# [561] ('N057', 'R188', '50 ST')
# [552] ('R245', 'R051', '59 ST')
# [551] ('R417', 'R222', 'PARKCHESTER')
# [549] ('R418', 'R106', 'CASTLE HILL AV')
# [547] ('N217', 'R112', 'FORDHAM RD')
# [542] ('B029', 'R172', 'BRIGHTON BEACH')
# [541] ('C025', 'R215', '86 ST')
# [540] ('R217A', 'R194', 'BLEECKER ST')
# [539] ('N191', 'R335', 'BEACH 67 ST')
# [536] ('C018', 'R197', '36 ST')
# [535] ('A060', 'R001', 'WHITEHALL S-FRY')
# [523] ('N513', 'R163', '14 ST')
# [520] ('N090', 'R139', 'CANAL ST')
# [519] ('N512', 'R163', '14 ST')
# [517] ('N327', 'R254', 'GRAND-NEWTOWN')
# [508] ('R284', 'R243', '170 ST')
# [506] ('A081', 'R028', 'FULTON ST')
# [503] ('N602', 'R259', 'ROOSEVELT ISLND')
# [499] ('E014', 'R374', 'BAY PKWY')
# [497] ('N117', 'R198', 'NOSTRAND AV')
# [491] ('H005', 'R330', '3 AV')
# [489] ('R525', 'R018', '74 ST-BROADWAY')
# [488] ('A038', 'R085', '8 ST-NYU')
# [486] ('R252', 'R180', '103 ST')
# [483] ('A014', 'R081', '49 ST')
# [479] ('R236', 'R045', 'GRD CNTRL-42 ST')
# [478] ('R110', 'R027', 'WALL ST')
# [478] ('N315', 'R238', 'STEINWAY ST')
# [477] ('N510', 'R163', '14 ST')
# [476] ('C021', 'R212', '59 ST')
# [475] ('N700', 'R570', '72 ST-2 AVE')
# [473] ('N091', 'R029', 'CHAMBERS ST')
# [472] ('H017', 'R265', 'MONTROSE AV')
# [470] ('N080', 'R138', 'W 4 ST-WASH SQ')
# [468] ('R621', 'R060', 'EASTN PKWY-MUSM')
# [468] ('R253', 'R181', '110 ST')
# [466] ('N536', 'R270', 'SMITH-9 ST')
# [465] ('N010', 'R126', '175 ST')
# [461] ('N102', 'R127', 'JAY ST-METROTEC')
# [458] ('N078', 'R175', '14 ST')
# [457] ('N141', 'R356', 'OZONE PK LEFFRT')
# [456] ('R248', 'R178', '77 ST')
# [455] ('R516', 'R291', '33 ST-RAWSON ST')
# [453] ('N196', 'R285', 'FAR ROCKAWAY')
# [450] ('N069', 'R013', '34 ST-PENN STA')
# [449] ('N546', 'R204', 'CHURCH AV')
# [448] ('H027', 'R137', 'MYRTLE-WYCKOFF')
# [434] ('R420', 'R107', 'WESTCHESTER SQ')
# [432] ('N339A', 'R114', 'PARSONS BLVD')
# [423] ('R331', 'R364', 'GUN HILL RD')
# [423] ('N305A', 'R016', 'LEXINGTON AV/53')
# [419] ('B024A', 'R211', 'KINGS HWY')
# [415] ('A043', 'R462', 'CANAL ST')
# [414] ('N025', 'R102', '125 ST')
# [412] ('N019', 'R101', '145 ST')
# [410] ('R415', 'R120', 'MORISN AV/SNDVW')
# [408] ('N101', 'R252', 'HIGH ST')
# [406] ('H019', 'R294', 'MORGAN AV')
# [402] ('R412', 'R146', 'HUNTS POINT AV')
# [402] ('A061', 'R142', 'DELANCEY/ESSEX')
# [402] ('A016', 'R081', '49 ST')
# [400] ('N700A', 'R570', '72 ST-2 AVE')
# [399] ('R139', 'R031', '34 ST-PENN STA')
# [398] ('N040', 'R251', '96 ST')
# [396] ('R514', 'R094', 'ASTORIA BLVD')
# [396] ('N529', 'R257', 'EAST BROADWAY')
# [394] ('R311', 'R053', '3 AV-149 ST')
# [394] ('N519A', 'R461', "B'WAY-LAFAYETTE")
# [394] ('N120', 'R153', 'UTICA AV')
# [392] ('R254', 'R181', '110 ST')
# [390] ('R504', 'R276', 'VERNON-JACKSON')
# [388] ('N537', 'R258', '4 AV-9 ST')
# [388] ('N502', 'R021', '42 ST-BRYANT PK')
# [386] ('R609', 'R056', 'NEVINS ST')
# [385] ('N343', 'R019', 'JAMAICA 179 ST')
# [374] ('R291', 'R183', 'BEDFORD PK BLVD')
# [370] ('C019', 'R232', '45 ST')
# [367] ('R177', 'R273', '145 ST')
# [366] ('R602', 'R108', 'BOROUGH HALL')
# [366] ('C011', 'R231', 'UNION ST')
# [366] ('B027', 'R136', 'SHEEPSHEAD BAY')
# [361] ('E004', 'R234', '50 ST')
# [359] ('R186', 'R036', 'DYCKMAN ST')
# [359] ('N333B', 'R141', 'FOREST HILLS 71')
# [358] ('R114', 'R028', 'FULTON ST')
# [356] ('R226', 'R131', '23 ST')
# [356] ('R165', 'R167', '86 ST')
# [356] ('N422', 'R318', 'FULTON ST')
# [354] ('N300', 'R113', '7 AV')
# [351] ('R220', 'R160', 'ASTOR PL')
# [351] ('N519', 'R461', "B'WAY-LAFAYETTE")
# [350] ('R524', 'R347', '69 ST')
# [348] ('R287', 'R244', 'BURNSIDE AV')
# [347] ('R188', 'R037', '207 ST')
# [346] ('R336', 'R145', 'WAKEFIELD/241')
# [343] ('N128', 'R200', 'EUCLID AV')
# [340] ('R310', 'R053', '3 AV-149 ST')
# [339] ('R606', 'R225', 'HOYT ST')
# [339] ('A047', 'R087', 'CITY HALL')
# [338] ('N549', 'R242', '18 AV')
# [337] ('N129', 'R382', 'GRANT AV')
# [332] ('H003', 'R163', '6 AV')
# [332] ('B019', 'R149', 'NEWKIRK PLAZA')
# [327] ('G009', 'R151', 'CONEY IS-STILLW')
# [326] ('A035', 'R170', '14 ST-UNION SQ')
# [325] ('R509', 'R121', 'QUEENSBORO PLZ')
# [325] ('R130', 'R321', '18 ST')
# [325] ('N701', 'R571', '86 ST-2 AVE')
# [324] ('R164', 'R167', '86 ST')
# [324] ('N309A', 'R140', 'QUEENS PLAZA')
# [324] ('B015', 'R098', 'CHURCH AV')
# [322] ('N207', 'R104', '167 ST')
# [319] ('A007', 'R079', '5 AV/59 ST')
# [318] ('R624', 'R124', 'KINGSTON AV')
# [318] ('N213', 'R154', 'TREMONT AV')
# [317] ('J001', 'R460', 'MARCY AV')
# [315] ('R608', 'R056', 'NEVINS ST')
# [310] ('R625', 'R062', 'CROWN HTS-UTICA')
# [309] ('N409', 'R268', 'METROPOLITAN AV')
# [309] ('H014', 'R249', 'GRAHAM AV')
# [308] ('R511', 'R091', '36 AV')
# [307] ('J009', 'R378', 'MYRTLE AV')
# [306] ('B021', 'R228', 'AVENUE J')
# [304] ('R113', 'R028', 'FULTON ST')
# [303] ('N525', 'R142', 'DELANCEY/ESSEX')
# [301] ('R623', 'R061', 'NOSTRAND AV')
# [301] ('A037', 'R170', '14 ST-UNION SQ')
# [300] ('R619', 'R059', 'GRAND ARMY PLAZ')
# [296] ('A011', 'R080', '57 ST-7 AV')
# [294] ('R232', 'R176', '33 ST')
# [294] ('G001', 'R151', 'CONEY IS-STILLW')
# [293] ('R645', 'R110', 'FLATBUSH AV-B.C')
# [291] ('R170', 'R191', '103 ST')
# [291] ('H016', 'R250', 'GRAND ST')
# [290] ('R103', 'R304', 'RECTOR ST')
# [290] ('N314', 'R238', 'STEINWAY ST')
# [286] ('H023', 'R236', 'DEKALB AV')
# [286] ('B032', 'R264', 'OCEAN PKWY')
# [284] ('R507', 'R134', 'HUNTERS PT AV')
# [284] ('A049', 'R088', 'CORTLANDT ST')
# [282] ('R197', 'R117', 'V.CORTLANDT PK')
# [277] ('R162', 'R166', '79 ST')
# [277] ('B018', 'R184', 'CORTELYOU RD')
# [276] ('R622', 'R123', 'FRANKLIN AV')
# [275] ('R288', 'R275', '183 ST')
# [275] ('R132', 'R190', '23 ST')
# [273] ('R178', 'R273', '145 ST')
# [271] ('N419', 'R287', 'CLASSON AV')
# [270] ('R416', 'R245', 'ST LAWRENCE AV')
# [269] ('R307', 'R207', '135 ST')
# [269] ('N702', 'R572', '96 ST-2 AVE')
# [266] ('R238A', 'R046', 'GRD CNTRL-42 ST')
# [265] ('R532', 'R328', 'METS-WILLETS PT')
# [265] ('H032', 'R295', 'WILSON AV')
# [264] ('A058', 'R001', 'WHITEHALL S-FRY')
# [263] ('R325', 'R388', 'E 180 ST')
# [261] ('N535', 'R220', 'CARROLL ST')
# [260] ('N044', 'R187', '81 ST-MUSEUM')
# [251] ('R175', 'R169', '137 ST CITY COL')
# [251] ('H039', 'R375', 'NEW LOTS')
# [251] ('C017', 'R455', '25 ST')
# [249] ('R635', 'R277', 'PRESIDENT ST')
# [249] ('N701A', 'R571', '86 ST-2 AVE')
# [248] ('R256', 'R182', '116 ST')
# [248] ('J002', 'R460', 'MARCY AV')
# [247] ('A066', 'R118', 'CANAL ST')
# [245] ('R401', 'R445', '3 AV 138 ST')
# [245] ('K026', 'R100', 'METROPOLITAN AV')
# [244] ('N006A', 'R280', '190 ST')
# [244] ('B022', 'R229', 'AVENUE M')
# [243] ('H013', 'R249', 'GRAHAM AV')
# [241] ('H015', 'R250', 'GRAND ST')
# [240] ('R285', 'R308', 'MT EDEN AV')
# [239] ('R251', 'R144', '96 ST')
# [239] ('R102', 'R304', 'RECTOR ST')
# [238] ('R290', 'R161', 'KINGSBRIDGE RD')
# [236] ('N039', 'R251', '96 ST')
# [234] ('N068', 'R012', '34 ST-PENN STA')
# [233] ('N340A', 'R115', '169 ST')
# [231] ('N118', 'R199', 'KINGSTON-THROOP')
# [230] ('R286', 'R309', '176 ST')
# [230] ('R229', 'R143', '28 ST')
# [230] ('N329', 'R201', 'WOODHAVEN BLVD')
# [228] ('R323', 'R387', 'WEST FARMS SQ')
# [228] ('N095A', 'R014', 'FULTON ST')
# [227] ('N539A', 'R288', '7 AV')
# [224] ('R617', 'R058', 'BERGEN ST')
# [224] ('R159', 'R164', '66 ST-LINCOLN')
# [224] ('N013', 'R035', '168 ST')
# [222] ('R115', 'R029', 'PARK PLACE')
# [222] ('B023', 'R211', 'KINGS HWY')
# [220] ('R521', 'R327', '52 ST')
# [217] ('JFK02', 'R535', 'HOWARD BCH JFK')
# [217] ('H006', 'R330', '3 AV')
# [210] ('R636', 'R209', 'STERLING ST')
# [208] ('R414', 'R162', 'ELDER AV')
# [207] ('R289', 'R119', 'FORDHAM RD')
# [205] ('B004', 'R171', '7 AV')
# [200] ('R215', 'R322', 'SPRING ST')
# [199] ('D010', 'R394', 'BAY PKWY')
# [198] ('N342', 'R019', 'JAMAICA 179 ST')
# [196] ('N095', 'R014', 'FULTON ST')
# [196] ('N086', 'R282', 'SPRING ST')
# [194] ('R125', 'R189', 'CHRISTOPHER ST')
# [192] ('E001', 'R368', '9 AV')
# [192] ('B017', 'R262', 'BEVERLEY ROAD')
# [191] ('R309', 'R345', 'HARLEM 148 ST')
# [191] ('R134', 'R272', '28 ST')
# [191] ('N340', 'R115', '169 ST')
# [190] ('R304', 'R206', '125 ST')
# [190] ('R206', 'R014', 'FULTON ST')
# [189] ('R173', 'R159', '116 ST-COLUMBIA')
# [188] ('R403', 'R446', 'BROOK AV')
# [188] ('R259', 'R307', '138/GRAND CONC')
# [188] ('N114', 'R297', 'FRANKLIN AV')
# [188] ('D005', 'R398', 'NEW UTRECHT AV')
# [188] ('A054', 'R227', 'RECTOR ST')
# [187] ('R201', 'R041', 'BOWLING GREEN')
# [187] ('H040', 'R376', 'EAST 105 ST')
# [186] ('C027', 'R216', 'BAY RIDGE-95 ST')
# [185] ('R306', 'R207', '135 ST')
# [183] ('R179', 'R193', '157 ST')
# [183] ('H030', 'R266', 'HALSEY ST')
# [183] ('C001', 'R108', 'BOROUGH HALL')
# [182] ('R204', 'R043', 'WALL ST')
# [182] ('H022', 'R279', 'JEFFERSON ST')
# [181] ('N220', 'R155', 'KINGSBRIDGE RD')
# [180] ('J007', 'R377', 'FLUSHING AV')
# [179] ('N702A', 'R572', '96 ST-2 AVE')
# [179] ('J020', 'R433', 'ALABAMA AV')
# [177] ('R321', 'R386', '174 ST')
# [175] ('N222', 'R156', 'BEDFORD PK BLVD')
# [174] ('R160A', 'R164', '66 ST-LINCOLN')
# [173] ('R618', 'R058', 'BERGEN ST')
# [172] ('R160', 'R164', '66 ST-LINCOLN')
# [172] ('N330', 'R202', '63 DR-REGO PARK')
# [171] ('R730', 'R431', 'EASTCHSTER/DYRE')
# [169] ('N604', 'R342', 'JAMAICA VAN WK')
# [169] ('N526', 'R142', 'DELANCEY/ESSEX')
# [169] ('N100', 'R252', 'HIGH ST')
# [168] ('H037', 'R349', 'SUTTER AV')
# [167] ('R328', 'R361', 'PELHAM PKWY')
# [167] ('N333A', 'R141', 'FOREST HILLS 71')
# [167] ('N112A', 'R284', 'CLINTON-WASH AV')
# [166] ('R260', 'R205', '149/GRAND CONC')
# [164] ('N561', 'R271', 'AVENUE X')
# [162] ('R294', 'R052', 'WOODLAWN')
# [162] ('J024', 'R437', 'CRESCENT ST')
# [159] ('R172', 'R192', 'CATHEDRAL PKWY')
# [159] ('A050', 'R088', 'CORTLANDT ST')
# [158] ('N534', 'R220', 'CARROLL ST')
# [158] ('N120A', 'R153', 'UTICA AV')
# [157] ('R316', 'R407', 'INTERVALE AV')
# [157] ('R176', 'R169', '137 ST CITY COL')
# [156] ('N224', 'R157', 'NORWOOD 205 ST')
# [155] ('J035', 'R008', '111 ST')
# [155] ('B020', 'R263', 'AVENUE H')
# [154] ('N121B', 'R438', 'RALPH AV')
# [153] ('N530', 'R301', 'YORK ST')
# [151] ('R644', 'R135', 'NEWKIRK AV')
# [151] ('R409', 'R449', 'E 149 ST')
# [151] ('R200A', 'R041', 'BOWLING GREEN')
# [151] ('N319', 'R298', 'NORTHERN BLVD')
# [151] ('N310', 'R140', 'QUEENS PLAZA')
# [150] ('R319', 'R409', 'FREEMAN ST')
# [150] ('J031', 'R006', 'WOODHAVEN BLVD')
# [149] ('N009', 'R174', '181 ST')
# [148] ('C022', 'R212', '59 ST')
# [147] ('R413', 'R325', 'WHITLOCK AV')
# [147] ('R163', 'R166', '79 ST')
# [147] ('N075', 'R111', '23 ST')
# [146] ('E011', 'R371', '79 ST')
# [146] ('E003', 'R369', 'FT HAMILTON PKY')
# [146] ('C003', 'R089', 'JAY ST-METROTEC')
# [145] ('R257', 'R182', '116 ST')
# [145] ('B014', 'R148', 'PARKSIDE AV')
# [144] ('N119', 'R199', 'KINGSTON-THROOP')
# [143] ('H028', 'R266', 'HALSEY ST')
# [142] ('R647', 'R110', 'FLATBUSH AV-B.C')
# [141] ('N192', 'R336', 'BEACH 60 ST')
# [141] ('H041', 'R152', 'CANARSIE-ROCKAW')
# [141] ('D003', 'R391', 'FT HAMILTON PKY')
# [140] ('D016', 'R397', '86 ST')
# [139] ('R232A', 'R176', '33 ST')
# [139] ('N111', 'R284', 'CLINTON-WASH AV')
# [138] ('N002A', 'R173', 'INWOOD-207 ST')
# [136] ('E012', 'R372', '18 AV')
# [136] ('A069', 'R044', 'CHAMBERS ST')
# [135] ('R231', 'R176', '33 ST')
# [135] ('N333', 'R141', 'FOREST HILLS 71')
# [135] ('E013', 'R373', '20 AV')
# [135] ('A083', 'R125', 'BROAD ST')
# [134] ('E005', 'R247', '55 ST')
# [133] ('R303', 'R324', '116 ST')
# [133] ('C024', 'R214', '77 ST')
# [132] ('R305', 'R206', '125 ST')
# [129] ('N307', 'R359', 'COURT SQ-23 ST')
# [127] ('R411', 'R450', 'LONGWOOD AV')
# [127] ('R194', 'R040', '231 ST')
# [127] ('R171', 'R192', 'CATHEDRAL PKWY')
# [125] ('N195', 'R358', 'BEACH 25 ST')
# [122] ('R210A', 'R044', 'BROOKLYN BRIDGE')
# [121] ('R510', 'R090', '39 AV')
# [121] ('N202', 'R315', '155 ST')
# [121] ('B034', 'R264', 'OCEAN PKWY')
# [120] ('R166', 'R167', '86 ST')
# [119] ('R639', 'R109', 'CHURCH AV')
# [119] ('R302', 'R324', '116 ST')
# [119] ('N030', 'R333', '116 ST')
# [117] ('N221', 'R155', 'KINGSBRIDGE RD')
# [116] ('N225', 'R157', 'NORWOOD 205 ST')
# [116] ('J028', 'R004', '75 ST-ELDERTS')
# [116] ('J022', 'R435', 'CLEVELAND ST')
# [116] ('J013', 'R380', 'GATES AV')
# [115] ('R124', 'R290', 'HOUSTON ST')
# [115] ('H038', 'R350', 'LIVONIA AV')
# [114] ('N126', 'R441', 'VAN SICLEN AVE')
# [113] ('R517', 'R291', '33 ST-RAWSON ST')
# [112] ('R604', 'R108', 'BOROUGH HALL')
# [112] ('J030', 'R005', '85 ST-FOREST PK')
# [112] ('E009', 'R370', '71 ST')
# [111] ('R402', 'R446', 'BROOK AV')
# [109] ('D012', 'R395', 'KINGS HWY')
# [108] ('R422', 'R428', 'BUHRE AV')
# [106] ('R180', 'R193', '157 ST')
# [106] ('J005', 'R353', 'LORIMER ST')
# [105] ('J023', 'R436', 'NORWOOD AV')
# [103] ('J012', 'R379', 'KOSCIUSZKO ST')
# [102] ('N331', 'R219', '67 AV')
# [101] ('R293', 'R133', 'MOSHOLU PKWY')
# [101] ('N555', 'R423', 'AVENUE N')
# [101] ('J021', 'R434', 'VAN SICLEN AV')
# [100] ('N556', 'R424', 'AVENUE P')
# [99] ('R419', 'R326', 'ZEREGA AV')
# [99] ('R329', 'R362', 'ALLERTON AV')
# [99] ('R190', 'R038', '215 ST')
# [98] ('N110', 'R283', 'LAFAYETTE AV')
# [97] ('N113', 'R297', 'FRANKLIN AV')
# [96] ('N035', 'R334', 'CATHEDRAL PKWY')
# [95] ('N127', 'R442', 'SHEPHERD AV')
# [94] ('R192', 'R039', 'MARBLE HILL-225')
# [94] ('N045', 'R187', '81 ST-MUSEUM')
# [93] ('R129', 'R321', '18 ST')
# [93] ('N122', 'R439', 'ROCKAWAY AV')
# [93] ('H033', 'R313', 'BUSHWICK AV')
# [93] ('B025', 'R150', 'AVENUE U')
# [91] ('R728', 'R226', 'GUN HILL RD')
# [91] ('R120', 'R320', 'CANAL ST')
# [91] ('N531', 'R129', 'BERGEN ST')
# [90] ('JFK01', 'R535', 'HOWARD BCH JFK')
# [90] ('B026', 'R230', 'NECK RD')
# [88] ('N215', 'R237', '182-183 STS')
# [88] ('N037', 'R314', '103 ST')
# [87] ('N209', 'R443', '170 ST')
# [87] ('N011', 'R126', '175 ST')
# [87] ('B028', 'R136', 'SHEEPSHEAD BAY')
# [86] ('N532', 'R129', 'BERGEN ST')
# [86] ('N316A', 'R267', '46 ST')
# [85] ('R520', 'R223', '46 ST BLISS ST')
# [85] ('R231A', 'R176', '33 ST')
# [85] ('N337', 'R255', 'BRIARWOOD')
# [85] ('N322', 'R340', '65 ST')
# [84] ('R333', 'R366', '225 ST')
# [84] ('N187', 'R419', 'ROCKAWAY PARK B')
# [84] ('K025', 'R404', 'FRESH POND RD')
# [84] ('H035', 'R348', 'ATLANTIC AV')
# [83] ('N125', 'R440', 'LIBERTY AV')
# [83] ('N012', 'R035', '168 ST')
# [82] ('R219', 'R160', 'ASTOR PL')
# [81] ('R405', 'R447', 'CYPRESS AV')
# [81] ('N557', 'R130', 'KINGS HWY')
# [81] ('J016', 'R381', 'HALSEY ST')
# [81] ('D015', 'R396', 'AVENUE U')
# [80] ('N311', 'R339', '36 ST')
# [80] ('N017', 'R331', '155 ST')
# [77] ('R334', 'R367', '233 ST')
# [77] ('A077', 'R028', 'FULTON ST')
# [76] ('R641', 'R210', 'BEVERLY RD')
# [76] ('R118', 'R343', 'FRANKLIN ST')
# [76] ('N332', 'R219', '67 AV')
# [75] ('B009', 'R411', 'PARK PLACE')
# [72] ('N134', 'R385', 'ROCKAWAY BLVD')
# [71] ('R421', 'R427', 'MIDDLETOWN RD')
# [71] ('N325A', 'R218', 'ELMHURST AV')
# [70] ('R404', 'R447', 'CYPRESS AV')
# [70] ('R332', 'R365', '219 ST')
# [70] ('N551', 'R421', 'AVENUE I')
# [70] ('K019', 'R413', 'KNICKERBOCKER')
# [68] ('R637', 'R451', 'WINTHROP ST')
# [68] ('N007A', 'R174', '181 ST')
# [68] ('B010', 'R412', 'BOTANIC GARDEN')
# [67] ('R226A', 'R131', '23 ST')
# [66] ('R131', 'R190', '23 ST')
# [66] ('N338B', 'R128', 'SUTPHIN BLVD')
# [65] ('N194', 'R338', 'BEACH 36 ST')
# [64] ('N548', 'R420', 'DITMAS AV')
# [61] ('R407', 'R448', "E 143/ST MARY'S")
# [61] ('N559', 'R425', 'AVENUE U')
# [61] ('N087', 'R282', 'SPRING ST')
# [60] ('R335', 'R444', 'NEREID AV')
# [60] ('R330', 'R363', 'BURKE AV')
# [60] ('N016A', 'R296', '163 ST-AMSTERDM')
# [60] ('C004', 'R089', 'JAY ST-METROTEC')
# [59] ('N545', 'R204', 'CHURCH AV')
# [58] ('R646', 'R110', 'FLATBUSH AV-B.C')
# [58] ('K017', 'R401', 'CENTRAL AV')
# [57] ('N317', 'R267', '46 ST')
# [57] ('N208', 'R443', '170 ST')
# [57] ('J025', 'R003', 'CYPRESS HILLS')
# [55] ('R227A', 'R131', '23 ST')
# [55] ('N511', 'R163', '14 ST')
# [54] ('J017', 'R432', 'CHAUNCEY ST')
# [53] ('R318', 'R408', 'SIMPSON ST')
# [53] ('N001', 'R173', 'INWOOD-207 ST')
# [51] ('R327', 'R361', 'PELHAM PKWY')
# [51] ('R326', 'R389', 'BRONX PARK EAST')
# [51] ('N181', 'R357', 'AQUEDUCT N.COND')
# [51] ('N135', 'R385', 'ROCKAWAY BLVD')
# [50] ('R727', 'R430', 'PELHAM PKWY')
# [50] ('R312', 'R405', 'JACKSON AV')
# [50] ('R208', 'R014', 'FULTON ST')
# [50] ('R203', 'R043', 'WALL ST')
# [50] ('N553', 'R422', 'BAY PKWY')
# [50] ('N210', 'R253', '174-175 STS')
# [50] ('A071', 'R044', 'CHAMBERS ST')
# [49] ('N034', 'R334', 'CATHEDRAL PKWY')
# [49] ('K024', 'R403', 'FOREST AVE')
# [47] ('R643', 'R135', 'NEWKIRK AV')
# [47] ('N212', 'R253', '174-175 STS')
# [46] ('J003', 'R352', 'HEWES ST')
# [45] ('N206', 'R104', '167 ST')
# [45] ('N193', 'R337', 'BEACH 44 ST')
# [43] ('R315', 'R406', 'PROSPECT AV')
# [43] ('N184', 'R416', 'BEACH 90 ST')
# [43] ('H012', 'R268', 'LORIMER ST')
# [42] ('A055', 'R227', 'RECTOR ST')
# [41] ('R205A', 'R014', 'FULTON ST')
# [41] ('N543', 'R289', 'FT HAMILTON PKY')
# [41] ('N181A', 'R464', 'AQUEDUCT RACETR')
# [40] ('R410', 'R450', 'LONGWOOD AV')
# [40] ('R320', 'R409', 'FREEMAN ST')
# [40] ('N418', 'R269', 'BEDFORD-NOSTRAN')
# [40] ('N339', 'R114', 'PARSONS BLVD')
# [39] ('N131', 'R383', '80 ST')
# [39] ('N024', 'R332', '135 ST')
# [39] ('N023', 'R332', '135 ST')
# [38] ('R227', 'R131', '23 ST')
# [38] ('R133', 'R272', '28 ST')
# [37] ('N533', 'R129', 'BERGEN ST')
# [37] ('N133', 'R384', '88 ST')
# [37] ('J032', 'R006', 'WOODHAVEN BLVD')
# [33] ('R314', 'R406', 'PROSPECT AV')
# [30] ('R317', 'R408', 'SIMPSON ST')
# [30] ('C026', 'R215', '86 ST')
# [29] ('R123', 'R290', 'HOUSTON ST')
# [29] ('N182', 'R414', 'HOWARD BCH JFK')
# [29] ('N137', 'R354', '104 ST')
# [29] ('N130', 'R383', '80 ST')
# [28] ('K022', 'R402', 'SENECA AVE')
# [26] ('R726', 'R329', 'MORRIS PARK')
# [26] ('D009', 'R393', '20 AV')
# [25] ('R322', 'R386', '174 ST')
# [24] ('R729', 'R292', 'BAYCHESTER AV')
# [24] ('R406', 'R448', "E 143/ST MARY'S")
# [24] ('R119', 'R320', 'CANAL ST')
# [24] ('N330C', 'R202', '63 DR-REGO PARK')
# [23] ('R506', 'R276', 'VERNON-JACKSON')
# [23] ('J037', 'R009', '121 ST')
# [22] ('R308', 'R344', '145 ST')
# [22] ('N562', 'R426', 'NEPTUNE AV')
# [21] ('R122', 'R290', 'HOUSTON ST')
# [18] ('N003', 'R185', 'DYCKMAN ST')
# [17] ('N558', 'R130', 'KINGS HWY')
# [17] ('N420B', 'R317', 'CLINTON-WASH AV')
# [17] ('N022', 'R332', '135 ST')
# [17] ('G015', 'R312', 'W 8 ST-AQUARIUM')
# [17] ('C028', 'R216', 'BAY RIDGE-95 ST')
# [16] ('N312', 'R339', '36 ST')
# [15] ('N547', 'R420', 'DITMAS AV')
# [14] ('N218', 'R112', 'FORDHAM RD')
# [14] ('N185', 'R417', 'BEACH 98 ST')
# [13] ('N139', 'R355', '111 ST')
# [12] ('N544', 'R289', 'FT HAMILTON PKY')
# [12] ('N338', 'R128', 'SUTPHIN BLVD')
# [12] ('J034', 'R007', '104 ST')
# [11] ('N329A', 'R201', 'WOODHAVEN BLVD')
# [11] ('N304', 'R015', '5 AV/53 ST')
# [9] ('N138', 'R355', '111 ST')
# [8] ('N186', 'R418', 'BEACH 105 ST')
# [7] ('TRAM2', 'R469', 'RIT-ROOSEVELT')
# [7] ('TRAM1', 'R468', 'RIT-MANHATTAN')
# [7] ('R196', 'R306', '238 ST')
# [7] ('R117', 'R343', 'FRANKLIN ST')
# [6] ('N316', 'R267', '46 ST')
# [6] ('N183', 'R415', 'BROAD CHANNEL')
# [5] ('R532H', 'R328', 'METS-WILLETS PT')
# [4] ('N414A', 'R316', 'FLUSHING AV')
# [4] ('N405', 'R239', 'GREENPOINT AV')
# [3] ('N408A', 'R256', 'NASSAU AV')
# [3] ('N223', 'R156', 'BEDFORD PK BLVD')
# [3] ('A084', 'R125', 'BROAD ST')
# [2] ('R629', 'R065', 'ROCKAWAY AV')
# [2] ('R628', 'R064', 'SARATOGA AV')
# [2] ('R121', 'R290', 'HOUSTON ST')
# [2] ('N508', 'R453', '23 ST')
# [2] ('N415', 'R286', 'MYRTLE-WILLOUGH')
# [2] ('N123B', 'R439', 'ROCKAWAY AV')
# [1] ('R633', 'R068', 'VAN SICLEN AV')
# [1] ('E016', 'R400', 'BAY 50 ST')
# [1] ('E015', 'R399', '25 AV')
# [1] ('A082', 'R028', 'FULTON ST')
# [0] ('S102', 'R165', 'TOMPKINSVILLE')
# [0] ('S101A', 'R070', 'ST. GEORGE')
# [0] ('S101', 'R070', 'ST. GEORGE')
# [0] ('R634', 'R069', 'NEW LOTS AV')
# [0] ('R632', 'R067', 'PENNSYLVANIA AV')
# [0] ('R242A', 'R049', '51 ST')
# [0] ('R237B', 'R047', 'GRD CNTRL-42 ST')
# [0] ('R237', 'R046', 'GRD CNTRL-42 ST')
# [0] ('R230', 'R143', '28 ST')
# [0] ('R204A', 'R043', 'WALL ST')
# [0] ('R203A', 'R043', 'WALL ST')
# [0] ('R137', 'R031', '34 ST-PENN STA')
# [0] ('R112A', 'R027', 'WALL ST')
# [0] ('R112', 'R027', 'WALL ST')
# [0] ('OB01', 'R459', 'ORCHARD BEACH')
# [0] ('N554', 'R423', 'AVENUE N')
# [0] ('N550', 'R242', '18 AV')
# [0] ('N416', 'R286', 'MYRTLE-WILLOUGH')
# [0] ('N414', 'R316', 'FLUSHING AV')
# [0] ('N412', 'R299', 'BROADWAY')
# [0] ('N401', 'R360', '21 ST')
# [0] ('N318', 'R298', 'NORTHERN BLVD')
# [0] ('C016', 'R278', '25 ST')
# [0] ('C010', 'R231', 'UNION ST')
# 0 ('A085', 'R125', 'BROAD ST')
# [-2] ('D008', 'R392', '18 AV')
# [-6] ('N334B', 'R341', '75 AV')
# [-42] ('N029', 'R333', '116 ST')
# [-228] ('R241A', 'R048', 'GRD CNTRL-42 ST')
# [-16941921] ('N501', 'R020', '47-50 STS ROCK')
